# %% [markdown]
# # QB role adjustments
# This notebook will change QB roles and then adjust the flex datasets accordingly.

# %%
import numpy as np
import pandas as pd
from functions import get_current_weekday, calculate_nfl_week, get_next_sunday, get_current_year

# %%
day = get_current_weekday()

# %%
date_string = get_next_sunday(day)

# %%
week = calculate_nfl_week(date_string)

# %%
season = get_current_year()

# %% [markdown]
# **FanDuel**

# %%
fd_qb_df = pd.read_csv('FD_qb_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
fd_flex_df = pd.read_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
fd_qb_df = fd_qb_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'], drop = True)

# %%
fd_flex_df = fd_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'], drop = True)

# %% [markdown]
# **DraftKings**

# %%
dk_qb_df = pd.read_csv('DK_qb_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
dk_flex_df = pd.read_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
dk_qb_df = dk_qb_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'], drop = True)

# %%
dk_flex_df = dk_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'], drop = True)

# %%
fd_qb_df.columns
# Out:
# Index(['FD_Pts_DvP', 'DK_Pts_DvP', 'QB_role', 'completions_L8', 'attempts_L8',
#        'passing_yards_L8', 'passing_tds_L8', 'interceptions_L8', 'sacks_L8',
#        'passing_air_yards_L8', 'pacr_L8', 'carries_L8', 'rushing_yards_L8',
#        'rushing_tds_L8', 'comp_pct', 'yds_per_attempt', 'td_pct', 'sack_pct',
#        'int_pct', 'wind', 'div_game', 'spread_line', 'total_line', 'outdoors',
#        'grass', 'home_team', 'pred_total', 'opp_total'],
#       dtype='object')

# %%
###First ask if there's any QB data that needs to update
#If so, then the FLEX data will have to update with the new QB strength variables.
#maybe still have a list of dfs and use an index

# %%
fd_qb_df.head()
# Out:
#                                                                   FD_Pts_DvP  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        15.3100
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        17.9225
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        14.7625
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        20.8225
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        15.4100
#
#                                                                   DK_Pts_DvP  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        15.5600
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        18.2975
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        15.7625
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        23.0725
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        16.9100
#
#                                                                   QB_role  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         1.0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         1.0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         1.0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         1.0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         1.0
#
#                                                                   completions_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             20.250
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             23.750
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3             19.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3             21.875
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             19.000
#
#                                                                   attempts_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3          32.125
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3          34.375
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3          29.250
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3          32.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3          28.750
#
#                                                                   passing_yards_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3              250.500
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3              246.625
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3              196.750
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3              220.500
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3              223.125
#
#                                                                   passing_tds_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3              2.000
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3              1.375
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3              1.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3              1.625
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3              1.250
#
#                                                                   interceptions_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3                0.500
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3                0.625
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3                1.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3                0.375
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3                0.000
#
#                                                                   sacks_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        2.250
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        1.875
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        1.250
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        2.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        2.375
#
#                                                                   passing_air_yards_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3                  275.375
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3                  193.500
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3                  241.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3                  216.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3                  235.250
#
#                                                                   ...  \
# name            team position salary opponent status season week  ...
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3     ...
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3     ...
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3     ...
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3     ...
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3     ...
#
#                                                                    int_pct  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3     0.015564
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3     0.018182
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3     0.034188
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3     0.011628
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3     0.000000
#
#                                                                   wind  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        0
#
#                                                                   div_game  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3            0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3            0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3            0
#
#                                                                   spread_line  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             1.5
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             3.0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            -2.5
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            -3.0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             1.5
#
#                                                                   total_line  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3           47.5
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3           46.5
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3           49.5
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3           51.5
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3           45.5
#
#                                                                   outdoors  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3            0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3            0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3            0
#
#                                                                   grass  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         1
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         1
#
#                                                                   home_team  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3             0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3             1
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             0
#
#                                                                   pred_total  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3          24.50
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3          24.75
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3          23.50
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3          24.25
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3          23.50
#
#                                                                   opp_total
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         23.00
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         21.75
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         26.00
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         27.25
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         22.00
#
# [5 rows x 28 columns]

# %%
dk_qb_df.head()
# Out:
#                                                                      FD_Pts_DvP  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        15.3100
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        14.7625
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        15.4100
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        20.8225
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        14.3400
#
#                                                                      DK_Pts_DvP  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        15.5600
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        15.7625
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        16.9100
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        23.0725
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        15.4650
#
#                                                                      QB_role  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         1.0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         1.0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         1.0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         1.0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         1.0
#
#                                                                      completions_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             20.250
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3             19.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             19.000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3             21.875
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             10.400
#
#                                                                      attempts_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3          32.125
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3          29.250
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3          28.750
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3          32.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3          20.000
#
#                                                                      passing_yards_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3              250.500
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3              196.750
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3              223.125
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3              220.500
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3              154.000
#
#                                                                      passing_tds_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3              2.000
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3              1.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3              1.250
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3              1.625
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3              1.000
#
#                                                                      interceptions_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3                0.500
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3                1.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3                0.000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3                0.375
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3                0.800
#
#                                                                      sacks_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        2.250
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        1.250
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        2.375
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        2.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        1.200
#
#                                                                      passing_air_yards_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3                  275.375
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3                  241.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3                  235.250
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3                  216.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3                  237.400
#
#                                                                      ...  \
# name               team position salary opponent status season week  ...
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3     ...
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3     ...
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3     ...
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3     ...
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3     ...
#
#                                                                       int_pct  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3     0.015564
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3     0.034188
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3     0.000000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3     0.011628
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3     0.040000
#
#                                                                      wind  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        0
#
#                                                                      div_game  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3            0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3            0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3            0
#
#                                                                      spread_line  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             1.0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            -3.0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             1.5
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            -3.0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             1.0
#
#                                                                      total_line  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3           47.5
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3           49.5
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3           46.0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3           51.5
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3           43.5
#
#                                                                      outdoors  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3            0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3            0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3            0
#
#                                                                      grass  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         1
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         1
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         0
#
#                                                                      home_team  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3             0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3             1
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             1
#
#                                                                      pred_total  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3          24.25
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3          23.25
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3          23.75
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3          24.25
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3          22.25
#
#                                                                      opp_total
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         23.25
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         26.25
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         22.25
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         27.25
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         21.25
#
# [5 rows x 28 columns]

# %%
injured_QBs = fd_qb_df.reset_index(drop = False)

# %%
injured_QBs[injured_QBs['name'] == 'Gardner Minshew']
# Out:
#                name team position  salary opponent  status  season  week  \
# 15  Gardner Minshew   LV       QB    7200      CAR  Active    2024     3
#
#     FD_Pts_DvP  DK_Pts_DvP  ...   int_pct  wind  div_game  spread_line  \
# 15       13.51     13.6975  ...  0.015152     0         0          6.5
#
#     total_line  outdoors  grass  home_team  pred_total  opp_total
# 15        39.5         0      0          1        23.0       16.5
#
# [1 rows x 36 columns]

# %%
injured_QBs['status'].value_counts()
# Out:
# status
# Active    98
# Q          6
# IR         3
# Name: count, dtype: int64

# %%
injured_QBs = injured_QBs[(injured_QBs['status'] != 'Active') & (injured_QBs['QB_role'] == 1)]

# %%
injured_QBs
# Out:
#               name team position  salary opponent status  season  week  \
# 13  Justin Herbert  LAC       QB    7300      PIT      Q    2024     3
#
#     FD_Pts_DvP  DK_Pts_DvP  ...  int_pct  wind  div_game  spread_line  \
# 13     17.7125     18.2125  ...    0.016     2         0         -3.0
#
#     total_line  outdoors  grass  home_team  pred_total  opp_total
# 13        34.5         1      1          0       15.75      18.75
#
# [1 rows x 36 columns]

# %%
fd_qb_df = fd_qb_df.reset_index(drop = False)
dk_qb_df = dk_qb_df.reset_index(drop = False)
fd_flex_df = fd_flex_df.reset_index(drop = False)
dk_flex_df = dk_flex_df.reset_index(drop = False)

# %%
def adjust_qb_role(df, name, new_role):
    df.loc[df['name'] == name, 'QB_role'] = new_role
    return df

# %%
# #Let's just hardcode this for now
# fd_qb_df.loc[fd_qb_df['name'] == 'Justin Herbert', 'QB_role'] = 2
# fd_qb_df.loc[fd_qb_df['name'] == 'Bryce Young', 'QB_role'] = 2
# fd_qb_df.loc[fd_qb_df['name'] == 'Easton Stick', 'QB_role'] = 1
# fd_qb_df.loc[fd_qb_df['name'] == 'Andy Dalton', 'QB_role'] = 1

# dk_qb_df.loc[dk_qb_df['name'] == 'Justin Herbert', 'QB_role'] = 2
# dk_qb_df.loc[dk_qb_df['name'] == 'Bryce Young', 'QB_role'] = 2
# dk_qb_df.loc[dk_qb_df['name'] == 'Easton Stick', 'QB_role'] = 1
# dk_qb_df.loc[dk_qb_df['name'] == 'Andy Dalton', 'QB_role'] = 1

# %%
# qb_update = input('Are there any starting QB changes? (y or n) ')

# %%
# Ensure valid input
# while qb_update not in ['y', 'n']:
#     qb_update = input('Please enter y or n: ')

# # If there are QB changes
# while qb_update == 'y':
#     fd_list = input('Is this QB in the FanDuel list? (y or n) ')
#     while fd_list not in ['y', 'n']:
#         fd_list = input('Please enter y or n: ')
    
#     # If QB is in the FanDuel list
#     if fd_list == 'y':
#         name = input('Enter name of new starting quarterback: ')
#         fd_qb_df.loc[fd_qb_df.index == name, 'QB_role'] = 1
#         backup = input('Enter name of previous starting quarterback: ')
#         fd_qb_df.loc[fd_qb_df.index == backup, 'QB_role'] = 2
    
#     dk_list = input('Is this QB in the DraftKings list? (y or n) ')
#     while dk_list not in ['y', 'n']:
#         dk_list = input('Please enter y or n: ')
    
#     # If QB is in the DraftKings list
#     if dk_list == 'y':
#         name = input('Enter name of new starting quarterback: ')
#         dk_qb_df.loc[dk_qb_df.index == name, 'QB_role'] = 1
#         backup = input('Enter name of previous starting quarterback: ')
#         dk_qb_df.loc[dk_qb_df.index == backup, 'QB_role'] = 2
        
#     qb_update = input('Are there any other starting QB changes? (y or n) ')

# %%
# Dictionary and list for column renaming
qb_column_dict = {
    'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',
    'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',
    'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'
}

# %%
qb_column_list = list(qb_column_dict.values())

# %%
temp_fd_qb_df = fd_qb_df[fd_qb_df['QB_role'] == 1]
temp_fd_qb_df = temp_fd_qb_df.rename(columns=qb_column_dict)
temp_fd_qb_df = temp_fd_qb_df[['season', 'week', 'team', 'opponent'] + qb_column_list]

fd_flex_df.drop(columns=qb_column_list, inplace=True)
fd_flex_df = pd.merge(fd_flex_df, temp_fd_qb_df, on=['season', 'week', 'team', 'opponent'], how='left')
        
#         # Drop old columns from fd_flex_df
#         fd_flex_df.drop(columns=qb_column_list, inplace=True)
        
#         # Merge the dataframes on common columns
#         fd_flex_df = pd.merge(fd_flex_df, temp_fd_qb_df, on=['season', 'week', 'team', 'opponent'], how='left')
# except NameError:
#     print('fd_list is not defined.')

# %%
temp_dk_qb_df = dk_qb_df[dk_qb_df['QB_role'] == 1]
temp_dk_qb_df = temp_dk_qb_df.rename(columns=qb_column_dict)
temp_dk_qb_df = temp_dk_qb_df[['season', 'week', 'team', 'opponent'] + qb_column_list]

dk_flex_df.drop(columns=qb_column_list, inplace=True)
dk_flex_df = pd.merge(dk_flex_df, temp_dk_qb_df, on=['season', 'week', 'team', 'opponent'], how='left')
# try:
#     if dk_list == 'y' | dk_list == None:
#         # Filter for starting QBs
#         temp_dk_qb_df = dk_qb_df[dk_qb_df['QB_role'] == 1]
        
#         # Rename columns
#         temp_dk_qb_df = temp_dk_qb_df.rename(columns=qb_column_dict)
        
#         # Select relevant columns
#         temp_dk_qb_df = temp_dk_qb_df[['season', 'week', 'team', 'opponent'] + qb_column_list]
        
#         # Drop old columns from fd_flex_df
#         dk_flex_df.drop(columns=qb_column_list, inplace=True)
        
#         # Merge the dataframes on common columns
#         dk_flex_df = pd.merge(dk_flex_df, temp_dk_qb_df, on=['season', 'week', 'team', 'opponent'], how='left')
# except NameError:
#     print('dk_list is not defined.')

# %%
# fd_qb_df = fd_qb_df.reset_index(drop = False)

# %%
fd_qb_df = fd_qb_df[~(fd_qb_df['status'].isin(['IR', 'O']))]

# %%
fd_qb_df = fd_qb_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])
fd_flex_df = fd_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])

# %%
# dk_qb_df = dk_qb_df.reset_index(drop = False)

# %%
dk_qb_df = dk_qb_df[~(dk_qb_df['status'].isin(['IR', 'O']))]

# %%
dk_qb_df = dk_qb_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])
dk_flex_df = dk_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])

# %%
fd_qb_df.head()
# Out:
#                                                                   FD_Pts_DvP  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        15.3100
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        17.9225
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        14.7625
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        20.8225
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        15.4100
#
#                                                                   DK_Pts_DvP  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        15.5600
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        18.2975
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        15.7625
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        23.0725
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        16.9100
#
#                                                                   QB_role  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         1.0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         1.0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         1.0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         1.0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         1.0
#
#                                                                   completions_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             20.250
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             23.750
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3             19.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3             21.875
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             19.000
#
#                                                                   attempts_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3          32.125
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3          34.375
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3          29.250
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3          32.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3          28.750
#
#                                                                   passing_yards_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3              250.500
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3              246.625
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3              196.750
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3              220.500
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3              223.125
#
#                                                                   passing_tds_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3              2.000
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3              1.375
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3              1.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3              1.625
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3              1.250
#
#                                                                   interceptions_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3                0.500
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3                0.625
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3                1.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3                0.375
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3                0.000
#
#                                                                   sacks_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        2.250
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        1.875
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        1.250
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        2.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        2.375
#
#                                                                   passing_air_yards_L8  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3                  275.375
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3                  193.500
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3                  241.000
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3                  216.250
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3                  235.250
#
#                                                                   ...  \
# name            team position salary opponent status season week  ...
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3     ...
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3     ...
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3     ...
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3     ...
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3     ...
#
#                                                                    int_pct  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3     0.015564
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3     0.018182
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3     0.034188
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3     0.011628
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3     0.000000
#
#                                                                   wind  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3        0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3        0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3        0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3        0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3        0
#
#                                                                   div_game  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3            0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3            0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3            0
#
#                                                                   spread_line  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             1.5
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             3.0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            -2.5
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            -3.0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             1.5
#
#                                                                   total_line  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3           47.5
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3           46.5
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3           49.5
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3           51.5
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3           45.5
#
#                                                                   outdoors  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3            0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3            0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3            0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3            0
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3            0
#
#                                                                   grass  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         1
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         1
#
#                                                                   home_team  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3             0
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3             0
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3             0
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3             1
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3             0
#
#                                                                   pred_total  \
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3          24.50
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3          24.75
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3          23.50
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3          24.25
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3          23.50
#
#                                                                   opp_total
# name            team position salary opponent status season week
# Lamar Jackson   BAL  QB       8800   DAL      Active 2024   3         23.00
# Patrick Mahomes KC   QB       8700   ATL      Active 2024   3         21.75
# Jalen Hurts     PHI  QB       8500   NO       Active 2024   3         26.00
# Kyler Murray    ARI  QB       8300   DET      Active 2024   3         27.25
# C.J. Stroud     HOU  QB       8200   MIN      Active 2024   3         22.00
#
# [5 rows x 28 columns]

# %%
dk_qb_df.head()
# Out:
#                                                                      FD_Pts_DvP  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        15.3100
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        14.7625
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        15.4100
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        20.8225
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        14.3400
#
#                                                                      DK_Pts_DvP  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        15.5600
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        15.7625
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        16.9100
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        23.0725
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        15.4650
#
#                                                                      QB_role  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         1.0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         1.0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         1.0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         1.0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         1.0
#
#                                                                      completions_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             20.250
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3             19.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             19.000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3             21.875
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             10.400
#
#                                                                      attempts_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3          32.125
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3          29.250
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3          28.750
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3          32.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3          20.000
#
#                                                                      passing_yards_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3              250.500
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3              196.750
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3              223.125
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3              220.500
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3              154.000
#
#                                                                      passing_tds_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3              2.000
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3              1.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3              1.250
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3              1.625
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3              1.000
#
#                                                                      interceptions_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3                0.500
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3                1.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3                0.000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3                0.375
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3                0.800
#
#                                                                      sacks_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        2.250
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        1.250
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        2.375
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        2.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        1.200
#
#                                                                      passing_air_yards_L8  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3                  275.375
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3                  241.000
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3                  235.250
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3                  216.250
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3                  237.400
#
#                                                                      ...  \
# name               team position salary opponent status season week  ...
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3     ...
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3     ...
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3     ...
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3     ...
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3     ...
#
#                                                                       int_pct  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3     0.015564
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3     0.034188
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3     0.000000
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3     0.011628
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3     0.040000
#
#                                                                      wind  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3        0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3        0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3        0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3        0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3        0
#
#                                                                      div_game  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3            0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3            0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3            0
#
#                                                                      spread_line  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             1.0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            -3.0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             1.5
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            -3.0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             1.0
#
#                                                                      total_line  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3           47.5
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3           49.5
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3           46.0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3           51.5
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3           43.5
#
#                                                                      outdoors  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3            0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3            0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3            0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3            0
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3            0
#
#                                                                      grass  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         1
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         1
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         0
#
#                                                                      home_team  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3             0
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3             0
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3             0
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3             1
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3             1
#
#                                                                      pred_total  \
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3          24.25
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3          23.25
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3          23.75
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3          24.25
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3          22.25
#
#                                                                      opp_total
# name               team position salary opponent status season week
# Lamar Jackson      BAL  QB       7500   DAL      Active 2024   3         23.25
# Jalen Hurts        PHI  QB       7300   NO       Active 2024   3         26.25
# C.J. Stroud        HOU  QB       7100   MIN      Active 2024   3         22.25
# Kyler Murray       ARI  QB       6900   DET      Active 2024   3         27.25
# Anthony Richardson IND  QB       6700   CHI      Active 2024   3         21.25
#
# [5 rows x 28 columns]

# %%
fd_flex_df.head()
# Out:
#                                                                     DK_Pts_RB_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           22.7500
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           18.6875
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           27.7100
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           27.3350
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           19.2875
#
#                                                                     DK_Pts_TE_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           16.0250
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           11.7375
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           12.8375
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           14.6000
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           11.3000
#
#                                                                     DK_Pts_WR_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           30.8500
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           30.9500
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           28.4875
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           31.3625
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           33.2500
#
#                                                                     FD_Pts_RB_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           18.4375
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           16.3125
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           24.2725
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           24.0225
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           16.0375
#
#                                                                     FD_Pts_TE_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           11.9000
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3            9.3000
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           10.5250
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           11.7250
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3            8.6125
#
#                                                                     FD_Pts_WR_DvP  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           24.3500
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           24.7625
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           23.4875
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           23.9875
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           27.1250
#
#                                                                     rushing_yards_L8  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3                7.375
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3               -1.500
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3                1.625
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3                1.000
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3               64.375
#
#                                                                     rushing_tds_L8  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3              0.125
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3              0.000
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3              0.000
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3              0.000
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3              0.875
#
#                                                                     rushing_fumbles_lost_L8  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3                       0.000
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3                       0.000
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3                       0.000
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3                       0.000
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3                       0.125
#
#                                                                     receptions_L8  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3             7.875
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3             5.375
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3             7.625
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3             5.750
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3             2.500
#
#                                                                     ...  \
# name              team position salary opponent status season week  ...
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3     ...
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3     ...
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3     ...
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3     ...
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3     ...
#
#                                                                     pos_WR  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3          1
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3          1
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3          1
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3          1
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3          0
#
#                                                                     qb_comp  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3      26.125
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3       7.875
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3      25.125
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3       8.375
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3      19.000
#
#                                                                     qb_att  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3     38.750
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3     11.875
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3     37.500
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3     16.375
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3     29.250
#
#                                                                      qb_yds  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3     269.625
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3      96.500
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3     276.125
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3      83.500
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3     196.750
#
#                                                                     qb_pass_td  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3          1.875
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3          0.750
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3          1.125
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3          0.250
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3          1.000
#
#                                                                     qb_int  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3      0.875
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3      0.375
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3      0.625
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3      0.500
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3      1.000
#
#                                                                     qb_comp_pct  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3        0.674194
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3        0.663158
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3        0.670000
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3        0.511450
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3        0.649573
#
#                                                                     qb_yds_per_att  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3           6.958065
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3           8.126316
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3           7.363333
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3           5.099237
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3           6.726496
#
#                                                                     qb_td_pct  \
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3      0.048387
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3      0.063158
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3      0.030000
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3      0.015267
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3      0.034188
#
#                                                                     qb_int_pct
# name              team position salary opponent status season week
# CeeDee Lamb       DAL  WR       9300   BAL      Active 2024   3       0.022581
# Justin Jefferson  MIN  WR       9200   HOU      Active 2024   3       0.031579
# Amon-Ra St. Brown DET  WR       9100   ARI      Active 2024   3       0.016667
# Tyreek Hill       MIA  WR       9000   SEA      Active 2024   3       0.030534
# Saquon Barkley    PHI  RB       8700   NO       Active 2024   3       0.034188
#
# [5 rows x 44 columns]

# %%
dk_flex_df.head()
# Out:
#                                                                       DK_Pts_RB_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           22.7500
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           18.6875
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           19.8250
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           27.3350
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           27.7100
#
#                                                                       DK_Pts_TE_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           16.0250
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           11.7375
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           12.5875
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           14.6000
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           12.8375
#
#                                                                       DK_Pts_WR_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           30.8500
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           30.9500
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           45.0125
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           31.3625
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           28.4875
#
#                                                                       FD_Pts_RB_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           18.4375
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           16.3125
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           17.4500
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           24.0225
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           24.2725
#
#                                                                       FD_Pts_TE_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           11.9000
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3            9.3000
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           10.3375
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           11.7250
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           10.5250
#
#                                                                       FD_Pts_WR_DvP  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           24.3500
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           24.7625
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           36.3875
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           23.9875
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           23.4875
#
#                                                                       rushing_yards_L8  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3                7.375
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3               -1.500
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3               98.500
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3                1.000
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3                1.625
#
#                                                                       rushing_tds_L8  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3              0.125
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3              0.000
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3              0.875
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3              0.000
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3              0.000
#
#                                                                       rushing_fumbles_lost_L8  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3                       0.000
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3                       0.000
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3                       0.125
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3                       0.000
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3                       0.000
#
#                                                                       receptions_L8  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3             7.875
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3             5.375
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3             4.750
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3             5.750
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3             7.625
#
#                                                                       ...  \
# name                team position salary opponent status season week  ...
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3     ...
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3     ...
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3     ...
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3     ...
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3     ...
#
#                                                                       pos_WR  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3        1.0
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3        1.0
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3        0.0
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3        1.0
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3        1.0
#
#                                                                       qb_comp  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3      26.125
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3       7.875
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3      21.125
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3       8.375
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3      25.125
#
#                                                                       qb_att  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3     38.750
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3     11.875
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3     32.250
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3     16.375
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3     37.500
#
#                                                                        qb_yds  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3     269.625
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3      96.500
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3     256.375
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3      83.500
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3     276.125
#
#                                                                       qb_pass_td  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3          1.875
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3          0.750
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3          1.250
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3          0.250
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3          1.125
#
#                                                                       qb_int  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3      0.875
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3      0.375
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3      0.750
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3      0.500
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3      0.625
#
#                                                                       qb_comp_pct  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3        0.674194
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3        0.663158
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3        0.655039
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3        0.511450
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3        0.670000
#
#                                                                       qb_yds_per_att  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3           6.958065
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3           8.126316
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3           7.949612
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3           5.099237
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3           7.363333
#
#                                                                       qb_td_pct  \
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3      0.048387
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3      0.063158
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3      0.038760
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3      0.015267
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3      0.030000
#
#                                                                       qb_int_pct
# name                team position salary opponent status season week
# CeeDee Lamb         DAL  WR       8800   BAL      Active 2024.0 3       0.022581
# Justin Jefferson    MIN  WR       8600   HOU      Active 2024.0 3       0.031579
# Christian McCaffrey SF   RB       8500   LAR      IR     2024.0 3       0.023256
# Tyreek Hill         MIA  WR       8400   SEA      Active 2024.0 3       0.030534
# Amon-Ra St. Brown   DET  WR       8200   ARI      Active 2024.0 3       0.016667
#
# [5 rows x 44 columns]

# %%
change_qb_data = input('Did QB dataset change? ')
if change_qb_data == 'y':
    fd_qb_df.to_csv('FD_qb_for_model_' + str(season) + '_' + str(week) + '.csv')
    dk_qb_df.to_csv('DK_qb_for_model_' + str(season) + '_' + str(week) + '.csv')
change_flex_data = input('Did flex dataset change? ')
if change_flex_data == 'y':
    fd_flex_df.to_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
    dk_flex_df.to_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
# Out:
# Did QB dataset change?  y
# Did flex dataset change?  y
