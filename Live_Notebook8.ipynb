# %% [markdown]
# # Ad hoc FLEX dataset adjustments
# If a starter is injured and not expected to play, we might adjust features such as carry_share and target_share to reflect the increased role of other players on the team.

# %%
import numpy as np
import pandas as pd
from IPython.display import display
from functions import get_current_weekday, calculate_nfl_week, get_next_sunday, get_current_year

# %%
day = get_current_weekday()

# %%
date_string = get_next_sunday(day)

# %%
week = calculate_nfl_week(date_string)

# %%
season = get_current_year()

# %%
fd_flex_df = pd.read_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
dk_flex_df = pd.read_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
dk_qb_df = pd.read_csv('DK_qb_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
dk_qb_df[dk_qb_df['team'].isin(['IND', 'GB', 'CAR', 'MIA'])][['name', 'team', 'comp_pct', 'passing_yards_L8', 'td_pct', 'QB_role']]
#dk_qb_df.info()
# Out:
#                   name team  comp_pct  passing_yards_L8    td_pct  QB_role
# 5          Jordan Love   GB  0.665455         273.75000  0.072727      1.0
# 8   Anthony Richardson  IND  0.552795         153.87500  0.037267      2.0
# 12       Tyler Huntley  MIA  0.605505          81.87500  0.055046      1.0
# 13          Joe Flacco  IND  0.618123         280.00000  0.051780      1.0
# 15         Andy Dalton  CAR  0.636364         171.00000  0.040404      1.0
# 18        Malik Willis   GB  0.685714          66.62500  0.028571      2.0
# 26         Bryce Young  CAR  0.557940         155.62500  0.008584      2.0
# 28     Skylar Thompson  MIA  0.532847          85.75000  0.014599      2.0
# 32           Tim Boyle  MIA  0.581633          94.40000  0.010204      2.0
# 40        Jack Plummer  CAR  0.644195         194.85586  0.041089      2.0
# 48        Sam Ehlinger  IND  0.633663         143.25000  0.029703      2.0
# 60       Sean Clifford   GB  1.000000          18.50000  0.000000      2.0

# %%
dk_flex_df[dk_flex_df['team'].isin(['IND', 'GB', 'HOU', 'CAR', 'MIA'])][['team', 'qb_yds', 'qb_td_pct', 'qb_comp_pct']]
# Out:
#     team   qb_yds  qb_td_pct  qb_comp_pct
# 3    HOU  247.500   0.047809     0.689243
# 4    IND  280.000   0.051780     0.618123
# 5    MIA   81.875   0.055046     0.605505
# 11   MIA   81.875   0.055046     0.605505
# 15   HOU  247.500   0.047809     0.689243
# 16   HOU  247.500   0.047809     0.689243
# 24    GB  273.750   0.072727     0.665455
# 26    GB  273.750   0.072727     0.665455
# 30   MIA   81.875   0.055046     0.605505
# 32   CAR  171.000   0.040404     0.636364
# 33   CAR  171.000   0.040404     0.636364
# 37   IND  280.000   0.051780     0.618123
# 48   IND  280.000   0.051780     0.618123
# 50   MIA   81.875   0.055046     0.605505
# 56   HOU  247.500   0.047809     0.689243
# 60   HOU  247.500   0.047809     0.689243
# 61   IND  280.000   0.051780     0.618123
# 62    GB  273.750   0.072727     0.665455
# 66   MIA   81.875   0.055046     0.605505
# 71   CAR  171.000   0.040404     0.636364
# 72   IND  280.000   0.051780     0.618123
# 75   CAR  171.000   0.040404     0.636364
# 76   CAR  171.000   0.040404     0.636364
# 77   HOU  247.500   0.047809     0.689243
# 79    GB  273.750   0.072727     0.665455
# 80   CAR  171.000   0.040404     0.636364
# 82   IND  280.000   0.051780     0.618123
# 84   HOU  247.500   0.047809     0.689243
# 87    GB  273.750   0.072727     0.665455
# 89   MIA   81.875   0.055046     0.605505
# 94    GB  273.750   0.072727     0.665455
# 103   GB  273.750   0.072727     0.665455
# 107  MIA   81.875   0.055046     0.605505
# 114  HOU  247.500   0.047809     0.689243
# 119  CAR  171.000   0.040404     0.636364
# 120  CAR  171.000   0.040404     0.636364
# 121  CAR  171.000   0.040404     0.636364
# 137  HOU  247.500   0.047809     0.689243
# 138  HOU  247.500   0.047809     0.689243
# 139  HOU  247.500   0.047809     0.689243
# 143  HOU  247.500   0.047809     0.689243
# 146  IND  280.000   0.051780     0.618123
# 149  MIA   81.875   0.055046     0.605505
# 150  MIA   81.875   0.055046     0.605505
# 173   GB  273.750   0.072727     0.665455
# 174   GB  273.750   0.072727     0.665455
# 175   GB  273.750   0.072727     0.665455
# 176   GB  273.750   0.072727     0.665455
# 184  IND  280.000   0.051780     0.618123
# 185  MIA   81.875   0.055046     0.605505
# 192  CAR  171.000   0.040404     0.636364
# 197   GB  273.750   0.072727     0.665455
# 203   GB  273.750   0.072727     0.665455
# 207  MIA   81.875   0.055046     0.605505
# 209   GB  273.750   0.072727     0.665455
# 212  HOU  247.500   0.047809     0.689243
# 216  CAR  171.000   0.040404     0.636364
# 217  CAR  171.000   0.040404     0.636364
# 218  CAR  171.000   0.040404     0.636364
# 219  CAR  171.000   0.040404     0.636364
# 220  CAR  171.000   0.040404     0.636364
# 239  HOU  247.500   0.047809     0.689243
# 240  HOU  247.500   0.047809     0.689243
# 241  HOU  247.500   0.047809     0.689243
# 242  HOU  247.500   0.047809     0.689243
# 243  HOU  247.500   0.047809     0.689243
# 250  IND  280.000   0.051780     0.618123
# 258  IND  280.000   0.051780     0.618123
# 259  IND  280.000   0.051780     0.618123
# 260  IND  280.000   0.051780     0.618123
# 261  IND  280.000   0.051780     0.618123
# 268  MIA   81.875   0.055046     0.605505
# 269  MIA   81.875   0.055046     0.605505
# 270  MIA   81.875   0.055046     0.605505
# 271  MIA   81.875   0.055046     0.605505
# 272  MIA   81.875   0.055046     0.605505
# 273  MIA   81.875   0.055046     0.605505
# 274  MIA   81.875   0.055046     0.605505
# 313   GB  273.750   0.072727     0.665455
# 314   GB  273.750   0.072727     0.665455
# 315   GB  273.750   0.072727     0.665455
# 326  CAR  171.000   0.040404     0.636364
# 330  MIA   81.875   0.055046     0.605505
# 333  HOU  247.500   0.047809     0.689243
# 334  MIA   81.875   0.055046     0.605505
# 338   GB  273.750   0.072727     0.665455
# 340  IND  280.000   0.051780     0.618123
# 344  CAR  171.000   0.040404     0.636364
# 345  CAR  171.000   0.040404     0.636364
# 346  CAR  171.000   0.040404     0.636364
# 347  CAR  171.000   0.040404     0.636364
# 359  HOU  247.500   0.047809     0.689243
# 360  HOU  247.500   0.047809     0.689243
# 361  HOU  247.500   0.047809     0.689243
# 367  IND  280.000   0.051780     0.618123
# 368  IND  280.000   0.051780     0.618123
# 369  IND  280.000   0.051780     0.618123
# 370  IND  280.000   0.051780     0.618123
# 371  IND  280.000   0.051780     0.618123
# 374  MIA   81.875   0.055046     0.605505
# 375  MIA   81.875   0.055046     0.605505
# 400   GB  273.750   0.072727     0.665455
# 401   GB  273.750   0.072727     0.665455
# 402   GB  273.750   0.072727     0.665455

# %%
# Dictionary to map changes based on ('name', 'team')
changes_dict = {
    
}

#('Brock Bowers', 'LV'): {'target_share_L8': 0.3, 'targets_L8': 10}

# %%
injured_flex = fd_flex_df.reset_index(drop = False)

# %%
injured_flex = injured_flex[injured_flex['status'].isin(['IR', 'D', 'O'])]

# %%
pd.set_option('display.max_rows', None)

# %%
injured_flex[['name', 'team', 'status', 'position']].sort_values(by = ['team', 'status'])
# Out:
#                       name team status position
# 343              Zay Jones  ARI     IR       WR
# 245            Owen Wright  BAL     IR       RB
# 329            Rasheen Ali  BAL     IR       RB
# 272      Scotty Washington  BAL      O       WR
# 512        Darrynton Evans  BUF     IR       RB
# 45           Khalil Shakir  BUF      O       WR
# 115        Jonathon Brooks  CAR     IR       RB
# 128           Adam Thielen  CAR     IR       WR
# 540             Ian Thomas  CAR     IR       TE
# 397         Nsimba Webster  CHI     IR       WR
# 430         Patrick Scales  CHI     IR       TE
# 444        Stephen Carlson  CHI     IR       TE
# 529           Travis Homer  CHI     IR       RB
# 535            Ian Wheeler  CHI     IR       RB
# 384            Chris Evans  CIN     IR       RB
# 282           Nyheim Hines  CLE     IR       RB
# 414             David Bell  CLE     IR       WR
# 102          Brandin Cooks  DAL     IR       WR
# 180            Tyler Badie  DEN     IR       RB
# 399          Audric Estime  DEN     IR       RB
# 90        Christian Watson   GB      D       WR
# 78             Romeo Doubs   GB     IR       WR
# 517            Tyler Davis   GB     IR       TE
# 572         MarShawn Lloyd   GB     IR       RB
# 582              AJ Dillon   GB     IR       RB
# 571          Brevin Jordan  HOU     IR       TE
# 601           Dalton Keene  HOU     IR       TE
# 11               Joe Mixon  HOU      O       RB
# 385           Jelani Woods  IND     IR       TE
# 546         Juwann Winfree  IND     IR       WR
# 6          Jonathan Taylor  IND      O       RB
# 362        Patrick Murtagh  JAX     IR       TE
# 436            David White  JAX     IR       WR
# 532        Keilan Robinson  JAX     IR       RB
# 457             Puka Nacua  LAR     IR       WR
# 13             Cooper Kupp  LAR      O       WR
# 577           Jeff Foreman   LV     IR       WR
# 24           Davante Adams   LV      O       WR
# 89             Zamir White   LV      O       RB
# 168          Michael Mayer   LV      O       TE
# 246         River Cracraft  MIA     IR       WR
# 294           Grant DuBose  MIA     IR       WR
# 321        Tahj Washington  MIA     IR       WR
# 460       Anthony Schwartz  MIA     IR       WR
# 557         JaQuae Jackson   NE     IR       WR
# 47        Devin Singletary  NYG      D       RB
# 279       Gunner Olszewski  NYG     IR       WR
# 10            Malik Nabers  NYG      O       WR
# 390          Ben Skowronek  PIT     IR       WR
# 105          Jaylen Warren  PIT      O       RB
# 123  Cordarrelle Patterson  PIT      O       RB
# 254          MyCole Pruitt  PIT      O       TE
# 471          Hayden Hatten  SEA     IR       WR
# 433          George Holani  SEA      O       RB
# 182           Chris Conley   SF      D       WR
# 322        Elijah Mitchell   SF     IR       RB
# 369         Ricky Pearsall   SF     IR       WR
# 526    Christian McCaffrey   SF     IR       RB
# 296        Jamison Crowder  WAS     IR       WR
# 140             Noah Brown  WAS      O       WR

# %%
adjustable_cols = ['name', 'position', 'status', 'targets_L8', 'carries_L8', 'target_share_L8', 'carry_share_L8']

# %%
###RB adjustments

# %%
def view_team_pos(df, team):
    return df[(df['team'] == team)][adjustable_cols]

# %%
def change_player_value(df, name, feature, new_value):
    df.loc[df['name'] == name, feature] = new_value
    return df

# %%
view_team = input('Do you want to view the players of a specific team? ')
while view_team == 'y':
    team = input('Which team? ')
    #Because FanDuel will have all the players, while DraftKings doesn't include night game
    team_df = view_team_pos(fd_flex_df, team)
    display(team_df)
    
    
    adjust_data = input('Do you want to adjust any features? ')
    while adjust_data == 'y':
        new_val_dict = {
        }
        #site = input('Which site? FD, DK or both? ')
        name = input('Which player? ')
        num_features = int(input('How many features do you want to change? '))
        for i in range(num_features):
            feature = input('Which feature? ')
            new_value = float(input('Enter new value: '))
            new_val_dict.update({feature: new_value})
        changes_dict.update({(name, team): new_val_dict})
        adjust_data = input('Do you want to adjust any more features? ')
    #     if site == 'FD':
    #         fd_flex_df = change_player_value(fd_flex_df, name, feature, new_value)
    #     else:
    #         dk_flex_df = change_player_value(dk_flex_df, name, feature, new_value)
    #    
    view_team = input('Do you want to view the players on another team? ')
# Out:
# Do you want to view the players of a specific team?  y
# Which site?  DK
# Which team?  IND
#                  name position  status  targets_L8  carries_L8  \
# 4     Jonathan Taylor       RB       O    1.750000   19.500000
# 37    Michael Pittman       WR  Active    7.250000    0.000000
# 48        Trey Sermon       RB  Active    0.500000    4.500000
# 61      Tyler Goodson       RB  Active    1.428571    1.857143
# 72         Josh Downs       WR  Active    4.875000    0.000000
# 82        Alec Pierce       WR  Active    3.875000    0.000000
# 146         Evan Hull       RB  Active    1.000000    1.000000
# 184   Adonai Mitchell       WR  Active    3.250000    0.250000
# 250      Ashton Dulin       WR  Active    1.625000    0.125000
# 258     Anthony Gould       WR  Active    4.869456    0.228761
# 259    Juwann Winfree       WR      IR    1.250000    0.000000
# 260     DJ Montgomery       WR  Active    4.869456    0.228761
# 261  Laquon Treadwell       WR  Active    3.250000    0.000000
# 340     Kylen Granson       TE  Active    2.500000    0.000000
# 367       Mo Alie-Cox       TE  Active    1.875000    0.000000
# 368     Drew Ogletree       TE  Active    3.489743    0.025456
# 369      Will Mallory       TE  Active    2.750000    0.000000
# 370      Jelani Woods       TE      IR    4.000000    0.000000
# 371       Sean McKeon       TE  Active    1.250000    0.000000
#
#      target_share_L8  carry_share_L8
# 4           0.068566        0.711875
# 37          0.291449        0.000000
# 48          0.019581        0.161500
# 61          0.046504        0.058714
# 72          0.174849        0.000000
# 82          0.146917        0.000000
# 146         0.025641        0.038000
# 184         0.138722        0.008000
# 250         0.054156        0.003000
# 258         0.150889        0.008811
# 259         0.034110        0.000000
# 260         0.150889        0.008811
# 261         0.099513        0.000000
# 340         0.088560        0.000000
# 367         0.078795        0.000000
# 368         0.109236        0.000900
# 369         0.080182        0.000000
# 370         0.128510        0.000000
# 371         0.033807        0.000000
# Do you want to view the players on another team?  y
# Which site?  DK
# Which team?  GB
#                    name position  status  targets_L8  carries_L8  \
# 24          Jayden Reed       WR  Active    5.125000    0.875000
# 26          Josh Jacobs       RB  Active    2.625000   18.125000
# 62          Romeo Doubs       WR      IR    4.875000    0.000000
# 79     Dontayvion Wicks       WR  Active    4.375000    0.000000
# 87     Christian Watson       WR       D    3.875000    0.375000
# 94       MarShawn Lloyd       RB      IR    1.000000    6.000000
# 103      Emanuel Wilson       RB  Active    1.125000    6.000000
# 173        Chris Brooks       RB  Active    2.316208    8.234368
# 174           AJ Dillon       RB      IR    2.316208    8.234368
# 175  Ellis Merriweather       RB  Active    2.316208    8.234368
# 176         Andrew Beck       RB  Active    1.250000    0.125000
# 197        Tucker Kraft       TE  Active    4.375000    0.000000
# 203           Bo Melton       WR  Active    3.750000    0.625000
# 209         Malik Heath       WR  Active    2.500000    0.000000
# 313           TJ Luther       WR  Active    4.869456    0.228761
# 314   Cornelius Johnson       WR  Active    4.869456    0.228761
# 315        Julian Hicks       WR  Active    4.869456    0.228761
# 338       Luke Musgrave       TE       Q    2.625000    0.000000
# 400            Ben Sims       TE  Active    1.000000    0.000000
# 401         Tyler Davis       TE      IR    1.400000    0.000000
# 402     Messiah Swinson       TE  Active    3.489743    0.025456
#
#      target_share_L8  carry_share_L8
# 24          0.178706        0.028375
# 26          0.077534        0.692125
# 62          0.172273        0.000000
# 79          0.149870        0.000000
# 87          0.123000        0.014625
# 94          0.076923        0.113000
# 103         0.037558        0.205125
# 173         0.071789        0.314788
# 174         0.071789        0.314788
# 175         0.071789        0.314788
# 176         0.041543        0.005250
# 197         0.145882        0.000000
# 203         0.118860        0.018375
# 209         0.073220        0.000000
# 313         0.150889        0.008811
# 314         0.150889        0.008811
# 315         0.150889        0.008811
# 338         0.087603        0.000000
# 400         0.030733        0.000000
# 401         0.043735        0.000000
# 402         0.109236        0.000900
# Do you want to view the players on another team?  n

# %% [markdown]
# # FanDuel changes

# %%
update_fd = input('Does the FanDuel player list need to be updated? ').lower()
if update_fd == 'y': 
    for (name, team), updates in changes_dict.items():
        fd_flex_df.loc[(fd_flex_df['name'] == name) & (fd_flex_df['team'] == team), updates.keys()] = updates.values()

# %% [markdown]
# # DraftKings changes

# %%
update_dk = input('Does the DraftKings player list need to be updated? ').lower()
if update_dk == 'y':
    adjust_for_dk = input("Are there any FanDuel changes that don't need to be made in DraftKings? ").lower()
    if adjust_for_dk == 'y':
        num_adjust = int(input('How many adjustments are not included in DraftKings? '))
        for i in range(num_adjust):
            name = input('Which player? ')
            team = input('Which team? ')
            del changes_dict[(name, player)]  
    for (name, team), updates in changes_dict.items():
        dk_flex_df.loc[(dk_flex_df['name'] == name) & (dk_flex_df['team'] == team),upd updates.keys()] = updates.values()

# %%
fd_flex_df = fd_flex_df.reset_index(drop = False)
fd_flex_df = fd_flex_df[~(fd_flex_df['status'].isin(['IR', 'O']))]
fd_flex_df = fd_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])

dk_flex_df = dk_flex_df.reset_index(drop = False)
dk_flex_df = dk_flex_df[~(dk_flex_df['status'].isin(['IR', 'O']))]
dk_flex_df = dk_flex_df.set_index(['name', 'team', 'position', 'salary', 'opponent', 'status', 'season', 'week'])

# %%
change_datasets = input('Did dataset values change? ')
if change_datasets == 'y':
    fd_flex_df.to_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
    dk_flex_df.to_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
# Out:
# Did dataset values change?  y

# %%
# fd_flex_df[(fd_flex_df['team'] == 'HOU') & (fd_flex_df['position'] == 'RB')][adjustable_cols]

# %%
dk_flex_df_test = pd.read_csv('DK_FLEX_for_model_2024_5.csv')

# %%
dk_flex_df_test[dk_flex_df_test['team'] == 'NYG'][['name', 'team', 'target_share_L8', 'targets_L8', 'carry_share_L8', 'carries_L8']]
# Out:
#                      name team  target_share_L8  targets_L8  carry_share_L8  \
# 22       Devin Singletary  NYG         0.097661    3.000000        0.646000
# 47      Wan'Dale Robinson  NYG         0.360000   13.000000        0.012250
# 96           Tyrone Tracy  NYG         0.041467    1.500000        0.440000
# 152             Eric Gray  NYG         0.029273    1.000000        0.250000
# 153          Dante Miller  NYG         0.071789    2.316208        0.430000
# 154        Jashaun Corbin  NYG         0.115385    3.000000        0.045000
# 156        Darius Slayton  NYG         0.270000    8.875000        0.000000
# 188           Jalin Hyatt  NYG         0.220000    6.625000        0.000000
# 282    Bryce Ford-Wheaton  NYG         0.150889    4.869456        0.008811
# 283  Ihmir Smith-Marsette  NYG         0.066589    1.625000        0.039750
# 284        Isaiah Hodgins  NYG         0.067863    1.875000        0.000000
# 302          Theo Johnson  NYG         0.074163    2.666667        0.000000
# 357        Chris Manhertz  NYG         0.038121    1.125000        0.000000
# 358      Daniel Bellinger  NYG         0.082530    2.375000        0.000000
# 359         Jakob Johnson  NYG         0.036441    1.142857        0.000000
# 360           Joel Wilson  NYG         0.109236    3.489743        0.000900
#
#      carries_L8
# 22    14.750000
# 47     0.250000
# 96    12.000000
# 152    5.625000
# 153   11.230000
# 154    1.000000
# 156    0.000000
# 188    0.000000
# 282    0.228761
# 283    1.125000
# 284    0.000000
# 302    0.000000
# 357    0.000000
# 358    0.000000
# 359    0.000000
# 360    0.025456

# %%
# fd_flex_df.loc[fd_flex_df['name'] == 'Cam Akers', 'carries_L8'] = 16
# fd_flex_df.loc[fd_flex_df['name'] == 'Dare Ogunbowale', 'carries_L8'] = 8.375
# fd_flex_df.loc[fd_flex_df['name'] == 'Cam Akers', 'carry_share_L8'] = .59
# fd_flex_df.loc[fd_flex_df['name'] == 'Dare Ogunbowale', 'carry_share_L8'] = .31

# dk_flex_df.loc[dk_flex_df['name'] == 'Cam Akers', 'carries_L8'] = 16
# dk_flex_df.loc[dk_flex_df['name'] == 'Dare Ogunbowale', 'carries_L8'] = 8.375
# dk_flex_df.loc[dk_flex_df['name'] == 'Cam Akers', 'carry_share_L8'] = .59
# dk_flex_df.loc[dk_flex_df['name'] == 'Dare Ogunbowale', 'carry_share_L8'] = .31

# %%
# fd_flex_df[(fd_flex_df['team'] == 'KC') & (fd_flex_df['position'].isin(['RB']))][adjustable_cols].sort_values(by = 'targets_L8', ascending = False)

# %%
# fd_flex_df.loc[fd_flex_df['name'] == 'Samaje Perine', 'carries_L8'] = 14
# fd_flex_df.loc[fd_flex_df['name'] == 'Carson Steele', 'carries_L8'] = 10.5
# fd_flex_df.loc[fd_flex_df['name'] == 'Samaje Perine', 'carry_share_L8'] = .59
# fd_flex_df.loc[fd_flex_df['name'] == 'Carson Steele', 'carry_share_L8'] = .31

# dk_flex_df.loc[dk_flex_df['name'] == 'Samaje Perine', 'carries_L8'] = 14
# dk_flex_df.loc[dk_flex_df['name'] == 'Carson Steele', 'carries_L8'] = 10.5
# dk_flex_df.loc[dk_flex_df['name'] == 'Samaje Perine', 'carry_share_L8'] = .59
# dk_flex_df.loc[dk_flex_df['name'] == 'Carson Steele', 'carry_share_L8'] = .31

# %%
# fd_flex_df[(fd_flex_df['team'] == 'LAR') & (fd_flex_df['position'].isin(['WR', 'TE']))][adjustable_cols].sort_values(by = 'targets_L8', ascending = False)

# %%
# fd_flex_df.loc[fd_flex_df['name'] == 'Demarcus Robinson', 'targets_L8'] = 10.3
# fd_flex_df.loc[fd_flex_df['name'] == 'Tyler Johnson', 'targets_L8'] = 8.3
# fd_flex_df.loc[fd_flex_df['name'] == 'Tutu Atwell', 'targets_L8'] = 4.125
# fd_flex_df.loc[fd_flex_df['name'] == 'Colby Parkinson', 'targets_L8'] = 3.75

# fd_flex_df.loc[fd_flex_df['name'] == 'Demarcus Robinson', 'target_share_L8'] = .28
# fd_flex_df.loc[fd_flex_df['name'] == 'Tyler Johnson', 'target_share_L8'] = .22
# fd_flex_df.loc[fd_flex_df['name'] == 'Tutu Atwell', 'target_share_L8'] = .15
# fd_flex_df.loc[fd_flex_df['name'] == 'Colby Parkinson', 'target_share_L8'] = .11

# dk_flex_df.loc[dk_flex_df['name'] == 'Demarcus Robinson', 'targets_L8'] = 10.3
# dk_flex_df.loc[dk_flex_df['name'] == 'Tyler Johnson', 'targets_L8'] = 8.3
# dk_flex_df.loc[dk_flex_df['name'] == 'Tutu Atwell', 'targets_L8'] = 4.125
# dk_flex_df.loc[dk_flex_df['name'] == 'Colby Parkinson', 'targets_L8'] = 3.75

# dk_flex_df.loc[dk_flex_df['name'] == 'Demarcus Robinson', 'target_share_L8'] = .28
# dk_flex_df.loc[dk_flex_df['name'] == 'Tyler Johnson', 'target_share_L8'] = .22
# dk_flex_df.loc[dk_flex_df['name'] == 'Tutu Atwell', 'target_share_L8'] = .15
# dk_flex_df.loc[dk_flex_df['name'] == 'Colby Parkinson', 'target_share_L8'] = .11

# %%
# fd_flex_df[(fd_flex_df['team'] == 'MIA') & (fd_flex_df['position'].isin(['RB']))][adjustable_cols].sort_values(by = 'targets_L8', ascending = False)

# %%
# fd_flex_df.loc[fd_flex_df['name'] == "De'Von Achane", 'carries_L8'] = 14
# fd_flex_df.loc[fd_flex_df['name'] == "Jeff Wilson Jr.", 'carries_L8'] = 7
# fd_flex_df.loc[fd_flex_df['name'] == "De'Von Achane", 'carry_share_L8'] = .51
# fd_flex_df.loc[fd_flex_df['name'] == "Jeff Wilson Jr.", 'carry_share_L8'] = .31

# dk_flex_df.loc[dk_flex_df['name'] == "De'Von Achane", 'carries_L8'] = 14
# dk_flex_df.loc[dk_flex_df['name'] == "Jeff Wilson Jr.", 'carries_L8'] = 7
# dk_flex_df.loc[dk_flex_df['name'] == "De'Von Achane", 'carry_share_L8'] = .51
# dk_flex_df.loc[dk_flex_df['name'] == "Jeff Wilson Jr.", 'carry_share_L8'] = .31

# %%
# fd_flex_df[(fd_flex_df['team'] == 'SF') & (fd_flex_df['position'].isin(['WR', 'TE']))][adjustable_cols].sort_values(by = 'targets_L8', ascending = False)

# %%
# fd_flex_df.loc[fd_flex_df['name'] == 'Brandon Aiyuk', 'targets_L8'] = 12
# fd_flex_df.loc[fd_flex_df['name'] == 'Jacob Cowing', 'targets_L8'] = 5.5
# fd_flex_df.loc[fd_flex_df['name'] == 'Jauan Jennings', 'targets_L8'] = 6

# fd_flex_df.loc[fd_flex_df['name'] == 'Brandon Aiyuk', 'target_share_L8'] = .4
# fd_flex_df.loc[fd_flex_df['name'] == 'Jacob Cowing', 'target_share_L8'] = .175
# fd_flex_df.loc[fd_flex_df['name'] == 'Jauan Jennings', 'target_share_L8'] = .2

# dk_flex_df.loc[dk_flex_df['name'] == 'Brandon Aiyuk', 'targets_L8'] = 12
# dk_flex_df.loc[dk_flex_df['name'] == 'Jacob Cowing', 'targets_L8'] = 5.5
# dk_flex_df.loc[dk_flex_df['name'] == 'Jauan Jennings', 'targets_L8'] = 6

# dk_flex_df.loc[dk_flex_df['name'] == 'Brandon Aiyuk', 'target_share_L8'] = .4
# dk_flex_df.loc[dk_flex_df['name'] == 'Jacob Cowing', 'target_share_L8'] = .175
# dk_flex_df.loc[dk_flex_df['name'] == 'Jauan Jennings', 'target_share_L8'] = .2

# %%
fd_flex_df.head()
# Out:
#                                                                    index  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4         0
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4         1
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4         2
# Jordan Mason     SF   RB       8800   NE       Active 2024   4         3
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4         4
#
#                                                                    DK_Pts_RB_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           22.2875
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           21.7500
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           24.0500
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           23.6450
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           22.0500
#
#                                                                    DK_Pts_TE_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           11.6125
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           16.6250
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           12.8750
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           10.3625
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           10.3125
#
#                                                                    DK_Pts_WR_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           29.9125
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           33.5125
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           26.5375
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           31.1125
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           30.5625
#
#                                                                    FD_Pts_RB_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           19.0375
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           18.5625
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           21.1125
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           20.2700
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           19.4875
#
#                                                                    FD_Pts_TE_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4            8.8000
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           13.7500
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           10.3750
# Jordan Mason     SF   RB       8800   NE       Active 2024   4            7.9875
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4            8.0000
#
#                                                                    FD_Pts_WR_DvP  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           22.7250
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           26.5125
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           21.7875
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           24.3000
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           24.1875
#
#                                                                    rushing_yards_L8  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4               77.000
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4               -1.500
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4                0.000
# Jordan Mason     SF   RB       8800   NE       Active 2024   4               51.625
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4               65.250
#
#                                                                    rushing_tds_L8  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4              1.125
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4              0.000
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4              0.000
# Jordan Mason     SF   RB       8800   NE       Active 2024   4              0.375
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4              0.875
#
#                                                                    rushing_fumbles_lost_L8  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4                       0.125
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4                       0.000
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4                       0.000
# Jordan Mason     SF   RB       8800   NE       Active 2024   4                       0.000
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4                       0.000
#
#                                                                    ...  \
# name             team position salary opponent status season week  ...
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4     ...
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4     ...
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4     ...
# Jordan Mason     SF   RB       8800   NE       Active 2024   4     ...
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4     ...
#
#                                                                    pos_WR  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4          0
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4          1
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4          1
# Jordan Mason     SF   RB       8800   NE       Active 2024   4          0
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4          0
#
#                                                                    qb_comp  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4      20.375
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4       9.875
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4      24.250
# Jordan Mason     SF   RB       8800   NE       Active 2024   4      21.875
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4      19.750
#
#                                                                    qb_att  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4     30.625
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4     15.125
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4     33.875
# Jordan Mason     SF   RB       8800   NE       Active 2024   4     32.875
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4     27.250
#
#                                                                     qb_yds  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4     211.000
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4     118.375
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4     251.250
# Jordan Mason     SF   RB       8800   NE       Active 2024   4     262.625
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4     212.750
#
#                                                                    qb_pass_td  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4          1.000
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4          1.250
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4          1.875
# Jordan Mason     SF   RB       8800   NE       Active 2024   4          1.125
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4          2.500
#
#                                                                    qb_int  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4      1.125
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4      0.375
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4      0.375
# Jordan Mason     SF   RB       8800   NE       Active 2024   4      0.750
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4      0.500
#
#                                                                    qb_comp_pct  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4        0.665306
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4        0.652893
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4        0.715867
# Jordan Mason     SF   RB       8800   NE       Active 2024   4        0.665399
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4        0.724771
#
#                                                                    qb_yds_per_att  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4           6.889796
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4           7.826446
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4           7.416974
# Jordan Mason     SF   RB       8800   NE       Active 2024   4           7.988593
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4           7.807339
#
#                                                                    qb_td_pct  \
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4      0.032653
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4      0.082645
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4      0.055351
# Jordan Mason     SF   RB       8800   NE       Active 2024   4      0.034221
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4      0.091743
#
#                                                                    qb_int_pct
# name             team position salary opponent status season week
# Saquon Barkley   PHI  RB       9700   TB       Active 2024   4       0.036735
# Justin Jefferson MIN  WR       9400   GB       Active 2024   4       0.024793
# Ja'Marr Chase    CIN  WR       9200   CAR      Active 2024   4       0.011070
# Jordan Mason     SF   RB       8800   NE       Active 2024   4       0.022814
# Alvin Kamara     NO   RB       8600   ATL      Q      2024   4       0.018349
#
# [5 rows x 45 columns]

# %%
dk_flex_df.head()
# Out:
#                                                                    index  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4         0
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4         2
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4         3
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4         5
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4         6
#
#                                                                    DK_Pts_RB_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           21.7500
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           22.2875
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           22.7000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           24.0500
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           17.7500
#
#                                                                    DK_Pts_TE_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           16.6250
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           11.6125
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           13.0625
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           12.8750
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           12.9375
#
#                                                                    DK_Pts_WR_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           33.5125
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           29.9125
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           30.6875
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           26.5375
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           28.2250
#
#                                                                    FD_Pts_RB_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           18.5625
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           19.0375
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           19.0750
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           21.1125
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           14.9375
#
#                                                                    FD_Pts_TE_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           13.7500
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4            8.8000
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           10.4375
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           10.3750
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           10.6875
#
#                                                                    FD_Pts_WR_DvP  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           26.5125
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           22.7250
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           24.5000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           21.7875
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           22.6000
#
#                                                                    rushing_yards_L8  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4               -1.500
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4               77.000
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4               72.375
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4                0.000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4               93.500
#
#                                                                    rushing_tds_L8  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4              0.000
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4              1.125
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4              0.625
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4              0.000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4              1.125
#
#                                                                    rushing_fumbles_lost_L8  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4                       0.000
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4                       0.125
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4                       0.000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4                       0.000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4                       0.000
#
#                                                                    ...  \
# name             team position salary opponent status season week  ...
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4     ...
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4     ...
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4     ...
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4     ...
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4     ...
#
#                                                                    pos_WR  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4        1.0
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4        0.0
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4        0.0
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4        1.0
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4        0.0
#
#                                                                      qb_comp  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4      9.875000
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4     20.375000
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4     19.250000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4     24.250000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4     10.333333
#
#                                                                    qb_att  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4     15.125
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4     30.625
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4     29.500
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4     33.875
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4     20.000
#
#                                                                        qb_yds  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4     118.375000
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4     211.000000
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4     204.625000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4     251.250000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4     156.166667
#
#                                                                    qb_pass_td  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4       1.250000
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4       1.000000
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4       1.250000
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4       1.875000
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4       0.833333
#
#                                                                    qb_int  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4      0.375
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4      1.125
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4      0.500
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4      0.375
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4      1.000
#
#                                                                    qb_comp_pct  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4        0.652893
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4        0.665306
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4        0.652542
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4        0.715867
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4        0.516667
#
#                                                                    qb_yds_per_att  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4           7.826446
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4           6.889796
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4           6.936441
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4           7.416974
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4           7.808333
#
#                                                                    qb_td_pct  \
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4      0.082645
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4      0.032653
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4      0.042373
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4      0.055351
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4      0.041667
#
#                                                                    qb_int_pct
# name             team position salary opponent status season week
# Justin Jefferson MIN  WR       8700   GB       Active 2024.0 4       0.024793
# Saquon Barkley   PHI  RB       8000   TB       Active 2024.0 4       0.036735
# Breece Hall      NYJ  RB       7800   DEN      Active 2024.0 4       0.016949
# Ja'Marr Chase    CIN  WR       7700   CAR      Active 2024.0 4       0.011070
# Jonathan Taylor  IND  RB       7700   PIT      Active 2024.0 4       0.050000
#
# [5 rows x 45 columns]

# %%
fd_flex_df.columns
# Out:
# Index(['index', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP',
#        'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP', 'rushing_yards_L8',
#        'rushing_tds_L8', 'rushing_fumbles_lost_L8', 'receptions_L8',
#        'receiving_yards_L8', 'receiving_tds_L8', 'receiving_fumbles_lost_L8',
#        'targets_L8', 'carries_L8', 'receiving_yards_after_catch_L8',
#        'receiving_air_yards_L8', 'target_share_L8', 'carry_share_L8',
#        'in_10_share_L8', 'yards_per_carry_L8', 'yards_per_reception_L8',
#        'yards_per_target_L8', 'wind', 'div_game', 'spread_line', 'total_line',
#        'outdoors', 'grass', 'home_team', 'pred_total', 'opp_total', 'pos_RB',
#        'pos_TE', 'pos_WR', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',
#        'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct'],
#       dtype='object')

# %%
dk_flex_df.columns
# Out:
# Index(['index', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP',
#        'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP', 'rushing_yards_L8',
#        'rushing_tds_L8', 'rushing_fumbles_lost_L8', 'receptions_L8',
#        'receiving_yards_L8', 'receiving_tds_L8', 'receiving_fumbles_lost_L8',
#        'targets_L8', 'carries_L8', 'receiving_yards_after_catch_L8',
#        'receiving_air_yards_L8', 'target_share_L8', 'carry_share_L8',
#        'in_10_share_L8', 'yards_per_carry_L8', 'yards_per_reception_L8',
#        'yards_per_target_L8', 'wind', 'div_game', 'spread_line', 'total_line',
#        'outdoors', 'grass', 'home_team', 'pred_total', 'opp_total', 'pos_RB',
#        'pos_TE', 'pos_WR', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',
#        'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct'],
#       dtype='object')
