# %% [markdown]
# # Assembling FLEX dataset
# This notebook will wrangle the FanDuel and DraftKings lists of running backs, wide receivers and tight ends and create a CSV that is ready to run through the model for predictions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nfl_data_py as nfl
#import itertools
from functions import get_current_weekday, calculate_nfl_week, get_next_sunday, get_current_year

# %%
import sqlite3

# %%
day = get_current_weekday()

# %%
date_string = get_next_sunday(day)

# %%
week = calculate_nfl_week(date_string)

# %%
season = get_current_year()

# %% [markdown]
# # Pulling from database
# Fetching the FD and DK lists from the database. These tables include names, positions, teams, opponents and salaries.

# %%
# Connect to the SQLite database
#These are the FD and DK player lists for the current week
conn = sqlite3.connect('nfl_dfs.db')

query_fd = "SELECT * FROM fd_table_" + str(week) + "_" + str(season)[2:]
query_dk = "SELECT * FROM dk_table_" + str(week) + "_" + str(season)[2:]

fanduel_df = pd.read_sql_query(query_fd, conn)
draftkings_df = pd.read_sql_query(query_dk, conn)

# Close the database connection
conn.close()

# %%
#The weekly and play-by-play data through the previous week
#We went into R Studio to get these and save them as CSVs that we can use here
weekly_df = pd.read_csv('weekly_data_' + str(season) + '_' + str(week) + '.csv')
pbp_df = pd.read_csv('pbp_data_' + str(season) + '_' + str(week) + '.csv', low_memory = False)

# %%
weekly_df.replace({'LA': 'LAR'}, inplace = True)
pbp_df.replace({'LA': 'LAR'}, inplace = True)

# %% [markdown]
# <!-- This is weekly data for each player. We can use this to calculate fantasy points for most players. -->

# %%
weekly_df.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 3  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 4  https://static.www.nfl.com/image/private/f_aut...          TB    2022
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                     0            NaN
# 1     2         REG  ...                     0            NaN
# 2     3         REG  ...                     0            NaN
# 3     4         REG  ...                     0            NaN
# 4     5         REG  ...                     0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 0                          0   NaN           NaN              NaN   NaN
# 1                          0   NaN           NaN              NaN   NaN
# 2                          0   NaN           NaN              NaN   NaN
# 3                          0   NaN           NaN              NaN   NaN
# 4                          0   NaN           NaN              NaN   NaN
#
#    special_teams_tds  fantasy_points  fantasy_points_ppr
# 0                  0           10.38               10.38
# 1                  0            9.40                9.40
# 2                  0           14.74               14.74
# 3                  0           25.40               25.40
# 4                  0           19.74               19.74
#
# [5 rows x 53 columns]

# %%
pbp_df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 1       43  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 2       68  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 3       89  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 4      115  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     NYJ         home     BAL  ...             0                     1
# 2     1     NYJ         home     BAL  ...             0                     1
# 3     1     NYJ         home     BAL  ...             0                     1
# 4     1     NYJ         home     BAL  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0  0.000000       NaN                NaN                  NaN          NaN
# 1 -0.443521       NaN                NaN                  NaN          NaN
# 2  1.468819       NaN                NaN                  NaN          NaN
# 3 -0.492192  0.727261           6.988125                  6.0      0.60693
# 4 -0.325931       NaN                NaN                  NaN          NaN
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.440373 -44.037291
# 3  0.227598  0.389904  61.009598
# 4       NaN  0.443575 -44.357494
#
# [5 rows x 372 columns]

# %%
#rb_wr_te_df.head()

# %%
#rb_wr_te_df.info()

# %%
#nfl.see_weekly_cols()

# %%
weekly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13057 entries, 0 to 13056
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    13057 non-null  object
#  1   player_name                  13057 non-null  object
#  2   player_display_name          13057 non-null  object
#  3   position                     13057 non-null  object
#  4   position_group               13057 non-null  object
#  5   headshot_url                 12981 non-null  object
#  6   recent_team                  13057 non-null  object
#  7   season                       13057 non-null  int64
#  8   week                         13057 non-null  int64
#  9   season_type                  13057 non-null  object
#  10  opponent_team                13057 non-null  object
#  11  completions                  13057 non-null  int64
#  12  attempts                     13057 non-null  int64
#  13  passing_yards                13057 non-null  int64
#  14  passing_tds                  13057 non-null  int64
#  15  interceptions                13057 non-null  int64
#  16  sacks                        13057 non-null  int64
#  17  sack_yards                   13057 non-null  int64
#  18  sack_fumbles                 13057 non-null  int64
#  19  sack_fumbles_lost            13057 non-null  int64
#  20  passing_air_yards            13057 non-null  int64
#  21  passing_yards_after_catch    13057 non-null  int64
#  22  passing_first_downs          13057 non-null  int64
#  23  passing_epa                  1629 non-null   float64
#  24  passing_2pt_conversions      13057 non-null  int64
#  25  pacr                         1603 non-null   float64
#  26  dakota                       1419 non-null   float64
#  27  carries                      13057 non-null  int64
#  28  rushing_yards                13057 non-null  int64
#  29  rushing_tds                  13057 non-null  int64
#  30  rushing_fumbles              13057 non-null  int64
#  31  rushing_fumbles_lost         13057 non-null  int64
#  32  rushing_first_downs          13057 non-null  int64
#  33  rushing_epa                  5523 non-null   float64
#  34  rushing_2pt_conversions      13057 non-null  int64
#  35  receptions                   13057 non-null  int64
#  36  targets                      13057 non-null  int64
#  37  receiving_yards              13057 non-null  int64
#  38  receiving_tds                13057 non-null  int64
#  39  receiving_fumbles            13057 non-null  int64
#  40  receiving_fumbles_lost       13057 non-null  int64
#  41  receiving_air_yards          13057 non-null  int64
#  42  receiving_yards_after_catch  13057 non-null  int64
#  43  receiving_first_downs        13057 non-null  int64
#  44  receiving_epa                10554 non-null  float64
#  45  receiving_2pt_conversions    13057 non-null  int64
#  46  racr                         10497 non-null  float64
#  47  target_share                 10554 non-null  float64
#  48  air_yards_share              10554 non-null  float64
#  49  wopr                         10554 non-null  float64
#  50  special_teams_tds            13057 non-null  int64
#  51  fantasy_points               13057 non-null  float64
#  52  fantasy_points_ppr           13057 non-null  float64
# dtypes: float64(11), int64(33), object(9)
# memory usage: 5.3+ MB

# %%
weekly_df['position_group'].value_counts()
# Out:
# position_group
# WR      5290
# RB      3492
# TE      2582
# QB      1609
# SPEC      30
# DB        27
# LB        14
# OL        11
# DL         2
# Name: count, dtype: int64

# %%
weekly_df['position'].value_counts()
# Out:
# position
# WR     5290
# RB     3294
# TE     2582
# QB     1609
# FB      198
# P        30
# CB       11
# T        10
# SS        9
# ILB       7
# FS        7
# OLB       6
# DT        2
# G         1
# MLB       1
# Name: count, dtype: int64

# %% [markdown]
# Weekly data filtered for RBs, WRs and TEs

# %%
flex_df = weekly_df[weekly_df['position'].isin(['RB', 'HB', 'FB', 'WR', 'TE'])]

# %%
cols_to_group = ['season', 'week', 'recent_team', 'opponent_team', 'player_id', 'player_display_name', 'position']

# %% [markdown]
# So we do have quite a few duplicate names so player_id becomes more important than names.

# %%
# Group by 'player_display_name' and check the number of unique 'player_id's
duplicate_names = flex_df.groupby('player_display_name')['player_id'].nunique()

# Filter the results to find names associated with more than one unique ID
duplicate_names = duplicate_names[duplicate_names > 1]

# %%
duplicate_names
# Out:
# Series([], Name: player_id, dtype: int64)

# %%
scoring_cols = ['passing_yards', 'passing_tds', 'interceptions', 'passing_2pt_conversions', 'rushing_yards',\
                   'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions', 'receptions', 'receiving_yards',\
                   'receiving_tds', 'receiving_fumbles_lost', 'receiving_2pt_conversions', 'sack_fumbles_lost', 'special_teams_tds',\
               'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share']

# %%
flex_df = flex_df.groupby(cols_to_group)[scoring_cols].sum()

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 11364 entries, (2022, 1, 'ARI', 'KC', '00-0027942', 'A.J. Green', 'WR') to (2024, 6, 'WAS', 'BAL', '00-0039355', 'Luke McCaffrey', 'WR')
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   passing_yards                11364 non-null  int64
#  1   passing_tds                  11364 non-null  int64
#  2   interceptions                11364 non-null  int64
#  3   passing_2pt_conversions      11364 non-null  int64
#  4   rushing_yards                11364 non-null  int64
#  5   rushing_tds                  11364 non-null  int64
#  6   rushing_fumbles_lost         11364 non-null  int64
#  7   rushing_2pt_conversions      11364 non-null  int64
#  8   receptions                   11364 non-null  int64
#  9   receiving_yards              11364 non-null  int64
#  10  receiving_tds                11364 non-null  int64
#  11  receiving_fumbles_lost       11364 non-null  int64
#  12  receiving_2pt_conversions    11364 non-null  int64
#  13  sack_fumbles_lost            11364 non-null  int64
#  14  special_teams_tds            11364 non-null  int64
#  15  targets                      11364 non-null  int64
#  16  carries                      11364 non-null  int64
#  17  receiving_yards_after_catch  11364 non-null  int64
#  18  receiving_air_yards          11364 non-null  int64
#  19  air_yards_share              11364 non-null  float64
#  20  target_share                 11364 non-null  float64
# dtypes: float64(2), int64(19)
# memory usage: 1.9+ MB

# %%
flex_df
# Out:
#                                                                                passing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                    0
#                                       00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                passing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  0
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                  0
#                                       00-0035208 Olamide Zaccheaus   WR                  0
#                                       00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0039355 Luke McCaffrey      WR                  0
#
#                                                                                interceptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                    0
#                                       00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                passing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                              0
#                                       00-0035208 Olamide Zaccheaus   WR                              0
#                                       00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0039355 Luke McCaffrey      WR                              0
#
#                                                                                rushing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                   26
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                    9
#                                       00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                rushing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  1
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                  0
#                                       00-0035208 Olamide Zaccheaus   WR                  0
#                                       00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0039355 Luke McCaffrey      WR                  0
#
#                                                                                rushing_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                           0
#                                       00-0030061 Zach Ertz           TE                           0
#                                       00-0033553 James Conner        RB                           0
#                                       00-0035500 Greg Dortch         WR                           0
#                                       00-0035527 Andy Isabella       WR                           0
# ...                                                                                             ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                           0
#                                       00-0035208 Olamide Zaccheaus   WR                           0
#                                       00-0035659 Terry McLaurin      WR                           0
#                                       00-0036626 Dyami Brown         WR                           0
#                                       00-0039355 Luke McCaffrey      WR                           0
#
#                                                                                rushing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                              0
#                                       00-0035208 Olamide Zaccheaus   WR                              0
#                                       00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0039355 Luke McCaffrey      WR                              0
#
#                                                                                receptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                 2
#                                       00-0030061 Zach Ertz           TE                 2
#                                       00-0033553 James Conner        RB                 5
#                                       00-0035500 Greg Dortch         WR                 7
#                                       00-0035527 Andy Isabella       WR                 1
# ...                                                                                   ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                 0
#                                       00-0035208 Olamide Zaccheaus   WR                 4
#                                       00-0035659 Terry McLaurin      WR                 6
#                                       00-0036626 Dyami Brown         WR                 1
#                                       00-0039355 Luke McCaffrey      WR                 1
#
#                                                                                receiving_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                     13
#                                       00-0030061 Zach Ertz           TE                     14
#                                       00-0033553 James Conner        RB                     29
#                                       00-0035500 Greg Dortch         WR                     63
#                                       00-0035527 Andy Isabella       WR                     10
# ...                                                                                        ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                      0
#                                       00-0035208 Olamide Zaccheaus   WR                     27
#                                       00-0035659 Terry McLaurin      WR                     53
#                                       00-0036626 Dyami Brown         WR                     11
#                                       00-0039355 Luke McCaffrey      WR                      5
#
#                                                                                ...  \
# season week recent_team opponent_team player_id  player_display_name position  ...
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR        ...
#                                       00-0030061 Zach Ertz           TE        ...
#                                       00-0033553 James Conner        RB        ...
#                                       00-0035500 Greg Dortch         WR        ...
#                                       00-0035527 Andy Isabella       WR        ...
# ...                                                                            ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB        ...
#                                       00-0035208 Olamide Zaccheaus   WR        ...
#                                       00-0035659 Terry McLaurin      WR        ...
#                                       00-0036626 Dyami Brown         WR        ...
#                                       00-0039355 Luke McCaffrey      WR        ...
#
#                                                                                receiving_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                             0
#                                       00-0030061 Zach Ertz           TE                             0
#                                       00-0033553 James Conner        RB                             0
#                                       00-0035500 Greg Dortch         WR                             0
#                                       00-0035527 Andy Isabella       WR                             0
# ...                                                                                               ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                             0
#                                       00-0035208 Olamide Zaccheaus   WR                             0
#                                       00-0035659 Terry McLaurin      WR                             0
#                                       00-0036626 Dyami Brown         WR                             0
#                                       00-0039355 Luke McCaffrey      WR                             0
#
#                                                                                receiving_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                0
#                                       00-0030061 Zach Ertz           TE                                1
#                                       00-0033553 James Conner        RB                                0
#                                       00-0035500 Greg Dortch         WR                                0
#                                       00-0035527 Andy Isabella       WR                                0
# ...                                                                                                  ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                                0
#                                       00-0035208 Olamide Zaccheaus   WR                                0
#                                       00-0035659 Terry McLaurin      WR                                0
#                                       00-0036626 Dyami Brown         WR                                0
#                                       00-0039355 Luke McCaffrey      WR                                0
#
#                                                                                sack_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                        0
#                                       00-0035208 Olamide Zaccheaus   WR                        0
#                                       00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0039355 Luke McCaffrey      WR                        0
#
#                                                                                special_teams_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                        0
#                                       00-0035208 Olamide Zaccheaus   WR                        0
#                                       00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0039355 Luke McCaffrey      WR                        0
#
#                                                                                targets  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              4
#                                       00-0030061 Zach Ertz           TE              4
#                                       00-0033553 James Conner        RB              6
#                                       00-0035500 Greg Dortch         WR              9
#                                       00-0035527 Andy Isabella       WR              3
# ...                                                                                ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB              0
#                                       00-0035208 Olamide Zaccheaus   WR              6
#                                       00-0035659 Terry McLaurin      WR              7
#                                       00-0036626 Dyami Brown         WR              1
#                                       00-0039355 Luke McCaffrey      WR              1
#
#                                                                                carries  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              0
#                                       00-0030061 Zach Ertz           TE              0
#                                       00-0033553 James Conner        RB             10
#                                       00-0035500 Greg Dortch         WR              0
#                                       00-0035527 Andy Isabella       WR              0
# ...                                                                                ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB              2
#                                       00-0035208 Olamide Zaccheaus   WR              0
#                                       00-0035659 Terry McLaurin      WR              1
#                                       00-0036626 Dyami Brown         WR              0
#                                       00-0039355 Luke McCaffrey      WR              0
#
#                                                                                receiving_yards_after_catch  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                  0
#                                       00-0030061 Zach Ertz           TE                                  4
#                                       00-0033553 James Conner        RB                                 38
#                                       00-0035500 Greg Dortch         WR                                 31
#                                       00-0035527 Andy Isabella       WR                                  4
# ...                                                                                                    ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                                  0
#                                       00-0035208 Olamide Zaccheaus   WR                                 14
#                                       00-0035659 Terry McLaurin      WR                                  1
#                                       00-0036626 Dyami Brown         WR                                 12
#                                       00-0039355 Luke McCaffrey      WR                                  0
#
#                                                                                receiving_air_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                         42
#                                       00-0030061 Zach Ertz           TE                         22
#                                       00-0033553 James Conner        RB                          7
#                                       00-0035500 Greg Dortch         WR                         62
#                                       00-0035527 Andy Isabella       WR                         30
# ...                                                                                            ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB                          0
#                                       00-0035208 Olamide Zaccheaus   WR                         33
#                                       00-0035659 Terry McLaurin      WR                         81
#                                       00-0036626 Dyami Brown         WR                         -1
#                                       00-0039355 Luke McCaffrey      WR                          5
#
#                                                                                air_yards_share  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR               0.157895
#                                       00-0030061 Zach Ertz           TE               0.082707
#                                       00-0033553 James Conner        RB               0.026316
#                                       00-0035500 Greg Dortch         WR               0.233083
#                                       00-0035527 Andy Isabella       WR               0.112782
# ...                                                                                        ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB               0.000000
#                                       00-0035208 Olamide Zaccheaus   WR               0.125954
#                                       00-0035659 Terry McLaurin      WR               0.309160
#                                       00-0036626 Dyami Brown         WR              -0.003817
#                                       00-0039355 Luke McCaffrey      WR               0.019084
#
#                                                                                target_share
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR            0.111111
#                                       00-0030061 Zach Ertz           TE            0.111111
#                                       00-0033553 James Conner        RB            0.166667
#                                       00-0035500 Greg Dortch         WR            0.250000
#                                       00-0035527 Andy Isabella       WR            0.083333
# ...                                                                                     ...
# 2024   6    WAS         BAL           00-0033955 Jeremy McNichols    RB            0.000000
#                                       00-0035208 Olamide Zaccheaus   WR            0.181818
#                                       00-0035659 Terry McLaurin      WR            0.212121
#                                       00-0036626 Dyami Brown         WR            0.030303
#                                       00-0039355 Luke McCaffrey      WR            0.030303
#
# [11364 rows x 21 columns]

# %%
def replace(code, old, new):
    """
    Basically a find and replace
    """
    return code.replace(old, new)

# %%
flex_df.reset_index(inplace = True, drop = False)

# %%
#There are a few errant rows where the opponent matches the team
flex_df = flex_df[~(flex_df['recent_team'] == flex_df['opponent_team'])]

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11357 entries, 0 to 11363
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       11357 non-null  int64
#  1   week                         11357 non-null  int64
#  2   recent_team                  11357 non-null  object
#  3   opponent_team                11357 non-null  object
#  4   player_id                    11357 non-null  object
#  5   player_display_name          11357 non-null  object
#  6   position                     11357 non-null  object
#  7   passing_yards                11357 non-null  int64
#  8   passing_tds                  11357 non-null  int64
#  9   interceptions                11357 non-null  int64
#  10  passing_2pt_conversions      11357 non-null  int64
#  11  rushing_yards                11357 non-null  int64
#  12  rushing_tds                  11357 non-null  int64
#  13  rushing_fumbles_lost         11357 non-null  int64
#  14  rushing_2pt_conversions      11357 non-null  int64
#  15  receptions                   11357 non-null  int64
#  16  receiving_yards              11357 non-null  int64
#  17  receiving_tds                11357 non-null  int64
#  18  receiving_fumbles_lost       11357 non-null  int64
#  19  receiving_2pt_conversions    11357 non-null  int64
#  20  sack_fumbles_lost            11357 non-null  int64
#  21  special_teams_tds            11357 non-null  int64
#  22  targets                      11357 non-null  int64
#  23  carries                      11357 non-null  int64
#  24  receiving_yards_after_catch  11357 non-null  int64
#  25  receiving_air_yards          11357 non-null  int64
#  26  air_yards_share              11357 non-null  float64
#  27  target_share                 11357 non-null  float64
# dtypes: float64(2), int64(21), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# # What do we need from play-by-play?
# Let's take a look at the data we'd like to have and see where we need to integrate the play-by-play data. We have yards_after_catch and air_yards. We have targets and target share. Even though the target share doesn't add up to 100 percent, it's still useful. We'll definitely want to spot-check that.<br>
#
# We have carries but no carry share. Maybe we need to just take the total carries for each team in each game from the pbp and join that with the flex_df. That shouldn't be too hard. Then we can figure out every RBs workload even if they don't all add up to 100.<br>
#
# We also want goal_to_go binary for each play to see how many carries or targets a player gets in goal-line situations and also the rate at which they score TDs in those situations.<br>

# %%
run_df = pbp_df[pbp_df['play_type'] == 'run']

# %%
running_play_counts = run_df.groupby(['season', 'week', 'posteam', 'defteam', 'game_id']).size().reset_index(name='total_carries')

# %%
running_play_counts.rename(columns = {'posteam' : 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_df, running_play_counts, on = ['season', 'week', 'recent_team', 'opponent_team'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11357 entries, 0 to 11356
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       11357 non-null  int64
#  1   week                         11357 non-null  int64
#  2   recent_team                  11357 non-null  object
#  3   opponent_team                11357 non-null  object
#  4   player_id                    11357 non-null  object
#  5   player_display_name          11357 non-null  object
#  6   position                     11357 non-null  object
#  7   passing_yards                11357 non-null  int64
#  8   passing_tds                  11357 non-null  int64
#  9   interceptions                11357 non-null  int64
#  10  passing_2pt_conversions      11357 non-null  int64
#  11  rushing_yards                11357 non-null  int64
#  12  rushing_tds                  11357 non-null  int64
#  13  rushing_fumbles_lost         11357 non-null  int64
#  14  rushing_2pt_conversions      11357 non-null  int64
#  15  receptions                   11357 non-null  int64
#  16  receiving_yards              11357 non-null  int64
#  17  receiving_tds                11357 non-null  int64
#  18  receiving_fumbles_lost       11357 non-null  int64
#  19  receiving_2pt_conversions    11357 non-null  int64
#  20  sack_fumbles_lost            11357 non-null  int64
#  21  special_teams_tds            11357 non-null  int64
#  22  targets                      11357 non-null  int64
#  23  carries                      11357 non-null  int64
#  24  receiving_yards_after_catch  11357 non-null  int64
#  25  receiving_air_yards          11357 non-null  int64
#  26  air_yards_share              11357 non-null  float64
#  27  target_share                 11357 non-null  float64
#  28  game_id                      11357 non-null  object
#  29  total_carries                11357 non-null  int64
# dtypes: float64(2), int64(22), object(6)
# memory usage: 2.6+ MB

# %%
flex_merge['carry_share'] = round(flex_merge['carries']/flex_merge['total_carries'], 3)

# %%
flex_merge.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  special_teams_tds  \
# 0       WR              0            0              0  ...                  0
# 1       TE              0            0              0  ...                  0
# 2       RB              0            0              0  ...                  0
# 3       WR              0            0              0  ...                  0
# 4       WR              0            0              0  ...                  0
#
#    targets  carries  receiving_yards_after_catch  receiving_air_yards  \
# 0        4        0                            0                   42
# 1        4        0                            4                   22
# 2        6       10                           38                    7
# 3        9        0                           31                   62
# 4        3        0                            4                   30
#
#    air_yards_share  target_share         game_id  total_carries  carry_share
# 0         0.157895      0.111111  2022_01_KC_ARI             21        0.000
# 1         0.082707      0.111111  2022_01_KC_ARI             21        0.000
# 2         0.026316      0.166667  2022_01_KC_ARI             21        0.476
# 3         0.233083      0.250000  2022_01_KC_ARI             21        0.000
# 4         0.112782      0.083333  2022_01_KC_ARI             21        0.000
#
# [5 rows x 31 columns]

# %%
flex_merge.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id  \
# 11327    2024     6          SF           SEA  00-0036259
# 11328    2024     6          SF           SEA  00-0036261
# 11329    2024     6          SF           SEA  00-0037525
# 11330    2024     6          SF           SEA  00-0039363
# 11331    2024     6          TB            NO  00-0031408
# 11332    2024     6          TB            NO  00-0032385
# 11333    2024     6          TB            NO  00-0033921
# 11334    2024     6          TB            NO  00-0038129
# 11335    2024     6          TB            NO  00-0038824
# 11336    2024     6          TB            NO  00-0038951
# 11337    2024     6          TB            NO  00-0039361
# 11338    2024     6          TB            NO  00-0039855
# 11339    2024     6         TEN           IND  00-0030564
# 11340    2024     6         TEN           IND  00-0033009
# 11341    2024     6         TEN           IND  00-0034837
# 11342    2024     6         TEN           IND  00-0035261
# 11343    2024     6         TEN           IND  00-0036182
# 11344    2024     6         TEN           IND  00-0037594
# 11345    2024     6         TEN           IND  00-0037742
# 11346    2024     6         TEN           IND  00-0037809
# 11347    2024     6         TEN           IND  00-0038589
# 11348    2024     6         TEN           IND  00-0039032
# 11349    2024     6         WAS           BAL  00-0030061
# 11350    2024     6         WAS           BAL  00-0033591
# 11351    2024     6         WAS           BAL  00-0033699
# 11352    2024     6         WAS           BAL  00-0033955
# 11353    2024     6         WAS           BAL  00-0035208
# 11354    2024     6         WAS           BAL  00-0035659
# 11355    2024     6         WAS           BAL  00-0036626
# 11356    2024     6         WAS           BAL  00-0039355
#
#          player_display_name position  passing_yards  passing_tds  \
# 11327         Jauan Jennings       WR              0            0
# 11328          Brandon Aiyuk       WR              0            0
# 11329           Jordan Mason       RB              0            0
# 11330         Isaac Guerendo       RB              0            0
# 11331             Mike Evans       WR              0            0
# 11332       Sterling Shepard       WR              0            0
# 11333           Chris Godwin       WR              0            0
# 11334             Cade Otton       TE              0            0
# 11335            Ryan Miller       WR              0            0
# 11336            Sean Tucker       RB              0            0
# 11337           Bucky Irving       RB              0            0
# 11338         Jalen McMillan       WR              0            0
# 11339        DeAndre Hopkins       WR              0            0
# 11340             Tyler Boyd       WR              0            0
# 11341          Calvin Ridley       WR              0            0
# 11342           Tony Pollard       RB              0            0
# 11343  Nick Westbrook-Ikhine       WR              0            0
# 11344        Julius Chestnut       RB              0            0
# 11345          Treylon Burks       WR              0            0
# 11346      Chigoziem Okonkwo       TE              0            0
# 11347             Josh Whyle       TE              0            0
# 11348           Tyjae Spears       RB              0            0
# 11349              Zach Ertz       TE              0            0
# 11350             Noah Brown       WR              0            0
# 11351          Austin Ekeler       RB              0            0
# 11352       Jeremy McNichols       RB              0            0
# 11353      Olamide Zaccheaus       WR              0            0
# 11354         Terry McLaurin       WR              0            0
# 11355            Dyami Brown       WR              0            0
# 11356         Luke McCaffrey       WR              0            0
#
#        interceptions  ...  special_teams_tds  targets  carries  \
# 11327              0  ...                  0        5        0
# 11328              0  ...                  0        4        0
# 11329              0  ...                  0        2        9
# 11330              0  ...                  0        0       10
# 11331              0  ...                  0        6        0
# 11332              0  ...                  0        4        4
# 11333              0  ...                  0       13        0
# 11334              0  ...                  0        6        0
# 11335              0  ...                  0        1        0
# 11336              0  ...                  0        3       14
# 11337              0  ...                  0        2       14
# 11338              0  ...                  0        1        0
# 11339              0  ...                  0        6        0
# 11340              0  ...                  0        3        0
# 11341              0  ...                  0        8        1
# 11342              0  ...                  0        3       17
# 11343              0  ...                  0        2        0
# 11344              0  ...                  0        0        1
# 11345              0  ...                  0        1        0
# 11346              0  ...                  0        3        0
# 11347              0  ...                  0        1        0
# 11348              0  ...                  0        0        6
# 11349              0  ...                  0        5        0
# 11350              0  ...                  0        8        0
# 11351              0  ...                  0        5        9
# 11352              0  ...                  0        0        2
# 11353              0  ...                  0        6        0
# 11354              0  ...                  0        7        1
# 11355              0  ...                  0        1        0
# 11356              0  ...                  0        1        0
#
#        receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 11327                            8                   27         0.139896
# 11328                            6                   63         0.326425
# 11329                            7                    6         0.031088
# 11330                            0                    0         0.000000
# 11331                           14                   87         0.399083
# 11332                            8                   26         0.119266
# 11333                           99                   51         0.233945
# 11334                            2                   45         0.206422
# 11335                           38                    1         0.004587
# 11336                           52                    4         0.018349
# 11337                           32                   -8        -0.036697
# 11338                            0                   12         0.055046
# 11339                            0                   91         0.369919
# 11340                           16                    3         0.012195
# 11341                            0                  133         0.540650
# 11342                            7                  -12        -0.048780
# 11343                            0                   20         0.081301
# 11344                            0                    0         0.000000
# 11345                            0                   10         0.040650
# 11346                            6                    0         0.000000
# 11347                            1                    1         0.004065
# 11348                            0                    0         0.000000
# 11349                           19                   46         0.175573
# 11350                            5                  106         0.404580
# 11351                           50                   -8        -0.030534
# 11352                            0                    0         0.000000
# 11353                           14                   33         0.125954
# 11354                            1                   81         0.309160
# 11355                           12                   -1        -0.003817
# 11356                            0                    5         0.019084
#
#        target_share          game_id  total_carries  carry_share
# 11327      0.185185   2024_06_SF_SEA             33        0.000
# 11328      0.148148   2024_06_SF_SEA             33        0.000
# 11329      0.074074   2024_06_SF_SEA             33        0.273
# 11330      0.000000   2024_06_SF_SEA             33        0.303
# 11331      0.166667    2024_06_TB_NO             35        0.000
# 11332      0.111111    2024_06_TB_NO             35        0.114
# 11333      0.361111    2024_06_TB_NO             35        0.000
# 11334      0.166667    2024_06_TB_NO             35        0.000
# 11335      0.027778    2024_06_TB_NO             35        0.000
# 11336      0.083333    2024_06_TB_NO             35        0.400
# 11337      0.055556    2024_06_TB_NO             35        0.400
# 11338      0.027778    2024_06_TB_NO             35        0.000
# 11339      0.222222  2024_06_IND_TEN             28        0.000
# 11340      0.111111  2024_06_IND_TEN             28        0.000
# 11341      0.296296  2024_06_IND_TEN             28        0.036
# 11342      0.111111  2024_06_IND_TEN             28        0.607
# 11343      0.074074  2024_06_IND_TEN             28        0.000
# 11344      0.000000  2024_06_IND_TEN             28        0.036
# 11345      0.037037  2024_06_IND_TEN             28        0.000
# 11346      0.111111  2024_06_IND_TEN             28        0.000
# 11347      0.037037  2024_06_IND_TEN             28        0.000
# 11348      0.000000  2024_06_IND_TEN             28        0.214
# 11349      0.151515  2024_06_WAS_BAL             18        0.000
# 11350      0.242424  2024_06_WAS_BAL             18        0.000
# 11351      0.151515  2024_06_WAS_BAL             18        0.500
# 11352      0.000000  2024_06_WAS_BAL             18        0.111
# 11353      0.181818  2024_06_WAS_BAL             18        0.000
# 11354      0.212121  2024_06_WAS_BAL             18        0.056
# 11355      0.030303  2024_06_WAS_BAL             18        0.000
# 11356      0.030303  2024_06_WAS_BAL             18        0.000
#
# [30 rows x 31 columns]

# %% [markdown]
# # Goal-to-go situations
# We'll filter the pbp data by rows in which goal_to_go is True and the play is either a run or a pass. We find that on passing plays, some of the receiver_player_id values are null, but for running plays none of them are null. This implies that on plays in which the QB is sacked, no pass is thrown so there's no receiver.<br>
#
# Those plays probably should be discarded as we are looking for a percentage of times a RB-WR-TE gets the ball in goal-to-go situations. When a QB is sacked, no one gets the ball.<br>
#
# **Update:** goal_to_go leaves out situations where it's 3rd and 2 from the 4-yard line. Maybe we should see if filtering by yardline_100 <= 10 gives us more data points.

# %%
gtg_df_10 = pbp_df[(pbp_df['yardline_100'] <= 10) & ((pbp_df['play_type'] == 'run') | (pbp_df['play_type'] == 'pass'))]
#gtg_df = rb_wr_te_df[(rb_wr_te_df['goal_to_go'] == True) & ((rb_wr_te_df['play_type'] == 'run') | (rb_wr_te_df['play_type'] == 'pass'))]

# %%
gtg_df_10['play_type'].value_counts()
# Out:
# play_type
# run     3107
# pass    3009
# Name: count, dtype: int64

# %%
gtg_df_10 = gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) | (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df = gtg_df[(gtg_df['receiver_player_id'].notnull()) | (gtg_df['rusher_player_id'].notnull())]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].isnull()) & (gtg_df_10['rusher_player_id'].isnull())]
#gtg_df[(gtg_df['receiver_player_id'].isnull()) & (gtg_df['rusher_player_id'].isnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) & (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df[(gtg_df['receiver_player_id'].notnull()) & (gtg_df['rusher_player_id'].notnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10['player_id'] = gtg_df_10['rusher_player_id'].fillna(gtg_df_10['receiver_player_id'])
#gtg_df['player_id'] = gtg_df['rusher_player_id'].fillna(gtg_df['receiver_player_id'])

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5751 entries, 31 to 114976
# Columns: 373 entries, play_id to player_id
# dtypes: float64(182), int64(39), object(152)
# memory usage: 16.4+ MB

# %%
#Total goal to go situations for each team in each game
grouped_gtg_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'plays_in_10')

#grouped_gtg = gtg_df.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'gtg_plays')

# %%
gtg_df_10.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'home_opening_kickoff', 'qb_epa', 'xyac_epa', 'xyac_mean_yardage',
#        'xyac_median_yardage', 'xyac_success', 'xyac_fd', 'xpass', 'pass_oe',
#        'player_id'],
#       dtype='object', length=373)

# %%
gtg_cols = ['play_id','week', 'posteam', 'defteam', 'sp', 'desc', 'play_type', 'td_player_id',
      'incomplete_pass', 'rush_attempt', 'pass_attempt',
       'touchdown', 'pass_touchdown', 'rush_touchdown', 'complete_pass', 'receiver_player_id',
       'receiver_player_name', 'rusher_player_id',
       'rusher_player_name', 'season', 'weather', 'player_id']

# %%
gtg_df_10 = gtg_df_10[gtg_cols]

# %%
gtg_df_10 = pd.merge(gtg_df_10, grouped_gtg_10, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')
#gtg_df = pd.merge(gtg_df, grouped_gtg, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')

# %%
##Next will be to derive how many times per gtg play a player gets the ball, and then when they get it their TD percentage

# %%
gtg_10_player = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'opps_in_10')
#gtg_player = gtg_df.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'gtg_opps')

# %%
gtg_df_10 = pd.merge(gtg_df_10, gtg_10_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')
#gtg_df = pd.merge(gtg_df, gtg_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')

# %%
gtg_df_10['in_10_share'] = round(gtg_df_10['opps_in_10']/gtg_df_10['plays_in_10'], 3)

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5751 entries, 0 to 5750
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   play_id               5751 non-null   int64
#  1   week                  5751 non-null   int64
#  2   posteam               5751 non-null   object
#  3   defteam               5751 non-null   object
#  4   sp                    5751 non-null   int64
#  5   desc                  5751 non-null   object
#  6   play_type             5751 non-null   object
#  7   td_player_id          1815 non-null   object
#  8   incomplete_pass       5751 non-null   float64
#  9   rush_attempt          5751 non-null   float64
#  10  pass_attempt          5751 non-null   float64
#  11  touchdown             5751 non-null   float64
#  12  pass_touchdown        5751 non-null   float64
#  13  rush_touchdown        5751 non-null   float64
#  14  complete_pass         5751 non-null   float64
#  15  receiver_player_id    2644 non-null   object
#  16  receiver_player_name  2644 non-null   object
#  17  rusher_player_id      3107 non-null   object
#  18  rusher_player_name    3107 non-null   object
#  19  season                5751 non-null   int64
#  20  weather               5527 non-null   object
#  21  player_id             5751 non-null   object
#  22  plays_in_10           5751 non-null   int64
#  23  opps_in_10            5751 non-null   int64
#  24  in_10_share           5751 non-null   float64
# dtypes: float64(8), int64(6), object(11)
# memory usage: 1.1+ MB

# %%
gtg_df_10['player_id'].nunique()
# Out:
# 591

# %%
flex_merge['player_id'].nunique()
# Out:
# 690

# %%
##Maybe we need to pause here. There are more players in our weekly data than we have in our gtg data, which makes sense.
#Not every player will be used in gtg situations.
#Maybe somehow just check that every player in flex_merge but not gtg doesn't have any True values in goal_to_go
####Maybe we should just use common sense
#We've filtered every gtg play that was a run or a pass.
#If there's any irregularity it's likely to come out during spot-checking

# %%
gtg_players = list(gtg_df_10['player_id'].unique())

# %%
flex_players = list(flex_merge['player_id'].unique())

# %%
len(gtg_players)
# Out:
# 591

# %%
len(flex_players)
# Out:
# 690

# %%
#gtg_df = gtg_df.sort_values(by = ['season', 'week', 'posteam', 'defteam'])

# %%
gtg_df_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id'], as_index=False).agg({'in_10_share': 'mean'})

# %%
#gtg_df = gtg_df[['season', 'week', 'posteam', 'defteam', 'player_id', 'gtg_share']]

# %%
gtg_df_10.tail(30)
# Out:
#       season  week posteam defteam   player_id  in_10_share
# 3665    2024     6     NYJ     BUF  00-0034521        0.167
# 3666    2024     6     NYJ     BUF  00-0037740        0.333
# 3667    2024     6     NYJ     BUF  00-0038120        0.167
# 3668    2024     6     NYJ     BUF  00-0039794        0.167
# 3669    2024     6     PIT      LV  00-0036893        0.222
# 3670    2024     6     PIT      LV  00-0036945        0.444
# 3671    2024     6     PIT      LV  00-0037247        0.111
# 3672    2024     6     PIT      LV  00-0037304        0.111
# 3673    2024     6     PIT      LV  00-0037609        0.111
# 3674    2024     6     SEA      SF  00-0030565        0.100
# 3675    2024     6     SEA      SF  00-0032211        0.300
# 3676    2024     6     SEA      SF  00-0035640        0.200
# 3677    2024     6     SEA      SF  00-0038134        0.200
# 3678    2024     6     SEA      SF  00-0038543        0.200
# 3679    2024     6      SF     SEA  00-0029892        0.111
# 3680    2024     6      SF     SEA  00-0033288        0.222
# 3681    2024     6      SF     SEA  00-0035719        0.111
# 3682    2024     6      SF     SEA  00-0035973        0.222
# 3683    2024     6      SF     SEA  00-0037525        0.222
# 3684    2024     6      SF     SEA  00-0039363        0.111
# 3685    2024     6      TB      NO  00-0031408        0.125
# 3686    2024     6      TB      NO  00-0033921        0.125
# 3687    2024     6      TB      NO  00-0038129        0.125
# 3688    2024     6      TB      NO  00-0038951        0.125
# 3689    2024     6      TB      NO  00-0039361        0.500
# 3690    2024     6     TEN     IND  00-0036182        1.000
# 3691    2024     6     WAS     BAL  00-0033591        0.200
# 3692    2024     6     WAS     BAL  00-0033699        0.200
# 3693    2024     6     WAS     BAL  00-0035659        0.400
# 3694    2024     6     WAS     BAL  00-0039355        0.200

# %%
check_for_one = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam'])['in_10_share'].sum()

# %%
check_for_one.min()
# Out:
# 0.9989999999999999

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3695 entries, 0 to 3694
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       3695 non-null   int64
#  1   week         3695 non-null   int64
#  2   posteam      3695 non-null   object
#  3   defteam      3695 non-null   object
#  4   player_id    3695 non-null   object
#  5   in_10_share  3695 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 173.3+ KB

# %%
gtg_df_10.rename(columns = {'posteam': 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_merge, gtg_df_10, on = ['season', 'week', 'recent_team', 'opponent_team', 'player_id'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11357 entries, 0 to 11356
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       11357 non-null  int64
#  1   week                         11357 non-null  int64
#  2   recent_team                  11357 non-null  object
#  3   opponent_team                11357 non-null  object
#  4   player_id                    11357 non-null  object
#  5   player_display_name          11357 non-null  object
#  6   position                     11357 non-null  object
#  7   passing_yards                11357 non-null  int64
#  8   passing_tds                  11357 non-null  int64
#  9   interceptions                11357 non-null  int64
#  10  passing_2pt_conversions      11357 non-null  int64
#  11  rushing_yards                11357 non-null  int64
#  12  rushing_tds                  11357 non-null  int64
#  13  rushing_fumbles_lost         11357 non-null  int64
#  14  rushing_2pt_conversions      11357 non-null  int64
#  15  receptions                   11357 non-null  int64
#  16  receiving_yards              11357 non-null  int64
#  17  receiving_tds                11357 non-null  int64
#  18  receiving_fumbles_lost       11357 non-null  int64
#  19  receiving_2pt_conversions    11357 non-null  int64
#  20  sack_fumbles_lost            11357 non-null  int64
#  21  special_teams_tds            11357 non-null  int64
#  22  targets                      11357 non-null  int64
#  23  carries                      11357 non-null  int64
#  24  receiving_yards_after_catch  11357 non-null  int64
#  25  receiving_air_yards          11357 non-null  int64
#  26  air_yards_share              11357 non-null  float64
#  27  target_share                 11357 non-null  float64
#  28  game_id                      11357 non-null  object
#  29  total_carries                11357 non-null  int64
#  30  carry_share                  11357 non-null  float64
#  31  in_10_share                  3284 non-null   float64
# dtypes: float64(4), int64(22), object(6)
# memory usage: 2.8+ MB

# %% [markdown]
# # A lot of missing in_10_share variables
# At first glance it seems like there are too many nulls in the in_10_share column, which is the percentage of plays inside the 10-yard-line that each player gets the ball. But maybe it is plausible. After all, in those goal-line situations only the best players are called upon. We'll replace with zero and investigate further when we examine the data.

# %%
flex_merge.fillna(value={'in_10_share': 0}, inplace=True)

# %% [markdown]
# Let's rename flex_merge flex_df so we can run the following code

# %%
flex_df = flex_merge

# %% [markdown]
# # Fantasy points
# This is where we calculate FanDuel and DraftKings points.

# %%
flex_df['FD_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 0.5)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost'] * 2) - (flex_df['receiving_fumbles_lost'] * 2)\
- (flex_df['rushing_fumbles_lost'] * 2)

# %%
flex_df['DK_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 1)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost']) - (flex_df['receiving_fumbles_lost'])\
- (flex_df['rushing_fumbles_lost'])

# %% [markdown]
# Adding DraftKings bonus points

# %%
flex_df['DK_Pts'] = np.where(flex_df['passing_yards'] >= 300, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['receiving_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['rushing_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])

# %%
flex_df.tail()
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 11352    2024     6         WAS           BAL  00-0033955    Jeremy McNichols
# 11353    2024     6         WAS           BAL  00-0035208   Olamide Zaccheaus
# 11354    2024     6         WAS           BAL  00-0035659      Terry McLaurin
# 11355    2024     6         WAS           BAL  00-0036626         Dyami Brown
# 11356    2024     6         WAS           BAL  00-0039355      Luke McCaffrey
#
#       position  passing_yards  passing_tds  interceptions  ...  \
# 11352       RB              0            0              0  ...
# 11353       WR              0            0              0  ...
# 11354       WR              0            0              0  ...
# 11355       WR              0            0              0  ...
# 11356       WR              0            0              0  ...
#
#        receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 11352                            0                    0         0.000000
# 11353                           14                   33         0.125954
# 11354                            1                   81         0.309160
# 11355                           12                   -1        -0.003817
# 11356                            0                    5         0.019084
#
#        target_share          game_id  total_carries  carry_share  in_10_share  \
# 11352      0.000000  2024_06_WAS_BAL             18        0.111          0.0
# 11353      0.181818  2024_06_WAS_BAL             18        0.000          0.0
# 11354      0.212121  2024_06_WAS_BAL             18        0.056          0.4
# 11355      0.030303  2024_06_WAS_BAL             18        0.000          0.0
# 11356      0.030303  2024_06_WAS_BAL             18        0.000          0.2
#
#        FD_Pts  DK_Pts
# 11352     0.9     0.9
# 11353     4.7     6.7
# 11354    20.3    23.3
# 11355     1.6     2.1
# 11356     1.0     1.5
#
# [5 rows x 34 columns]

# %% [markdown]
# # Storing last week's points to evaluate model

# %%
flex_points_last_week = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week - 1)]\
[['season', 'week', 'player_display_name', 'recent_team', 'opponent_team', 'position', 'FD_Pts', 'DK_Pts']]

# %%
flex_points_last_week.to_csv('flex_target_' + str(season) + '_' + str(week - 1) + '.csv')

# %%
flex_df['position'].value_counts()
# Out:
# position
# WR    5283
# RB    3294
# TE    2582
# FB     198
# Name: count, dtype: int64

# %%
flex_df['position'] = np.where(flex_df['position'].isin(['HB', 'FB']), 'RB', flex_df['position'])

# %%
pos_mean_by_team = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position']).size().reset_index(name = 'num_players')

# %%
mean_by_pos = pos_mean_by_team.groupby('position')['num_players'].agg(['mean', 'max', 'min'])

# %%
mean_by_pos
# Out:
#               mean  max  min
# position
# RB        2.641452    5    1
# TE        1.966489    4    1
# WR        3.996218    7    2

# %% [markdown]
# # Grouping points allowed by position
# First step in deriving DvP variables.

# %%
grouped_pts = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position'])[['DK_Pts', 'FD_Pts']].sum().round(3)

# %%
grouped_pts
# Out:
#                                                 DK_Pts  FD_Pts
# season week recent_team opponent_team position
# 2022   1    ARI         KC            RB          25.6    21.6
#                                       TE          11.4    10.4
#                                       WR          32.9    25.9
#             ATL         NO            RB          28.3    23.3
#                                       TE           7.0     5.0
# ...                                                ...     ...
# 2024   6    TEN         IND           TE           4.8     2.8
#                                       WR          25.1    20.6
#             WAS         BAL           RB          11.7     9.7
#                                       TE          10.8     8.8
#                                       WR          43.4    35.4
#
# [3957 rows x 2 columns]

# %%
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts = grouped_pts.sort_values(by = ['opponent_team', 'season', 'week'])
#grouped_pts['opp_game_num'] = grouped_pts.groupby(['opponent_team', 'season', 'week', 'recent_team']).cumcount() + 1
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts_raw = grouped_pts.copy()

# %%
grouped_pts.drop(columns = ['index'], inplace = True)

# %%
grouped_pts
# Out:
#       season  week recent_team opponent_team position  DK_Pts  FD_Pts
# 0       2022     1          KC           ARI       RB    42.5    39.5
# 1       2022     1          KC           ARI       TE    38.2    30.2
# 2       2022     1          KC           ARI       WR    35.6    27.6
# 3       2022     2          LV           ARI       RB    12.6    11.6
# 4       2022     2          LV           ARI       TE    23.0    18.5
# ...      ...   ...         ...           ...      ...     ...     ...
# 3952    2024     5         CLE           WAS       TE    13.6    11.6
# 3953    2024     5         CLE           WAS       WR    16.7    12.7
# 3954    2024     6         BAL           WAS       RB    29.6    26.1
# 3955    2024     6         BAL           WAS       TE    20.3    17.8
# 3956    2024     6         BAL           WAS       WR    40.0    30.0
#
# [3957 rows x 7 columns]

# %%
# Create the pivot table
pivot_df = grouped_pts.pivot_table(
    index=['season', 'week', 'recent_team', 'opponent_team'],
    columns='position',
    values=['DK_Pts', 'FD_Pts'],
    aggfunc='sum',  # Assuming you want to sum the points if there are duplicates
    fill_value=0  # Fill missing values with 0
)

# %%
# Flatten the MultiIndex columns created by pivot_table
pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]

# %%
# Reset the index to turn the pivot table back into a DataFrame
pivot_df.reset_index(inplace=True)

# %%
pivot_df.head()
# Out:
#    season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 0    2022     1         ARI            KC       25.6       11.4       32.9
# 1    2022     1         ATL            NO       28.3        7.0       27.1
# 2    2022     1         BAL           NYJ       11.5       10.2       39.2
# 3    2022     1         BUF           LAR       16.0        1.5       63.7
# 4    2022     1         CAR           CLE       16.5        8.4       34.4
#
#    FD_Pts_RB  FD_Pts_TE  FD_Pts_WR
# 0       21.6       10.4       25.9
# 1       23.3        5.0       20.1
# 2        9.5        7.7       35.2
# 3       10.0        1.0       52.2
# 4       14.5        6.9       26.9

# %%
pivot_df = pivot_df.sort_values(by = ['opponent_team', 'season', 'week'])

# %% [markdown]
# # Bringing in current week's FanDuel and DraftKings rows here
# We're basically cloning this notebook from model training. We need features that apply to the current NFL week. We're trying the **one extra row** concept. For now we can probably add one row for each team, with the season value being 2024 and the week value being 1.

# %%
# Connect to the SQLite database
conn = sqlite3.connect('nfl_dfs.db')

# query_flex = "SELECT * FROM flex_dataset"
# #query_weekly = "SELECT * FROM weekly_data"
# query_fd_spread = "SELECT * FROM fd_spreads"
# query_dk_spread = "SELECT * FROM dk_spreads"
query_qb_model = "SELECT * FROM fd_qb_model_ready"
# # query_pbp = "S#ELECT * FROM pbp_non_defense"
query_fd = "SELECT * FROM fd_table"
query_dk = "SELECT * FROM dk_table"
#query_rb_wr_te = "SELECT * FROM rb_wr_te_data WHERE season >= 2022"

# flex_dataset = pd.read_sql_query(query_flex, conn)
# #weekly_df = pd.read_sql_query(query_weekly, conn)
# fd_spreads = pd.read_sql_query(query_fd_spread, conn)
# dk_spreads = pd.read_sql_query(query_dk_spread, conn)
# #pbp_df = pd.read_sql_query(query_pbp, conn)
fd_table = pd.read_sql_query(query_fd, conn)
dk_table = pd.read_sql_query(query_dk, conn)
qb_model = pd.read_sql_query(query_qb_model, conn)
# rb_wr_te_df = pd.read_sql_query(query_rb_wr_te, conn)

# Close the database connection
conn.close()

# %%
fanduel_df.head()
# Out:
#               ID              name position  salary team opponent  home_team  \
# 0   108151-85671  Justin Jefferson       WR    9400  MIN      DET          1
# 1   108151-85701     Ja'Marr Chase       WR    9300  CIN      CLE          0
# 2   108151-62239        Josh Allen       QB    9200  BUF      TEN          1
# 3  108151-102785    Jayden Daniels       QB    9100  WAS      CAR          1
# 4   108151-64401    Saquon Barkley       RB    9000  PHI      NYG          0
#
#    status        date  week
# 0  Active  10-20-2024     7
# 1  Active  10-20-2024     7
# 2  Active  10-20-2024     7
# 3  Active  10-20-2024     7
# 4  Active  10-20-2024     7

# %%
draftkings_df.head()
# Out:
#          ID              name position  salary team opponent  home_team  \
# 0  36291011  Justin Jefferson       WR    8500  MIN      DET          1
# 1  36291013     Ja'Marr Chase       WR    8400  CIN      CLE          0
# 2  36291015  Amon-Ra St Brown       WR    8300  DET      MIN          0
# 3  36290791    Saquon Barkley       RB    8200  PHI      NYG          0
# 4  36290793    Kyren Williams       RB    8100  LAR       LV          1
#
#    status        date  week
# 0  Active  10-20-2024     7
# 1  Active  10-20-2024     7
# 2  Active  10-20-2024     7
# 3  Active  10-20-2024     7
# 4  Active  10-20-2024     7

# %%
# Initialize empty lists for teams and opponents
#We'll use FanDuel here because they tend to list more players than DK and we're less likely to miss anyone.
team_list = []
opponent_list = []

# Initialize a set to keep track of already added matchups
added_matchups = set()

# Loop through each row in the dataframe
for index, row in fanduel_df.iterrows():
    team = row['team']
    opponent = row['opponent']
    
    # Ensure each team and opponent are added only once in reverse order as well
    if (team, opponent) not in added_matchups and (opponent, team) not in added_matchups:
        # Add the matchup as-is
        team_list.append(team)
        opponent_list.append(opponent)
        
        # Add the reverse matchup
        team_list.append(opponent)
        opponent_list.append(team)
        
        # Track the added matchups
        added_matchups.add((team, opponent))
        added_matchups.add((opponent, team))

# Display the resulting lists
print("Team list:", team_list)
print("Opponent list:", opponent_list)
# Out:
# Team list: ['MIN', 'DET', 'CIN', 'CLE', 'BUF', 'TEN', 'WAS', 'CAR', 'PHI', 'NYG', 'SF', 'KC', 'GB', 'HOU', 'LAR', 'LV', 'IND', 'MIA', 'ATL', 'SEA', 'NYJ', 'PIT']
# Opponent list: ['DET', 'MIN', 'CLE', 'CIN', 'TEN', 'BUF', 'CAR', 'WAS', 'NYG', 'PHI', 'KC', 'SF', 'HOU', 'GB', 'LV', 'LAR', 'MIA', 'IND', 'SEA', 'ATL', 'PIT', 'NYJ']

# %%
len(team_list), len(opponent_list)
# Out:
# (22, 22)

# %%
append_to_pivot = {'season': [season] * len(team_list), 'week': [week] * len(team_list), 'recent_team': team_list, 'opponent_team': opponent_list}

# %%
append_to_pivot = pd.DataFrame(append_to_pivot)

# %%
pivot_df = pd.concat([pivot_df, append_to_pivot], axis = 0)

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1344 entries, 15 to 21
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1344 non-null   int64
#  1   week           1344 non-null   int64
#  2   recent_team    1344 non-null   object
#  3   opponent_team  1344 non-null   object
#  4   DK_Pts_RB      1322 non-null   float64
#  5   DK_Pts_TE      1322 non-null   float64
#  6   DK_Pts_WR      1322 non-null   float64
#  7   FD_Pts_RB      1322 non-null   float64
#  8   FD_Pts_TE      1322 non-null   float64
#  9   FD_Pts_WR      1322 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 115.5+ KB

# %%
pivot_df['opp_game_num'] = pivot_df.groupby(['opponent_team']).cumcount() + 1

# %%
cols_for_dvp = ['DK_Pts_RB', 'DK_Pts_TE', 'DK_Pts_WR', 'FD_Pts_RB', 'FD_Pts_TE', 'FD_Pts_WR']

# %%
pivot_df_by_game = pivot_df.copy()

# %%
pivot_df.head()
# Out:
#      season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 15     2022     1          KC           ARI       42.5       38.2       35.6
# 50     2022     2          LV           ARI       12.6       23.0       32.7
# 81     2022     3         LAR           ARI       12.8       13.9       37.0
# 100    2022     4         CAR           ARI       26.0        8.0       17.7
# 153    2022     5         PHI           ARI       10.4       17.5       29.8
#
#      FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 15        39.5       30.2       27.6             1
# 50        11.6       18.5       24.7             2
# 81        11.8       11.4       30.5             3
# 100       21.5        6.0       13.2             4
# 153        9.4       13.5       21.8             5

# %%
pivot_df.tail()
# Out:
#     season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 17    2024     7         MIA           IND        NaN        NaN        NaN
# 18    2024     7         ATL           SEA        NaN        NaN        NaN
# 19    2024     7         SEA           ATL        NaN        NaN        NaN
# 20    2024     7         NYJ           PIT        NaN        NaN        NaN
# 21    2024     7         PIT           NYJ        NaN        NaN        NaN
#
#     FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 17        NaN        NaN        NaN            41
# 18        NaN        NaN        NaN            42
# 19        NaN        NaN        NaN            41
# 20        NaN        NaN        NaN            42
# 21        NaN        NaN        NaN            41

# %%
pivot_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # DvP variables
# We'll take an 8-game rolling mean for fantasy points allowed to RBs, WRs and TEs for each team, even if the games go back to last season. DvP means defense vs. position.

# %%
def calculate_equal_rolling_mean(group, cols, suffix):
    """
    This function calculates a rolling mean for the last eight games, going back to previous season if necessary.
    It also calculates when there are less than eight games to use.
    """
    for col in cols:
        group[f'{col}{suffix}'] = (
            group[col].shift().rolling(window=8, min_periods=1).mean()
        )
    return group

# %%
pivot_df = pivot_df.groupby('opponent_team', as_index = False).apply(calculate_equal_rolling_mean, cols=cols_for_dvp, suffix = '_DvP')

# %%
pivot_df.drop(columns = cols_for_dvp + ['opp_game_num'], inplace = True)

# %%
pivot_df
# Out:
#          season  week recent_team opponent_team  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0  15      2022     1          KC           ARI            NaN            NaN
#    50      2022     2          LV           ARI      42.500000      38.200000
#    81      2022     3         LAR           ARI      27.550000      30.600000
#    100     2022     4         CAR           ARI      22.633333      25.033333
#    153     2022     5         PHI           ARI      23.475000      20.775000
# ...         ...   ...         ...           ...            ...            ...
# 31 1208    2024     3         CIN           WAS      31.725000       6.537500
#    1234    2024     4         ARI           WAS      31.437500       7.562500
#    1273    2024     5         CLE           WAS      30.250000       7.425000
#    1296    2024     6         BAL           WAS      28.250000       7.875000
#    7       2024     7         CAR           WAS      26.025000       9.462500
#
#          DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0  15              NaN            NaN            NaN            NaN
#    50          35.6000      39.500000      30.200000        27.6000
#    81          34.1500      25.550000      24.350000        26.1500
#    100         35.1000      20.966667      20.033333        27.6000
#    153         30.7500      21.100000      16.525000        24.0000
# ...                ...            ...            ...            ...
# 31 1208        50.0000      27.850000       5.037500        41.3125
#    1234        49.8000      27.562500       5.687500        40.6750
#    1273        47.3000      26.187500       5.550000        38.4250
#    1296        42.7500      24.875000       6.062500        34.6875
#    7           44.4625      22.962500       7.587500        35.8375
#
# [1344 rows x 10 columns]

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1344 entries, (0, 15) to (31, 7)
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1344 non-null   int64
#  1   week           1344 non-null   int64
#  2   recent_team    1344 non-null   object
#  3   opponent_team  1344 non-null   object
#  4   DK_Pts_RB_DvP  1312 non-null   float64
#  5   DK_Pts_TE_DvP  1312 non-null   float64
#  6   DK_Pts_WR_DvP  1312 non-null   float64
#  7   FD_Pts_RB_DvP  1312 non-null   float64
#  8   FD_Pts_TE_DvP  1312 non-null   float64
#  9   FD_Pts_WR_DvP  1312 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 152.9+ KB

# %%
flex_df.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  \
# 0       WR              0            0              0  ...
# 1       TE              0            0              0  ...
# 2       RB              0            0              0  ...
# 3       WR              0            0              0  ...
# 4       WR              0            0              0  ...
#
#    receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 0                            0                   42         0.157895
# 1                            4                   22         0.082707
# 2                           38                    7         0.026316
# 3                           31                   62         0.233083
# 4                            4                   30         0.112782
#
#    target_share         game_id  total_carries  carry_share  in_10_share  \
# 0      0.111111  2022_01_KC_ARI             21        0.000        0.143
# 1      0.111111  2022_01_KC_ARI             21        0.000        0.429
# 2      0.166667  2022_01_KC_ARI             21        0.476        0.286
# 3      0.250000  2022_01_KC_ARI             21        0.000        0.000
# 4      0.083333  2022_01_KC_ARI             21        0.000        0.000
#
#    FD_Pts  DK_Pts
# 0     2.3     3.3
# 1    10.4    11.4
# 2    14.0    16.5
# 3     9.8    13.3
# 4     1.5     2.0
#
# [5 rows x 34 columns]

# %%
flex_df = flex_df.merge(
    pivot_df, 
    on=['season', 'week', 'recent_team', 'opponent_team'],  # common columns to merge on
    how='outer'  # outer join to keep all rows from both dataframes
)

# %%
flex_df.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 11349    2024     6         WAS           BAL  00-0030061           Zach Ertz
# 11350    2024     6         WAS           BAL  00-0033591          Noah Brown
# 11351    2024     6         WAS           BAL  00-0033699       Austin Ekeler
# 11352    2024     6         WAS           BAL  00-0033955    Jeremy McNichols
# 11353    2024     6         WAS           BAL  00-0035208   Olamide Zaccheaus
# 11354    2024     6         WAS           BAL  00-0035659      Terry McLaurin
# 11355    2024     6         WAS           BAL  00-0036626         Dyami Brown
# 11356    2024     6         WAS           BAL  00-0039355      Luke McCaffrey
# 11357    2024     7         SEA           ATL         NaN                 NaN
# 11358    2024     7         TEN           BUF         NaN                 NaN
# 11359    2024     7         WAS           CAR         NaN                 NaN
# 11360    2024     7         CLE           CIN         NaN                 NaN
# 11361    2024     7         CIN           CLE         NaN                 NaN
# 11362    2024     7         MIN           DET         NaN                 NaN
# 11363    2024     7         HOU            GB         NaN                 NaN
# 11364    2024     7          GB           HOU         NaN                 NaN
# 11365    2024     7         MIA           IND         NaN                 NaN
# 11366    2024     7          SF            KC         NaN                 NaN
# 11367    2024     7          LV           LAR         NaN                 NaN
# 11368    2024     7         LAR            LV         NaN                 NaN
# 11369    2024     7         IND           MIA         NaN                 NaN
# 11370    2024     7         DET           MIN         NaN                 NaN
# 11371    2024     7         PHI           NYG         NaN                 NaN
# 11372    2024     7         PIT           NYJ         NaN                 NaN
# 11373    2024     7         NYG           PHI         NaN                 NaN
# 11374    2024     7         NYJ           PIT         NaN                 NaN
# 11375    2024     7         ATL           SEA         NaN                 NaN
# 11376    2024     7          KC            SF         NaN                 NaN
# 11377    2024     7         BUF           TEN         NaN                 NaN
# 11378    2024     7         CAR           WAS         NaN                 NaN
#
#       position  passing_yards  passing_tds  interceptions  ...  carry_share  \
# 11349       TE            0.0          0.0            0.0  ...        0.000
# 11350       WR            0.0          0.0            0.0  ...        0.000
# 11351       RB            0.0          0.0            0.0  ...        0.500
# 11352       RB            0.0          0.0            0.0  ...        0.111
# 11353       WR            0.0          0.0            0.0  ...        0.000
# 11354       WR            0.0          0.0            0.0  ...        0.056
# 11355       WR            0.0          0.0            0.0  ...        0.000
# 11356       WR            0.0          0.0            0.0  ...        0.000
# 11357      NaN            NaN          NaN            NaN  ...          NaN
# 11358      NaN            NaN          NaN            NaN  ...          NaN
# 11359      NaN            NaN          NaN            NaN  ...          NaN
# 11360      NaN            NaN          NaN            NaN  ...          NaN
# 11361      NaN            NaN          NaN            NaN  ...          NaN
# 11362      NaN            NaN          NaN            NaN  ...          NaN
# 11363      NaN            NaN          NaN            NaN  ...          NaN
# 11364      NaN            NaN          NaN            NaN  ...          NaN
# 11365      NaN            NaN          NaN            NaN  ...          NaN
# 11366      NaN            NaN          NaN            NaN  ...          NaN
# 11367      NaN            NaN          NaN            NaN  ...          NaN
# 11368      NaN            NaN          NaN            NaN  ...          NaN
# 11369      NaN            NaN          NaN            NaN  ...          NaN
# 11370      NaN            NaN          NaN            NaN  ...          NaN
# 11371      NaN            NaN          NaN            NaN  ...          NaN
# 11372      NaN            NaN          NaN            NaN  ...          NaN
# 11373      NaN            NaN          NaN            NaN  ...          NaN
# 11374      NaN            NaN          NaN            NaN  ...          NaN
# 11375      NaN            NaN          NaN            NaN  ...          NaN
# 11376      NaN            NaN          NaN            NaN  ...          NaN
# 11377      NaN            NaN          NaN            NaN  ...          NaN
# 11378      NaN            NaN          NaN            NaN  ...          NaN
#
#        in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 11349          0.0     8.8    10.8        20.2625        15.0625
# 11350          0.2     7.8     9.8        20.2625        15.0625
# 11351          0.2     8.8    10.8        20.2625        15.0625
# 11352          0.0     0.9     0.9        20.2625        15.0625
# 11353          0.0     4.7     6.7        20.2625        15.0625
# 11354          0.4    20.3    23.3        20.2625        15.0625
# 11355          0.0     1.6     2.1        20.2625        15.0625
# 11356          0.2     1.0     1.5        20.2625        15.0625
# 11357          NaN     NaN     NaN        22.0625         8.2500
# 11358          NaN     NaN     NaN        28.8625        12.3625
# 11359          NaN     NaN     NaN        32.2375        11.4625
# 11360          NaN     NaN     NaN        24.0250        10.8375
# 11361          NaN     NaN     NaN        21.3750         9.5375
# 11362          NaN     NaN     NaN        20.5500         7.9500
# 11363          NaN     NaN     NaN        25.1500        17.5250
# 11364          NaN     NaN     NaN        18.9375         9.9375
# 11365          NaN     NaN     NaN        24.5250        12.1500
# 11366          NaN     NaN     NaN        18.1625        14.1625
# 11367          NaN     NaN     NaN        24.5500        12.4875
# 11368          NaN     NaN     NaN        27.4625         8.2625
# 11369          NaN     NaN     NaN        27.4250        13.3625
# 11370          NaN     NaN     NaN        20.3125        12.6250
# 11371          NaN     NaN     NaN        20.5625         8.8250
# 11372          NaN     NaN     NaN        21.5750         9.7750
# 11373          NaN     NaN     NaN        23.3625         9.4125
# 11374          NaN     NaN     NaN        17.4250        14.2500
# 11375          NaN     NaN     NaN        29.2000        13.2875
# 11376          NaN     NaN     NaN        23.2625        12.5000
# 11377          NaN     NaN     NaN        16.6000         9.2125
# 11378          NaN     NaN     NaN        26.0250         9.4625
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 11349        35.7500        17.0125        11.2500        28.8125
# 11350        35.7500        17.0125        11.2500        28.8125
# 11351        35.7500        17.0125        11.2500        28.8125
# 11352        35.7500        17.0125        11.2500        28.8125
# 11353        35.7500        17.0125        11.2500        28.8125
# 11354        35.7500        17.0125        11.2500        28.8125
# 11355        35.7500        17.0125        11.2500        28.8125
# 11356        35.7500        17.0125        11.2500        28.8125
# 11357        38.4250        19.0625         6.1875        31.1750
# 11358        29.0125        25.1750         9.6750        22.7625
# 11359        31.6375        29.1750         9.0875        25.6375
# 11360        31.9500        20.4625         8.6500        25.3875
# 11361        37.1750        19.3125         7.9125        30.6125
# 11362        46.5750        18.3625         6.3875        35.5125
# 11363        35.8250        20.9000        14.2750        28.3250
# 11364        32.1500        16.6250         7.9375        26.4625
# 11365        40.4375        20.9625         9.4000        31.4375
# 11366        29.9925        15.4125        10.7250        24.3050
# 11367        37.4625        22.2375        10.3625        30.0250
# 11368        29.8125        23.2750         6.4500        24.5625
# 11369        31.4875        25.2375        10.8625        24.7375
# 11370        49.5275        17.5625         9.7500        38.4025
# 11371        35.3625        17.8125         6.5125        28.0500
# 11372        22.6500        18.7000         7.2125        18.6500
# 11373        41.0375        21.1750         6.9750        34.3500
# 11374        27.4000        14.5500        11.5625        22.0250
# 11375        30.7725        25.6375        10.4125        24.3350
# 11376        34.6250        19.8250         9.6250        28.7500
# 11377        29.6875        14.7250         7.2750        23.1875
# 11378        44.4625        22.9625         7.5875        35.8375
#
# [30 rows x 40 columns]

# %%
flex_df.reset_index(inplace = True)

# %%
flex_df.columns
# Out:
# Index(['index', 'season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'passing_yards', 'passing_tds',
#        'interceptions', 'passing_2pt_conversions', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions',
#        'receptions', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles_lost', 'receiving_2pt_conversions',
#        'sack_fumbles_lost', 'special_teams_tds', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'game_id', 'total_carries', 'carry_share',
#        'in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
#        'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # Paring down some of the columns
# We're drop columns that won't be needed for features.

# %%
cols_to_keep = ['season', 'week', 'recent_team', 'opponent_team', 'player_id',
       'player_display_name', 'position', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 
       'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
       'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share','in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
       'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']

# %%
flex_df = flex_df[cols_to_keep]

# %%
#quarterback_df[quarterback_df['season'] >= 2006]['passing_air_yards']

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11379 entries, 0 to 11378
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       11379 non-null  int64
#  1   week                         11379 non-null  int64
#  2   recent_team                  11379 non-null  object
#  3   opponent_team                11379 non-null  object
#  4   player_id                    11357 non-null  object
#  5   player_display_name          11357 non-null  object
#  6   position                     11357 non-null  object
#  7   rushing_yards                11357 non-null  float64
#  8   rushing_tds                  11357 non-null  float64
#  9   rushing_fumbles_lost         11357 non-null  float64
#  10  receptions                   11357 non-null  float64
#  11  receiving_yards              11357 non-null  float64
#  12  receiving_tds                11357 non-null  float64
#  13  receiving_fumbles_lost       11357 non-null  float64
#  14  targets                      11357 non-null  float64
#  15  carries                      11357 non-null  float64
#  16  receiving_yards_after_catch  11357 non-null  float64
#  17  receiving_air_yards          11357 non-null  float64
#  18  air_yards_share              11357 non-null  float64
#  19  target_share                 11357 non-null  float64
#  20  carry_share                  11357 non-null  float64
#  21  in_10_share                  11357 non-null  float64
#  22  FD_Pts                       11357 non-null  float64
#  23  DK_Pts                       11357 non-null  float64
#  24  DK_Pts_RB_DvP                11099 non-null  float64
#  25  DK_Pts_TE_DvP                11099 non-null  float64
#  26  DK_Pts_WR_DvP                11099 non-null  float64
#  27  FD_Pts_RB_DvP                11099 non-null  float64
#  28  FD_Pts_TE_DvP                11099 non-null  float64
#  29  FD_Pts_WR_DvP                11099 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.6+ MB

# %% [markdown]
# # Filling missing values
# We have found that dropping rows with missing values can affect calculations down the line. So we need to find ways to fill the missing values.<br>

# %% [markdown]
# The first row of every team grouping when we calculated DvP was NaN because there was no previous value. We'll fill those in with the mean.

# %%
flex_df['FD_Pts_RB_DvP'] = flex_df['FD_Pts_RB_DvP'].fillna(flex_df['FD_Pts_RB_DvP'].mean())
flex_df['DK_Pts_RB_DvP'] = flex_df['DK_Pts_RB_DvP'].fillna(flex_df['DK_Pts_RB_DvP'].mean())
flex_df['FD_Pts_TE_DvP'] = flex_df['FD_Pts_TE_DvP'].fillna(flex_df['FD_Pts_TE_DvP'].mean())
flex_df['DK_Pts_TE_DvP'] = flex_df['DK_Pts_TE_DvP'].fillna(flex_df['DK_Pts_TE_DvP'].mean())
flex_df['FD_Pts_WR_DvP'] = flex_df['FD_Pts_WR_DvP'].fillna(flex_df['FD_Pts_WR_DvP'].mean())
flex_df['DK_Pts_WR_DvP'] = flex_df['DK_Pts_WR_DvP'].fillna(flex_df['DK_Pts_WR_DvP'].mean())

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11379 entries, 0 to 11378
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       11379 non-null  int64
#  1   week                         11379 non-null  int64
#  2   recent_team                  11379 non-null  object
#  3   opponent_team                11379 non-null  object
#  4   player_id                    11357 non-null  object
#  5   player_display_name          11357 non-null  object
#  6   position                     11357 non-null  object
#  7   rushing_yards                11357 non-null  float64
#  8   rushing_tds                  11357 non-null  float64
#  9   rushing_fumbles_lost         11357 non-null  float64
#  10  receptions                   11357 non-null  float64
#  11  receiving_yards              11357 non-null  float64
#  12  receiving_tds                11357 non-null  float64
#  13  receiving_fumbles_lost       11357 non-null  float64
#  14  targets                      11357 non-null  float64
#  15  carries                      11357 non-null  float64
#  16  receiving_yards_after_catch  11357 non-null  float64
#  17  receiving_air_yards          11357 non-null  float64
#  18  air_yards_share              11357 non-null  float64
#  19  target_share                 11357 non-null  float64
#  20  carry_share                  11357 non-null  float64
#  21  in_10_share                  11357 non-null  float64
#  22  FD_Pts                       11357 non-null  float64
#  23  DK_Pts                       11357 non-null  float64
#  24  DK_Pts_RB_DvP                11379 non-null  float64
#  25  DK_Pts_TE_DvP                11379 non-null  float64
#  26  DK_Pts_WR_DvP                11379 non-null  float64
#  27  FD_Pts_RB_DvP                11379 non-null  float64
#  28  FD_Pts_TE_DvP                11379 non-null  float64
#  29  FD_Pts_WR_DvP                11379 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.6+ MB

# %%
flex_24 = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_24.head()
# Out:
#        season  week recent_team opponent_team player_id player_display_name  \
# 11357    2024     7         SEA           ATL       NaN                 NaN
# 11358    2024     7         TEN           BUF       NaN                 NaN
# 11359    2024     7         WAS           CAR       NaN                 NaN
# 11360    2024     7         CLE           CIN       NaN                 NaN
# 11361    2024     7         CIN           CLE       NaN                 NaN
#
#       position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 11357      NaN            NaN          NaN                   NaN  ...
# 11358      NaN            NaN          NaN                   NaN  ...
# 11359      NaN            NaN          NaN                   NaN  ...
# 11360      NaN            NaN          NaN                   NaN  ...
# 11361      NaN            NaN          NaN                   NaN  ...
#
#        carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 11357          NaN          NaN     NaN     NaN        22.0625         8.2500
# 11358          NaN          NaN     NaN     NaN        28.8625        12.3625
# 11359          NaN          NaN     NaN     NaN        32.2375        11.4625
# 11360          NaN          NaN     NaN     NaN        24.0250        10.8375
# 11361          NaN          NaN     NaN     NaN        21.3750         9.5375
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 11357        38.4250        19.0625         6.1875        31.1750
# 11358        29.0125        25.1750         9.6750        22.7625
# 11359        31.6375        29.1750         9.0875        25.6375
# 11360        31.9500        20.4625         8.6500        25.3875
# 11361        37.1750        19.3125         7.9125        30.6125
#
# [5 rows x 30 columns]

# %%
fd_flex = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
dk_flex = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
fd_names = set(list(fd_flex['name'].unique()))
dk_names = set(list(dk_flex['name'].unique()))

# %%
# Initialize empty lists for names, positions, teams, and opponents
name_list = []
position_list = []
team_list = []
opponent_list = []

# Loop through the dataframe to extract names, positions, teams, and opponents
for index, row in fd_flex.iterrows():
    name_list.append(row['name'])          # Add player name to name_list
    position_list.append(row['position'])  # Add player position to position_list
    team_list.append(row['team'])          # Add player's team to team_list
    opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# dk_name_list = []
# dk_position_list = []
# dk_team_list = []
# dk_opponent_list = []

# for index, row in dk_flex.iterrows():
#     dk_name_list.append(row['name'])          # Add player name to name_list
#     dk_position_list.append(row['position'])  # Add player position to position_list
#     dk_team_list.append(row['team'])          # Add player's team to team_list
#     dk_opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# Display the resulting lists
# print("Name list:", name_list)
# print("Position list:", position_list)
# print("Team list:", team_list)
# print("Opponent list:", opponent_list)

# %%
len(name_list), len(position_list)
# Out:
# (606, 606)

# %%
to_concat = {'season': [season] * len(name_list), 'week': [week] * len(name_list), 'player_display_name': name_list, 'position': position_list,\
            'recent_team': team_list, 'opponent_team': opponent_list}

# %%
to_concat = pd.DataFrame(to_concat)

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team
# 0      2024     7    Justin Jefferson       WR         MIN           DET
# 1      2024     7       Ja'Marr Chase       WR         CIN           CLE
# 2      2024     7      Saquon Barkley       RB         PHI           NYG
# 3      2024     7            AJ Brown       WR         PHI           NYG
# 4      2024     7        Jordan Mason       RB          SF            KC
# ..      ...   ...                 ...      ...         ...           ...
# 601    2024     7      Jesper Horsted       TE         CAR           WAS
# 602    2024     7        Dalton Keene       TE         HOU            GB
# 603    2024     7        Jody Fortson       TE          KC            SF
# 604    2024     7      Tre'Quan Smith       WR         DET           MIN
# 605    2024     7           Nick Muse       TE         MIN           DET
#
# [606 rows x 6 columns]

# %%
to_concat['recent_team'].value_counts()
# Out:
# recent_team
# KC     32
# CAR    32
# GB     31
# MIA    31
# MIN    30
# PIT    30
# NYJ    29
# PHI    28
# IND    28
# ATL    28
# SEA    28
# SF     27
# NYG    27
# CLE    26
# BUF    26
# CIN    26
# HOU    26
# TEN    25
# WAS    25
# LV     24
# DET    24
# LAR    23
# Name: count, dtype: int64

# %%
flex_24.columns
# Out:
# Index(['season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'rushing_yards', 'rushing_tds',
#        'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'FD_Pts', 'DK_Pts',
#        'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
#        'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_24 = flex_24[['season', 'week', 'recent_team', 'opponent_team', 
       'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']]

# %%
to_concat = pd.merge(to_concat, flex_24, on = ['season', 'week', 'recent_team', 'opponent_team'])

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team  \
# 0      2024     7    Justin Jefferson       WR         MIN           DET
# 1      2024     7         Aaron Jones       RB         MIN           DET
# 2      2024     7         Ty Chandler       RB         MIN           DET
# 3      2024     7      Jordan Addison       WR         MIN           DET
# 4      2024     7        TJ Hockenson       TE         MIN           DET
# ..      ...   ...                 ...      ...         ...           ...
# 601    2024     7        James Proche       WR         CLE           CIN
# 602    2024     7       Aidan Robbins       RB         CLE           CIN
# 603    2024     7       Michael Woods       WR         CLE           CIN
# 604    2024     7       Jaelon Darden       WR         CLE           CIN
# 605    2024     7      Giovanni Ricci       TE         CLE           CIN
#
#      DK_Pts_RB_DvP  DK_Pts_TE_DvP  DK_Pts_WR_DvP  FD_Pts_RB_DvP  \
# 0           20.550         7.9500         46.575        18.3625
# 1           20.550         7.9500         46.575        18.3625
# 2           20.550         7.9500         46.575        18.3625
# 3           20.550         7.9500         46.575        18.3625
# 4           20.550         7.9500         46.575        18.3625
# ..             ...            ...            ...            ...
# 601         24.025        10.8375         31.950        20.4625
# 602         24.025        10.8375         31.950        20.4625
# 603         24.025        10.8375         31.950        20.4625
# 604         24.025        10.8375         31.950        20.4625
# 605         24.025        10.8375         31.950        20.4625
#
#      FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0           6.3875        35.5125
# 1           6.3875        35.5125
# 2           6.3875        35.5125
# 3           6.3875        35.5125
# 4           6.3875        35.5125
# ..             ...            ...
# 601         8.6500        25.3875
# 602         8.6500        25.3875
# 603         8.6500        25.3875
# 604         8.6500        25.3875
# 605         8.6500        25.3875
#
# [606 rows x 12 columns]

# %%
to_concat['opponent_team'].value_counts()
# Out:
# opponent_team
# SF     32
# WAS    32
# HOU    31
# IND    31
# DET    30
# NYJ    30
# PIT    29
# NYG    28
# MIA    28
# SEA    28
# ATL    28
# KC     27
# PHI    27
# CIN    26
# TEN    26
# CLE    26
# GB     26
# BUF    25
# CAR    25
# LAR    24
# MIN    24
# LV     23
# Name: count, dtype: int64

# %%
flex_df = flex_df[~((flex_df['season'] == season) & (flex_df['week'] == week))]

# %%
flex_df = pd.concat([flex_df, to_concat], axis = 0)

# %%
flex_df
# Out:
#      season  week recent_team opponent_team   player_id player_display_name  \
# 0      2022     1         ARI            KC  00-0027942          A.J. Green
# 1      2022     1         ARI            KC  00-0030061           Zach Ertz
# 2      2022     1         ARI            KC  00-0033553        James Conner
# 3      2022     1         ARI            KC  00-0035500         Greg Dortch
# 4      2022     1         ARI            KC  00-0035527       Andy Isabella
# ..      ...   ...         ...           ...         ...                 ...
# 601    2024     7         CLE           CIN         NaN        James Proche
# 602    2024     7         CLE           CIN         NaN       Aidan Robbins
# 603    2024     7         CLE           CIN         NaN       Michael Woods
# 604    2024     7         CLE           CIN         NaN       Jaelon Darden
# 605    2024     7         CLE           CIN         NaN      Giovanni Ricci
#
#     position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 0         WR            0.0          0.0                   0.0  ...
# 1         TE            0.0          0.0                   0.0  ...
# 2         RB           26.0          1.0                   0.0  ...
# 3         WR            0.0          0.0                   0.0  ...
# 4         WR            0.0          0.0                   0.0  ...
# ..       ...            ...          ...                   ...  ...
# 601       WR            NaN          NaN                   NaN  ...
# 602       RB            NaN          NaN                   NaN  ...
# 603       WR            NaN          NaN                   NaN  ...
# 604       WR            NaN          NaN                   NaN  ...
# 605       TE            NaN          NaN                   NaN  ...
#
#      carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0          0.000        0.143     2.3     3.3      22.721614      11.878494
# 1          0.000        0.429    10.4    11.4      22.721614      11.878494
# 2          0.476        0.286    14.0    16.5      22.721614      11.878494
# 3          0.000        0.000     9.8    13.3      22.721614      11.878494
# 4          0.000        0.000     1.5     2.0      22.721614      11.878494
# ..           ...          ...     ...     ...            ...            ...
# 601          NaN          NaN     NaN     NaN      24.025000      10.837500
# 602          NaN          NaN     NaN     NaN      24.025000      10.837500
# 603          NaN          NaN     NaN     NaN      24.025000      10.837500
# 604          NaN          NaN     NaN     NaN      24.025000      10.837500
# 605          NaN          NaN     NaN     NaN      24.025000      10.837500
#
#      DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0        34.380093      19.716492       9.384399      27.311969
# 1        34.380093      19.716492       9.384399      27.311969
# 2        34.380093      19.716492       9.384399      27.311969
# 3        34.380093      19.716492       9.384399      27.311969
# 4        34.380093      19.716492       9.384399      27.311969
# ..             ...            ...            ...            ...
# 601      31.950000      20.462500       8.650000      25.387500
# 602      31.950000      20.462500       8.650000      25.387500
# 603      31.950000      20.462500       8.650000      25.387500
# 604      31.950000      20.462500       8.650000      25.387500
# 605      31.950000      20.462500       8.650000      25.387500
#
# [11963 rows x 30 columns]

# %%
cols_L8 = ['rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets',\
           'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share', 'carry_share', 'in_10_share']

# %%
flex_L8_features = flex_df.groupby(['player_display_name', 'season', 'week'])[cols_L8].sum()

# %% [markdown]
# # L8 variables
# L8 variables are rolling means of features over the last eight games. Just like we did for the DvP variables, we'll calculate features over the previous eight games for individual QBs.

# %%
flex_L8_features = flex_L8_features.sort_values(by = ['player_display_name', 'season', 'week'])
flex_L8_features['game_num'] = flex_L8_features.groupby(['player_display_name', 'season']).cumcount() + 1
#quarterback_df.reset_index(drop = True, inplace = True)

# %%
flex_L8_features = flex_L8_features.groupby(['player_display_name'], as_index = False).apply(calculate_equal_rolling_mean, cols=cols_L8, suffix = '_L8')

# %%
flex_L8_features.reset_index(inplace = True)

# %%
flex_L8_features.columns
# Out:
# Index(['level_0', 'player_display_name', 'season', 'week', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'game_num',
#        'rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8',
#        'receptions_L8', 'receiving_yards_L8', 'receiving_tds_L8',
#        'receiving_fumbles_lost_L8', 'targets_L8', 'carries_L8',
#        'receiving_yards_after_catch_L8', 'receiving_air_yards_L8',
#        'air_yards_share_L8', 'target_share_L8', 'carry_share_L8',
#        'in_10_share_L8'],
#       dtype='object')

# %%
flex_L8_features.drop(columns = ['level_0', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
       'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share', 'in_10_share'], inplace = True)

# %%
flex_L8_features
# Out:
#       player_display_name  season  week  game_num  rushing_yards_L8  \
# 0             A.J. Barner    2024     3         1               NaN
# 1             A.J. Barner    2024     4         2          0.000000
# 2             A.J. Barner    2024     5         3          0.000000
# 3             A.J. Barner    2024     6         4          0.000000
# 4              A.J. Brown    2022     1         1               NaN
# ...                   ...     ...   ...       ...               ...
# 11958      Zonovan Knight    2022    17         6         50.200000
# 11959      Zonovan Knight    2022    18         7         46.333333
# 11960      Zonovan Knight    2023     3         1         42.857143
# 11961      Zonovan Knight    2023     5         2         39.125000
# 11962      Zonovan Knight    2024     7         1         30.500000
#
#        rushing_tds_L8  rushing_fumbles_lost_L8  receptions_L8  \
# 0                 NaN                      NaN            NaN
# 1            0.000000                      0.0       3.000000
# 2            0.000000                      0.0       2.500000
# 3            0.000000                      0.0       2.000000
# 4                 NaN                      NaN            NaN
# ...               ...                      ...            ...
# 11958        0.200000                      0.0       2.200000
# 11959        0.166667                      0.0       2.166667
# 11960        0.142857                      0.0       1.857143
# 11961        0.125000                      0.0       1.625000
# 11962        0.125000                      0.0       1.375000
#
#        receiving_yards_L8  receiving_tds_L8  receiving_fumbles_lost_L8  \
# 0                     NaN               NaN                        NaN
# 1               13.000000          0.000000                        0.0
# 2               20.000000          0.500000                        0.0
# 3               17.666667          0.333333                        0.0
# 4                     NaN               NaN                        NaN
# ...                   ...               ...                        ...
# 11958           16.600000          0.000000                        0.0
# 11959           16.666667          0.000000                        0.0
# 11960           14.285714          0.000000                        0.0
# 11961           12.500000          0.000000                        0.0
# 11962            9.250000          0.000000                        0.0
#
#        targets_L8  carries_L8  receiving_yards_after_catch_L8  \
# 0             NaN         NaN                             NaN
# 1        3.000000    0.000000                       11.000000
# 2        2.500000    0.000000                       17.000000
# 3        2.000000    0.000000                       13.333333
# 4             NaN         NaN                             NaN
# ...           ...         ...                             ...
# 11958    2.200000   13.000000                       22.400000
# 11959    2.333333   12.166667                       22.000000
# 11960    2.000000   12.142857                       18.857143
# 11961    1.750000   11.000000                       16.500000
# 11962    1.500000    9.250000                       13.625000
#
#        receiving_air_yards_L8  air_yards_share_L8  target_share_L8  \
# 0                         NaN                 NaN              NaN
# 1                    2.000000            0.010363         0.090909
# 2                    3.000000            0.011739         0.064322
# 3                    4.333333            0.019670         0.051429
# 4                         NaN                 NaN              NaN
# ...                       ...                 ...              ...
# 11958               -5.800000           -0.014043         0.055368
# 11959               -5.000000           -0.012165         0.057251
# 11960               -4.285714           -0.010427         0.049072
# 11961               -3.750000           -0.009124         0.042938
# 11962               -4.125000           -0.011336         0.034175
#
#        carry_share_L8  in_10_share_L8
# 0                 NaN             NaN
# 1            0.000000        0.000000
# 2            0.000000        0.062500
# 3            0.000000        0.041667
# 4                 NaN             NaN
# ...               ...             ...
# 11958        0.551200        0.116600
# 11959        0.537833        0.097167
# 11960        0.546714        0.083286
# 11961        0.491750        0.072875
# 11962        0.433375        0.031250
#
# [11963 rows x 19 columns]

# %%
flex_df = pd.merge(flex_df, flex_L8_features, on = ['player_display_name', 'season', 'week'], how = 'left')

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11963 entries, 0 to 11962
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11963 non-null  int64
#  1   week                            11963 non-null  int64
#  2   recent_team                     11963 non-null  object
#  3   opponent_team                   11963 non-null  object
#  4   player_id                       11357 non-null  object
#  5   player_display_name             11963 non-null  object
#  6   position                        11963 non-null  object
#  7   rushing_yards                   11357 non-null  float64
#  8   rushing_tds                     11357 non-null  float64
#  9   rushing_fumbles_lost            11357 non-null  float64
#  10  receptions                      11357 non-null  float64
#  11  receiving_yards                 11357 non-null  float64
#  12  receiving_tds                   11357 non-null  float64
#  13  receiving_fumbles_lost          11357 non-null  float64
#  14  targets                         11357 non-null  float64
#  15  carries                         11357 non-null  float64
#  16  receiving_yards_after_catch     11357 non-null  float64
#  17  receiving_air_yards             11357 non-null  float64
#  18  air_yards_share                 11357 non-null  float64
#  19  target_share                    11357 non-null  float64
#  20  carry_share                     11357 non-null  float64
#  21  in_10_share                     11357 non-null  float64
#  22  FD_Pts                          11357 non-null  float64
#  23  DK_Pts                          11357 non-null  float64
#  24  DK_Pts_RB_DvP                   11963 non-null  float64
#  25  DK_Pts_TE_DvP                   11963 non-null  float64
#  26  DK_Pts_WR_DvP                   11963 non-null  float64
#  27  FD_Pts_RB_DvP                   11963 non-null  float64
#  28  FD_Pts_TE_DvP                   11963 non-null  float64
#  29  FD_Pts_WR_DvP                   11963 non-null  float64
#  30  game_num                        11963 non-null  int64
#  31  rushing_yards_L8                11049 non-null  float64
#  32  rushing_tds_L8                  11049 non-null  float64
#  33  rushing_fumbles_lost_L8         11049 non-null  float64
#  34  receptions_L8                   11049 non-null  float64
#  35  receiving_yards_L8              11049 non-null  float64
#  36  receiving_tds_L8                11049 non-null  float64
#  37  receiving_fumbles_lost_L8       11049 non-null  float64
#  38  targets_L8                      11049 non-null  float64
#  39  carries_L8                      11049 non-null  float64
#  40  receiving_yards_after_catch_L8  11049 non-null  float64
#  41  receiving_air_yards_L8          11049 non-null  float64
#  42  air_yards_share_L8              11049 non-null  float64
#  43  target_share_L8                 11049 non-null  float64
#  44  carry_share_L8                  11049 non-null  float64
#  45  in_10_share_L8                  11049 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 4.2+ MB

# %% [markdown]
# # Filling missing values with mean
# In our QB model we made the mistake of dropping missing values at this point. Rookies making their debut won't have L8 variables because they haven't played before. So let's fill those values with the means.

# %%
cols_to_fill = ['rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8', 'receptions_L8',
       'receiving_yards_L8', 'receiving_tds_L8', 'receiving_fumbles_lost_L8',
       'targets_L8', 'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
       'carry_share_L8', 'in_10_share_L8']

# %%
for col in cols_to_fill:
    flex_df[col] = flex_df.groupby('position')[col].transform(lambda x: x.fillna(x.mean()))

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11963 entries, 0 to 11962
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11963 non-null  int64
#  1   week                            11963 non-null  int64
#  2   recent_team                     11963 non-null  object
#  3   opponent_team                   11963 non-null  object
#  4   player_id                       11357 non-null  object
#  5   player_display_name             11963 non-null  object
#  6   position                        11963 non-null  object
#  7   rushing_yards                   11357 non-null  float64
#  8   rushing_tds                     11357 non-null  float64
#  9   rushing_fumbles_lost            11357 non-null  float64
#  10  receptions                      11357 non-null  float64
#  11  receiving_yards                 11357 non-null  float64
#  12  receiving_tds                   11357 non-null  float64
#  13  receiving_fumbles_lost          11357 non-null  float64
#  14  targets                         11357 non-null  float64
#  15  carries                         11357 non-null  float64
#  16  receiving_yards_after_catch     11357 non-null  float64
#  17  receiving_air_yards             11357 non-null  float64
#  18  air_yards_share                 11357 non-null  float64
#  19  target_share                    11357 non-null  float64
#  20  carry_share                     11357 non-null  float64
#  21  in_10_share                     11357 non-null  float64
#  22  FD_Pts                          11357 non-null  float64
#  23  DK_Pts                          11357 non-null  float64
#  24  DK_Pts_RB_DvP                   11963 non-null  float64
#  25  DK_Pts_TE_DvP                   11963 non-null  float64
#  26  DK_Pts_WR_DvP                   11963 non-null  float64
#  27  FD_Pts_RB_DvP                   11963 non-null  float64
#  28  FD_Pts_TE_DvP                   11963 non-null  float64
#  29  FD_Pts_WR_DvP                   11963 non-null  float64
#  30  game_num                        11963 non-null  int64
#  31  rushing_yards_L8                11963 non-null  float64
#  32  rushing_tds_L8                  11963 non-null  float64
#  33  rushing_fumbles_lost_L8         11963 non-null  float64
#  34  receptions_L8                   11963 non-null  float64
#  35  receiving_yards_L8              11963 non-null  float64
#  36  receiving_tds_L8                11963 non-null  float64
#  37  receiving_fumbles_lost_L8       11963 non-null  float64
#  38  targets_L8                      11963 non-null  float64
#  39  carries_L8                      11963 non-null  float64
#  40  receiving_yards_after_catch_L8  11963 non-null  float64
#  41  receiving_air_yards_L8          11963 non-null  float64
#  42  air_yards_share_L8              11963 non-null  float64
#  43  target_share_L8                 11963 non-null  float64
#  44  carry_share_L8                  11963 non-null  float64
#  45  in_10_share_L8                  11963 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 4.2+ MB

# %% [markdown]
# # A few more features
# yards_per_carry, yards_per_reception, yards_per_target

# %%
flex_df['yards_per_carry_L8'] = flex_df['rushing_yards_L8']/flex_df['carries_L8']
flex_df['yards_per_reception_L8'] = flex_df['receiving_yards_L8']/flex_df['receptions_L8']
flex_df['yards_per_target_L8'] = flex_df['receiving_yards_L8']/flex_df['targets_L8']

# %% [markdown]
# # More missing
# Now this gives us some more missing values. In most cases, it's because we've tried to divide by zero when a player has averaged 0 carries over the last eight games. So here we should fill the missing values with 0

# %%
flex_df.fillna(0, inplace = True)

# %%
flex_df_full = flex_df.copy()

# %%
flex_df.drop(columns = cols_L8, inplace = True)

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11963 entries, 0 to 11962
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11963 non-null  int64
#  1   week                            11963 non-null  int64
#  2   recent_team                     11963 non-null  object
#  3   opponent_team                   11963 non-null  object
#  4   player_id                       11963 non-null  object
#  5   player_display_name             11963 non-null  object
#  6   position                        11963 non-null  object
#  7   FD_Pts                          11963 non-null  float64
#  8   DK_Pts                          11963 non-null  float64
#  9   DK_Pts_RB_DvP                   11963 non-null  float64
#  10  DK_Pts_TE_DvP                   11963 non-null  float64
#  11  DK_Pts_WR_DvP                   11963 non-null  float64
#  12  FD_Pts_RB_DvP                   11963 non-null  float64
#  13  FD_Pts_TE_DvP                   11963 non-null  float64
#  14  FD_Pts_WR_DvP                   11963 non-null  float64
#  15  game_num                        11963 non-null  int64
#  16  rushing_yards_L8                11963 non-null  float64
#  17  rushing_tds_L8                  11963 non-null  float64
#  18  rushing_fumbles_lost_L8         11963 non-null  float64
#  19  receptions_L8                   11963 non-null  float64
#  20  receiving_yards_L8              11963 non-null  float64
#  21  receiving_tds_L8                11963 non-null  float64
#  22  receiving_fumbles_lost_L8       11963 non-null  float64
#  23  targets_L8                      11963 non-null  float64
#  24  carries_L8                      11963 non-null  float64
#  25  receiving_yards_after_catch_L8  11963 non-null  float64
#  26  receiving_air_yards_L8          11963 non-null  float64
#  27  air_yards_share_L8              11963 non-null  float64
#  28  target_share_L8                 11963 non-null  float64
#  29  carry_share_L8                  11963 non-null  float64
#  30  in_10_share_L8                  11963 non-null  float64
#  31  yards_per_carry_L8              11963 non-null  float64
#  32  yards_per_reception_L8          11963 non-null  float64
#  33  yards_per_target_L8             11963 non-null  float64
# dtypes: float64(26), int64(3), object(5)
# memory usage: 3.1+ MB

# %%
flex_df = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_df['opponent_team'].nunique()
# Out:
# 22

# %%
flex_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# # Odds, grass, outdoors, wind
# We'll bring in CSVs with FanDuel and DraftKings odds.<br>
# This will be where we need to separate FanDuel from DraftKings dataframes since the odds and totals might be different.

# %%
fd_spreads = pd.read_csv('fd_spreads_' + str(season) + '_' + str(week) + '.csv')
dk_spreads = pd.read_csv('dk_spreads_' + str(season) + '_' + str(week) + '.csv')

# %%
fd_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      JAX   NE        42.5         1      1          0
# 1           1      ATL  SEA        51.5         0      0          0
# 2           2      BUF  TEN        41.5         1      0          0
# 3           3      CLE  CIN        41.5         1      1          0
# 4           4      MIN  DET        50.5         0      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -5.5       18.50      24.00    14    2024     7
# 1         -3.0       24.25      27.25     0    2024     7
# 2         -8.5       16.50      25.00     8    2024     7
# 3          5.5       23.50      18.00     6    2024     7
# 4         -1.5       24.50      26.00     0    2024     7

# %%
dk_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      JAX   NE        42.5         1      1          0
# 1           1      ATL  SEA        51.0         0      0          0
# 2           2      BUF  TEN        41.0         1      0          0
# 3           3      CLE  CIN        41.5         1      1          0
# 4           4      MIN  DET        51.0         0      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -5.5       18.50      24.00    14    2024     7
# 1         -3.0       24.00      27.00     0    2024     7
# 2         -9.0       16.00      25.00     8    2024     7
# 3          6.0       23.75      17.75     6    2024     7
# 4         -1.5       24.75      26.25     0    2024     7

# %%
fd_spreads.drop(columns = ['Unnamed: 0'], inplace = True)
dk_spreads.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
flex_df.rename(columns = {'recent_team': 'team', 'opponent_team': 'opponent'}, inplace = True)

# %%
flex_df_fd = pd.merge(flex_df, fd_spreads, on = ['team', 'opponent', 'season', 'week'])
flex_df_dk = pd.merge(flex_df, dk_spreads, on = ['team', 'opponent', 'season', 'week'])

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (606, 606)

# %%
# weekly_df[weekly_df['player_display_name'] == 'Jonathan Taylor'].tail()

# %% [markdown]
# <!-- # Bringing in point spreads and totals
# Pulling this dataframe from our database. It also includes binary variables for indoors and grass. -->

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# # Query specific columns from the table
# query1 = "SELECT * FROM spreads_totals"
# spread_df = pd.read_sql_query(query1, conn)

# # Close the connection
# conn.close()

# %%
flex_df.columns
# Out:
# Index(['season', 'week', 'team', 'opponent', 'player_id',
#        'player_display_name', 'position', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP',
#        'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP',
#        'FD_Pts_WR_DvP', 'game_num', 'rushing_yards_L8', 'rushing_tds_L8',
#        'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
#        'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
#        'carries_L8', 'receiving_yards_after_catch_L8',
#        'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
#        'carry_share_L8', 'in_10_share_L8', 'yards_per_carry_L8',
#        'yards_per_reception_L8', 'yards_per_target_L8'],
#       dtype='object')

# %%
#quarterback_df.drop(columns = ['defteam', 'passing_air_yards'], inplace = True)

# %%
flex_df.head()
# Out:
#        season  week team opponent  player_id player_display_name position  \
# 11357    2024     7  MIN      DET          0    Justin Jefferson       WR
# 11358    2024     7  MIN      DET          0         Aaron Jones       RB
# 11359    2024     7  MIN      DET          0         Ty Chandler       RB
# 11360    2024     7  MIN      DET          0      Jordan Addison       WR
# 11361    2024     7  MIN      DET          0        TJ Hockenson       TE
#
#        FD_Pts  DK_Pts  DK_Pts_RB_DvP  ...  carries_L8  \
# 11357     0.0     0.0          20.55  ...    0.125000
# 11358     0.0     0.0          20.55  ...   16.500000
# 11359     0.0     0.0          20.55  ...    9.000000
# 11360     0.0     0.0          20.55  ...    0.125000
# 11361     0.0     0.0          20.55  ...    0.025185
#
#        receiving_yards_after_catch_L8  receiving_air_yards_L8  \
# 11357                       25.375000              137.875000
# 11358                       27.375000                2.375000
# 11359                       13.625000               -3.625000
# 11360                       10.250000               81.375000
# 11361                       12.110995               23.048785
#
#        air_yards_share_L8  target_share_L8  carry_share_L8  in_10_share_L8  \
# 11357            0.463374         0.325339        0.005625        0.172375
# 11358            0.001016         0.147943        0.604500        0.431750
# 11359           -0.012668         0.050680        0.446250        0.154500
# 11360            0.258862         0.168476        0.004000        0.121000
# 11361            0.095233         0.109175        0.000888        0.061252
#
#        yards_per_carry_L8  yards_per_reception_L8  yards_per_target_L8
# 11357          -12.000000               17.183673            10.935065
# 11358            5.204545                8.384615             6.812500
# 11359            3.791667                7.818182             7.166667
# 11360            7.000000               14.720000             8.761905
# 11361            2.086663               10.365028             7.278637
#
# [5 rows x 34 columns]

# %%
divisions = {
    'CLE': 'AFC North',
    'LAR': 'NFC West',
    'LV': 'AFC West',
    'KC': 'AFC West',
    'CAR': 'NFC South',
    'NYG': 'NFC East',
    'HOU': 'AFC South',
    'DEN': 'AFC West',
    'MIN': 'NFC North',
    'TEN': 'AFC South',
    'JAX': 'AFC South',
    'SEA': 'NFC West',
    'DET': 'NFC North',
    'NO': 'NFC South',
    'CIN': 'AFC North',
    'ATL': 'NFC South',
    'NYJ': 'AFC East',
    'PHI': 'NFC East',
    'DAL': 'NFC East',
    'WAS': 'NFC East',
    'PIT': 'AFC North',
    'ARI': 'NFC West',
    'CHI': 'NFC North',
    'MIA': 'AFC East',
    'BUF': 'AFC East',
    'BAL': 'AFC North',
    'TB': 'NFC South',
    'SF': 'NFC West',
    'LAC': 'AFC West',
    'IND': 'AFC South',
    'GB': 'NFC North',
    'NE': 'AFC East'
}

# You now have a dictionary `divisions` where each team is mapped to its division.flex_df.info()

# %% [markdown]
# # Adding div_game binary column

# %%
# Map the team and opponent columns to their respective divisions
flex_df_fd['team_division'] = flex_df_fd['team'].map(divisions)
flex_df_fd['opponent_division'] = flex_df_fd['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_fd['div_game'] = np.where(flex_df_fd['team_division'] == flex_df_fd['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_fd.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Map the team and opponent columns to their respective divisions
flex_df_dk['team_division'] = flex_df_dk['team'].map(divisions)
flex_df_dk['opponent_division'] = flex_df_dk['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_dk['div_game'] = np.where(flex_df_dk['team_division'] == flex_df_dk['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_dk.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Check for positive or negative infinity in the entire DataFrame
# infinity_mask_fd = np.isinf(flex_df_fd)
# infinity_mask_dk = np.isinf(flex_df_dk)

# # Display rows with infinity values
# infinity_rows_fd = flex_df_fd[infinity_mask_fd.any(axis=1)]
# infinity_rows_dk = flex_df_dk[infinity_mask_dk.any(axis=1)]
# print(infinity_rows_fd)
# print(infinity_rows_dk)

# %% [markdown]
# # One-hot encoding for position

# %%
position_dummies_fd = pd.get_dummies(flex_df_fd['position'], prefix='pos')
position_dummies_dk = pd.get_dummies(flex_df_dk['position'], prefix='pos')

# %%
flex_df_fd = pd.concat([flex_df_fd, position_dummies_fd], axis = 1)

# %%
flex_df_dk = pd.concat([flex_df_dk, position_dummies_dk], axis = 1)

# %%
flex_df_fd['pos_RB'] = flex_df_fd['pos_RB'].astype(int)
flex_df_fd['pos_TE'] = flex_df_fd['pos_TE'].astype(int)
flex_df_fd['pos_WR'] = flex_df_fd['pos_WR'].astype(int)
flex_df_dk['pos_RB'] = flex_df_dk['pos_RB'].astype(int)
flex_df_dk['pos_TE'] = flex_df_dk['pos_TE'].astype(int)
flex_df_dk['pos_WR'] = flex_df_dk['pos_WR'].astype(int)

# %%
flex_df_fd.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)
flex_df_dk.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)

# %%
fanduel_df = fanduel_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]
draftkings_df = draftkings_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]

# %%
fanduel_df = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
draftkings_df = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
len(fanduel_df), len(draftkings_df)
# Out:
# (606, 410)

# %%
#################### Sept. 16, 2024 #####################
#Just filtered for Flex positions.
#Next will be to rename player_display_name to name and try to merge again with the flex data.
#Don't forget QB strength variables!!!!!

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (606, 606)

# %%
flex_df_fd.rename(columns = {'player_display_name': 'name'}, inplace = True)
flex_df_dk.rename(columns = {'player_display_name': 'name'}, inplace = True)

# %% [markdown]
# # Name matching here

# %%
def clean_name(name):
    # Remove periods between initials like C.J., D.J. (case-sensitive)
    name = re.sub(r'\b([A-Z])\.\s*([A-Z])\.\b', r'\1\2', name)
    
    # Remove common suffixes like Jr., Sr., III, II, IV (case-sensitive)
    cleaned_name = re.sub(r'(\,|\.|Sr|Jr|III|II|IV)', '', name).strip()
    
    return cleaned_name

# %%
import re
from rapidfuzz import process, fuzz

# %%
flex_df_fd['name'] = flex_df_fd['name'].apply(clean_name)
flex_df_dk['name'] = flex_df_dk['name'].apply(clean_name)

# %%
SIMILARITY_THRESHOLD = 80

# %%
def fuzzy_match(name, dk_names):
    match, score, _ = process.extractOne(name, dk_names, scorer=fuzz.token_sort_ratio)
    return match if score >= SIMILARITY_THRESHOLD else None

# %%
flex_names = flex_df_fd['name']

# %%
flex_df_fd['matched_name'] = flex_df_fd['name'].apply(lambda x: fuzzy_match(x, flex_names))
flex_df_dk['matched_name'] = flex_df_dk['name'].apply(lambda x: fuzzy_match(x, flex_names))

# %%
unmatched_in_fd = flex_df_fd[flex_df_fd['matched_name'].isna()]

# %%
unmatched_in_fd.reset_index(inplace = True, drop = True)

# %%
unmatched_in_fd
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_fd[(flex_df_fd['name'] != flex_df_fd['matched_name']) & (flex_df_fd['matched_name'].notna())]
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
unmatched_in_dk = flex_df_dk[flex_df_dk['matched_name'].isna()]

# %%
unmatched_in_dk.reset_index(inplace = True, drop = True)

# %%
unmatched_in_dk
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_dk[(flex_df_dk['name'] != flex_df_dk['matched_name']) & (flex_df_dk['matched_name'].notna())]
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_fd = pd.merge(fanduel_df, flex_df_fd, on = ['name', 'team', 'opponent', 'week'], how = 'left')
flex_df_dk = pd.merge(draftkings_df, flex_df_dk, on = ['name', 'team', 'opponent', 'week'], how = 'left')

# %%
flex_df_fd['position'] = flex_df_fd['position_x']
flex_df_fd.drop(columns = ['position_x', 'position_y'], inplace = True)
flex_df_dk['position'] = flex_df_dk['position_x']
flex_df_dk.drop(columns = ['position_x', 'position_y'], inplace = True)

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606 entries, 0 to 605
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            606 non-null    object
#  1   salary                          606 non-null    int64
#  2   team                            606 non-null    object
#  3   opponent                        606 non-null    object
#  4   status                          606 non-null    object
#  5   week                            606 non-null    int64
#  6   season                          606 non-null    int64
#  7   player_id                       606 non-null    int64
#  8   DK_Pts_RB_DvP                   606 non-null    float64
#  9   DK_Pts_TE_DvP                   606 non-null    float64
#  10  DK_Pts_WR_DvP                   606 non-null    float64
#  11  FD_Pts_RB_DvP                   606 non-null    float64
#  12  FD_Pts_TE_DvP                   606 non-null    float64
#  13  FD_Pts_WR_DvP                   606 non-null    float64
#  14  game_num                        606 non-null    int64
#  15  rushing_yards_L8                606 non-null    float64
#  16  rushing_tds_L8                  606 non-null    float64
#  17  rushing_fumbles_lost_L8         606 non-null    float64
#  18  receptions_L8                   606 non-null    float64
#  19  receiving_yards_L8              606 non-null    float64
#  20  receiving_tds_L8                606 non-null    float64
#  21  receiving_fumbles_lost_L8       606 non-null    float64
#  22  targets_L8                      606 non-null    float64
#  23  carries_L8                      606 non-null    float64
#  24  receiving_yards_after_catch_L8  606 non-null    float64
#  25  receiving_air_yards_L8          606 non-null    float64
#  26  air_yards_share_L8              606 non-null    float64
#  27  target_share_L8                 606 non-null    float64
#  28  carry_share_L8                  606 non-null    float64
#  29  in_10_share_L8                  606 non-null    float64
#  30  yards_per_carry_L8              606 non-null    float64
#  31  yards_per_reception_L8          606 non-null    float64
#  32  yards_per_target_L8             606 non-null    float64
#  33  total_line                      606 non-null    float64
#  34  outdoors                        606 non-null    int64
#  35  grass                           606 non-null    int64
#  36  home_team                       606 non-null    int64
#  37  spread_line                     606 non-null    float64
#  38  pred_total                      606 non-null    float64
#  39  opp_total                       606 non-null    float64
#  40  wind                            606 non-null    int64
#  41  div_game                        606 non-null    int32
#  42  pos_RB                          606 non-null    int32
#  43  pos_TE                          606 non-null    int32
#  44  pos_WR                          606 non-null    int32
#  45  matched_name                    606 non-null    object
#  46  position                        606 non-null    object
# dtypes: float64(28), int32(4), int64(9), object(6)
# memory usage: 213.2+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            410 non-null    object
#  1   salary                          410 non-null    int64
#  2   team                            410 non-null    object
#  3   opponent                        410 non-null    object
#  4   status                          410 non-null    object
#  5   week                            410 non-null    int64
#  6   season                          410 non-null    int64
#  7   player_id                       410 non-null    int64
#  8   DK_Pts_RB_DvP                   410 non-null    float64
#  9   DK_Pts_TE_DvP                   410 non-null    float64
#  10  DK_Pts_WR_DvP                   410 non-null    float64
#  11  FD_Pts_RB_DvP                   410 non-null    float64
#  12  FD_Pts_TE_DvP                   410 non-null    float64
#  13  FD_Pts_WR_DvP                   410 non-null    float64
#  14  game_num                        410 non-null    int64
#  15  rushing_yards_L8                410 non-null    float64
#  16  rushing_tds_L8                  410 non-null    float64
#  17  rushing_fumbles_lost_L8         410 non-null    float64
#  18  receptions_L8                   410 non-null    float64
#  19  receiving_yards_L8              410 non-null    float64
#  20  receiving_tds_L8                410 non-null    float64
#  21  receiving_fumbles_lost_L8       410 non-null    float64
#  22  targets_L8                      410 non-null    float64
#  23  carries_L8                      410 non-null    float64
#  24  receiving_yards_after_catch_L8  410 non-null    float64
#  25  receiving_air_yards_L8          410 non-null    float64
#  26  air_yards_share_L8              410 non-null    float64
#  27  target_share_L8                 410 non-null    float64
#  28  carry_share_L8                  410 non-null    float64
#  29  in_10_share_L8                  410 non-null    float64
#  30  yards_per_carry_L8              410 non-null    float64
#  31  yards_per_reception_L8          410 non-null    float64
#  32  yards_per_target_L8             410 non-null    float64
#  33  total_line                      368 non-null    float64
#  34  outdoors                        410 non-null    int64
#  35  grass                           410 non-null    int64
#  36  home_team                       410 non-null    int64
#  37  spread_line                     410 non-null    float64
#  38  pred_total                      368 non-null    float64
#  39  opp_total                       368 non-null    float64
#  40  wind                            410 non-null    int64
#  41  div_game                        410 non-null    int32
#  42  pos_RB                          410 non-null    int32
#  43  pos_TE                          410 non-null    int32
#  44  pos_WR                          410 non-null    int32
#  45  matched_name                    410 non-null    object
#  46  position                        410 non-null    object
# dtypes: float64(28), int32(4), int64(9), object(6)
# memory usage: 144.3+ KB

# %%
###FANDUEL SCORING
#Rushing yards made = 0.1pts	
#Rushing touchdowns = 6pts	
#Passing yards = 0.04pts	
#Passing touchdowns = 4pts	
#Interceptions = -1pt	
#Receiving yards = 0.1pts	
#Receiving touchdowns = 6pts	
#Receptions = 0.5pts	
#Kickoff return touchdowns = 6pts	
#Punt return touchdowns = 6pts	
#Fumbles lost = -2pts	
#Own fumbles recovered touchdowns = 6pts	
#Two-point conversions scored = 2pts	
#Two-point conversion passes = 2pts	
#Field-goals from 0-39 yards = 3pts	
#Field-goals from 40-49 yards = 4pts	
#Field-goals from 50+ yards = 5pts	
#Extra-point conversions = 1pt

###DRAFTKINGS SCORING
#PAssing TD = 4 pts
#passing yards = .04 pts
#300 passing yards = 3 pts (bonus)
#Interception = -1 pts
#Rushing TD = 6 pts
#Rushing yds = 0.1 pts
#100 yd rushing game = 3 pts (bonus)
#Receiving TD = 6 pts
#Receiving yds = 0.1 pts
#100 receiving yards game = 3 pts (bonus)
#Receptions = 1 pt
#Punt/kickoff/FG return for TD = 6 pts
#Fumble lost = -1 pt
#2 pt conversion (pass, run or catch) = 2 pts
#Offensive fumble recovery TD = 6

# %%
features = ['DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP', 'rushing_yards_L8', 'rushing_tds_L8',
       'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
       'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
       'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'target_share_L8', 'carry_share_L8',
       'in_10_share_L8', 'yards_per_carry_L8', 'yards_per_reception_L8',
       'yards_per_target_L8', 'wind', 'div_game', 'spread_line', 'total_line',
       'outdoors', 'grass', 'home_team', 'pred_total', 'opp_total', 'qb_comp',
       'qb_att', 'qb_yds', 'qb_pass_td', 'qb_int', 'qb_comp_pct',
       'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct', 'pos_RB', 'pos_TE',
       'pos_WR']

# %% [markdown]
# # QB strength
# One last variable we want to try to add is a variable or variables that look at quarterback strength. If a team's backup QB is playing, the entire offense is downgraded and it could affect the fantasy performance of RBs, WRs and TEs.<br>
#
# We'll take the dataset we used for the QB model, filter for the primary QBs in each game and use some of the variables that look at L8 means.

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# query_qb = "SELECT * FROM qb_dataset WHERE season >= 2006"

# qb_df = pd.read_sql_query(query_qb, conn)

# # Close the database connection
# conn.close()

# %%
qb_data_fd = pd.read_csv('FD_QB_for_model_' + str(season) + '_' + str(week) + '.csv')
qb_data_dk = pd.read_csv('DK_QB_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
qb_data_fd = qb_data_fd[qb_data_fd['QB_role'] == 1]
qb_data_dk = qb_data_dk[qb_data_dk['QB_role'] == 1]

# %%
qb_data_fd.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_dk.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_fd = qb_data_fd[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
qb_data_dk = qb_data_dk[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
flex_df_fd = pd.merge(flex_df_fd, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_dk = pd.merge(flex_df_dk, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_fd = flex_df_fd.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)
flex_df_dk = flex_df_dk.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)

# %%
flex_df_fd = flex_df_fd[features]
flex_df_dk = flex_df_dk[features]

# %%
flex_df_fd.replace([np.inf, -np.inf], np.nan, inplace=True)
flex_df_dk.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# flex_df_dk[flex_df_dk.isna().any(axis = 1)]

# %%
# flex_df_dk = flex_df_dk.dropna()

# %%
# Fill missing values with the mean of each column
flex_df_fd = flex_df_fd.groupby('position').transform(lambda x: x.fillna(x.mean()))
flex_df_dk = flex_df_dk.groupby('position').transform(lambda x: x.fillna(x.mean()))

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 606 entries, ('Justin Jefferson', 'WR', 'MIN', 'DET', 9400, 'Active', 7, 2024) to ('Nick Muse', 'TE', 'MIN', 'DET', 4000, 'IR', 7, 2024)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   606 non-null    float64
#  1   DK_Pts_TE_DvP                   606 non-null    float64
#  2   DK_Pts_WR_DvP                   606 non-null    float64
#  3   FD_Pts_RB_DvP                   606 non-null    float64
#  4   FD_Pts_TE_DvP                   606 non-null    float64
#  5   FD_Pts_WR_DvP                   606 non-null    float64
#  6   rushing_yards_L8                606 non-null    float64
#  7   rushing_tds_L8                  606 non-null    float64
#  8   rushing_fumbles_lost_L8         606 non-null    float64
#  9   receptions_L8                   606 non-null    float64
#  10  receiving_yards_L8              606 non-null    float64
#  11  receiving_tds_L8                606 non-null    float64
#  12  receiving_fumbles_lost_L8       606 non-null    float64
#  13  targets_L8                      606 non-null    float64
#  14  carries_L8                      606 non-null    float64
#  15  receiving_yards_after_catch_L8  606 non-null    float64
#  16  receiving_air_yards_L8          606 non-null    float64
#  17  target_share_L8                 606 non-null    float64
#  18  carry_share_L8                  606 non-null    float64
#  19  in_10_share_L8                  606 non-null    float64
#  20  yards_per_carry_L8              606 non-null    float64
#  21  yards_per_reception_L8          606 non-null    float64
#  22  yards_per_target_L8             606 non-null    float64
#  23  wind                            606 non-null    int64
#  24  div_game                        606 non-null    int32
#  25  spread_line                     606 non-null    float64
#  26  total_line                      606 non-null    float64
#  27  outdoors                        606 non-null    int64
#  28  grass                           606 non-null    int64
#  29  home_team                       606 non-null    int64
#  30  pred_total                      606 non-null    float64
#  31  opp_total                       606 non-null    float64
#  32  qb_comp                         606 non-null    float64
#  33  qb_att                          606 non-null    float64
#  34  qb_yds                          606 non-null    float64
#  35  qb_pass_td                      606 non-null    float64
#  36  qb_int                          606 non-null    float64
#  37  qb_comp_pct                     606 non-null    float64
#  38  qb_yds_per_att                  606 non-null    float64
#  39  qb_td_pct                       606 non-null    float64
#  40  qb_int_pct                      606 non-null    float64
#  41  pos_RB                          606 non-null    int32
#  42  pos_TE                          606 non-null    int32
#  43  pos_WR                          606 non-null    int32
# dtypes: float64(36), int32(4), int64(4)
# memory usage: 229.9+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 410 entries, ('Justin Jefferson', 'WR', 'MIN', 'DET', 8500, 'Active', 7, 2024) to ('James Winchester', 'TE', 'KC', 'SF', 2500, 'Active', 7, 2024)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   410 non-null    float64
#  1   DK_Pts_TE_DvP                   410 non-null    float64
#  2   DK_Pts_WR_DvP                   410 non-null    float64
#  3   FD_Pts_RB_DvP                   410 non-null    float64
#  4   FD_Pts_TE_DvP                   410 non-null    float64
#  5   FD_Pts_WR_DvP                   410 non-null    float64
#  6   rushing_yards_L8                410 non-null    float64
#  7   rushing_tds_L8                  410 non-null    float64
#  8   rushing_fumbles_lost_L8         410 non-null    float64
#  9   receptions_L8                   410 non-null    float64
#  10  receiving_yards_L8              410 non-null    float64
#  11  receiving_tds_L8                410 non-null    float64
#  12  receiving_fumbles_lost_L8       410 non-null    float64
#  13  targets_L8                      410 non-null    float64
#  14  carries_L8                      410 non-null    float64
#  15  receiving_yards_after_catch_L8  410 non-null    float64
#  16  receiving_air_yards_L8          410 non-null    float64
#  17  target_share_L8                 410 non-null    float64
#  18  carry_share_L8                  410 non-null    float64
#  19  in_10_share_L8                  410 non-null    float64
#  20  yards_per_carry_L8              410 non-null    float64
#  21  yards_per_reception_L8          410 non-null    float64
#  22  yards_per_target_L8             410 non-null    float64
#  23  wind                            410 non-null    int64
#  24  div_game                        410 non-null    int32
#  25  spread_line                     410 non-null    float64
#  26  total_line                      410 non-null    float64
#  27  outdoors                        410 non-null    int64
#  28  grass                           410 non-null    int64
#  29  home_team                       410 non-null    int64
#  30  pred_total                      410 non-null    float64
#  31  opp_total                       410 non-null    float64
#  32  qb_comp                         410 non-null    float64
#  33  qb_att                          410 non-null    float64
#  34  qb_yds                          410 non-null    float64
#  35  qb_pass_td                      410 non-null    float64
#  36  qb_int                          410 non-null    float64
#  37  qb_comp_pct                     410 non-null    float64
#  38  qb_yds_per_att                  410 non-null    float64
#  39  qb_td_pct                       410 non-null    float64
#  40  qb_int_pct                      410 non-null    float64
#  41  pos_RB                          410 non-null    int32
#  42  pos_TE                          410 non-null    int32
#  43  pos_WR                          410 non-null    int32
# dtypes: float64(36), int32(4), int64(4)
# memory usage: 162.4+ KB

# %%
flex_df_fd.head()
# Out:
#                                                                    DK_Pts_RB_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024          20.5500
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024          21.3750
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024          20.5625
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024          20.5625
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          18.1625
#
#                                                                    DK_Pts_TE_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024           7.9500
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024           9.5375
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024           8.8250
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024           8.8250
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          14.1625
#
#                                                                    DK_Pts_WR_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024          46.5750
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024          37.1750
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024          35.3625
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024          35.3625
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          29.9925
#
#                                                                    FD_Pts_RB_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024          18.3625
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024          19.3125
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024          17.8125
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024          17.8125
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          15.4125
#
#                                                                    FD_Pts_TE_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024           6.3875
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024           7.9125
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024           6.5125
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024           6.5125
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          10.7250
#
#                                                                    FD_Pts_WR_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024          35.5125
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024          30.6125
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024          28.0500
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024          28.0500
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          24.3050
#
#                                                                    rushing_yards_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024           -1.500000
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024            0.000000
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024           80.875000
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024            1.385669
# Jordan Mason     RB       SF   KC       8800   Q      7    2024           81.000000
#
#                                                                    rushing_tds_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024           0.00000
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024           0.00000
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024           0.87500
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024           0.01143
# Jordan Mason     RB       SF   KC       8800   Q      7    2024           0.37500
#
#                                                                    rushing_fumbles_lost_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024                   0.000000
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024                   0.000000
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024                   0.000000
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024                   0.002039
# Jordan Mason     RB       SF   KC       8800   Q      7    2024                   0.125000
#
#                                                                    receptions_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024         6.125000
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024         5.125000
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024         2.750000
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024         3.085124
# Jordan Mason     RB       SF   KC       8800   Q      7    2024         1.125000
#
#                                                                    ...  \
# name             position team opponent salary status week season  ...
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024    ...
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024    ...
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024    ...
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024    ...
# Jordan Mason     RB       SF   KC       8800   Q      7    2024    ...
#
#                                                                     qb_yds  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024    172.625
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024    253.250
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024    208.250
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024    208.250
# Jordan Mason     RB       SF   KC       8800   Q      7    2024    268.875
#
#                                                                    qb_pass_td  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024         1.625
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024         1.875
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024         1.250
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024         1.250
# Jordan Mason     RB       SF   KC       8800   Q      7    2024         1.375
#
#                                                                    qb_int  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024     0.625
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024     0.500
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024     0.750
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024     0.750
# Jordan Mason     RB       SF   KC       8800   Q      7    2024     0.625
#
#                                                                    qb_comp_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024       0.627119
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024       0.705426
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024       0.675325
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024       0.675325
# Jordan Mason     RB       SF   KC       8800   Q      7    2024       0.645669
#
#                                                                    qb_yds_per_att  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024          7.802260
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024          7.852713
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024          7.212121
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024          7.212121
# Jordan Mason     RB       SF   KC       8800   Q      7    2024          8.468504
#
#                                                                    qb_td_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024     0.073446
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024     0.058140
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024     0.043290
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024     0.043290
# Jordan Mason     RB       SF   KC       8800   Q      7    2024     0.043307
#
#                                                                    qb_int_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024      0.028249
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024      0.015504
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024      0.025974
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024      0.025974
# Jordan Mason     RB       SF   KC       8800   Q      7    2024      0.019685
#
#                                                                    pos_RB  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024         0
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024         0
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024         1
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024         0
# Jordan Mason     RB       SF   KC       8800   Q      7    2024         1
#
#                                                                    pos_TE  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024         0
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024         0
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024         0
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024         0
# Jordan Mason     RB       SF   KC       8800   Q      7    2024         0
#
#                                                                    pos_WR
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      9400   Active 7    2024         1
# Ja'Marr Chase    WR       CIN  CLE      9300   Active 7    2024         1
# Saquon Barkley   RB       PHI  NYG      9000   Active 7    2024         0
# AJ Brown         WR       PHI  NYG      8900   Active 7    2024         1
# Jordan Mason     RB       SF   KC       8800   Q      7    2024         0
#
# [5 rows x 44 columns]

# %%
flex_df_dk.head()
# Out:
#                                                                    DK_Pts_RB_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024          20.5500
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024          21.3750
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          20.3125
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024          20.5625
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024          27.4625
#
#                                                                    DK_Pts_TE_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024           7.9500
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024           9.5375
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          12.6250
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024           8.8250
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024           8.2625
#
#                                                                    DK_Pts_WR_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024          46.5750
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024          37.1750
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          49.5275
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024          35.3625
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024          29.8125
#
#                                                                    FD_Pts_RB_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024          18.3625
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024          19.3125
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          17.5625
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024          17.8125
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024          23.2750
#
#                                                                    FD_Pts_TE_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024           6.3875
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024           7.9125
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024           9.7500
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024           6.5125
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024           6.4500
#
#                                                                    FD_Pts_WR_DvP  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024          35.5125
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024          30.6125
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          38.4025
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024          28.0500
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024          24.5625
#
#                                                                    rushing_yards_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024           -1.500000
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024            0.000000
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024            1.385669
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024           80.875000
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024           76.500000
#
#                                                                    rushing_tds_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024           0.00000
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024           0.00000
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024           0.01143
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024           0.87500
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024           1.25000
#
#                                                                    rushing_fumbles_lost_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024                   0.000000
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024                   0.000000
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024                   0.002039
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024                   0.000000
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024                   0.125000
#
#                                                                    receptions_L8  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024         6.125000
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024         5.125000
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024         3.085124
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024         2.750000
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024         2.125000
#
#                                                                    ...  \
# name             position team opponent salary status week season  ...
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024    ...
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024    ...
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024    ...
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024    ...
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024    ...
#
#                                                                     qb_yds  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024    172.625
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024    253.250
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024    270.875
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024    208.250
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024    281.250
#
#                                                                    qb_pass_td  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024         1.625
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024         1.875
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024         1.500
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024         1.250
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024         1.000
#
#                                                                    qb_int  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024     0.625
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024     0.500
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024     0.500
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024     0.750
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024     0.625
#
#                                                                    qb_comp_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024       0.627119
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024       0.705426
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024       0.703846
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024       0.675325
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024       0.684588
#
#                                                                    qb_yds_per_att  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024          7.802260
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024          7.852713
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024          8.334615
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024          7.212121
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024          8.064516
#
#                                                                    qb_td_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024     0.073446
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024     0.058140
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024     0.046154
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024     0.043290
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024     0.028674
#
#                                                                    qb_int_pct  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024      0.028249
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024      0.015504
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024      0.015385
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024      0.025974
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024      0.017921
#
#                                                                    pos_RB  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024         0
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024         0
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024         0
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024         1
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024         1
#
#                                                                    pos_TE  \
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024         0
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024         0
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024         0
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024         0
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024         0
#
#                                                                    pos_WR
# name             position team opponent salary status week season
# Justin Jefferson WR       MIN  DET      8500   Active 7    2024         1
# Ja'Marr Chase    WR       CIN  CLE      8400   Active 7    2024         1
# Amon-Ra St Brown WR       DET  MIN      8300   Active 7    2024         1
# Saquon Barkley   RB       PHI  NYG      8200   Active 7    2024         0
# Kyren Williams   RB       LAR  LV       8100   Active 7    2024         0
#
# [5 rows x 44 columns]

# %%
flex_df_fd.to_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
flex_df_dk.to_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
