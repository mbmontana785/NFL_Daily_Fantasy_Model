# %% [markdown]
# # Assembling FLEX dataset
# This notebook will wrangle the FanDuel and DraftKings lists of running backs, wide receivers and tight ends and create a CSV that is ready to run through the model for predictions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nfl_data_py as nfl
#import itertools
from functions import get_current_weekday, calculate_nfl_week, get_next_sunday, get_current_year

# %%
import sqlite3

# %%
day = get_current_weekday()

# %%
date_string = get_next_sunday(day)

# %%
week = calculate_nfl_week(date_string)

# %%
season = get_current_year()

# %% [markdown]
# # Pulling from database
# Fetching the FD and DK lists from the database. These tables include names, positions, teams, opponents and salaries.

# %%
# Connect to the SQLite database
#These are the FD and DK player lists for the current week
conn = sqlite3.connect('nfl_dfs.db')

query_fd = "SELECT * FROM fd_table_" + str(week) + "_" + str(season)[2:]
query_dk = "SELECT * FROM dk_table_" + str(week) + "_" + str(season)[2:]

fanduel_df = pd.read_sql_query(query_fd, conn)
draftkings_df = pd.read_sql_query(query_dk, conn)

# Close the database connection
conn.close()

# %%
#The weekly and play-by-play data through the previous week
#We went into R Studio to get these and save them as CSVs that we can use here
weekly_df = pd.read_csv('weekly_data_' + str(season) + '_' + str(week) + '.csv')
pbp_df = pd.read_csv('pbp_data_' + str(season) + '_' + str(week) + '.csv', low_memory = False)

# %%
weekly_df.replace({'LA': 'LAR'}, inplace = True)
pbp_df.replace({'LA': 'LAR'}, inplace = True)

# %% [markdown]
# This is weekly data for each player. We can use this to calculate fantasy points for most players.

# %%
weekly_df.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 3  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 4  https://static.www.nfl.com/image/private/f_aut...          TB    2022
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                     0            NaN
# 1     2         REG  ...                     0            NaN
# 2     3         REG  ...                     0            NaN
# 3     4         REG  ...                     0            NaN
# 4     5         REG  ...                     0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 0                          0   NaN           NaN              NaN   NaN
# 1                          0   NaN           NaN              NaN   NaN
# 2                          0   NaN           NaN              NaN   NaN
# 3                          0   NaN           NaN              NaN   NaN
# 4                          0   NaN           NaN              NaN   NaN
#
#    special_teams_tds  fantasy_points  fantasy_points_ppr
# 0                  0           10.38               10.38
# 1                  0            9.40                9.40
# 2                  0           14.74               14.74
# 3                  0           25.40               25.40
# 4                  0           19.74               19.74
#
# [5 rows x 53 columns]

# %%
pbp_df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 1       43  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 2       68  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 3       89  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 4      115  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     NYJ         home     BAL  ...             0                     1
# 2     1     NYJ         home     BAL  ...             0                     1
# 3     1     NYJ         home     BAL  ...             0                     1
# 4     1     NYJ         home     BAL  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0  0.000000       NaN                NaN                  NaN          NaN
# 1 -0.443521       NaN                NaN                  NaN          NaN
# 2  1.468819       NaN                NaN                  NaN          NaN
# 3 -0.492192  0.727261           6.988125                  6.0      0.60693
# 4 -0.325931       NaN                NaN                  NaN          NaN
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.440373 -44.037291
# 3  0.227598  0.389904  61.009598
# 4       NaN  0.443575 -44.357494
#
# [5 rows x 372 columns]

# %%
#rb_wr_te_df.head()

# %%
#rb_wr_te_df.info()

# %%
#nfl.see_weekly_cols()

# %%
weekly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11903 entries, 0 to 11902
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    11903 non-null  object
#  1   player_name                  11903 non-null  object
#  2   player_display_name          11903 non-null  object
#  3   position                     11903 non-null  object
#  4   position_group               11903 non-null  object
#  5   headshot_url                 11853 non-null  object
#  6   recent_team                  11903 non-null  object
#  7   season                       11903 non-null  int64
#  8   week                         11903 non-null  int64
#  9   season_type                  11903 non-null  object
#  10  opponent_team                11903 non-null  object
#  11  completions                  11903 non-null  int64
#  12  attempts                     11903 non-null  int64
#  13  passing_yards                11903 non-null  int64
#  14  passing_tds                  11903 non-null  int64
#  15  interceptions                11903 non-null  int64
#  16  sacks                        11903 non-null  int64
#  17  sack_yards                   11903 non-null  int64
#  18  sack_fumbles                 11903 non-null  int64
#  19  sack_fumbles_lost            11903 non-null  int64
#  20  passing_air_yards            11903 non-null  int64
#  21  passing_yards_after_catch    11903 non-null  int64
#  22  passing_first_downs          11903 non-null  int64
#  23  passing_epa                  1480 non-null   float64
#  24  passing_2pt_conversions      11903 non-null  int64
#  25  pacr                         1454 non-null   float64
#  26  dakota                       1290 non-null   float64
#  27  carries                      11903 non-null  int64
#  28  rushing_yards                11903 non-null  int64
#  29  rushing_tds                  11903 non-null  int64
#  30  rushing_fumbles              11903 non-null  int64
#  31  rushing_fumbles_lost         11903 non-null  int64
#  32  rushing_first_downs          11903 non-null  int64
#  33  rushing_epa                  5032 non-null   float64
#  34  rushing_2pt_conversions      11903 non-null  int64
#  35  receptions                   11903 non-null  int64
#  36  targets                      11903 non-null  int64
#  37  receiving_yards              11903 non-null  int64
#  38  receiving_tds                11903 non-null  int64
#  39  receiving_fumbles            11903 non-null  int64
#  40  receiving_fumbles_lost       11903 non-null  int64
#  41  receiving_air_yards          11903 non-null  int64
#  42  receiving_yards_after_catch  11903 non-null  int64
#  43  receiving_first_downs        11903 non-null  int64
#  44  receiving_epa                9635 non-null   float64
#  45  receiving_2pt_conversions    11903 non-null  int64
#  46  racr                         9584 non-null   float64
#  47  target_share                 9635 non-null   float64
#  48  air_yards_share              9635 non-null   float64
#  49  wopr                         9635 non-null   float64
#  50  special_teams_tds            11903 non-null  int64
#  51  fantasy_points               11903 non-null  float64
#  52  fantasy_points_ppr           11903 non-null  float64
# dtypes: float64(11), int64(33), object(9)
# memory usage: 4.8+ MB

# %%
weekly_df['position_group'].value_counts()
# Out:
# position_group
# WR      4820
# RB      3186
# TE      2358
# QB      1462
# SPEC      28
# DB        25
# LB        14
# OL         8
# DL         2
# Name: count, dtype: int64

# %%
weekly_df['position'].value_counts()
# Out:
# position
# WR     4820
# RB     2998
# TE     2358
# QB     1462
# FB      188
# P        28
# CB       10
# SS        9
# ILB       7
# T         7
# FS        6
# OLB       6
# DT        2
# G         1
# MLB       1
# Name: count, dtype: int64

# %% [markdown]
# Weekly data filtered for RBs, WRs and TEs

# %%
flex_df = weekly_df[weekly_df['position'].isin(['RB', 'HB', 'FB', 'WR', 'TE'])]

# %%
cols_to_group = ['season', 'week', 'recent_team', 'opponent_team', 'player_id', 'player_display_name', 'position']

# %% [markdown]
# So we do have quite a few duplicate names so player_id becomes more important than names.

# %%
# Group by 'player_display_name' and check the number of unique 'player_id's
duplicate_names = flex_df.groupby('player_display_name')['player_id'].nunique()

# Filter the results to find names associated with more than one unique ID
duplicate_names = duplicate_names[duplicate_names > 1]

# %%
duplicate_names
# Out:
# Series([], Name: player_id, dtype: int64)

# %%
scoring_cols = ['passing_yards', 'passing_tds', 'interceptions', 'passing_2pt_conversions', 'rushing_yards',\
                   'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions', 'receptions', 'receiving_yards',\
                   'receiving_tds', 'receiving_fumbles_lost', 'receiving_2pt_conversions', 'sack_fumbles_lost', 'special_teams_tds',\
               'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share']

# %%
flex_df = flex_df.groupby(cols_to_group)[scoring_cols].sum()

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10364 entries, (2022, 1, 'ARI', 'KC', '00-0027942', 'A.J. Green', 'WR') to (2024, 2, 'WAS', 'NYG', '00-0037746', 'Brian Robinson', 'RB')
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   passing_yards                10364 non-null  int64
#  1   passing_tds                  10364 non-null  int64
#  2   interceptions                10364 non-null  int64
#  3   passing_2pt_conversions      10364 non-null  int64
#  4   rushing_yards                10364 non-null  int64
#  5   rushing_tds                  10364 non-null  int64
#  6   rushing_fumbles_lost         10364 non-null  int64
#  7   rushing_2pt_conversions      10364 non-null  int64
#  8   receptions                   10364 non-null  int64
#  9   receiving_yards              10364 non-null  int64
#  10  receiving_tds                10364 non-null  int64
#  11  receiving_fumbles_lost       10364 non-null  int64
#  12  receiving_2pt_conversions    10364 non-null  int64
#  13  sack_fumbles_lost            10364 non-null  int64
#  14  special_teams_tds            10364 non-null  int64
#  15  targets                      10364 non-null  int64
#  16  carries                      10364 non-null  int64
#  17  receiving_yards_after_catch  10364 non-null  int64
#  18  receiving_air_yards          10364 non-null  int64
#  19  air_yards_share              10364 non-null  float64
#  20  target_share                 10364 non-null  float64
# dtypes: float64(2), int64(19)
# memory usage: 1.8+ MB

# %%
flex_df
# Out:
#                                                                                passing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                    0
#
#                                                                                passing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  0
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                  0
#                                       00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0036628 John Bates          TE                  0
#                                       00-0037746 Brian Robinson      RB                  0
#
#                                                                                interceptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                    0
#
#                                                                                passing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                              0
#                                       00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0036628 John Bates          TE                              0
#                                       00-0037746 Brian Robinson      RB                              0
#
#                                                                                rushing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                   26
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                    0
#                                       00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                  133
#
#                                                                                rushing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  1
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                  0
#                                       00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0036628 John Bates          TE                  0
#                                       00-0037746 Brian Robinson      RB                  0
#
#                                                                                rushing_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                           0
#                                       00-0030061 Zach Ertz           TE                           0
#                                       00-0033553 James Conner        RB                           0
#                                       00-0035500 Greg Dortch         WR                           0
#                                       00-0035527 Andy Isabella       WR                           0
# ...                                                                                             ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                           0
#                                       00-0035659 Terry McLaurin      WR                           0
#                                       00-0036626 Dyami Brown         WR                           0
#                                       00-0036628 John Bates          TE                           0
#                                       00-0037746 Brian Robinson      RB                           0
#
#                                                                                rushing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                              0
#                                       00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0036628 John Bates          TE                              0
#                                       00-0037746 Brian Robinson      RB                              0
#
#                                                                                receptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                 2
#                                       00-0030061 Zach Ertz           TE                 2
#                                       00-0033553 James Conner        RB                 5
#                                       00-0035500 Greg Dortch         WR                 7
#                                       00-0035527 Andy Isabella       WR                 1
# ...                                                                                   ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                 3
#                                       00-0035659 Terry McLaurin      WR                 6
#                                       00-0036626 Dyami Brown         WR                 2
#                                       00-0036628 John Bates          TE                 1
#                                       00-0037746 Brian Robinson      RB                 1
#
#                                                                                receiving_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                     13
#                                       00-0030061 Zach Ertz           TE                     14
#                                       00-0033553 James Conner        RB                     29
#                                       00-0035500 Greg Dortch         WR                     63
#                                       00-0035527 Andy Isabella       WR                     10
# ...                                                                                        ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                     14
#                                       00-0035659 Terry McLaurin      WR                     22
#                                       00-0036626 Dyami Brown         WR                     17
#                                       00-0036628 John Bates          TE                      5
#                                       00-0037746 Brian Robinson      RB                      3
#
#                                                                                ...  \
# season week recent_team opponent_team player_id  player_display_name position  ...
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR        ...
#                                       00-0030061 Zach Ertz           TE        ...
#                                       00-0033553 James Conner        RB        ...
#                                       00-0035500 Greg Dortch         WR        ...
#                                       00-0035527 Andy Isabella       WR        ...
# ...                                                                            ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR        ...
#                                       00-0035659 Terry McLaurin      WR        ...
#                                       00-0036626 Dyami Brown         WR        ...
#                                       00-0036628 John Bates          TE        ...
#                                       00-0037746 Brian Robinson      RB        ...
#
#                                                                                receiving_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                             0
#                                       00-0030061 Zach Ertz           TE                             0
#                                       00-0033553 James Conner        RB                             0
#                                       00-0035500 Greg Dortch         WR                             0
#                                       00-0035527 Andy Isabella       WR                             0
# ...                                                                                               ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                             0
#                                       00-0035659 Terry McLaurin      WR                             0
#                                       00-0036626 Dyami Brown         WR                             0
#                                       00-0036628 John Bates          TE                             0
#                                       00-0037746 Brian Robinson      RB                             0
#
#                                                                                receiving_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                0
#                                       00-0030061 Zach Ertz           TE                                1
#                                       00-0033553 James Conner        RB                                0
#                                       00-0035500 Greg Dortch         WR                                0
#                                       00-0035527 Andy Isabella       WR                                0
# ...                                                                                                  ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                                0
#                                       00-0035659 Terry McLaurin      WR                                0
#                                       00-0036626 Dyami Brown         WR                                0
#                                       00-0036628 John Bates          TE                                0
#                                       00-0037746 Brian Robinson      RB                                0
#
#                                                                                sack_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                        0
#                                       00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0036628 John Bates          TE                        0
#                                       00-0037746 Brian Robinson      RB                        0
#
#                                                                                special_teams_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                        0
#                                       00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0036628 John Bates          TE                        0
#                                       00-0037746 Brian Robinson      RB                        0
#
#                                                                                targets  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              4
#                                       00-0030061 Zach Ertz           TE              4
#                                       00-0033553 James Conner        RB              6
#                                       00-0035500 Greg Dortch         WR              9
#                                       00-0035527 Andy Isabella       WR              3
# ...                                                                                ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR              3
#                                       00-0035659 Terry McLaurin      WR              8
#                                       00-0036626 Dyami Brown         WR              4
#                                       00-0036628 John Bates          TE              1
#                                       00-0037746 Brian Robinson      RB              3
#
#                                                                                carries  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              0
#                                       00-0030061 Zach Ertz           TE              0
#                                       00-0033553 James Conner        RB             10
#                                       00-0035500 Greg Dortch         WR              0
#                                       00-0035527 Andy Isabella       WR              0
# ...                                                                                ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR              0
#                                       00-0035659 Terry McLaurin      WR              0
#                                       00-0036626 Dyami Brown         WR              0
#                                       00-0036628 John Bates          TE              0
#                                       00-0037746 Brian Robinson      RB             17
#
#                                                                                receiving_yards_after_catch  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                  0
#                                       00-0030061 Zach Ertz           TE                                  4
#                                       00-0033553 James Conner        RB                                 38
#                                       00-0035500 Greg Dortch         WR                                 31
#                                       00-0035527 Andy Isabella       WR                                  4
# ...                                                                                                    ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                                 19
#                                       00-0035659 Terry McLaurin      WR                                 11
#                                       00-0036626 Dyami Brown         WR                                 20
#                                       00-0036628 John Bates          TE                                  0
#                                       00-0037746 Brian Robinson      RB                                 10
#
#                                                                                receiving_air_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                         42
#                                       00-0030061 Zach Ertz           TE                         22
#                                       00-0033553 James Conner        RB                          7
#                                       00-0035500 Greg Dortch         WR                         62
#                                       00-0035527 Andy Isabella       WR                         30
# ...                                                                                            ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR                         -5
#                                       00-0035659 Terry McLaurin      WR                         31
#                                       00-0036626 Dyami Brown         WR                         17
#                                       00-0036628 John Bates          TE                          5
#                                       00-0037746 Brian Robinson      RB                         -9
#
#                                                                                air_yards_share  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR               0.157895
#                                       00-0030061 Zach Ertz           TE               0.082707
#                                       00-0033553 James Conner        RB               0.026316
#                                       00-0035500 Greg Dortch         WR               0.233083
#                                       00-0035527 Andy Isabella       WR               0.112782
# ...                                                                                        ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR              -0.040984
#                                       00-0035659 Terry McLaurin      WR               0.254098
#                                       00-0036626 Dyami Brown         WR               0.139344
#                                       00-0036628 John Bates          TE               0.040984
#                                       00-0037746 Brian Robinson      RB              -0.073770
#
#                                                                                target_share
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR            0.111111
#                                       00-0030061 Zach Ertz           TE            0.111111
#                                       00-0033553 James Conner        RB            0.166667
#                                       00-0035500 Greg Dortch         WR            0.250000
#                                       00-0035527 Andy Isabella       WR            0.083333
# ...                                                                                     ...
# 2024   2    WAS         NYG           00-0035208 Olamide Zaccheaus   WR            0.103448
#                                       00-0035659 Terry McLaurin      WR            0.275862
#                                       00-0036626 Dyami Brown         WR            0.137931
#                                       00-0036628 John Bates          TE            0.034483
#                                       00-0037746 Brian Robinson      RB            0.103448
#
# [10364 rows x 21 columns]

# %%
def replace(code, old, new):
    """
    Basically a find and replace
    """
    return code.replace(old, new)

# %%
flex_df.reset_index(inplace = True, drop = False)

# %%
#There are a few errant rows where the opponent matches the team
flex_df = flex_df[~(flex_df['recent_team'] == flex_df['opponent_team'])]

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10363
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10358 non-null  int64
#  1   week                         10358 non-null  int64
#  2   recent_team                  10358 non-null  object
#  3   opponent_team                10358 non-null  object
#  4   player_id                    10358 non-null  object
#  5   player_display_name          10358 non-null  object
#  6   position                     10358 non-null  object
#  7   passing_yards                10358 non-null  int64
#  8   passing_tds                  10358 non-null  int64
#  9   interceptions                10358 non-null  int64
#  10  passing_2pt_conversions      10358 non-null  int64
#  11  rushing_yards                10358 non-null  int64
#  12  rushing_tds                  10358 non-null  int64
#  13  rushing_fumbles_lost         10358 non-null  int64
#  14  rushing_2pt_conversions      10358 non-null  int64
#  15  receptions                   10358 non-null  int64
#  16  receiving_yards              10358 non-null  int64
#  17  receiving_tds                10358 non-null  int64
#  18  receiving_fumbles_lost       10358 non-null  int64
#  19  receiving_2pt_conversions    10358 non-null  int64
#  20  sack_fumbles_lost            10358 non-null  int64
#  21  special_teams_tds            10358 non-null  int64
#  22  targets                      10358 non-null  int64
#  23  carries                      10358 non-null  int64
#  24  receiving_yards_after_catch  10358 non-null  int64
#  25  receiving_air_yards          10358 non-null  int64
#  26  air_yards_share              10358 non-null  float64
#  27  target_share                 10358 non-null  float64
# dtypes: float64(2), int64(21), object(5)
# memory usage: 2.3+ MB

# %% [markdown]
# # What do we need from play-by-play?
# Let's take a look at the data we'd like to have and see where we need to integrate the play-by-play data. We have yards_after_catch and air_yards. We have targets and target share. Even though the target share doesn't add up to 100 percent, it's still useful. We'll definitely want to spot-check that.<br>
#
# We have carries but no carry share. Maybe we need to just take the total carries for each team in each game from the pbp and join that with the flex_df. That shouldn't be too hard. Then we can figure out every RBs workload even if they don't all add up to 100.<br>
#
# We also want goal_to_go binary for each play to see how many carries or targets a player gets in goal-line situations and also the rate at which they score TDs in those situations.<br>

# %%
run_df = pbp_df[pbp_df['play_type'] == 'run']

# %%
running_play_counts = run_df.groupby(['season', 'week', 'posteam', 'defteam', 'game_id']).size().reset_index(name='total_carries')

# %%
running_play_counts.rename(columns = {'posteam' : 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_df, running_play_counts, on = ['season', 'week', 'recent_team', 'opponent_team'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10358 non-null  int64
#  1   week                         10358 non-null  int64
#  2   recent_team                  10358 non-null  object
#  3   opponent_team                10358 non-null  object
#  4   player_id                    10358 non-null  object
#  5   player_display_name          10358 non-null  object
#  6   position                     10358 non-null  object
#  7   passing_yards                10358 non-null  int64
#  8   passing_tds                  10358 non-null  int64
#  9   interceptions                10358 non-null  int64
#  10  passing_2pt_conversions      10358 non-null  int64
#  11  rushing_yards                10358 non-null  int64
#  12  rushing_tds                  10358 non-null  int64
#  13  rushing_fumbles_lost         10358 non-null  int64
#  14  rushing_2pt_conversions      10358 non-null  int64
#  15  receptions                   10358 non-null  int64
#  16  receiving_yards              10358 non-null  int64
#  17  receiving_tds                10358 non-null  int64
#  18  receiving_fumbles_lost       10358 non-null  int64
#  19  receiving_2pt_conversions    10358 non-null  int64
#  20  sack_fumbles_lost            10358 non-null  int64
#  21  special_teams_tds            10358 non-null  int64
#  22  targets                      10358 non-null  int64
#  23  carries                      10358 non-null  int64
#  24  receiving_yards_after_catch  10358 non-null  int64
#  25  receiving_air_yards          10358 non-null  int64
#  26  air_yards_share              10358 non-null  float64
#  27  target_share                 10358 non-null  float64
#  28  game_id                      10358 non-null  object
#  29  total_carries                10358 non-null  int64
# dtypes: float64(2), int64(22), object(6)
# memory usage: 2.4+ MB

# %%
flex_merge['carry_share'] = round(flex_merge['carries']/flex_merge['total_carries'], 3)

# %%
flex_merge.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  special_teams_tds  \
# 0       WR              0            0              0  ...                  0
# 1       TE              0            0              0  ...                  0
# 2       RB              0            0              0  ...                  0
# 3       WR              0            0              0  ...                  0
# 4       WR              0            0              0  ...                  0
#
#    targets  carries  receiving_yards_after_catch  receiving_air_yards  \
# 0        4        0                            0                   42
# 1        4        0                            4                   22
# 2        6       10                           38                    7
# 3        9        0                           31                   62
# 4        3        0                            4                   30
#
#    air_yards_share  target_share         game_id  total_carries  carry_share
# 0         0.157895      0.111111  2022_01_KC_ARI             21        0.000
# 1         0.082707      0.111111  2022_01_KC_ARI             21        0.000
# 2         0.026316      0.166667  2022_01_KC_ARI             21        0.476
# 3         0.233083      0.250000  2022_01_KC_ARI             21        0.000
# 4         0.112782      0.083333  2022_01_KC_ARI             21        0.000
#
# [5 rows x 31 columns]

# %%
flex_merge.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10328    2024     2          SF           MIN  00-0032128        Chris Conley
# 10329    2024     2          SF           MIN  00-0033288       George Kittle
# 10330    2024     2          SF           MIN  00-0033576        Eric Saubert
# 10331    2024     2          SF           MIN  00-0035719        Deebo Samuel
# 10332    2024     2          SF           MIN  00-0036259      Jauan Jennings
# 10333    2024     2          SF           MIN  00-0036261       Brandon Aiyuk
# 10334    2024     2          SF           MIN  00-0037525        Jordan Mason
# 10335    2024     2          SF           MIN  00-0039363      Isaac Guerendo
# 10336    2024     2          TB           DET  00-0031408          Mike Evans
# 10337    2024     2          TB           DET  00-0033921        Chris Godwin
# 10338    2024     2          TB           DET  00-0037256       Rachaad White
# 10339    2024     2          TB           DET  00-0038129          Cade Otton
# 10340    2024     2          TB           DET  00-0039361        Bucky Irving
# 10341    2024     2          TB           DET  00-0039855      Jalen McMillan
# 10342    2024     2         TEN           NYJ  00-0030564     DeAndre Hopkins
# 10343    2024     2         TEN           NYJ  00-0033009          Tyler Boyd
# 10344    2024     2         TEN           NYJ  00-0034837       Calvin Ridley
# 10345    2024     2         TEN           NYJ  00-0035261        Tony Pollard
# 10346    2024     2         TEN           NYJ  00-0037742       Treylon Burks
# 10347    2024     2         TEN           NYJ  00-0037809   Chigoziem Okonkwo
# 10348    2024     2         TEN           NYJ  00-0038589          Josh Whyle
# 10349    2024     2         TEN           NYJ  00-0039032        Tyjae Spears
# 10350    2024     2         WAS           NYG  00-0030061           Zach Ertz
# 10351    2024     2         WAS           NYG  00-0033591          Noah Brown
# 10352    2024     2         WAS           NYG  00-0033699       Austin Ekeler
# 10353    2024     2         WAS           NYG  00-0035208   Olamide Zaccheaus
# 10354    2024     2         WAS           NYG  00-0035659      Terry McLaurin
# 10355    2024     2         WAS           NYG  00-0036626         Dyami Brown
# 10356    2024     2         WAS           NYG  00-0036628          John Bates
# 10357    2024     2         WAS           NYG  00-0037746      Brian Robinson
#
#       position  passing_yards  passing_tds  interceptions  ...  \
# 10328       WR              0            0              0  ...
# 10329       TE              0            0              0  ...
# 10330       TE              0            0              0  ...
# 10331       WR              0            0              0  ...
# 10332       WR              0            0              0  ...
# 10333       WR              0            0              0  ...
# 10334       RB              0            0              0  ...
# 10335       RB              0            0              0  ...
# 10336       WR              0            0              0  ...
# 10337       WR              0            0              0  ...
# 10338       RB              0            0              0  ...
# 10339       TE              0            0              0  ...
# 10340       RB              0            0              0  ...
# 10341       WR              0            0              0  ...
# 10342       WR              0            0              0  ...
# 10343       WR              0            0              0  ...
# 10344       WR              0            0              0  ...
# 10345       RB              0            0              0  ...
# 10346       WR              0            0              0  ...
# 10347       TE              0            0              0  ...
# 10348       TE              0            0              0  ...
# 10349       RB              0            0              0  ...
# 10350       TE              0            0              0  ...
# 10351       WR              0            0              0  ...
# 10352       RB              0            0              0  ...
# 10353       WR              0            0              0  ...
# 10354       WR              0            0              0  ...
# 10355       WR              0            0              0  ...
# 10356       TE              0            0              0  ...
# 10357       RB              0            0              0  ...
#
#        special_teams_tds  targets  carries  receiving_yards_after_catch  \
# 10328                  0        1        0                            0
# 10329                  0        8        0                           45
# 10330                  0        2        0                           11
# 10331                  0       10        2                           19
# 10332                  0        4        0                            6
# 10333                  0        5        0                            5
# 10334                  0        1       20                            1
# 10335                  0        0        1                            0
# 10336                  0        6        0                           18
# 10337                  0        8        0                           61
# 10338                  0        1       10                           11
# 10339                  0        2        1                            0
# 10340                  0        0        7                            0
# 10341                  0        2        0                            0
# 10342                  0        2        0                            0
# 10343                  0        5        0                            9
# 10344                  0        6        1                           14
# 10345                  0        6       17                           22
# 10346                  0        1        0                            0
# 10347                  0        3        0                           15
# 10348                  0        2        0                            8
# 10349                  0        2        6                           14
# 10350                  0        4        0                           11
# 10351                  0        3        0                           17
# 10352                  0        3        8                           54
# 10353                  0        3        0                           19
# 10354                  0        8        0                           11
# 10355                  0        4        0                           20
# 10356                  0        1        0                            0
# 10357                  0        3       17                           10
#
#        receiving_air_yards  air_yards_share  target_share          game_id  \
# 10328                    4         0.013029      0.027778   2024_02_SF_MIN
# 10329                   58         0.188925      0.222222   2024_02_SF_MIN
# 10330                   15         0.048860      0.055556   2024_02_SF_MIN
# 10331                  104         0.338762      0.277778   2024_02_SF_MIN
# 10332                   55         0.179153      0.111111   2024_02_SF_MIN
# 10333                   42         0.136808      0.138889   2024_02_SF_MIN
# 10334                    3         0.009772      0.027778   2024_02_SF_MIN
# 10335                    0         0.000000      0.000000   2024_02_SF_MIN
# 10336                   43         0.282895      0.315789   2024_02_TB_DET
# 10337                   76         0.500000      0.421053   2024_02_TB_DET
# 10338                   -6        -0.039474      0.052632   2024_02_TB_DET
# 10339                    0         0.000000      0.105263   2024_02_TB_DET
# 10340                    0         0.000000      0.000000   2024_02_TB_DET
# 10341                   39         0.256579      0.105263   2024_02_TB_DET
# 10342                   17         0.057823      0.074074  2024_02_NYJ_TEN
# 10343                   50         0.170068      0.185185  2024_02_NYJ_TEN
# 10344                  159         0.540816      0.222222  2024_02_NYJ_TEN
# 10345                   17         0.057823      0.222222  2024_02_NYJ_TEN
# 10346                   48         0.163265      0.037037  2024_02_NYJ_TEN
# 10347                    1         0.003401      0.111111  2024_02_NYJ_TEN
# 10348                    5         0.017007      0.074074  2024_02_NYJ_TEN
# 10349                   -3        -0.010204      0.074074  2024_02_NYJ_TEN
# 10350                   51         0.418033      0.137931  2024_02_NYG_WAS
# 10351                   39         0.319672      0.103448  2024_02_NYG_WAS
# 10352                   -7        -0.057377      0.103448  2024_02_NYG_WAS
# 10353                   -5        -0.040984      0.103448  2024_02_NYG_WAS
# 10354                   31         0.254098      0.275862  2024_02_NYG_WAS
# 10355                   17         0.139344      0.137931  2024_02_NYG_WAS
# 10356                    5         0.040984      0.034483  2024_02_NYG_WAS
# 10357                   -9        -0.073770      0.103448  2024_02_NYG_WAS
#
#        total_carries  carry_share
# 10328             25        0.000
# 10329             25        0.000
# 10330             25        0.000
# 10331             25        0.080
# 10332             25        0.000
# 10333             25        0.000
# 10334             25        0.800
# 10335             25        0.040
# 10336             22        0.000
# 10337             22        0.000
# 10338             22        0.455
# 10339             22        0.045
# 10340             22        0.318
# 10341             22        0.000
# 10342             28        0.000
# 10343             28        0.000
# 10344             28        0.036
# 10345             28        0.607
# 10346             28        0.000
# 10347             28        0.000
# 10348             28        0.000
# 10349             28        0.214
# 10350             33        0.000
# 10351             33        0.000
# 10352             33        0.242
# 10353             33        0.000
# 10354             33        0.000
# 10355             33        0.000
# 10356             33        0.000
# 10357             33        0.515
#
# [30 rows x 31 columns]

# %% [markdown]
# # Goal-to-go situations
# We'll filter the pbp data by rows in which goal_to_go is True and the play is either a run or a pass. We find that on passing plays, some of the receiver_player_id values are null, but for running plays none of them are null. This implies that on plays in which the QB is sacked, no pass is thrown so there's no receiver.<br>
#
# Those plays probably should be discarded as we are looking for a percentage of times a RB-WR-TE gets the ball in goal-to-go situations. When a QB is sacked, no one gets the ball.<br>
#
# **Update:** goal_to_go leaves out situations where it's 3rd and 2 from the 4-yard line. Maybe we should see if filtering by yardline_100 <= 10 gives us more data points.

# %%
gtg_df_10 = pbp_df[(pbp_df['yardline_100'] <= 10) & ((pbp_df['play_type'] == 'run') | (pbp_df['play_type'] == 'pass'))]
#gtg_df = rb_wr_te_df[(rb_wr_te_df['goal_to_go'] == True) & ((rb_wr_te_df['play_type'] == 'run') | (rb_wr_te_df['play_type'] == 'pass'))]

# %%
gtg_df_10['play_type'].value_counts()
# Out:
# play_type
# run     2805
# pass    2720
# Name: count, dtype: int64

# %%
gtg_df_10 = gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) | (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df = gtg_df[(gtg_df['receiver_player_id'].notnull()) | (gtg_df['rusher_player_id'].notnull())]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].isnull()) & (gtg_df_10['rusher_player_id'].isnull())]
#gtg_df[(gtg_df['receiver_player_id'].isnull()) & (gtg_df['rusher_player_id'].isnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) & (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df[(gtg_df['receiver_player_id'].notnull()) & (gtg_df['rusher_player_id'].notnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10['player_id'] = gtg_df_10['rusher_player_id'].fillna(gtg_df_10['receiver_player_id'])
#gtg_df['player_id'] = gtg_df['rusher_player_id'].fillna(gtg_df['receiver_player_id'])

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5197 entries, 31 to 104495
# Columns: 373 entries, play_id to player_id
# dtypes: float64(182), int64(39), object(152)
# memory usage: 14.8+ MB

# %%
#Total goal to go situations for each team in each game
grouped_gtg_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'plays_in_10')

#grouped_gtg = gtg_df.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'gtg_plays')

# %%
gtg_df_10.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'home_opening_kickoff', 'qb_epa', 'xyac_epa', 'xyac_mean_yardage',
#        'xyac_median_yardage', 'xyac_success', 'xyac_fd', 'xpass', 'pass_oe',
#        'player_id'],
#       dtype='object', length=373)

# %%
gtg_cols = ['play_id','week', 'posteam', 'defteam', 'sp', 'desc', 'play_type', 'td_player_id',
      'incomplete_pass', 'rush_attempt', 'pass_attempt',
       'touchdown', 'pass_touchdown', 'rush_touchdown', 'complete_pass', 'receiver_player_id',
       'receiver_player_name', 'rusher_player_id',
       'rusher_player_name', 'season', 'weather', 'player_id']

# %%
gtg_df_10 = gtg_df_10[gtg_cols]

# %%
gtg_df_10 = pd.merge(gtg_df_10, grouped_gtg_10, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')
#gtg_df = pd.merge(gtg_df, grouped_gtg, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')

# %%
##Next will be to derive how many times per gtg play a player gets the ball, and then when they get it their TD percentage

# %%
gtg_10_player = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'opps_in_10')
#gtg_player = gtg_df.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'gtg_opps')

# %%
gtg_df_10 = pd.merge(gtg_df_10, gtg_10_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')
#gtg_df = pd.merge(gtg_df, gtg_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')

# %%
gtg_df_10['in_10_share'] = round(gtg_df_10['opps_in_10']/gtg_df_10['plays_in_10'], 3)

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5197 entries, 0 to 5196
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   play_id               5197 non-null   int64
#  1   week                  5197 non-null   int64
#  2   posteam               5197 non-null   object
#  3   defteam               5197 non-null   object
#  4   sp                    5197 non-null   int64
#  5   desc                  5197 non-null   object
#  6   play_type             5197 non-null   object
#  7   td_player_id          1622 non-null   object
#  8   incomplete_pass       5197 non-null   float64
#  9   rush_attempt          5197 non-null   float64
#  10  pass_attempt          5197 non-null   float64
#  11  touchdown             5197 non-null   float64
#  12  pass_touchdown        5197 non-null   float64
#  13  rush_touchdown        5197 non-null   float64
#  14  complete_pass         5197 non-null   float64
#  15  receiver_player_id    2392 non-null   object
#  16  receiver_player_name  2392 non-null   object
#  17  rusher_player_id      2805 non-null   object
#  18  rusher_player_name    2805 non-null   object
#  19  season                5197 non-null   int64
#  20  weather               5020 non-null   object
#  21  player_id             5197 non-null   object
#  22  plays_in_10           5197 non-null   int64
#  23  opps_in_10            5197 non-null   int64
#  24  in_10_share           5197 non-null   float64
# dtypes: float64(8), int64(6), object(11)
# memory usage: 1015.2+ KB

# %%
gtg_df_10['player_id'].nunique()
# Out:
# 561

# %%
flex_merge['player_id'].nunique()
# Out:
# 668

# %%
##Maybe we need to pause here. There are more players in our weekly data than we have in our gtg data, which makes sense.
#Not every player will be used in gtg situations.
#Maybe somehow just check that every player in flex_merge but not gtg doesn't have any True values in goal_to_go
####Maybe we should just use common sense
#We've filtered every gtg play that was a run or a pass.
#If there's any irregularity it's likely to come out during spot-checking

# %%
gtg_players = list(gtg_df_10['player_id'].unique())

# %%
flex_players = list(flex_merge['player_id'].unique())

# %%
len(gtg_players)
# Out:
# 561

# %%
len(flex_players)
# Out:
# 668

# %%
#gtg_df = gtg_df.sort_values(by = ['season', 'week', 'posteam', 'defteam'])

# %%
gtg_df_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id'], as_index=False).agg({'in_10_share': 'mean'})

# %%
#gtg_df = gtg_df[['season', 'week', 'posteam', 'defteam', 'player_id', 'gtg_share']]

# %%
gtg_df_10.tail(30)
# Out:
#       season  week posteam defteam   player_id  in_10_share
# 3310    2024     2      NO     DAL  00-0033906        0.500
# 3311    2024     2      NO     DAL  00-0033948        0.250
# 3312    2024     2     NYG     WAS  00-0035250        0.250
# 3313    2024     2     NYG     WAS  00-0035535        0.125
# 3314    2024     2     NYG     WAS  00-0038117        0.125
# 3315    2024     2     NYG     WAS  00-0039337        0.375
# 3316    2024     2     NYG     WAS  00-0039384        0.125
# 3317    2024     2     PHI     ATL  00-0034351        0.091
# 3318    2024     2     PHI     ATL  00-0034844        0.364
# 3319    2024     2     PHI     ATL  00-0036389        0.091
# 3320    2024     2     PHI     ATL  00-0036912        0.182
# 3321    2024     2     PHI     ATL  00-0037132        0.182
# 3322    2024     2     PHI     ATL  00-0039236        0.091
# 3323    2024     2     PIT     DEN  00-0036893        0.500
# 3324    2024     2     PIT     DEN  00-0038558        0.500
# 3325    2024     2     SEA      NE  00-0039165        1.000
# 3326    2024     2      SF     MIN  00-0033288        0.250
# 3327    2024     2      SF     MIN  00-0035719        0.125
# 3328    2024     2      SF     MIN  00-0036259        0.125
# 3329    2024     2      SF     MIN  00-0036261        0.125
# 3330    2024     2      SF     MIN  00-0037525        0.375
# 3331    2024     2      TB     DET  00-0037256        0.500
# 3332    2024     2      TB     DET  00-0038129        0.500
# 3333    2024     2     TEN     NYJ  00-0030564        0.200
# 3334    2024     2     TEN     NYJ  00-0034837        0.200
# 3335    2024     2     TEN     NYJ  00-0035261        0.400
# 3336    2024     2     TEN     NYJ  00-0039152        0.200
# 3337    2024     2     WAS     NYG  00-0033699        0.333
# 3338    2024     2     WAS     NYG  00-0036626        0.167
# 3339    2024     2     WAS     NYG  00-0037746        0.500

# %%
check_for_one = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam'])['in_10_share'].sum()

# %%
check_for_one.min()
# Out:
# 0.9989999999999999

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3340 entries, 0 to 3339
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       3340 non-null   int64
#  1   week         3340 non-null   int64
#  2   posteam      3340 non-null   object
#  3   defteam      3340 non-null   object
#  4   player_id    3340 non-null   object
#  5   in_10_share  3340 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 156.7+ KB

# %%
gtg_df_10.rename(columns = {'posteam': 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_merge, gtg_df_10, on = ['season', 'week', 'recent_team', 'opponent_team', 'player_id'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10358 entries, 0 to 10357
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10358 non-null  int64
#  1   week                         10358 non-null  int64
#  2   recent_team                  10358 non-null  object
#  3   opponent_team                10358 non-null  object
#  4   player_id                    10358 non-null  object
#  5   player_display_name          10358 non-null  object
#  6   position                     10358 non-null  object
#  7   passing_yards                10358 non-null  int64
#  8   passing_tds                  10358 non-null  int64
#  9   interceptions                10358 non-null  int64
#  10  passing_2pt_conversions      10358 non-null  int64
#  11  rushing_yards                10358 non-null  int64
#  12  rushing_tds                  10358 non-null  int64
#  13  rushing_fumbles_lost         10358 non-null  int64
#  14  rushing_2pt_conversions      10358 non-null  int64
#  15  receptions                   10358 non-null  int64
#  16  receiving_yards              10358 non-null  int64
#  17  receiving_tds                10358 non-null  int64
#  18  receiving_fumbles_lost       10358 non-null  int64
#  19  receiving_2pt_conversions    10358 non-null  int64
#  20  sack_fumbles_lost            10358 non-null  int64
#  21  special_teams_tds            10358 non-null  int64
#  22  targets                      10358 non-null  int64
#  23  carries                      10358 non-null  int64
#  24  receiving_yards_after_catch  10358 non-null  int64
#  25  receiving_air_yards          10358 non-null  int64
#  26  air_yards_share              10358 non-null  float64
#  27  target_share                 10358 non-null  float64
#  28  game_id                      10358 non-null  object
#  29  total_carries                10358 non-null  int64
#  30  carry_share                  10358 non-null  float64
#  31  in_10_share                  2963 non-null   float64
# dtypes: float64(4), int64(22), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# # A lot of missing in_10_share variables
# At first glance it seems like there are too many nulls in the in_10_share column, which is the percentage of plays inside the 10-yard-line that each player gets the ball. But maybe it is plausible. After all, in those goal-line situations only the best players are called upon. We'll replace with zero and investigate further when we examine the data.

# %%
flex_merge.fillna(value={'in_10_share': 0}, inplace=True)

# %% [markdown]
# Let's rename flex_merge flex_df so we can run the following code

# %%
flex_df = flex_merge

# %% [markdown]
# # Fantasy points
# This is where we calculate FanDuel and DraftKings points.

# %%
flex_df['FD_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 0.5)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost'] * 2) - (flex_df['receiving_fumbles_lost'] * 2)\
- (flex_df['rushing_fumbles_lost'] * 2)

# %%
flex_df['DK_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 1)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost']) - (flex_df['receiving_fumbles_lost'])\
- (flex_df['rushing_fumbles_lost'])

# %% [markdown]
# Adding DraftKings bonus points

# %%
flex_df['DK_Pts'] = np.where(flex_df['passing_yards'] >= 300, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['receiving_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['rushing_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])

# %%
flex_df.tail()
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10353    2024     2         WAS           NYG  00-0035208   Olamide Zaccheaus
# 10354    2024     2         WAS           NYG  00-0035659      Terry McLaurin
# 10355    2024     2         WAS           NYG  00-0036626         Dyami Brown
# 10356    2024     2         WAS           NYG  00-0036628          John Bates
# 10357    2024     2         WAS           NYG  00-0037746      Brian Robinson
#
#       position  passing_yards  passing_tds  interceptions  ...  \
# 10353       WR              0            0              0  ...
# 10354       WR              0            0              0  ...
# 10355       WR              0            0              0  ...
# 10356       TE              0            0              0  ...
# 10357       RB              0            0              0  ...
#
#        receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 10353                           19                   -5        -0.040984
# 10354                           11                   31         0.254098
# 10355                           20                   17         0.139344
# 10356                            0                    5         0.040984
# 10357                           10                   -9        -0.073770
#
#        target_share          game_id  total_carries  carry_share  in_10_share  \
# 10353      0.103448  2024_02_NYG_WAS             33        0.000        0.000
# 10354      0.275862  2024_02_NYG_WAS             33        0.000        0.000
# 10355      0.137931  2024_02_NYG_WAS             33        0.000        0.167
# 10356      0.034483  2024_02_NYG_WAS             33        0.000        0.000
# 10357      0.103448  2024_02_NYG_WAS             33        0.515        0.500
#
#        FD_Pts  DK_Pts
# 10353     2.9     4.4
# 10354     5.2     8.2
# 10355     2.7     3.7
# 10356     1.0     1.5
# 10357    14.1    17.6
#
# [5 rows x 34 columns]

# %% [markdown]
# # Storing last week's points to evaluate model

# %%
flex_points_last_week = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week - 1)]\
[['season', 'week', 'player_display_name', 'recent_team', 'opponent_team', 'position', 'FD_Pts', 'DK_Pts']]

# %%
flex_points_last_week.to_csv('flex_points_' + str(season) + '_' + str(week - 1) + '.csv')

# %%
flex_df['position'].value_counts()
# Out:
# position
# WR    4814
# RB    2998
# TE    2358
# FB     188
# Name: count, dtype: int64

# %%
flex_df['position'] = np.where(flex_df['position'].isin(['HB', 'FB']), 'RB', flex_df['position'])

# %%
pos_mean_by_team = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position']).size().reset_index(name = 'num_players')

# %%
mean_by_pos = pos_mean_by_team.groupby('position')['num_players'].agg(['mean', 'max', 'min'])

# %%
mean_by_pos
# Out:
#               mean  max  min
# position
# RB        2.650582    5    1
# TE        1.976530    4    1
# WR        4.004992    7    2

# %% [markdown]
# # Grouping points allowed by position
# First step in deriving DvP variables.

# %%
grouped_pts = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position'])[['DK_Pts', 'FD_Pts']].sum().round(3)

# %%
grouped_pts
# Out:
#                                                 DK_Pts  FD_Pts
# season week recent_team opponent_team position
# 2022   1    ARI         KC            RB          25.6    21.6
#                                       TE          11.4    10.4
#                                       WR          32.9    25.9
#             ATL         NO            RB          28.3    23.3
#                                       TE           7.0     5.0
# ...                                                ...     ...
# 2024   2    TEN         NYJ           TE           7.9     5.4
#                                       WR          31.2    27.7
#             WAS         NYG           RB          29.1    24.1
#                                       TE          11.7     9.2
#                                       WR          24.9    17.9
#
# [3597 rows x 2 columns]

# %%
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts = grouped_pts.sort_values(by = ['opponent_team', 'season', 'week'])
#grouped_pts['opp_game_num'] = grouped_pts.groupby(['opponent_team', 'season', 'week', 'recent_team']).cumcount() + 1
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts_raw = grouped_pts.copy()

# %%
grouped_pts.drop(columns = ['index'], inplace = True)

# %%
grouped_pts
# Out:
#       season  week recent_team opponent_team position  DK_Pts  FD_Pts
# 0       2022     1          KC           ARI       RB    42.5    39.5
# 1       2022     1          KC           ARI       TE    38.2    30.2
# 2       2022     1          KC           ARI       WR    35.6    27.6
# 3       2022     2          LV           ARI       RB    12.6    11.6
# 4       2022     2          LV           ARI       TE    23.0    18.5
# ...      ...   ...         ...           ...      ...     ...     ...
# 3592    2024     1          TB           WAS       RB    26.2    22.2
# 3593    2024     1          TB           WAS       TE     1.5     1.0
# 3594    2024     1          TB           WAS       WR    58.5    51.0
# 3595    2024     2         NYG           WAS       RB    15.7    14.2
# 3596    2024     2         NYG           WAS       WR    47.8    37.3
#
# [3597 rows x 7 columns]

# %%
# Create the pivot table
pivot_df = grouped_pts.pivot_table(
    index=['season', 'week', 'recent_team', 'opponent_team'],
    columns='position',
    values=['DK_Pts', 'FD_Pts'],
    aggfunc='sum',  # Assuming you want to sum the points if there are duplicates
    fill_value=0  # Fill missing values with 0
)

# %%
# Flatten the MultiIndex columns created by pivot_table
pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]

# %%
# Reset the index to turn the pivot table back into a DataFrame
pivot_df.reset_index(inplace=True)

# %%
pivot_df.head()
# Out:
#    season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 0    2022     1         ARI            KC       25.6       11.4       32.9
# 1    2022     1         ATL            NO       28.3        7.0       27.1
# 2    2022     1         BAL           NYJ       11.5       10.2       39.2
# 3    2022     1         BUF           LAR       16.0        1.5       63.7
# 4    2022     1         CAR           CLE       16.5        8.4       34.4
#
#    FD_Pts_RB  FD_Pts_TE  FD_Pts_WR
# 0       21.6       10.4       25.9
# 1       23.3        5.0       20.1
# 2        9.5        7.7       35.2
# 3       10.0        1.0       52.2
# 4       14.5        6.9       26.9

# %%
pivot_df = pivot_df.sort_values(by = ['opponent_team', 'season', 'week'])

# %% [markdown]
# # Bringing in current week's FanDuel and DraftKings rows here
# We're basically cloning this notebook from model training. We need features that apply to the current NFL week. We're trying the **one extra row** concept. For now we can probably add one row for each team, with the season value being 2024 and the week value being 1.

# %%
# Connect to the SQLite database
conn = sqlite3.connect('nfl_dfs.db')

# query_flex = "SELECT * FROM flex_dataset"
# #query_weekly = "SELECT * FROM weekly_data"
# query_fd_spread = "SELECT * FROM fd_spreads"
# query_dk_spread = "SELECT * FROM dk_spreads"
query_qb_model = "SELECT * FROM fd_qb_model_ready"
# # query_pbp = "S#ELECT * FROM pbp_non_defense"
query_fd = "SELECT * FROM fd_table"
query_dk = "SELECT * FROM dk_table"
#query_rb_wr_te = "SELECT * FROM rb_wr_te_data WHERE season >= 2022"

# flex_dataset = pd.read_sql_query(query_flex, conn)
# #weekly_df = pd.read_sql_query(query_weekly, conn)
# fd_spreads = pd.read_sql_query(query_fd_spread, conn)
# dk_spreads = pd.read_sql_query(query_dk_spread, conn)
# #pbp_df = pd.read_sql_query(query_pbp, conn)
fd_table = pd.read_sql_query(query_fd, conn)
dk_table = pd.read_sql_query(query_dk, conn)
qb_model = pd.read_sql_query(query_qb_model, conn)
# rb_wr_te_df = pd.read_sql_query(query_rb_wr_te, conn)

# Close the database connection
conn.close()

# %%
fanduel_df.head()
# Out:
#              ID               name position  salary team opponent  home_team  \
# 0  107027-86631        CeeDee Lamb       WR    9300  DAL      BAL          1
# 1  107027-85671   Justin Jefferson       WR    9200  MIN      HOU          1
# 2  107027-86997  Amon-Ra St. Brown       WR    9100  DET      ARI          0
# 3  107027-53681        Tyreek Hill       WR    9000  MIA      SEA          0
# 4  107027-63115      Lamar Jackson       QB    8800  BAL      DAL          0
#
#    status        date  week
# 0  Active  09-22-2024     3
# 1  Active  09-22-2024     3
# 2  Active  09-22-2024     3
# 3  Active  09-22-2024     3
# 4  Active  09-22-2024     3

# %%
draftkings_df.head()
# Out:
#          ID                 name position  salary team opponent  home_team  \
# 0  35940249          CeeDee Lamb       WR    8800  DAL      BAL          1
# 1  35940251     Justin Jefferson       WR    8600  MIN      HOU          1
# 2  35939981  Christian McCaffrey       RB    8500   SF      LAR          0
# 3  35940253          Tyreek Hill       WR    8400  MIA      SEA          0
# 4  35940255    Amon-Ra St. Brown       WR    8200  DET      ARI          0
#
#    status        date  week
# 0  Active  09-22-2024     3
# 1  Active  09-22-2024     3
# 2      IR  09-22-2024     3
# 3  Active  09-22-2024     3
# 4  Active  09-22-2024     3

# %%
# Initialize empty lists for teams and opponents
#We'll use FanDuel here because they tend to list more players than DK and we're less likely to miss anyone.
team_list = []
opponent_list = []

# Initialize a set to keep track of already added matchups
added_matchups = set()

# Loop through each row in the dataframe
for index, row in fanduel_df.iterrows():
    team = row['team']
    opponent = row['opponent']
    
    # Ensure each team and opponent are added only once in reverse order as well
    if (team, opponent) not in added_matchups and (opponent, team) not in added_matchups:
        # Add the matchup as-is
        team_list.append(team)
        opponent_list.append(opponent)
        
        # Add the reverse matchup
        team_list.append(opponent)
        opponent_list.append(team)
        
        # Track the added matchups
        added_matchups.add((team, opponent))
        added_matchups.add((opponent, team))

# Display the resulting lists
print("Team list:", team_list)
print("Opponent list:", opponent_list)
# Out:
# Team list: ['DAL', 'BAL', 'MIN', 'HOU', 'DET', 'ARI', 'MIA', 'SEA', 'KC', 'ATL', 'PHI', 'NO', 'SF', 'LAR', 'TB', 'DEN', 'IND', 'CHI', 'LV', 'CAR', 'GB', 'TEN', 'LAC', 'PIT', 'CLE', 'NYG']
# Opponent list: ['BAL', 'DAL', 'HOU', 'MIN', 'ARI', 'DET', 'SEA', 'MIA', 'ATL', 'KC', 'NO', 'PHI', 'LAR', 'SF', 'DEN', 'TB', 'CHI', 'IND', 'CAR', 'LV', 'TEN', 'GB', 'PIT', 'LAC', 'NYG', 'CLE']

# %%
len(team_list), len(opponent_list)
# Out:
# (26, 26)

# %%
append_to_pivot = {'season': [season] * len(team_list), 'week': [week] * len(team_list), 'recent_team': team_list, 'opponent_team': opponent_list}

# %%
append_to_pivot = pd.DataFrame(append_to_pivot)

# %%
pivot_df = pd.concat([pivot_df, append_to_pivot], axis = 0)

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1228 entries, 15 to 25
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1228 non-null   int64
#  1   week           1228 non-null   int64
#  2   recent_team    1228 non-null   object
#  3   opponent_team  1228 non-null   object
#  4   DK_Pts_RB      1202 non-null   float64
#  5   DK_Pts_TE      1202 non-null   float64
#  6   DK_Pts_WR      1202 non-null   float64
#  7   FD_Pts_RB      1202 non-null   float64
#  8   FD_Pts_TE      1202 non-null   float64
#  9   FD_Pts_WR      1202 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 105.5+ KB

# %%
pivot_df['opp_game_num'] = pivot_df.groupby(['opponent_team']).cumcount() + 1

# %%
cols_for_dvp = ['DK_Pts_RB', 'DK_Pts_TE', 'DK_Pts_WR', 'FD_Pts_RB', 'FD_Pts_TE', 'FD_Pts_WR']

# %%
pivot_df_by_game = pivot_df.copy()

# %%
pivot_df.head()
# Out:
#      season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 15     2022     1          KC           ARI       42.5       38.2       35.6
# 50     2022     2          LV           ARI       12.6       23.0       32.7
# 81     2022     3         LAR           ARI       12.8       13.9       37.0
# 100    2022     4         CAR           ARI       26.0        8.0       17.7
# 153    2022     5         PHI           ARI       10.4       17.5       29.8
#
#      FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 15        39.5       30.2       27.6             1
# 50        11.6       18.5       24.7             2
# 81        11.8       11.4       30.5             3
# 100       21.5        6.0       13.2             4
# 153        9.4       13.5       21.8             5

# %%
pivot_df.tail()
# Out:
#     season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 21    2024     3         TEN            GB        NaN        NaN        NaN
# 22    2024     3         LAC           PIT        NaN        NaN        NaN
# 23    2024     3         PIT           LAC        NaN        NaN        NaN
# 24    2024     3         CLE           NYG        NaN        NaN        NaN
# 25    2024     3         NYG           CLE        NaN        NaN        NaN
#
#     FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 21        NaN        NaN        NaN            39
# 22        NaN        NaN        NaN            38
# 23        NaN        NaN        NaN            38
# 24        NaN        NaN        NaN            39
# 25        NaN        NaN        NaN            38

# %%
pivot_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # DvP variables
# We'll take an 8-game rolling mean for fantasy points allowed to RBs, WRs and TEs for each team, even if the games go back to last season. DvP means defense vs. position.

# %%
def calculate_equal_rolling_mean(group, cols, suffix):
    """
    This function calculates a rolling mean for the last eight games, going back to previous season if necessary.
    It also calculates when there are less than eight games to use.
    """
    for col in cols:
        group[f'{col}{suffix}'] = (
            group[col].shift().rolling(window=8, min_periods=1).mean()
        )
    return group

# %%
pivot_df = pivot_df.groupby('opponent_team', as_index = False).apply(calculate_equal_rolling_mean, cols=cols_for_dvp, suffix = '_DvP')

# %%
pivot_df.drop(columns = cols_for_dvp + ['opp_game_num'], inplace = True)

# %%
pivot_df
# Out:
#          season  week recent_team opponent_team  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0  15      2022     1          KC           ARI            NaN            NaN
#    50      2022     2          LV           ARI      42.500000      38.200000
#    81      2022     3         LAR           ARI      27.550000      30.600000
#    100     2022     4         CAR           ARI      22.633333      25.033333
#    153     2022     5         PHI           ARI      23.475000      20.775000
# ...         ...   ...         ...           ...            ...            ...
# 31 1040    2023    16         NYJ           WAS      29.400000      10.025000
#    1076    2023    17          SF           WAS      32.612500       8.125000
#    1088    2023    18         DAL           WAS      33.900000       7.912500
#    1167    2024     1          TB           WAS      33.962500       8.212500
#    1193    2024     2         NYG           WAS      33.500000       7.387500
#
#          DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0  15              NaN            NaN            NaN            NaN
#    50          35.6000      39.500000      30.200000        27.6000
#    81          34.1500      25.550000      24.350000        26.1500
#    100         35.1000      20.966667      20.033333        27.6000
#    153         30.7500      21.100000      16.525000        24.0000
# ...                ...            ...            ...            ...
# 31 1040        44.8375      25.712500       8.025000        36.9000
#    1076        45.5625      28.550000       6.312500        37.3750
#    1088        42.7375      30.025000       6.162500        34.8625
#    1167        47.3250      30.212500       6.275000        38.8875
#    1193        48.0625      29.562500       5.700000        40.0000
#
# [1228 rows x 10 columns]

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1228 entries, (0, 15) to (31, 1193)
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1228 non-null   int64
#  1   week           1228 non-null   int64
#  2   recent_team    1228 non-null   object
#  3   opponent_team  1228 non-null   object
#  4   DK_Pts_RB_DvP  1196 non-null   float64
#  5   DK_Pts_TE_DvP  1196 non-null   float64
#  6   DK_Pts_WR_DvP  1196 non-null   float64
#  7   FD_Pts_RB_DvP  1196 non-null   float64
#  8   FD_Pts_TE_DvP  1196 non-null   float64
#  9   FD_Pts_WR_DvP  1196 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 142.5+ KB

# %%
flex_df.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  \
# 0       WR              0            0              0  ...
# 1       TE              0            0              0  ...
# 2       RB              0            0              0  ...
# 3       WR              0            0              0  ...
# 4       WR              0            0              0  ...
#
#    receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 0                            0                   42         0.157895
# 1                            4                   22         0.082707
# 2                           38                    7         0.026316
# 3                           31                   62         0.233083
# 4                            4                   30         0.112782
#
#    target_share         game_id  total_carries  carry_share  in_10_share  \
# 0      0.111111  2022_01_KC_ARI             21        0.000        0.143
# 1      0.111111  2022_01_KC_ARI             21        0.000        0.429
# 2      0.166667  2022_01_KC_ARI             21        0.476        0.286
# 3      0.250000  2022_01_KC_ARI             21        0.000        0.000
# 4      0.083333  2022_01_KC_ARI             21        0.000        0.000
#
#    FD_Pts  DK_Pts
# 0     2.3     3.3
# 1    10.4    11.4
# 2    14.0    16.5
# 3     9.8    13.3
# 4     1.5     2.0
#
# [5 rows x 34 columns]

# %%
flex_df = flex_df.merge(
    pivot_df, 
    on=['season', 'week', 'recent_team', 'opponent_team'],  # common columns to merge on
    how='outer'  # outer join to keep all rows from both dataframes
)

# %%
flex_df.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10354    2024     2         WAS           NYG  00-0035659      Terry McLaurin
# 10355    2024     2         WAS           NYG  00-0036626         Dyami Brown
# 10356    2024     2         WAS           NYG  00-0036628          John Bates
# 10357    2024     2         WAS           NYG  00-0037746      Brian Robinson
# 10358    2024     3         DET           ARI         NaN                 NaN
# 10359    2024     3          KC           ATL         NaN                 NaN
# 10360    2024     3         DAL           BAL         NaN                 NaN
# 10361    2024     3          LV           CAR         NaN                 NaN
# 10362    2024     3         IND           CHI         NaN                 NaN
# 10363    2024     3         NYG           CLE         NaN                 NaN
# 10364    2024     3         BAL           DAL         NaN                 NaN
# 10365    2024     3          TB           DEN         NaN                 NaN
# 10366    2024     3         ARI           DET         NaN                 NaN
# 10367    2024     3         TEN            GB         NaN                 NaN
# 10368    2024     3         MIN           HOU         NaN                 NaN
# 10369    2024     3         CHI           IND         NaN                 NaN
# 10370    2024     3         ATL            KC         NaN                 NaN
# 10371    2024     3         PIT           LAC         NaN                 NaN
# 10372    2024     3          SF           LAR         NaN                 NaN
# 10373    2024     3         CAR            LV         NaN                 NaN
# 10374    2024     3         SEA           MIA         NaN                 NaN
# 10375    2024     3         HOU           MIN         NaN                 NaN
# 10376    2024     3         PHI            NO         NaN                 NaN
# 10377    2024     3         CLE           NYG         NaN                 NaN
# 10378    2024     3          NO           PHI         NaN                 NaN
# 10379    2024     3         LAC           PIT         NaN                 NaN
# 10380    2024     3         MIA           SEA         NaN                 NaN
# 10381    2024     3         LAR            SF         NaN                 NaN
# 10382    2024     3         DEN            TB         NaN                 NaN
# 10383    2024     3          GB           TEN         NaN                 NaN
#
#       position  passing_yards  passing_tds  interceptions  ...  carry_share  \
# 10354       WR            0.0          0.0            0.0  ...        0.000
# 10355       WR            0.0          0.0            0.0  ...        0.000
# 10356       TE            0.0          0.0            0.0  ...        0.000
# 10357       RB            0.0          0.0            0.0  ...        0.515
# 10358      NaN            NaN          NaN            NaN  ...          NaN
# 10359      NaN            NaN          NaN            NaN  ...          NaN
# 10360      NaN            NaN          NaN            NaN  ...          NaN
# 10361      NaN            NaN          NaN            NaN  ...          NaN
# 10362      NaN            NaN          NaN            NaN  ...          NaN
# 10363      NaN            NaN          NaN            NaN  ...          NaN
# 10364      NaN            NaN          NaN            NaN  ...          NaN
# 10365      NaN            NaN          NaN            NaN  ...          NaN
# 10366      NaN            NaN          NaN            NaN  ...          NaN
# 10367      NaN            NaN          NaN            NaN  ...          NaN
# 10368      NaN            NaN          NaN            NaN  ...          NaN
# 10369      NaN            NaN          NaN            NaN  ...          NaN
# 10370      NaN            NaN          NaN            NaN  ...          NaN
# 10371      NaN            NaN          NaN            NaN  ...          NaN
# 10372      NaN            NaN          NaN            NaN  ...          NaN
# 10373      NaN            NaN          NaN            NaN  ...          NaN
# 10374      NaN            NaN          NaN            NaN  ...          NaN
# 10375      NaN            NaN          NaN            NaN  ...          NaN
# 10376      NaN            NaN          NaN            NaN  ...          NaN
# 10377      NaN            NaN          NaN            NaN  ...          NaN
# 10378      NaN            NaN          NaN            NaN  ...          NaN
# 10379      NaN            NaN          NaN            NaN  ...          NaN
# 10380      NaN            NaN          NaN            NaN  ...          NaN
# 10381      NaN            NaN          NaN            NaN  ...          NaN
# 10382      NaN            NaN          NaN            NaN  ...          NaN
# 10383      NaN            NaN          NaN            NaN  ...          NaN
#
#        in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 10354        0.000     5.2     8.2        23.3625        12.0375
# 10355        0.167     2.7     3.7        23.3625        12.0375
# 10356        0.000     1.0     1.5        23.3625        12.0375
# 10357        0.500    14.1    17.6        23.3625        12.0375
# 10358          NaN     NaN     NaN        27.7100        12.8375
# 10359          NaN     NaN     NaN        22.0125        10.2375
# 10360          NaN     NaN     NaN        22.7500        16.0250
# 10361          NaN     NaN     NaN        24.2250        11.7750
# 10362          NaN     NaN     NaN        22.4625        12.5375
# 10363          NaN     NaN     NaN        23.2000        15.9125
# 10364          NaN     NaN     NaN        29.2625         8.5125
# 10365          NaN     NaN     NaN        22.5500        12.8625
# 10366          NaN     NaN     NaN        16.9125        10.0875
# 10367          NaN     NaN     NaN        22.6500        15.7375
# 10368          NaN     NaN     NaN        18.6875        11.7375
# 10369          NaN     NaN     NaN        29.0500         9.8500
# 10370          NaN     NaN     NaN        18.7375        14.6875
# 10371          NaN     NaN     NaN        21.0000         8.3625
# 10372          NaN     NaN     NaN        19.8250        12.5875
# 10373          NaN     NaN     NaN        22.3250        11.6875
# 10374          NaN     NaN     NaN        23.5625        13.4375
# 10375          NaN     NaN     NaN        21.9625        12.0875
# 10376          NaN     NaN     NaN        19.2875        11.3000
# 10377          NaN     NaN     NaN        23.5875        11.6250
# 10378          NaN     NaN     NaN        24.7625        11.2000
# 10379          NaN     NaN     NaN        19.9625        14.4375
# 10380          NaN     NaN     NaN        27.3350        14.6000
# 10381          NaN     NaN     NaN        20.3500        11.8250
# 10382          NaN     NaN     NaN        21.1125        13.0875
# 10383          NaN     NaN     NaN        20.3000        10.5125
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 10354        35.2250        20.7375         9.2875        27.9750
# 10355        35.2250        20.7375         9.2875        27.9750
# 10356        35.2250        20.7375         9.2875        27.9750
# 10357        35.2250        20.7375         9.2875        27.9750
# 10358        28.4875        24.2725        10.5250        23.4875
# 10359        27.0250        19.1375         7.9875        21.5875
# 10360        30.8500        18.4375        11.9000        24.3500
# 10361        25.9000        21.3500         9.5250        21.2750
# 10362        30.1750        18.7125         9.5375        23.8625
# 10363        29.6125        20.0750        12.9750        24.1750
# 10364        29.1200        26.3250         6.6375        23.4325
# 10365        32.7375        19.2375        10.6125        26.1125
# 10366        53.7250        15.2875         8.0875        42.5375
# 10367        37.3875        19.7750        13.1750        29.6375
# 10368        30.9500        16.3125         9.3000        24.7625
# 10369        33.2125        25.1125         7.6625        26.7125
# 10370        28.6925        15.6125        10.8750        23.0675
# 10371        29.3225        17.8125         6.5500        23.8850
# 10372        45.0125        17.4500        10.3375        36.3875
# 10373        33.0000        19.2000         8.8750        26.9375
# 10374        35.0375        21.3125        10.8750        27.7250
# 10375        40.9500        18.9000         9.2750        31.2000
# 10376        33.2500        16.0375         8.6125        27.1250
# 10377        34.3125        20.9625         9.1875        27.1250
# 10378        41.2125        22.3875         8.4500        34.9000
# 10379        27.8625        16.9000        12.2500        22.1125
# 10380        31.3625        24.0225        11.7250        23.9875
# 10381        36.7375        17.0375         9.0125        30.8000
# 10382        31.4625        17.9250        10.1500        24.2125
# 10383        34.9000        17.6750         8.3875        26.7750
#
# [30 rows x 40 columns]

# %%
flex_df.reset_index(inplace = True)

# %%
flex_df.columns
# Out:
# Index(['index', 'season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'passing_yards', 'passing_tds',
#        'interceptions', 'passing_2pt_conversions', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions',
#        'receptions', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles_lost', 'receiving_2pt_conversions',
#        'sack_fumbles_lost', 'special_teams_tds', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'game_id', 'total_carries', 'carry_share',
#        'in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
#        'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # Paring down some of the columns
# We're drop columns that won't be needed for features.

# %%
cols_to_keep = ['season', 'week', 'recent_team', 'opponent_team', 'player_id',
       'player_display_name', 'position', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 
       'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
       'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share','in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
       'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']

# %%
flex_df = flex_df[cols_to_keep]

# %%
#quarterback_df[quarterback_df['season'] >= 2006]['passing_air_yards']

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10384 non-null  int64
#  1   week                         10384 non-null  int64
#  2   recent_team                  10384 non-null  object
#  3   opponent_team                10384 non-null  object
#  4   player_id                    10358 non-null  object
#  5   player_display_name          10358 non-null  object
#  6   position                     10358 non-null  object
#  7   rushing_yards                10358 non-null  float64
#  8   rushing_tds                  10358 non-null  float64
#  9   rushing_fumbles_lost         10358 non-null  float64
#  10  receptions                   10358 non-null  float64
#  11  receiving_yards              10358 non-null  float64
#  12  receiving_tds                10358 non-null  float64
#  13  receiving_fumbles_lost       10358 non-null  float64
#  14  targets                      10358 non-null  float64
#  15  carries                      10358 non-null  float64
#  16  receiving_yards_after_catch  10358 non-null  float64
#  17  receiving_air_yards          10358 non-null  float64
#  18  air_yards_share              10358 non-null  float64
#  19  target_share                 10358 non-null  float64
#  20  carry_share                  10358 non-null  float64
#  21  in_10_share                  10358 non-null  float64
#  22  FD_Pts                       10358 non-null  float64
#  23  DK_Pts                       10358 non-null  float64
#  24  DK_Pts_RB_DvP                10104 non-null  float64
#  25  DK_Pts_TE_DvP                10104 non-null  float64
#  26  DK_Pts_WR_DvP                10104 non-null  float64
#  27  FD_Pts_RB_DvP                10104 non-null  float64
#  28  FD_Pts_TE_DvP                10104 non-null  float64
#  29  FD_Pts_WR_DvP                10104 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.4+ MB

# %% [markdown]
# # Filling missing values
# We have found that dropping rows with missing values can affect calculations down the line. So we need to find ways to fill the missing values.<br>

# %% [markdown]
# The first row of every team grouping when we calculated DvP was NaN because there was no previous value. We'll fill those in with the mean.

# %%
flex_df['FD_Pts_RB_DvP'] = flex_df['FD_Pts_RB_DvP'].fillna(flex_df['FD_Pts_RB_DvP'].mean())
flex_df['DK_Pts_RB_DvP'] = flex_df['DK_Pts_RB_DvP'].fillna(flex_df['DK_Pts_RB_DvP'].mean())
flex_df['FD_Pts_TE_DvP'] = flex_df['FD_Pts_TE_DvP'].fillna(flex_df['FD_Pts_TE_DvP'].mean())
flex_df['DK_Pts_TE_DvP'] = flex_df['DK_Pts_TE_DvP'].fillna(flex_df['DK_Pts_TE_DvP'].mean())
flex_df['FD_Pts_WR_DvP'] = flex_df['FD_Pts_WR_DvP'].fillna(flex_df['FD_Pts_WR_DvP'].mean())
flex_df['DK_Pts_WR_DvP'] = flex_df['DK_Pts_WR_DvP'].fillna(flex_df['DK_Pts_WR_DvP'].mean())

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10384 entries, 0 to 10383
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10384 non-null  int64
#  1   week                         10384 non-null  int64
#  2   recent_team                  10384 non-null  object
#  3   opponent_team                10384 non-null  object
#  4   player_id                    10358 non-null  object
#  5   player_display_name          10358 non-null  object
#  6   position                     10358 non-null  object
#  7   rushing_yards                10358 non-null  float64
#  8   rushing_tds                  10358 non-null  float64
#  9   rushing_fumbles_lost         10358 non-null  float64
#  10  receptions                   10358 non-null  float64
#  11  receiving_yards              10358 non-null  float64
#  12  receiving_tds                10358 non-null  float64
#  13  receiving_fumbles_lost       10358 non-null  float64
#  14  targets                      10358 non-null  float64
#  15  carries                      10358 non-null  float64
#  16  receiving_yards_after_catch  10358 non-null  float64
#  17  receiving_air_yards          10358 non-null  float64
#  18  air_yards_share              10358 non-null  float64
#  19  target_share                 10358 non-null  float64
#  20  carry_share                  10358 non-null  float64
#  21  in_10_share                  10358 non-null  float64
#  22  FD_Pts                       10358 non-null  float64
#  23  DK_Pts                       10358 non-null  float64
#  24  DK_Pts_RB_DvP                10384 non-null  float64
#  25  DK_Pts_TE_DvP                10384 non-null  float64
#  26  DK_Pts_WR_DvP                10384 non-null  float64
#  27  FD_Pts_RB_DvP                10384 non-null  float64
#  28  FD_Pts_TE_DvP                10384 non-null  float64
#  29  FD_Pts_WR_DvP                10384 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.4+ MB

# %%
flex_24 = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_24.head()
# Out:
#        season  week recent_team opponent_team player_id player_display_name  \
# 10358    2024     3         DET           ARI       NaN                 NaN
# 10359    2024     3          KC           ATL       NaN                 NaN
# 10360    2024     3         DAL           BAL       NaN                 NaN
# 10361    2024     3          LV           CAR       NaN                 NaN
# 10362    2024     3         IND           CHI       NaN                 NaN
#
#       position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 10358      NaN            NaN          NaN                   NaN  ...
# 10359      NaN            NaN          NaN                   NaN  ...
# 10360      NaN            NaN          NaN                   NaN  ...
# 10361      NaN            NaN          NaN                   NaN  ...
# 10362      NaN            NaN          NaN                   NaN  ...
#
#        carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 10358          NaN          NaN     NaN     NaN        27.7100        12.8375
# 10359          NaN          NaN     NaN     NaN        22.0125        10.2375
# 10360          NaN          NaN     NaN     NaN        22.7500        16.0250
# 10361          NaN          NaN     NaN     NaN        24.2250        11.7750
# 10362          NaN          NaN     NaN     NaN        22.4625        12.5375
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 10358        28.4875        24.2725        10.5250        23.4875
# 10359        27.0250        19.1375         7.9875        21.5875
# 10360        30.8500        18.4375        11.9000        24.3500
# 10361        25.9000        21.3500         9.5250        21.2750
# 10362        30.1750        18.7125         9.5375        23.8625
#
# [5 rows x 30 columns]

# %%
fd_flex = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
dk_flex = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
fd_names = set(list(fd_flex['name'].unique()))
dk_names = set(list(dk_flex['name'].unique()))

# %%
# Initialize empty lists for names, positions, teams, and opponents
name_list = []
position_list = []
team_list = []
opponent_list = []

# Loop through the dataframe to extract names, positions, teams, and opponents
for index, row in fd_flex.iterrows():
    name_list.append(row['name'])          # Add player name to name_list
    position_list.append(row['position'])  # Add player position to position_list
    team_list.append(row['team'])          # Add player's team to team_list
    opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# dk_name_list = []
# dk_position_list = []
# dk_team_list = []
# dk_opponent_list = []

# for index, row in dk_flex.iterrows():
#     dk_name_list.append(row['name'])          # Add player name to name_list
#     dk_position_list.append(row['position'])  # Add player position to position_list
#     dk_team_list.append(row['team'])          # Add player's team to team_list
#     dk_opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# Display the resulting lists
# print("Name list:", name_list)
# print("Position list:", position_list)
# print("Team list:", team_list)
# print("Opponent list:", opponent_list)

# %%
len(name_list), len(position_list)
# Out:
# (747, 747)

# %%
to_concat = {'season': [season] * len(name_list), 'week': [week] * len(name_list), 'player_display_name': name_list, 'position': position_list,\
            'recent_team': team_list, 'opponent_team': opponent_list}

# %%
to_concat = pd.DataFrame(to_concat)

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team
# 0      2024     3         CeeDee Lamb       WR         DAL           BAL
# 1      2024     3    Justin Jefferson       WR         MIN           HOU
# 2      2024     3   Amon-Ra St. Brown       WR         DET           ARI
# 3      2024     3         Tyreek Hill       WR         MIA           SEA
# 4      2024     3      Saquon Barkley       RB         PHI            NO
# ..      ...   ...                 ...      ...         ...           ...
# 742    2024     3        Dalton Keene       TE         HOU           MIN
# 743    2024     3      John Kelly Jr.       RB         BAL           DAL
# 744    2024     3    Jody Fortson Jr.       TE         MIA           SEA
# 745    2024     3      Tre'Quan Smith       WR         DET           ARI
# 746    2024     3           Nick Muse       TE         MIN           HOU
#
# [747 rows x 6 columns]

# %%
to_concat['recent_team'].value_counts()
# Out:
# recent_team
# MIA    34
# KC     34
# CAR    32
# PHI    31
# NO     31
# MIN    30
# CLE    30
# GB     30
# SEA    30
# BAL    30
# PIT    29
# LAC    29
# ARI    29
# DAL    29
# ATL    29
# IND    28
# HOU    28
# SF     27
# NYG    27
# CHI    27
# DEN    27
# TB     26
# TEN    26
# LV     26
# LAR    24
# DET    24
# Name: count, dtype: int64

# %%
flex_24.columns
# Out:
# Index(['season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'rushing_yards', 'rushing_tds',
#        'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'FD_Pts', 'DK_Pts',
#        'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
#        'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_24 = flex_24[['season', 'week', 'recent_team', 'opponent_team', 
       'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']]

# %%
to_concat = pd.merge(to_concat, flex_24, on = ['season', 'week', 'recent_team', 'opponent_team'])

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team  \
# 0      2024     3         CeeDee Lamb       WR         DAL           BAL
# 1      2024     3     Ezekiel Elliott       RB         DAL           BAL
# 2      2024     3       Brandin Cooks       WR         DAL           BAL
# 3      2024     3         Rico Dowdle       RB         DAL           BAL
# 4      2024     3       Jake Ferguson       TE         DAL           BAL
# ..      ...   ...                 ...      ...         ...           ...
# 742    2024     3      Dillon Johnson       RB         CAR            LV
# 743    2024     3      Feleipe Franks       TE         CAR            LV
# 744    2024     3        Devin Carter       WR         CAR            LV
# 745    2024     3       Curtis Hodges       TE         CAR            LV
# 746    2024     3      Jesper Horsted       TE         CAR            LV
#
#      DK_Pts_RB_DvP  DK_Pts_TE_DvP  DK_Pts_WR_DvP  FD_Pts_RB_DvP  \
# 0           22.750        16.0250          30.85        18.4375
# 1           22.750        16.0250          30.85        18.4375
# 2           22.750        16.0250          30.85        18.4375
# 3           22.750        16.0250          30.85        18.4375
# 4           22.750        16.0250          30.85        18.4375
# ..             ...            ...            ...            ...
# 742         22.325        11.6875          33.00        19.2000
# 743         22.325        11.6875          33.00        19.2000
# 744         22.325        11.6875          33.00        19.2000
# 745         22.325        11.6875          33.00        19.2000
# 746         22.325        11.6875          33.00        19.2000
#
#      FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0           11.900        24.3500
# 1           11.900        24.3500
# 2           11.900        24.3500
# 3           11.900        24.3500
# 4           11.900        24.3500
# ..             ...            ...
# 742          8.875        26.9375
# 743          8.875        26.9375
# 744          8.875        26.9375
# 745          8.875        26.9375
# 746          8.875        26.9375
#
# [747 rows x 12 columns]

# %%
to_concat['opponent_team'].value_counts()
# Out:
# opponent_team
# SEA    34
# ATL    34
# LV     32
# NO     31
# PHI    31
# HOU    30
# NYG    30
# TEN    30
# MIA    30
# DAL    30
# LAC    29
# PIT    29
# DET    29
# BAL    29
# KC     29
# CHI    28
# MIN    28
# LAR    27
# CLE    27
# IND    27
# TB     27
# DEN    26
# GB     26
# CAR    26
# SF     24
# ARI    24
# Name: count, dtype: int64

# %%
flex_df = flex_df[~((flex_df['season'] == season) & (flex_df['week'] == week))]

# %%
flex_df = pd.concat([flex_df, to_concat], axis = 0)

# %%
flex_df
# Out:
#      season  week recent_team opponent_team   player_id player_display_name  \
# 0      2022     1         ARI            KC  00-0027942          A.J. Green
# 1      2022     1         ARI            KC  00-0030061           Zach Ertz
# 2      2022     1         ARI            KC  00-0033553        James Conner
# 3      2022     1         ARI            KC  00-0035500         Greg Dortch
# 4      2022     1         ARI            KC  00-0035527       Andy Isabella
# ..      ...   ...         ...           ...         ...                 ...
# 742    2024     3         CAR            LV         NaN      Dillon Johnson
# 743    2024     3         CAR            LV         NaN      Feleipe Franks
# 744    2024     3         CAR            LV         NaN        Devin Carter
# 745    2024     3         CAR            LV         NaN       Curtis Hodges
# 746    2024     3         CAR            LV         NaN      Jesper Horsted
#
#     position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 0         WR            0.0          0.0                   0.0  ...
# 1         TE            0.0          0.0                   0.0  ...
# 2         RB           26.0          1.0                   0.0  ...
# 3         WR            0.0          0.0                   0.0  ...
# 4         WR            0.0          0.0                   0.0  ...
# ..       ...            ...          ...                   ...  ...
# 742       RB            NaN          NaN                   NaN  ...
# 743       TE            NaN          NaN                   NaN  ...
# 744       WR            NaN          NaN                   NaN  ...
# 745       TE            NaN          NaN                   NaN  ...
# 746       TE            NaN          NaN                   NaN  ...
#
#      carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0          0.000        0.143     2.3     3.3      22.658752       11.91623
# 1          0.000        0.429    10.4    11.4      22.658752       11.91623
# 2          0.476        0.286    14.0    16.5      22.658752       11.91623
# 3          0.000        0.000     9.8    13.3      22.658752       11.91623
# 4          0.000        0.000     1.5     2.0      22.658752       11.91623
# ..           ...          ...     ...     ...            ...            ...
# 742          NaN          NaN     NaN     NaN      22.325000       11.68750
# 743          NaN          NaN     NaN     NaN      22.325000       11.68750
# 744          NaN          NaN     NaN     NaN      22.325000       11.68750
# 745          NaN          NaN     NaN     NaN      22.325000       11.68750
# 746          NaN          NaN     NaN     NaN      22.325000       11.68750
#
#      DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0        34.486949      19.662571       9.422346      27.380205
# 1        34.486949      19.662571       9.422346      27.380205
# 2        34.486949      19.662571       9.422346      27.380205
# 3        34.486949      19.662571       9.422346      27.380205
# 4        34.486949      19.662571       9.422346      27.380205
# ..             ...            ...            ...            ...
# 742      33.000000      19.200000       8.875000      26.937500
# 743      33.000000      19.200000       8.875000      26.937500
# 744      33.000000      19.200000       8.875000      26.937500
# 745      33.000000      19.200000       8.875000      26.937500
# 746      33.000000      19.200000       8.875000      26.937500
#
# [11105 rows x 30 columns]

# %%
cols_L8 = ['rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets',\
           'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share', 'carry_share', 'in_10_share']

# %%
flex_L8_features = flex_df.groupby(['player_display_name', 'season', 'week'])[cols_L8].sum()

# %% [markdown]
# # L8 variables
# L8 variables are rolling means of features over the last eight games. Just like we did for the DvP variables, we'll calculate features over the previous eight games for individual QBs.

# %%
flex_L8_features = flex_L8_features.sort_values(by = ['player_display_name', 'season', 'week'])
flex_L8_features['game_num'] = flex_L8_features.groupby(['player_display_name', 'season']).cumcount() + 1
#quarterback_df.reset_index(drop = True, inplace = True)

# %%
flex_L8_features = flex_L8_features.groupby(['player_display_name'], as_index = False).apply(calculate_equal_rolling_mean, cols=cols_L8, suffix = '_L8')

# %%
flex_L8_features.reset_index(inplace = True)

# %%
flex_L8_features.columns
# Out:
# Index(['level_0', 'player_display_name', 'season', 'week', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'game_num',
#        'rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8',
#        'receptions_L8', 'receiving_yards_L8', 'receiving_tds_L8',
#        'receiving_fumbles_lost_L8', 'targets_L8', 'carries_L8',
#        'receiving_yards_after_catch_L8', 'receiving_air_yards_L8',
#        'air_yards_share_L8', 'target_share_L8', 'carry_share_L8',
#        'in_10_share_L8'],
#       dtype='object')

# %%
flex_L8_features.drop(columns = ['level_0', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
       'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share', 'in_10_share'], inplace = True)

# %%
flex_L8_features
# Out:
#       player_display_name  season  week  game_num  rushing_yards_L8  \
# 0              A.J. Brown    2022     1         1               NaN
# 1              A.J. Brown    2022     2         2          0.000000
# 2              A.J. Brown    2022     3         3          0.000000
# 3              A.J. Brown    2022     4         4          0.000000
# 4              A.J. Brown    2022     5         5          0.000000
# ...                   ...     ...   ...       ...               ...
# 11100      Zonovan Knight    2022    17         6         50.200000
# 11101      Zonovan Knight    2022    18         7         46.333333
# 11102      Zonovan Knight    2023     3         1         42.857143
# 11103      Zonovan Knight    2023     5         2         39.125000
# 11104      Zonovan Knight    2024     3         1         30.500000
#
#        rushing_tds_L8  rushing_fumbles_lost_L8  receptions_L8  \
# 0                 NaN                      NaN            NaN
# 1            0.000000                      0.0      10.000000
# 2            0.000000                      0.0       7.500000
# 3            0.000000                      0.0       6.666667
# 4            0.000000                      0.0       6.250000
# ...               ...                      ...            ...
# 11100        0.200000                      0.0       2.200000
# 11101        0.166667                      0.0       2.166667
# 11102        0.142857                      0.0       1.857143
# 11103        0.125000                      0.0       1.625000
# 11104        0.125000                      0.0       1.375000
#
#        receiving_yards_L8  receiving_tds_L8  receiving_fumbles_lost_L8  \
# 0                     NaN               NaN                        NaN
# 1              155.000000          0.000000                        0.0
# 2              112.000000          0.000000                        0.0
# 3              103.000000          0.333333                        0.0
# 4              101.000000          0.250000                        0.0
# ...                   ...               ...                        ...
# 11100           16.600000          0.000000                        0.0
# 11101           16.666667          0.000000                        0.0
# 11102           14.285714          0.000000                        0.0
# 11103           12.500000          0.000000                        0.0
# 11104            9.250000          0.000000                        0.0
#
#        targets_L8  carries_L8  receiving_yards_after_catch_L8  \
# 0             NaN         NaN                             NaN
# 1       13.000000    0.000000                       63.000000
# 2       10.500000    0.000000                       48.500000
# 3       10.333333    0.000000                       42.333333
# 4        9.500000    0.000000                       40.250000
# ...           ...         ...                             ...
# 11100    2.200000   13.000000                       22.400000
# 11101    2.333333   12.166667                       22.000000
# 11102    2.000000   12.142857                       18.857143
# 11103    1.750000   11.000000                       16.500000
# 11104    1.500000    9.250000                       13.625000
#
#        receiving_air_yards_L8  air_yards_share_L8  target_share_L8  \
# 0                         NaN                 NaN              NaN
# 1                   94.000000            0.728682         0.448276
# 2                  102.500000            0.557721         0.353170
# 3                  110.333333            0.481474         0.333486
# 4                  105.250000            0.499995         0.323031
# ...                       ...                 ...              ...
# 11100               -5.800000           -0.014043         0.055368
# 11101               -5.000000           -0.012165         0.057251
# 11102               -4.285714           -0.010427         0.049072
# 11103               -3.750000           -0.009124         0.042938
# 11104               -4.125000           -0.011336         0.034175
#
#        carry_share_L8  in_10_share_L8
# 0                 NaN             NaN
# 1            0.000000        0.167000
# 2            0.000000        0.083500
# 3            0.000000        0.198667
# 4            0.000000        0.149000
# ...               ...             ...
# 11100        0.551200        0.116600
# 11101        0.537833        0.097167
# 11102        0.546714        0.083286
# 11103        0.491750        0.072875
# 11104        0.433375        0.031250
#
# [11105 rows x 19 columns]

# %%
flex_df = pd.merge(flex_df, flex_L8_features, on = ['player_display_name', 'season', 'week'], how = 'left')

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11105 entries, 0 to 11104
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11105 non-null  int64
#  1   week                            11105 non-null  int64
#  2   recent_team                     11105 non-null  object
#  3   opponent_team                   11105 non-null  object
#  4   player_id                       10358 non-null  object
#  5   player_display_name             11105 non-null  object
#  6   position                        11105 non-null  object
#  7   rushing_yards                   10358 non-null  float64
#  8   rushing_tds                     10358 non-null  float64
#  9   rushing_fumbles_lost            10358 non-null  float64
#  10  receptions                      10358 non-null  float64
#  11  receiving_yards                 10358 non-null  float64
#  12  receiving_tds                   10358 non-null  float64
#  13  receiving_fumbles_lost          10358 non-null  float64
#  14  targets                         10358 non-null  float64
#  15  carries                         10358 non-null  float64
#  16  receiving_yards_after_catch     10358 non-null  float64
#  17  receiving_air_yards             10358 non-null  float64
#  18  air_yards_share                 10358 non-null  float64
#  19  target_share                    10358 non-null  float64
#  20  carry_share                     10358 non-null  float64
#  21  in_10_share                     10358 non-null  float64
#  22  FD_Pts                          10358 non-null  float64
#  23  DK_Pts                          10358 non-null  float64
#  24  DK_Pts_RB_DvP                   11105 non-null  float64
#  25  DK_Pts_TE_DvP                   11105 non-null  float64
#  26  DK_Pts_WR_DvP                   11105 non-null  float64
#  27  FD_Pts_RB_DvP                   11105 non-null  float64
#  28  FD_Pts_TE_DvP                   11105 non-null  float64
#  29  FD_Pts_WR_DvP                   11105 non-null  float64
#  30  game_num                        11105 non-null  int64
#  31  rushing_yards_L8                10120 non-null  float64
#  32  rushing_tds_L8                  10120 non-null  float64
#  33  rushing_fumbles_lost_L8         10120 non-null  float64
#  34  receptions_L8                   10120 non-null  float64
#  35  receiving_yards_L8              10120 non-null  float64
#  36  receiving_tds_L8                10120 non-null  float64
#  37  receiving_fumbles_lost_L8       10120 non-null  float64
#  38  targets_L8                      10120 non-null  float64
#  39  carries_L8                      10120 non-null  float64
#  40  receiving_yards_after_catch_L8  10120 non-null  float64
#  41  receiving_air_yards_L8          10120 non-null  float64
#  42  air_yards_share_L8              10120 non-null  float64
#  43  target_share_L8                 10120 non-null  float64
#  44  carry_share_L8                  10120 non-null  float64
#  45  in_10_share_L8                  10120 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 3.9+ MB

# %% [markdown]
# # Filling missing values with mean
# In our QB model we made the mistake of dropping missing values at this point. Rookies making their debut won't have L8 variables because they haven't played before. So let's fill those values with the means.

# %%
cols_to_fill = ['rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8', 'receptions_L8',
       'receiving_yards_L8', 'receiving_tds_L8', 'receiving_fumbles_lost_L8',
       'targets_L8', 'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
       'carry_share_L8', 'in_10_share_L8']

# %%
for col in cols_to_fill:
    flex_df[col] = flex_df.groupby('position')[col].transform(lambda x: x.fillna(x.mean()))

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11105 entries, 0 to 11104
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11105 non-null  int64
#  1   week                            11105 non-null  int64
#  2   recent_team                     11105 non-null  object
#  3   opponent_team                   11105 non-null  object
#  4   player_id                       10358 non-null  object
#  5   player_display_name             11105 non-null  object
#  6   position                        11105 non-null  object
#  7   rushing_yards                   10358 non-null  float64
#  8   rushing_tds                     10358 non-null  float64
#  9   rushing_fumbles_lost            10358 non-null  float64
#  10  receptions                      10358 non-null  float64
#  11  receiving_yards                 10358 non-null  float64
#  12  receiving_tds                   10358 non-null  float64
#  13  receiving_fumbles_lost          10358 non-null  float64
#  14  targets                         10358 non-null  float64
#  15  carries                         10358 non-null  float64
#  16  receiving_yards_after_catch     10358 non-null  float64
#  17  receiving_air_yards             10358 non-null  float64
#  18  air_yards_share                 10358 non-null  float64
#  19  target_share                    10358 non-null  float64
#  20  carry_share                     10358 non-null  float64
#  21  in_10_share                     10358 non-null  float64
#  22  FD_Pts                          10358 non-null  float64
#  23  DK_Pts                          10358 non-null  float64
#  24  DK_Pts_RB_DvP                   11105 non-null  float64
#  25  DK_Pts_TE_DvP                   11105 non-null  float64
#  26  DK_Pts_WR_DvP                   11105 non-null  float64
#  27  FD_Pts_RB_DvP                   11105 non-null  float64
#  28  FD_Pts_TE_DvP                   11105 non-null  float64
#  29  FD_Pts_WR_DvP                   11105 non-null  float64
#  30  game_num                        11105 non-null  int64
#  31  rushing_yards_L8                11105 non-null  float64
#  32  rushing_tds_L8                  11105 non-null  float64
#  33  rushing_fumbles_lost_L8         11105 non-null  float64
#  34  receptions_L8                   11105 non-null  float64
#  35  receiving_yards_L8              11105 non-null  float64
#  36  receiving_tds_L8                11105 non-null  float64
#  37  receiving_fumbles_lost_L8       11105 non-null  float64
#  38  targets_L8                      11105 non-null  float64
#  39  carries_L8                      11105 non-null  float64
#  40  receiving_yards_after_catch_L8  11105 non-null  float64
#  41  receiving_air_yards_L8          11105 non-null  float64
#  42  air_yards_share_L8              11105 non-null  float64
#  43  target_share_L8                 11105 non-null  float64
#  44  carry_share_L8                  11105 non-null  float64
#  45  in_10_share_L8                  11105 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 3.9+ MB

# %% [markdown]
# # A few more features
# yards_per_carry, yards_per_reception, yards_per_target

# %%
flex_df['yards_per_carry_L8'] = flex_df['rushing_yards_L8']/flex_df['carries_L8']
flex_df['yards_per_reception_L8'] = flex_df['receiving_yards_L8']/flex_df['receptions_L8']
flex_df['yards_per_target_L8'] = flex_df['receiving_yards_L8']/flex_df['targets_L8']

# %% [markdown]
# # More missing
# Now this gives us some more missing values. In most cases, it's because we've tried to divide by zero when a player has averaged 0 carries over the last eight games. So here we should fill the missing values with 0

# %%
flex_df.fillna(0, inplace = True)

# %%
flex_df_full = flex_df.copy()

# %%
flex_df.drop(columns = cols_L8, inplace = True)

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11105 entries, 0 to 11104
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11105 non-null  int64
#  1   week                            11105 non-null  int64
#  2   recent_team                     11105 non-null  object
#  3   opponent_team                   11105 non-null  object
#  4   player_id                       11105 non-null  object
#  5   player_display_name             11105 non-null  object
#  6   position                        11105 non-null  object
#  7   FD_Pts                          11105 non-null  float64
#  8   DK_Pts                          11105 non-null  float64
#  9   DK_Pts_RB_DvP                   11105 non-null  float64
#  10  DK_Pts_TE_DvP                   11105 non-null  float64
#  11  DK_Pts_WR_DvP                   11105 non-null  float64
#  12  FD_Pts_RB_DvP                   11105 non-null  float64
#  13  FD_Pts_TE_DvP                   11105 non-null  float64
#  14  FD_Pts_WR_DvP                   11105 non-null  float64
#  15  game_num                        11105 non-null  int64
#  16  rushing_yards_L8                11105 non-null  float64
#  17  rushing_tds_L8                  11105 non-null  float64
#  18  rushing_fumbles_lost_L8         11105 non-null  float64
#  19  receptions_L8                   11105 non-null  float64
#  20  receiving_yards_L8              11105 non-null  float64
#  21  receiving_tds_L8                11105 non-null  float64
#  22  receiving_fumbles_lost_L8       11105 non-null  float64
#  23  targets_L8                      11105 non-null  float64
#  24  carries_L8                      11105 non-null  float64
#  25  receiving_yards_after_catch_L8  11105 non-null  float64
#  26  receiving_air_yards_L8          11105 non-null  float64
#  27  air_yards_share_L8              11105 non-null  float64
#  28  target_share_L8                 11105 non-null  float64
#  29  carry_share_L8                  11105 non-null  float64
#  30  in_10_share_L8                  11105 non-null  float64
#  31  yards_per_carry_L8              11105 non-null  float64
#  32  yards_per_reception_L8          11105 non-null  float64
#  33  yards_per_target_L8             11105 non-null  float64
# dtypes: float64(26), int64(3), object(5)
# memory usage: 2.9+ MB

# %%
flex_df = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_df['opponent_team'].nunique()
# Out:
# 26

# %%
flex_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# # Odds, grass, outdoors, wind
# We'll bring in CSVs with FanDuel and DraftKings odds.<br>
# This will be where we need to separate FanDuel from DraftKings dataframes since the odds and totals might be different.

# %%
fd_spreads = pd.read_csv('fd_spreads_' + str(season) + '_' + str(week) + '.csv')
dk_spreads = pd.read_csv('dk_spreads_' + str(season) + '_' + str(week) + '.csv')

# %%
fd_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      IND  CHI        43.5         0      0          0
# 1           1      CLE  NYG        38.5         1      1          0
# 2           2       TB  DEN        40.5         1      1          0
# 3           3      TEN   GB        38.5         1      0          0
# 4           4      MIN  HOU        45.5         0      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -1.5        21.0       22.5     0    2024     3
# 1         -6.5        16.0       22.5     5    2024     3
# 2         -6.5        17.0       23.5     5    2024     3
# 3         -2.5        18.0       20.5     4    2024     3
# 4          1.5        23.5       22.0     0    2024     3

# %%
dk_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      IND  CHI        43.5         0      0          0
# 1           1      CLE  NYG        38.0         1      1          0
# 2           2       TB  DEN        41.0         1      1          0
# 3           3      TEN   GB        38.0         1      0          0
# 4           4      MIN  HOU        46.0         0      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -1.0       21.25      22.25     0    2024     3
# 1         -6.5       15.75      22.25     5    2024     3
# 2         -6.0       17.50      23.50     5    2024     3
# 3         -3.0       17.50      20.50     4    2024     3
# 4          1.5       23.75      22.25     0    2024     3

# %%
fd_spreads.drop(columns = ['Unnamed: 0'], inplace = True)
dk_spreads.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
flex_df.rename(columns = {'recent_team': 'team', 'opponent_team': 'opponent'}, inplace = True)

# %%
flex_df_fd = pd.merge(flex_df, fd_spreads, on = ['team', 'opponent', 'season', 'week'])
flex_df_dk = pd.merge(flex_df, dk_spreads, on = ['team', 'opponent', 'season', 'week'])

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (747, 747)

# %%
# weekly_df[weekly_df['player_display_name'] == 'Jonathan Taylor'].tail()

# %% [markdown]
# <!-- # Bringing in point spreads and totals
# Pulling this dataframe from our database. It also includes binary variables for indoors and grass. -->

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# # Query specific columns from the table
# query1 = "SELECT * FROM spreads_totals"
# spread_df = pd.read_sql_query(query1, conn)

# # Close the connection
# conn.close()

# %%
flex_df.columns
# Out:
# Index(['season', 'week', 'team', 'opponent', 'player_id',
#        'player_display_name', 'position', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP',
#        'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP',
#        'FD_Pts_WR_DvP', 'game_num', 'rushing_yards_L8', 'rushing_tds_L8',
#        'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
#        'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
#        'carries_L8', 'receiving_yards_after_catch_L8',
#        'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
#        'carry_share_L8', 'in_10_share_L8', 'yards_per_carry_L8',
#        'yards_per_reception_L8', 'yards_per_target_L8'],
#       dtype='object')

# %%
#quarterback_df.drop(columns = ['defteam', 'passing_air_yards'], inplace = True)

# %%
flex_df.head()
# Out:
#        season  week team opponent  player_id player_display_name position  \
# 10358    2024     3  DAL      BAL          0         CeeDee Lamb       WR
# 10359    2024     3  DAL      BAL          0     Ezekiel Elliott       RB
# 10360    2024     3  DAL      BAL          0       Brandin Cooks       WR
# 10361    2024     3  DAL      BAL          0         Rico Dowdle       RB
# 10362    2024     3  DAL      BAL          0       Jake Ferguson       TE
#
#        FD_Pts  DK_Pts  DK_Pts_RB_DvP  ...  carries_L8  \
# 10358     0.0     0.0          22.75  ...       1.125
# 10359     0.0     0.0          22.75  ...      13.125
# 10360     0.0     0.0          22.75  ...       0.625
# 10361     0.0     0.0          22.75  ...       6.000
# 10362     0.0     0.0          22.75  ...       0.000
#
#        receiving_yards_after_catch_L8  receiving_air_yards_L8  \
# 10358                          49.750                  107.25
# 10359                          34.375                   -3.50
# 10360                           3.500                   77.25
# 10361                          13.750                    7.25
# 10362                          33.500                   35.50
#
#        air_yards_share_L8  target_share_L8  carry_share_L8  in_10_share_L8  \
# 10358            0.364360         0.306536        0.047375        0.238875
# 10359           -0.018676         0.190852        0.575125        0.375000
# 10360            0.265803         0.150867        0.025375        0.119125
# 10361            0.024891         0.064103        0.226750        0.033500
# 10362            0.119437         0.198185        0.000000        0.063000
#
#        yards_per_carry_L8  yards_per_reception_L8  yards_per_target_L8
# 10358            6.555556               13.142857             8.808511
# 10359            3.057143                6.400000             5.090909
# 10360            4.000000                9.172414             5.782609
# 10361            3.791667                8.857143             6.200000
# 10362            0.000000               10.181818             7.344262
#
# [5 rows x 34 columns]

# %%
divisions = {
    'CLE': 'AFC North',
    'LAR': 'NFC West',
    'LV': 'AFC West',
    'KC': 'AFC West',
    'CAR': 'NFC South',
    'NYG': 'NFC East',
    'HOU': 'AFC South',
    'DEN': 'AFC West',
    'MIN': 'NFC North',
    'TEN': 'AFC South',
    'JAX': 'AFC South',
    'SEA': 'NFC West',
    'DET': 'NFC North',
    'NO': 'NFC South',
    'CIN': 'AFC North',
    'ATL': 'NFC South',
    'NYJ': 'AFC East',
    'PHI': 'NFC East',
    'DAL': 'NFC East',
    'WAS': 'NFC East',
    'PIT': 'AFC North',
    'ARI': 'NFC West',
    'CHI': 'NFC North',
    'MIA': 'AFC East',
    'BUF': 'AFC East',
    'BAL': 'AFC North',
    'TB': 'NFC South',
    'SF': 'NFC West',
    'LAC': 'AFC West',
    'IND': 'AFC South',
    'GB': 'NFC North',
    'NE': 'AFC East'
}

# You now have a dictionary `divisions` where each team is mapped to its division.flex_df.info()

# %% [markdown]
# # Adding div_game binary column

# %%
# Map the team and opponent columns to their respective divisions
flex_df_fd['team_division'] = flex_df_fd['team'].map(divisions)
flex_df_fd['opponent_division'] = flex_df_fd['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_fd['div_game'] = np.where(flex_df_fd['team_division'] == flex_df_fd['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_fd.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Map the team and opponent columns to their respective divisions
flex_df_dk['team_division'] = flex_df_dk['team'].map(divisions)
flex_df_dk['opponent_division'] = flex_df_dk['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_dk['div_game'] = np.where(flex_df_dk['team_division'] == flex_df_dk['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_dk.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Check for positive or negative infinity in the entire DataFrame
# infinity_mask_fd = np.isinf(flex_df_fd)
# infinity_mask_dk = np.isinf(flex_df_dk)

# # Display rows with infinity values
# infinity_rows_fd = flex_df_fd[infinity_mask_fd.any(axis=1)]
# infinity_rows_dk = flex_df_dk[infinity_mask_dk.any(axis=1)]
# print(infinity_rows_fd)
# print(infinity_rows_dk)

# %% [markdown]
# # One-hot encoding for position

# %%
position_dummies_fd = pd.get_dummies(flex_df_fd['position'], prefix='pos')
position_dummies_dk = pd.get_dummies(flex_df_dk['position'], prefix='pos')

# %%
flex_df_fd = pd.concat([flex_df_fd, position_dummies_fd], axis = 1)

# %%
flex_df_dk = pd.concat([flex_df_dk, position_dummies_dk], axis = 1)

# %%
flex_df_fd['pos_RB'] = flex_df_fd['pos_RB'].astype(int)
flex_df_fd['pos_TE'] = flex_df_fd['pos_TE'].astype(int)
flex_df_fd['pos_WR'] = flex_df_fd['pos_WR'].astype(int)
flex_df_dk['pos_RB'] = flex_df_dk['pos_RB'].astype(int)
flex_df_dk['pos_TE'] = flex_df_dk['pos_TE'].astype(int)
flex_df_dk['pos_WR'] = flex_df_dk['pos_WR'].astype(int)

# %%
flex_df_fd.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)
flex_df_dk.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)

# %%
fanduel_df = fanduel_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]
draftkings_df = draftkings_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]

# %%
fanduel_df = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
draftkings_df = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
len(fanduel_df), len(draftkings_df)
# Out:
# (747, 486)

# %%
#################### Sept. 16, 2024 #####################
#Just filtered for Flex positions.
#Next will be to rename player_display_name to name and try to merge again with the flex data.
#Don't forget QB strength variables!!!!!

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (747, 747)

# %%
flex_df_fd.rename(columns = {'player_display_name': 'name'}, inplace = True)
flex_df_dk.rename(columns = {'player_display_name': 'name'}, inplace = True)

# %%
flex_df_fd = pd.merge(fanduel_df, flex_df_fd, on = ['name', 'team', 'opponent', 'week'], how = 'left')
flex_df_dk = pd.merge(draftkings_df, flex_df_dk, on = ['name', 'team', 'opponent', 'week'], how = 'left')

# %%
flex_df_fd['position'] = flex_df_fd['position_x']
flex_df_fd.drop(columns = ['position_x', 'position_y'], inplace = True)
flex_df_dk['position'] = flex_df_dk['position_x']
flex_df_dk.drop(columns = ['position_x', 'position_y'], inplace = True)

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 747 entries, 0 to 746
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            747 non-null    object
#  1   salary                          747 non-null    int64
#  2   team                            747 non-null    object
#  3   opponent                        747 non-null    object
#  4   status                          747 non-null    object
#  5   week                            747 non-null    int64
#  6   season                          747 non-null    int64
#  7   player_id                       747 non-null    int64
#  8   DK_Pts_RB_DvP                   747 non-null    float64
#  9   DK_Pts_TE_DvP                   747 non-null    float64
#  10  DK_Pts_WR_DvP                   747 non-null    float64
#  11  FD_Pts_RB_DvP                   747 non-null    float64
#  12  FD_Pts_TE_DvP                   747 non-null    float64
#  13  FD_Pts_WR_DvP                   747 non-null    float64
#  14  game_num                        747 non-null    int64
#  15  rushing_yards_L8                747 non-null    float64
#  16  rushing_tds_L8                  747 non-null    float64
#  17  rushing_fumbles_lost_L8         747 non-null    float64
#  18  receptions_L8                   747 non-null    float64
#  19  receiving_yards_L8              747 non-null    float64
#  20  receiving_tds_L8                747 non-null    float64
#  21  receiving_fumbles_lost_L8       747 non-null    float64
#  22  targets_L8                      747 non-null    float64
#  23  carries_L8                      747 non-null    float64
#  24  receiving_yards_after_catch_L8  747 non-null    float64
#  25  receiving_air_yards_L8          747 non-null    float64
#  26  air_yards_share_L8              747 non-null    float64
#  27  target_share_L8                 747 non-null    float64
#  28  carry_share_L8                  747 non-null    float64
#  29  in_10_share_L8                  747 non-null    float64
#  30  yards_per_carry_L8              747 non-null    float64
#  31  yards_per_reception_L8          747 non-null    float64
#  32  yards_per_target_L8             747 non-null    float64
#  33  total_line                      747 non-null    float64
#  34  outdoors                        747 non-null    int64
#  35  grass                           747 non-null    int64
#  36  home_team                       747 non-null    int64
#  37  spread_line                     747 non-null    float64
#  38  pred_total                      747 non-null    float64
#  39  opp_total                       747 non-null    float64
#  40  wind                            747 non-null    int64
#  41  div_game                        747 non-null    int32
#  42  pos_RB                          747 non-null    int32
#  43  pos_TE                          747 non-null    int32
#  44  pos_WR                          747 non-null    int32
#  45  position                        747 non-null    object
# dtypes: float64(28), int32(4), int64(9), object(5)
# memory usage: 256.9+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            486 non-null    object
#  1   salary                          486 non-null    int64
#  2   team                            486 non-null    object
#  3   opponent                        486 non-null    object
#  4   status                          486 non-null    object
#  5   week                            486 non-null    int64
#  6   season                          482 non-null    float64
#  7   player_id                       482 non-null    float64
#  8   DK_Pts_RB_DvP                   482 non-null    float64
#  9   DK_Pts_TE_DvP                   482 non-null    float64
#  10  DK_Pts_WR_DvP                   482 non-null    float64
#  11  FD_Pts_RB_DvP                   482 non-null    float64
#  12  FD_Pts_TE_DvP                   482 non-null    float64
#  13  FD_Pts_WR_DvP                   482 non-null    float64
#  14  game_num                        482 non-null    float64
#  15  rushing_yards_L8                482 non-null    float64
#  16  rushing_tds_L8                  482 non-null    float64
#  17  rushing_fumbles_lost_L8         482 non-null    float64
#  18  receptions_L8                   482 non-null    float64
#  19  receiving_yards_L8              482 non-null    float64
#  20  receiving_tds_L8                482 non-null    float64
#  21  receiving_fumbles_lost_L8       482 non-null    float64
#  22  targets_L8                      482 non-null    float64
#  23  carries_L8                      482 non-null    float64
#  24  receiving_yards_after_catch_L8  482 non-null    float64
#  25  receiving_air_yards_L8          482 non-null    float64
#  26  air_yards_share_L8              482 non-null    float64
#  27  target_share_L8                 482 non-null    float64
#  28  carry_share_L8                  482 non-null    float64
#  29  in_10_share_L8                  482 non-null    float64
#  30  yards_per_carry_L8              482 non-null    float64
#  31  yards_per_reception_L8          482 non-null    float64
#  32  yards_per_target_L8             482 non-null    float64
#  33  total_line                      482 non-null    float64
#  34  outdoors                        482 non-null    float64
#  35  grass                           482 non-null    float64
#  36  home_team                       482 non-null    float64
#  37  spread_line                     482 non-null    float64
#  38  pred_total                      482 non-null    float64
#  39  opp_total                       482 non-null    float64
#  40  wind                            482 non-null    float64
#  41  div_game                        482 non-null    float64
#  42  pos_RB                          482 non-null    float64
#  43  pos_TE                          482 non-null    float64
#  44  pos_WR                          482 non-null    float64
#  45  position                        486 non-null    object
# dtypes: float64(39), int64(2), object(5)
# memory usage: 174.8+ KB

# %%
###FANDUEL SCORING
#Rushing yards made = 0.1pts	
#Rushing touchdowns = 6pts	
#Passing yards = 0.04pts	
#Passing touchdowns = 4pts	
#Interceptions = -1pt	
#Receiving yards = 0.1pts	
#Receiving touchdowns = 6pts	
#Receptions = 0.5pts	
#Kickoff return touchdowns = 6pts	
#Punt return touchdowns = 6pts	
#Fumbles lost = -2pts	
#Own fumbles recovered touchdowns = 6pts	
#Two-point conversions scored = 2pts	
#Two-point conversion passes = 2pts	
#Field-goals from 0-39 yards = 3pts	
#Field-goals from 40-49 yards = 4pts	
#Field-goals from 50+ yards = 5pts	
#Extra-point conversions = 1pt

###DRAFTKINGS SCORING
#PAssing TD = 4 pts
#passing yards = .04 pts
#300 passing yards = 3 pts (bonus)
#Interception = -1 pts
#Rushing TD = 6 pts
#Rushing yds = 0.1 pts
#100 yd rushing game = 3 pts (bonus)
#Receiving TD = 6 pts
#Receiving yds = 0.1 pts
#100 receiving yards game = 3 pts (bonus)
#Receptions = 1 pt
#Punt/kickoff/FG return for TD = 6 pts
#Fumble lost = -1 pt
#2 pt conversion (pass, run or catch) = 2 pts
#Offensive fumble recovery TD = 6

# %%
features = ['DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP', 'rushing_yards_L8', 'rushing_tds_L8',
       'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
       'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
       'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'target_share_L8', 'carry_share_L8',
       'in_10_share_L8', 'yards_per_carry_L8', 'yards_per_reception_L8',
       'yards_per_target_L8', 'wind', 'div_game', 'spread_line', 'total_line',
       'outdoors', 'grass', 'home_team', 'pred_total', 'opp_total', 'qb_comp',
       'qb_att', 'qb_yds', 'qb_pass_td', 'qb_int', 'qb_comp_pct',
       'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct', 'pos_RB', 'pos_TE',
       'pos_WR']

# %% [markdown]
# # QB strength
# One last variable we want to try to add is a variable or variables that look at quarterback strength. If a team's backup QB is playing, the entire offense is downgraded and it could affect the fantasy performance of RBs, WRs and TEs.<br>
#
# We'll take the dataset we used for the QB model, filter for the primary QBs in each game and use some of the variables that look at L8 means.

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# query_qb = "SELECT * FROM qb_dataset WHERE season >= 2006"

# qb_df = pd.read_sql_query(query_qb, conn)

# # Close the database connection
# conn.close()

# %%
qb_data_fd = pd.read_csv('FD_QB_for_model_' + str(season) + '_' + str(week) + '.csv')
qb_data_dk = pd.read_csv('DK_QB_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
qb_data_fd = qb_data_fd[qb_data_fd['QB_role'] == 1]
qb_data_dk = qb_data_dk[qb_data_dk['QB_role'] == 1]

# %%
qb_data_fd.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_dk.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_fd = qb_data_fd[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
qb_data_dk = qb_data_dk[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
flex_df_fd = pd.merge(flex_df_fd, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_dk = pd.merge(flex_df_dk, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_fd = flex_df_fd.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)
flex_df_dk = flex_df_dk.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)

# %%
flex_df_fd = flex_df_fd[features]
flex_df_dk = flex_df_dk[features]

# %%
flex_df_fd.replace([np.inf, -np.inf], np.nan, inplace=True)
flex_df_dk.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# Fill missing values with the mean of each column
flex_df_fd = flex_df_fd.groupby('position').transform(lambda x: x.fillna(x.mean()))
flex_df_dk = flex_df_dk.groupby('position').transform(lambda x: x.fillna(x.mean()))

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 747 entries, ('CeeDee Lamb', 'WR', 'DAL', 'BAL', 9300, 'Active', 3, 2024) to ('Nick Muse', 'TE', 'MIN', 'HOU', 4000, 'IR', 3, 2024)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   747 non-null    float64
#  1   DK_Pts_TE_DvP                   747 non-null    float64
#  2   DK_Pts_WR_DvP                   747 non-null    float64
#  3   FD_Pts_RB_DvP                   747 non-null    float64
#  4   FD_Pts_TE_DvP                   747 non-null    float64
#  5   FD_Pts_WR_DvP                   747 non-null    float64
#  6   rushing_yards_L8                747 non-null    float64
#  7   rushing_tds_L8                  747 non-null    float64
#  8   rushing_fumbles_lost_L8         747 non-null    float64
#  9   receptions_L8                   747 non-null    float64
#  10  receiving_yards_L8              747 non-null    float64
#  11  receiving_tds_L8                747 non-null    float64
#  12  receiving_fumbles_lost_L8       747 non-null    float64
#  13  targets_L8                      747 non-null    float64
#  14  carries_L8                      747 non-null    float64
#  15  receiving_yards_after_catch_L8  747 non-null    float64
#  16  receiving_air_yards_L8          747 non-null    float64
#  17  target_share_L8                 747 non-null    float64
#  18  carry_share_L8                  747 non-null    float64
#  19  in_10_share_L8                  747 non-null    float64
#  20  yards_per_carry_L8              747 non-null    float64
#  21  yards_per_reception_L8          747 non-null    float64
#  22  yards_per_target_L8             747 non-null    float64
#  23  wind                            747 non-null    int64
#  24  div_game                        747 non-null    int32
#  25  spread_line                     747 non-null    float64
#  26  total_line                      747 non-null    float64
#  27  outdoors                        747 non-null    int64
#  28  grass                           747 non-null    int64
#  29  home_team                       747 non-null    int64
#  30  pred_total                      747 non-null    float64
#  31  opp_total                       747 non-null    float64
#  32  qb_comp                         747 non-null    float64
#  33  qb_att                          747 non-null    float64
#  34  qb_yds                          747 non-null    float64
#  35  qb_pass_td                      747 non-null    float64
#  36  qb_int                          747 non-null    float64
#  37  qb_comp_pct                     747 non-null    float64
#  38  qb_yds_per_att                  747 non-null    float64
#  39  qb_td_pct                       747 non-null    float64
#  40  qb_int_pct                      747 non-null    float64
#  41  pos_RB                          747 non-null    int32
#  42  pos_TE                          747 non-null    int32
#  43  pos_WR                          747 non-null    int32
# dtypes: float64(36), int32(4), int64(4)
# memory usage: 279.6+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 486 entries, ('CeeDee Lamb', 'WR', 'DAL', 'BAL', 8800, 'Active', 3, 2024.0) to ('Miller Forristall', 'TE', 'LAR', 'SF', 2500, 'Active', 3, 2024.0)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   486 non-null    float64
#  1   DK_Pts_TE_DvP                   486 non-null    float64
#  2   DK_Pts_WR_DvP                   486 non-null    float64
#  3   FD_Pts_RB_DvP                   486 non-null    float64
#  4   FD_Pts_TE_DvP                   486 non-null    float64
#  5   FD_Pts_WR_DvP                   486 non-null    float64
#  6   rushing_yards_L8                486 non-null    float64
#  7   rushing_tds_L8                  486 non-null    float64
#  8   rushing_fumbles_lost_L8         486 non-null    float64
#  9   receptions_L8                   486 non-null    float64
#  10  receiving_yards_L8              486 non-null    float64
#  11  receiving_tds_L8                486 non-null    float64
#  12  receiving_fumbles_lost_L8       486 non-null    float64
#  13  targets_L8                      486 non-null    float64
#  14  carries_L8                      486 non-null    float64
#  15  receiving_yards_after_catch_L8  486 non-null    float64
#  16  receiving_air_yards_L8          486 non-null    float64
#  17  target_share_L8                 486 non-null    float64
#  18  carry_share_L8                  486 non-null    float64
#  19  in_10_share_L8                  486 non-null    float64
#  20  yards_per_carry_L8              486 non-null    float64
#  21  yards_per_reception_L8          486 non-null    float64
#  22  yards_per_target_L8             486 non-null    float64
#  23  wind                            486 non-null    float64
#  24  div_game                        486 non-null    float64
#  25  spread_line                     486 non-null    float64
#  26  total_line                      486 non-null    float64
#  27  outdoors                        486 non-null    float64
#  28  grass                           486 non-null    float64
#  29  home_team                       486 non-null    float64
#  30  pred_total                      486 non-null    float64
#  31  opp_total                       486 non-null    float64
#  32  qb_comp                         486 non-null    float64
#  33  qb_att                          486 non-null    float64
#  34  qb_yds                          486 non-null    float64
#  35  qb_pass_td                      486 non-null    float64
#  36  qb_int                          486 non-null    float64
#  37  qb_comp_pct                     486 non-null    float64
#  38  qb_yds_per_att                  486 non-null    float64
#  39  qb_td_pct                       486 non-null    float64
#  40  qb_int_pct                      486 non-null    float64
#  41  pos_RB                          486 non-null    float64
#  42  pos_TE                          486 non-null    float64
#  43  pos_WR                          486 non-null    float64
# dtypes: float64(44)
# memory usage: 196.3+ KB

# %%
flex_df_fd.head()
# Out:
#                                                                     DK_Pts_RB_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          22.7500
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          18.6875
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          27.7100
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          27.3350
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          19.2875
#
#                                                                     DK_Pts_TE_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          16.0250
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          11.7375
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          12.8375
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          14.6000
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          11.3000
#
#                                                                     DK_Pts_WR_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          30.8500
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          30.9500
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          28.4875
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          31.3625
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          33.2500
#
#                                                                     FD_Pts_RB_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          18.4375
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          16.3125
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          24.2725
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          24.0225
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          16.0375
#
#                                                                     FD_Pts_TE_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          11.9000
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024           9.3000
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          10.5250
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          11.7250
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024           8.6125
#
#                                                                     FD_Pts_WR_DvP  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          24.3500
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          24.7625
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          23.4875
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          23.9875
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          27.1250
#
#                                                                     rushing_yards_L8  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024               7.375
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024              -1.500
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024               1.625
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024               1.000
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024              64.375
#
#                                                                     rushing_tds_L8  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024             0.125
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024             0.000
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024             0.000
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024             0.000
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024             0.875
#
#                                                                     rushing_fumbles_lost_L8  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024                      0.000
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024                      0.000
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024                      0.000
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024                      0.000
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024                      0.125
#
#                                                                     receptions_L8  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024            7.875
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024            5.375
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024            7.625
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024            5.750
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024            2.500
#
#                                                                     ...  \
# name              position team opponent salary status week season  ...
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024    ...
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024    ...
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024    ...
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024    ...
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024    ...
#
#                                                                      qb_yds  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024    269.625
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024     96.500
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024    276.125
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024     83.500
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024    196.750
#
#                                                                     qb_pass_td  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024         1.875
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024         0.750
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024         1.125
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024         0.250
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024         1.000
#
#                                                                     qb_int  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024     0.875
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024     0.375
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024     0.625
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024     0.500
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024     1.000
#
#                                                                     qb_comp_pct  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024       0.674194
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024       0.663158
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024       0.670000
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024       0.511450
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024       0.649573
#
#                                                                     qb_yds_per_att  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024          6.958065
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024          8.126316
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024          7.363333
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024          5.099237
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024          6.726496
#
#                                                                     qb_td_pct  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024     0.048387
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024     0.063158
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024     0.030000
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024     0.015267
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024     0.034188
#
#                                                                     qb_int_pct  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024      0.022581
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024      0.031579
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024      0.016667
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024      0.030534
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024      0.034188
#
#                                                                     pos_RB  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024         0
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024         0
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024         0
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024         0
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024         1
#
#                                                                     pos_TE  \
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024         0
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024         0
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024         0
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024         0
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024         0
#
#                                                                     pos_WR
# name              position team opponent salary status week season
# CeeDee Lamb       WR       DAL  BAL      9300   Active 3    2024         1
# Justin Jefferson  WR       MIN  HOU      9200   Active 3    2024         1
# Amon-Ra St. Brown WR       DET  ARI      9100   Active 3    2024         1
# Tyreek Hill       WR       MIA  SEA      9000   Active 3    2024         1
# Saquon Barkley    RB       PHI  NO       8700   Active 3    2024         0
#
# [5 rows x 44 columns]

# %%
flex_df_dk.head()
# Out:
#                                                                       DK_Pts_RB_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        22.7500
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        18.6875
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        19.8250
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        27.3350
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        27.7100
#
#                                                                       DK_Pts_TE_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        16.0250
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        11.7375
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        12.5875
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        14.6000
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        12.8375
#
#                                                                       DK_Pts_WR_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        30.8500
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        30.9500
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        45.0125
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        31.3625
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        28.4875
#
#                                                                       FD_Pts_RB_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        18.4375
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        16.3125
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        17.4500
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        24.0225
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        24.2725
#
#                                                                       FD_Pts_TE_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        11.9000
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0         9.3000
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        10.3375
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        11.7250
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        10.5250
#
#                                                                       FD_Pts_WR_DvP  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        24.3500
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        24.7625
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        36.3875
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        23.9875
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        23.4875
#
#                                                                       rushing_yards_L8  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0             7.375
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0            -1.500
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0            98.500
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0             1.000
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0             1.625
#
#                                                                       rushing_tds_L8  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0           0.125
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0           0.000
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0           0.875
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0           0.000
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0           0.000
#
#                                                                       rushing_fumbles_lost_L8  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0                    0.000
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0                    0.000
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0                    0.125
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0                    0.000
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0                    0.000
#
#                                                                       receptions_L8  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0          7.875
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0          5.375
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0          4.750
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0          5.750
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0          7.625
#
#                                                                       ...  \
# name                position team opponent salary status week season  ...
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0  ...
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0  ...
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0  ...
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0  ...
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0  ...
#
#                                                                        qb_yds  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0  269.625
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0   96.500
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0  256.375
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0   83.500
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0  276.125
#
#                                                                       qb_pass_td  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0       1.875
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0       0.750
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0       1.250
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0       0.250
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0       1.125
#
#                                                                       qb_int  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0   0.875
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0   0.375
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0   0.750
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0   0.500
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0   0.625
#
#                                                                       qb_comp_pct  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0     0.674194
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0     0.663158
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0     0.655039
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0     0.511450
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0     0.670000
#
#                                                                       qb_yds_per_att  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0        6.958065
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0        8.126316
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0        7.949612
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0        5.099237
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0        7.363333
#
#                                                                       qb_td_pct  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0   0.048387
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0   0.063158
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0   0.038760
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0   0.015267
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0   0.030000
#
#                                                                       qb_int_pct  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0    0.022581
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0    0.031579
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0    0.023256
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0    0.030534
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0    0.016667
#
#                                                                       pos_RB  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0     0.0
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0     0.0
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0     1.0
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0     0.0
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0     0.0
#
#                                                                       pos_TE  \
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0     0.0
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0     0.0
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0     0.0
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0     0.0
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0     0.0
#
#                                                                       pos_WR
# name                position team opponent salary status week season
# CeeDee Lamb         WR       DAL  BAL      8800   Active 3    2024.0     1.0
# Justin Jefferson    WR       MIN  HOU      8600   Active 3    2024.0     1.0
# Christian McCaffrey RB       SF   LAR      8500   IR     3    2024.0     0.0
# Tyreek Hill         WR       MIA  SEA      8400   Active 3    2024.0     1.0
# Amon-Ra St. Brown   WR       DET  ARI      8200   Active 3    2024.0     1.0
#
# [5 rows x 44 columns]

# %%
flex_df_fd.to_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
flex_df_dk.to_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
