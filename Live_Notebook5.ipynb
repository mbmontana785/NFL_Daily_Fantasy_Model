# %% [markdown]
# # Assembling FLEX dataset
# This notebook will wrangle the FanDuel and DraftKings lists of running backs, wide receivers and tight ends and create a CSV that is ready to run through the model for predictions.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import nfl_data_py as nfl
#import itertools
from functions import get_current_weekday, calculate_nfl_week, get_next_sunday, get_current_year

# %%
import sqlite3

# %%
day = get_current_weekday()

# %%
date_string = get_next_sunday(day)

# %%
week = calculate_nfl_week(date_string)

# %%
season = get_current_year()

# %% [markdown]
# # Pulling from database
# Fetching the FD and DK lists from the database. These tables include names, positions, teams, opponents and salaries.

# %%
# Connect to the SQLite database
#These are the FD and DK player lists for the current week
conn = sqlite3.connect('nfl_dfs.db')

query_fd = "SELECT * FROM fd_table_" + str(week) + "_" + str(season)[2:]
query_dk = "SELECT * FROM dk_table_" + str(week) + "_" + str(season)[2:]

fanduel_df = pd.read_sql_query(query_fd, conn)
draftkings_df = pd.read_sql_query(query_dk, conn)

# Close the database connection
conn.close()

# %%
#The weekly and play-by-play data through the previous week
#We went into R Studio to get these and save them as CSVs that we can use here
weekly_df = pd.read_csv('weekly_data_' + str(season) + '_' + str(week) + '.csv')
pbp_df = pd.read_csv('pbp_data_' + str(season) + '_' + str(week) + '.csv', low_memory = False)

# %%
weekly_df.replace({'LA': 'LAR'}, inplace = True)
pbp_df.replace({'LA': 'LAR'}, inplace = True)

# %% [markdown]
# This is weekly data for each player. We can use this to calculate fantasy points for most players.

# %%
weekly_df.head()
# Out:
#     player_id player_name player_display_name position position_group  \
# 0  00-0019596     T.Brady           Tom Brady       QB             QB
# 1  00-0019596     T.Brady           Tom Brady       QB             QB
# 2  00-0019596     T.Brady           Tom Brady       QB             QB
# 3  00-0019596     T.Brady           Tom Brady       QB             QB
# 4  00-0019596     T.Brady           Tom Brady       QB             QB
#
#                                         headshot_url recent_team  season  \
# 0  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 1  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 2  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 3  https://static.www.nfl.com/image/private/f_aut...          TB    2022
# 4  https://static.www.nfl.com/image/private/f_aut...          TB    2022
#
#    week season_type  ... receiving_first_downs  receiving_epa  \
# 0     1         REG  ...                     0            NaN
# 1     2         REG  ...                     0            NaN
# 2     3         REG  ...                     0            NaN
# 3     4         REG  ...                     0            NaN
# 4     5         REG  ...                     0            NaN
#
#    receiving_2pt_conversions  racr  target_share  air_yards_share  wopr  \
# 0                          0   NaN           NaN              NaN   NaN
# 1                          0   NaN           NaN              NaN   NaN
# 2                          0   NaN           NaN              NaN   NaN
# 3                          0   NaN           NaN              NaN   NaN
# 4                          0   NaN           NaN              NaN   NaN
#
#    special_teams_tds  fantasy_points  fantasy_points_ppr
# 0                  0           10.38               10.38
# 1                  0            9.40                9.40
# 2                  0           14.74               14.74
# 3                  0           25.40               25.40
# 4                  0           19.74               19.74
#
# [5 rows x 53 columns]

# %%
pbp_df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 1       43  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 2       68  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 3       89  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
# 4      115  2022_01_BAL_NYJ   2022091107       NYJ       BAL         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     NYJ         home     BAL  ...             0                     1
# 2     1     NYJ         home     BAL  ...             0                     1
# 3     1     NYJ         home     BAL  ...             0                     1
# 4     1     NYJ         home     BAL  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0  0.000000       NaN                NaN                  NaN          NaN
# 1 -0.443521       NaN                NaN                  NaN          NaN
# 2  1.468819       NaN                NaN                  NaN          NaN
# 3 -0.492192  0.727261           6.988125                  6.0      0.60693
# 4 -0.325931       NaN                NaN                  NaN          NaN
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.440373 -44.037291
# 3  0.227598  0.389904  61.009598
# 4       NaN  0.443575 -44.357494
#
# [5 rows x 372 columns]

# %%
#rb_wr_te_df.head()

# %%
#rb_wr_te_df.info()

# %%
#nfl.see_weekly_cols()

# %%
weekly_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12518 entries, 0 to 12517
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player_id                    12518 non-null  object
#  1   player_name                  12518 non-null  object
#  2   player_display_name          12518 non-null  object
#  3   position                     12518 non-null  object
#  4   position_group               12518 non-null  object
#  5   headshot_url                 12456 non-null  object
#  6   recent_team                  12518 non-null  object
#  7   season                       12518 non-null  int64
#  8   week                         12518 non-null  int64
#  9   season_type                  12518 non-null  object
#  10  opponent_team                12518 non-null  object
#  11  completions                  12518 non-null  int64
#  12  attempts                     12518 non-null  int64
#  13  passing_yards                12518 non-null  int64
#  14  passing_tds                  12518 non-null  int64
#  15  interceptions                12518 non-null  int64
#  16  sacks                        12518 non-null  int64
#  17  sack_yards                   12518 non-null  int64
#  18  sack_fumbles                 12518 non-null  int64
#  19  sack_fumbles_lost            12518 non-null  int64
#  20  passing_air_yards            12518 non-null  int64
#  21  passing_yards_after_catch    12518 non-null  int64
#  22  passing_first_downs          12518 non-null  int64
#  23  passing_epa                  1560 non-null   float64
#  24  passing_2pt_conversions      12518 non-null  int64
#  25  pacr                         1534 non-null   float64
#  26  dakota                       1359 non-null   float64
#  27  carries                      12518 non-null  int64
#  28  rushing_yards                12518 non-null  int64
#  29  rushing_tds                  12518 non-null  int64
#  30  rushing_fumbles              12518 non-null  int64
#  31  rushing_fumbles_lost         12518 non-null  int64
#  32  rushing_first_downs          12518 non-null  int64
#  33  rushing_epa                  5286 non-null   float64
#  34  rushing_2pt_conversions      12518 non-null  int64
#  35  receptions                   12518 non-null  int64
#  36  targets                      12518 non-null  int64
#  37  receiving_yards              12518 non-null  int64
#  38  receiving_tds                12518 non-null  int64
#  39  receiving_fumbles            12518 non-null  int64
#  40  receiving_fumbles_lost       12518 non-null  int64
#  41  receiving_air_yards          12518 non-null  int64
#  42  receiving_yards_after_catch  12518 non-null  int64
#  43  receiving_first_downs        12518 non-null  int64
#  44  receiving_epa                10128 non-null  float64
#  45  receiving_2pt_conversions    12518 non-null  int64
#  46  racr                         10071 non-null  float64
#  47  target_share                 10128 non-null  float64
#  48  air_yards_share              10128 non-null  float64
#  49  wopr                         10128 non-null  float64
#  50  special_teams_tds            12518 non-null  int64
#  51  fantasy_points               12518 non-null  float64
#  52  fantasy_points_ppr           12518 non-null  float64
# dtypes: float64(11), int64(33), object(9)
# memory usage: 5.1+ MB

# %%
weekly_df['position_group'].value_counts()
# Out:
# position_group
# WR      5074
# RB      3349
# TE      2475
# QB      1540
# SPEC      29
# DB        25
# LB        14
# OL        10
# DL         2
# Name: count, dtype: int64

# %%
weekly_df['position'].value_counts()
# Out:
# position
# WR     5074
# RB     3156
# TE     2475
# QB     1540
# FB      193
# P        29
# CB       10
# T         9
# SS        9
# ILB       7
# FS        6
# OLB       6
# DT        2
# G         1
# MLB       1
# Name: count, dtype: int64

# %% [markdown]
# Weekly data filtered for RBs, WRs and TEs

# %%
flex_df = weekly_df[weekly_df['position'].isin(['RB', 'HB', 'FB', 'WR', 'TE'])]

# %%
cols_to_group = ['season', 'week', 'recent_team', 'opponent_team', 'player_id', 'player_display_name', 'position']

# %% [markdown]
# So we do have quite a few duplicate names so player_id becomes more important than names.

# %%
# Group by 'player_display_name' and check the number of unique 'player_id's
duplicate_names = flex_df.groupby('player_display_name')['player_id'].nunique()

# Filter the results to find names associated with more than one unique ID
duplicate_names = duplicate_names[duplicate_names > 1]

# %%
duplicate_names
# Out:
# Series([], Name: player_id, dtype: int64)

# %%
scoring_cols = ['passing_yards', 'passing_tds', 'interceptions', 'passing_2pt_conversions', 'rushing_yards',\
                   'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions', 'receptions', 'receiving_yards',\
                   'receiving_tds', 'receiving_fumbles_lost', 'receiving_2pt_conversions', 'sack_fumbles_lost', 'special_teams_tds',\
               'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share']

# %%
flex_df = flex_df.groupby(cols_to_group)[scoring_cols].sum()

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 10898 entries, (2022, 1, 'ARI', 'KC', '00-0027942', 'A.J. Green', 'WR') to (2024, 4, 'WAS', 'ARI', '00-0039355', 'Luke McCaffrey', 'WR')
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   passing_yards                10898 non-null  int64
#  1   passing_tds                  10898 non-null  int64
#  2   interceptions                10898 non-null  int64
#  3   passing_2pt_conversions      10898 non-null  int64
#  4   rushing_yards                10898 non-null  int64
#  5   rushing_tds                  10898 non-null  int64
#  6   rushing_fumbles_lost         10898 non-null  int64
#  7   rushing_2pt_conversions      10898 non-null  int64
#  8   receptions                   10898 non-null  int64
#  9   receiving_yards              10898 non-null  int64
#  10  receiving_tds                10898 non-null  int64
#  11  receiving_fumbles_lost       10898 non-null  int64
#  12  receiving_2pt_conversions    10898 non-null  int64
#  13  sack_fumbles_lost            10898 non-null  int64
#  14  special_teams_tds            10898 non-null  int64
#  15  targets                      10898 non-null  int64
#  16  carries                      10898 non-null  int64
#  17  receiving_yards_after_catch  10898 non-null  int64
#  18  receiving_air_yards          10898 non-null  int64
#  19  air_yards_share              10898 non-null  float64
#  20  target_share                 10898 non-null  float64
# dtypes: float64(2), int64(19)
# memory usage: 1.9+ MB

# %%
flex_df
# Out:
#                                                                                passing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                    0
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                passing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  0
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0036628 John Bates          TE                  0
#                                       00-0037746 Brian Robinson      RB                  0
#                                       00-0039355 Luke McCaffrey      WR                  0
#
#                                                                                interceptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                    0
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                    0
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                passing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0036628 John Bates          TE                              0
#                                       00-0037746 Brian Robinson      RB                              0
#                                       00-0039355 Luke McCaffrey      WR                              0
#
#                                                                                rushing_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                    0
#                                       00-0030061 Zach Ertz           TE                    0
#                                       00-0033553 James Conner        RB                   26
#                                       00-0035500 Greg Dortch         WR                    0
#                                       00-0035527 Andy Isabella       WR                    0
# ...                                                                                      ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                    0
#                                       00-0036626 Dyami Brown         WR                    0
#                                       00-0036628 John Bates          TE                    0
#                                       00-0037746 Brian Robinson      RB                  101
#                                       00-0039355 Luke McCaffrey      WR                    0
#
#                                                                                rushing_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                  0
#                                       00-0030061 Zach Ertz           TE                  0
#                                       00-0033553 James Conner        RB                  1
#                                       00-0035500 Greg Dortch         WR                  0
#                                       00-0035527 Andy Isabella       WR                  0
# ...                                                                                    ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                  0
#                                       00-0036626 Dyami Brown         WR                  0
#                                       00-0036628 John Bates          TE                  0
#                                       00-0037746 Brian Robinson      RB                  1
#                                       00-0039355 Luke McCaffrey      WR                  0
#
#                                                                                rushing_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                           0
#                                       00-0030061 Zach Ertz           TE                           0
#                                       00-0033553 James Conner        RB                           0
#                                       00-0035500 Greg Dortch         WR                           0
#                                       00-0035527 Andy Isabella       WR                           0
# ...                                                                                             ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                           0
#                                       00-0036626 Dyami Brown         WR                           0
#                                       00-0036628 John Bates          TE                           0
#                                       00-0037746 Brian Robinson      RB                           0
#                                       00-0039355 Luke McCaffrey      WR                           0
#
#                                                                                rushing_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                              0
#                                       00-0030061 Zach Ertz           TE                              0
#                                       00-0033553 James Conner        RB                              0
#                                       00-0035500 Greg Dortch         WR                              0
#                                       00-0035527 Andy Isabella       WR                              0
# ...                                                                                                ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                              0
#                                       00-0036626 Dyami Brown         WR                              0
#                                       00-0036628 John Bates          TE                              0
#                                       00-0037746 Brian Robinson      RB                              0
#                                       00-0039355 Luke McCaffrey      WR                              0
#
#                                                                                receptions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                 2
#                                       00-0030061 Zach Ertz           TE                 2
#                                       00-0033553 James Conner        RB                 5
#                                       00-0035500 Greg Dortch         WR                 7
#                                       00-0035527 Andy Isabella       WR                 1
# ...                                                                                   ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                 7
#                                       00-0036626 Dyami Brown         WR                 1
#                                       00-0036628 John Bates          TE                 1
#                                       00-0037746 Brian Robinson      RB                 3
#                                       00-0039355 Luke McCaffrey      WR                 1
#
#                                                                                receiving_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                     13
#                                       00-0030061 Zach Ertz           TE                     14
#                                       00-0033553 James Conner        RB                     29
#                                       00-0035500 Greg Dortch         WR                     63
#                                       00-0035527 Andy Isabella       WR                     10
# ...                                                                                        ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                     52
#                                       00-0036626 Dyami Brown         WR                      4
#                                       00-0036628 John Bates          TE                      9
#                                       00-0037746 Brian Robinson      RB                     12
#                                       00-0039355 Luke McCaffrey      WR                     17
#
#                                                                                ...  \
# season week recent_team opponent_team player_id  player_display_name position  ...
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR        ...
#                                       00-0030061 Zach Ertz           TE        ...
#                                       00-0033553 James Conner        RB        ...
#                                       00-0035500 Greg Dortch         WR        ...
#                                       00-0035527 Andy Isabella       WR        ...
# ...                                                                            ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR        ...
#                                       00-0036626 Dyami Brown         WR        ...
#                                       00-0036628 John Bates          TE        ...
#                                       00-0037746 Brian Robinson      RB        ...
#                                       00-0039355 Luke McCaffrey      WR        ...
#
#                                                                                receiving_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                             0
#                                       00-0030061 Zach Ertz           TE                             0
#                                       00-0033553 James Conner        RB                             0
#                                       00-0035500 Greg Dortch         WR                             0
#                                       00-0035527 Andy Isabella       WR                             0
# ...                                                                                               ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                             0
#                                       00-0036626 Dyami Brown         WR                             0
#                                       00-0036628 John Bates          TE                             0
#                                       00-0037746 Brian Robinson      RB                             0
#                                       00-0039355 Luke McCaffrey      WR                             0
#
#                                                                                receiving_2pt_conversions  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                0
#                                       00-0030061 Zach Ertz           TE                                1
#                                       00-0033553 James Conner        RB                                0
#                                       00-0035500 Greg Dortch         WR                                0
#                                       00-0035527 Andy Isabella       WR                                0
# ...                                                                                                  ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                                0
#                                       00-0036626 Dyami Brown         WR                                0
#                                       00-0036628 John Bates          TE                                0
#                                       00-0037746 Brian Robinson      RB                                0
#                                       00-0039355 Luke McCaffrey      WR                                0
#
#                                                                                sack_fumbles_lost  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0036628 John Bates          TE                        0
#                                       00-0037746 Brian Robinson      RB                        0
#                                       00-0039355 Luke McCaffrey      WR                        0
#
#                                                                                special_teams_tds  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                        0
#                                       00-0030061 Zach Ertz           TE                        0
#                                       00-0033553 James Conner        RB                        0
#                                       00-0035500 Greg Dortch         WR                        0
#                                       00-0035527 Andy Isabella       WR                        0
# ...                                                                                          ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                        0
#                                       00-0036626 Dyami Brown         WR                        0
#                                       00-0036628 John Bates          TE                        0
#                                       00-0037746 Brian Robinson      RB                        0
#                                       00-0039355 Luke McCaffrey      WR                        0
#
#                                                                                targets  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              4
#                                       00-0030061 Zach Ertz           TE              4
#                                       00-0033553 James Conner        RB              6
#                                       00-0035500 Greg Dortch         WR              9
#                                       00-0035527 Andy Isabella       WR              3
# ...                                                                                ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR             10
#                                       00-0036626 Dyami Brown         WR              1
#                                       00-0036628 John Bates          TE              1
#                                       00-0037746 Brian Robinson      RB              3
#                                       00-0039355 Luke McCaffrey      WR              1
#
#                                                                                carries  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR              0
#                                       00-0030061 Zach Ertz           TE              0
#                                       00-0033553 James Conner        RB             10
#                                       00-0035500 Greg Dortch         WR              0
#                                       00-0035527 Andy Isabella       WR              0
# ...                                                                                ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR              0
#                                       00-0036626 Dyami Brown         WR              0
#                                       00-0036628 John Bates          TE              0
#                                       00-0037746 Brian Robinson      RB             21
#                                       00-0039355 Luke McCaffrey      WR              0
#
#                                                                                receiving_yards_after_catch  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                                  0
#                                       00-0030061 Zach Ertz           TE                                  4
#                                       00-0033553 James Conner        RB                                 38
#                                       00-0035500 Greg Dortch         WR                                 31
#                                       00-0035527 Andy Isabella       WR                                  4
# ...                                                                                                    ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                                  6
#                                       00-0036626 Dyami Brown         WR                                  0
#                                       00-0036628 John Bates          TE                                  6
#                                       00-0037746 Brian Robinson      RB                                 18
#                                       00-0039355 Luke McCaffrey      WR                                  4
#
#                                                                                receiving_air_yards  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR                         42
#                                       00-0030061 Zach Ertz           TE                         22
#                                       00-0033553 James Conner        RB                          7
#                                       00-0035500 Greg Dortch         WR                         62
#                                       00-0035527 Andy Isabella       WR                         30
# ...                                                                                            ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR                        103
#                                       00-0036626 Dyami Brown         WR                          4
#                                       00-0036628 John Bates          TE                          3
#                                       00-0037746 Brian Robinson      RB                         -6
#                                       00-0039355 Luke McCaffrey      WR                         13
#
#                                                                                air_yards_share  \
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR               0.157895
#                                       00-0030061 Zach Ertz           TE               0.082707
#                                       00-0033553 James Conner        RB               0.026316
#                                       00-0035500 Greg Dortch         WR               0.233083
#                                       00-0035527 Andy Isabella       WR               0.112782
# ...                                                                                        ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR               0.591954
#                                       00-0036626 Dyami Brown         WR               0.022989
#                                       00-0036628 John Bates          TE               0.017241
#                                       00-0037746 Brian Robinson      RB              -0.034483
#                                       00-0039355 Luke McCaffrey      WR               0.074713
#
#                                                                                target_share
# season week recent_team opponent_team player_id  player_display_name position
# 2022   1    ARI         KC            00-0027942 A.J. Green          WR            0.111111
#                                       00-0030061 Zach Ertz           TE            0.111111
#                                       00-0033553 James Conner        RB            0.166667
#                                       00-0035500 Greg Dortch         WR            0.250000
#                                       00-0035527 Andy Isabella       WR            0.083333
# ...                                                                                     ...
# 2024   4    WAS         ARI           00-0035659 Terry McLaurin      WR            0.333333
#                                       00-0036626 Dyami Brown         WR            0.033333
#                                       00-0036628 John Bates          TE            0.033333
#                                       00-0037746 Brian Robinson      RB            0.100000
#                                       00-0039355 Luke McCaffrey      WR            0.033333
#
# [10898 rows x 21 columns]

# %%
def replace(code, old, new):
    """
    Basically a find and replace
    """
    return code.replace(old, new)

# %%
flex_df.reset_index(inplace = True, drop = False)

# %%
#There are a few errant rows where the opponent matches the team
flex_df = flex_df[~(flex_df['recent_team'] == flex_df['opponent_team'])]

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10892 entries, 0 to 10897
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10892 non-null  int64
#  1   week                         10892 non-null  int64
#  2   recent_team                  10892 non-null  object
#  3   opponent_team                10892 non-null  object
#  4   player_id                    10892 non-null  object
#  5   player_display_name          10892 non-null  object
#  6   position                     10892 non-null  object
#  7   passing_yards                10892 non-null  int64
#  8   passing_tds                  10892 non-null  int64
#  9   interceptions                10892 non-null  int64
#  10  passing_2pt_conversions      10892 non-null  int64
#  11  rushing_yards                10892 non-null  int64
#  12  rushing_tds                  10892 non-null  int64
#  13  rushing_fumbles_lost         10892 non-null  int64
#  14  rushing_2pt_conversions      10892 non-null  int64
#  15  receptions                   10892 non-null  int64
#  16  receiving_yards              10892 non-null  int64
#  17  receiving_tds                10892 non-null  int64
#  18  receiving_fumbles_lost       10892 non-null  int64
#  19  receiving_2pt_conversions    10892 non-null  int64
#  20  sack_fumbles_lost            10892 non-null  int64
#  21  special_teams_tds            10892 non-null  int64
#  22  targets                      10892 non-null  int64
#  23  carries                      10892 non-null  int64
#  24  receiving_yards_after_catch  10892 non-null  int64
#  25  receiving_air_yards          10892 non-null  int64
#  26  air_yards_share              10892 non-null  float64
#  27  target_share                 10892 non-null  float64
# dtypes: float64(2), int64(21), object(5)
# memory usage: 2.4+ MB

# %% [markdown]
# # What do we need from play-by-play?
# Let's take a look at the data we'd like to have and see where we need to integrate the play-by-play data. We have yards_after_catch and air_yards. We have targets and target share. Even though the target share doesn't add up to 100 percent, it's still useful. We'll definitely want to spot-check that.<br>
#
# We have carries but no carry share. Maybe we need to just take the total carries for each team in each game from the pbp and join that with the flex_df. That shouldn't be too hard. Then we can figure out every RBs workload even if they don't all add up to 100.<br>
#
# We also want goal_to_go binary for each play to see how many carries or targets a player gets in goal-line situations and also the rate at which they score TDs in those situations.<br>

# %%
run_df = pbp_df[pbp_df['play_type'] == 'run']

# %%
running_play_counts = run_df.groupby(['season', 'week', 'posteam', 'defteam', 'game_id']).size().reset_index(name='total_carries')

# %%
running_play_counts.rename(columns = {'posteam' : 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_df, running_play_counts, on = ['season', 'week', 'recent_team', 'opponent_team'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10892 entries, 0 to 10891
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10892 non-null  int64
#  1   week                         10892 non-null  int64
#  2   recent_team                  10892 non-null  object
#  3   opponent_team                10892 non-null  object
#  4   player_id                    10892 non-null  object
#  5   player_display_name          10892 non-null  object
#  6   position                     10892 non-null  object
#  7   passing_yards                10892 non-null  int64
#  8   passing_tds                  10892 non-null  int64
#  9   interceptions                10892 non-null  int64
#  10  passing_2pt_conversions      10892 non-null  int64
#  11  rushing_yards                10892 non-null  int64
#  12  rushing_tds                  10892 non-null  int64
#  13  rushing_fumbles_lost         10892 non-null  int64
#  14  rushing_2pt_conversions      10892 non-null  int64
#  15  receptions                   10892 non-null  int64
#  16  receiving_yards              10892 non-null  int64
#  17  receiving_tds                10892 non-null  int64
#  18  receiving_fumbles_lost       10892 non-null  int64
#  19  receiving_2pt_conversions    10892 non-null  int64
#  20  sack_fumbles_lost            10892 non-null  int64
#  21  special_teams_tds            10892 non-null  int64
#  22  targets                      10892 non-null  int64
#  23  carries                      10892 non-null  int64
#  24  receiving_yards_after_catch  10892 non-null  int64
#  25  receiving_air_yards          10892 non-null  int64
#  26  air_yards_share              10892 non-null  float64
#  27  target_share                 10892 non-null  float64
#  28  game_id                      10892 non-null  object
#  29  total_carries                10892 non-null  int64
# dtypes: float64(2), int64(22), object(6)
# memory usage: 2.5+ MB

# %%
flex_merge['carry_share'] = round(flex_merge['carries']/flex_merge['total_carries'], 3)

# %%
flex_merge.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  special_teams_tds  \
# 0       WR              0            0              0  ...                  0
# 1       TE              0            0              0  ...                  0
# 2       RB              0            0              0  ...                  0
# 3       WR              0            0              0  ...                  0
# 4       WR              0            0              0  ...                  0
#
#    targets  carries  receiving_yards_after_catch  receiving_air_yards  \
# 0        4        0                            0                   42
# 1        4        0                            4                   22
# 2        6       10                           38                    7
# 3        9        0                           31                   62
# 4        3        0                            4                   30
#
#    air_yards_share  target_share         game_id  total_carries  carry_share
# 0         0.157895      0.111111  2022_01_KC_ARI             21        0.000
# 1         0.082707      0.111111  2022_01_KC_ARI             21        0.000
# 2         0.026316      0.166667  2022_01_KC_ARI             21        0.476
# 3         0.233083      0.250000  2022_01_KC_ARI             21        0.000
# 4         0.112782      0.083333  2022_01_KC_ARI             21        0.000
#
# [5 rows x 31 columns]

# %%
flex_merge.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10862    2024     4          SF            NE  00-0036259      Jauan Jennings
# 10863    2024     4          SF            NE  00-0036261       Brandon Aiyuk
# 10864    2024     4          SF            NE  00-0037525        Jordan Mason
# 10865    2024     4          SF            NE  00-0039363      Isaac Guerendo
# 10866    2024     4          TB           PHI  00-0031408          Mike Evans
# 10867    2024     4          TB           PHI  00-0032385    Sterling Shepard
# 10868    2024     4          TB           PHI  00-0033921        Chris Godwin
# 10869    2024     4          TB           PHI  00-0037256       Rachaad White
# 10870    2024     4          TB           PHI  00-0038129          Cade Otton
# 10871    2024     4          TB           PHI  00-0038951         Sean Tucker
# 10872    2024     4          TB           PHI  00-0039052         Trey Palmer
# 10873    2024     4          TB           PHI  00-0039361        Bucky Irving
# 10874    2024     4          TB           PHI  00-0039589     Kameron Johnson
# 10875    2024     4         TEN           MIA  00-0030564     DeAndre Hopkins
# 10876    2024     4         TEN           MIA  00-0033009          Tyler Boyd
# 10877    2024     4         TEN           MIA  00-0034837       Calvin Ridley
# 10878    2024     4         TEN           MIA  00-0035261        Tony Pollard
# 10879    2024     4         TEN           MIA  00-0037742       Treylon Burks
# 10880    2024     4         TEN           MIA  00-0037809   Chigoziem Okonkwo
# 10881    2024     4         TEN           MIA  00-0038589          Josh Whyle
# 10882    2024     4         TEN           MIA  00-0039032        Tyjae Spears
# 10883    2024     4         WAS           ARI  00-0030061           Zach Ertz
# 10884    2024     4         WAS           ARI  00-0033591          Noah Brown
# 10885    2024     4         WAS           ARI  00-0033955    Jeremy McNichols
# 10886    2024     4         WAS           ARI  00-0035208   Olamide Zaccheaus
# 10887    2024     4         WAS           ARI  00-0035659      Terry McLaurin
# 10888    2024     4         WAS           ARI  00-0036626         Dyami Brown
# 10889    2024     4         WAS           ARI  00-0036628          John Bates
# 10890    2024     4         WAS           ARI  00-0037746      Brian Robinson
# 10891    2024     4         WAS           ARI  00-0039355      Luke McCaffrey
#
#       position  passing_yards  passing_tds  interceptions  ...  \
# 10862       WR              0            0              0  ...
# 10863       WR              0            0              0  ...
# 10864       RB              0            0              0  ...
# 10865       RB              0            0              0  ...
# 10866       WR              0            0              0  ...
# 10867       WR              0            0              0  ...
# 10868       WR              0            0              0  ...
# 10869       RB              0            0              0  ...
# 10870       TE              0            0              0  ...
# 10871       RB              0            0              0  ...
# 10872       WR              0            0              0  ...
# 10873       RB              0            0              0  ...
# 10874       WR              0            0              0  ...
# 10875       WR              0            0              0  ...
# 10876       WR              0            0              0  ...
# 10877       WR              0            0              0  ...
# 10878       RB              0            0              0  ...
# 10879       WR              0            0              0  ...
# 10880       TE              0            0              0  ...
# 10881       TE              0            0              0  ...
# 10882       RB              0            0              0  ...
# 10883       TE              0            0              0  ...
# 10884       WR              0            0              0  ...
# 10885       RB              0            0              0  ...
# 10886       WR              0            0              0  ...
# 10887       WR              0            0              0  ...
# 10888       WR              0            0              0  ...
# 10889       TE              0            0              0  ...
# 10890       RB              0            0              0  ...
# 10891       WR              0            0              0  ...
#
#        special_teams_tds  targets  carries  receiving_yards_after_catch  \
# 10862                  0        6        0                           20
# 10863                  0        5        0                           20
# 10864                  0        3       24                           25
# 10865                  0        0        1                            0
# 10866                  0       14        0                           32
# 10867                  0        5        0                            8
# 10868                  0        9        0                           50
# 10869                  0        3       10                           39
# 10870                  0        9        0                           27
# 10871                  0        1        1                           14
# 10872                  0        3        0                           19
# 10873                  0        2       10                            6
# 10874                  0        1        0                            0
# 10875                  0        4        0                            0
# 10876                  0        2        0                           10
# 10877                  0        3        1                            9
# 10878                  0        2       22                           24
# 10879                  0        1        0                            0
# 10880                  0        3        0                            6
# 10881                  0        1        0                            0
# 10882                  0        2       15                            4
# 10883                  0        3        0                            7
# 10884                  0        4        0                            2
# 10885                  0        1        8                            9
# 10886                  0        6        0                           70
# 10887                  0       10        0                            6
# 10888                  0        1        0                            0
# 10889                  0        1        0                            6
# 10890                  0        3       21                           18
# 10891                  0        1        0                            4
#
#        receiving_air_yards  air_yards_share  target_share          game_id  \
# 10862                   84         0.227027      0.230769    2024_04_NE_SF
# 10863                   90         0.243243      0.192308    2024_04_NE_SF
# 10864                   28         0.075676      0.115385    2024_04_NE_SF
# 10865                    0         0.000000      0.000000    2024_04_NE_SF
# 10866                  145         0.480132      0.297872   2024_04_PHI_TB
# 10867                   78         0.258278      0.106383   2024_04_PHI_TB
# 10868                   39         0.129139      0.191489   2024_04_PHI_TB
# 10869                   -6        -0.019868      0.063830   2024_04_PHI_TB
# 10870                   40         0.132450      0.191489   2024_04_PHI_TB
# 10871                    0         0.000000      0.021277   2024_04_PHI_TB
# 10872                    7         0.023179      0.063830   2024_04_PHI_TB
# 10873                   -4        -0.013245      0.042553   2024_04_PHI_TB
# 10874                    3         0.009934      0.021277   2024_04_PHI_TB
# 10875                   47         0.528090      0.222222  2024_04_TEN_MIA
# 10876                   21         0.235955      0.111111  2024_04_TEN_MIA
# 10877                   -2        -0.022472      0.166667  2024_04_TEN_MIA
# 10878                   -4        -0.044944      0.111111  2024_04_TEN_MIA
# 10879                   13         0.146067      0.055556  2024_04_TEN_MIA
# 10880                   13         0.146067      0.166667  2024_04_TEN_MIA
# 10881                    5         0.056180      0.055556  2024_04_TEN_MIA
# 10882                   -4        -0.044944      0.111111  2024_04_TEN_MIA
# 10883                   15         0.086207      0.100000  2024_04_WAS_ARI
# 10884                   30         0.172414      0.133333  2024_04_WAS_ARI
# 10885                   -3        -0.017241      0.033333  2024_04_WAS_ARI
# 10886                   15         0.086207      0.200000  2024_04_WAS_ARI
# 10887                  103         0.591954      0.333333  2024_04_WAS_ARI
# 10888                    4         0.022989      0.033333  2024_04_WAS_ARI
# 10889                    3         0.017241      0.033333  2024_04_WAS_ARI
# 10890                   -6        -0.034483      0.100000  2024_04_WAS_ARI
# 10891                   13         0.074713      0.033333  2024_04_WAS_ARI
#
#        total_carries  carry_share
# 10862             31        0.000
# 10863             31        0.000
# 10864             31        0.774
# 10865             31        0.032
# 10866             24        0.000
# 10867             24        0.000
# 10868             24        0.000
# 10869             24        0.417
# 10870             24        0.000
# 10871             24        0.042
# 10872             24        0.000
# 10873             24        0.417
# 10874             24        0.000
# 10875             40        0.000
# 10876             40        0.000
# 10877             40        0.025
# 10878             40        0.550
# 10879             40        0.000
# 10880             40        0.000
# 10881             40        0.000
# 10882             40        0.375
# 10883             37        0.000
# 10884             37        0.000
# 10885             37        0.216
# 10886             37        0.000
# 10887             37        0.000
# 10888             37        0.000
# 10889             37        0.000
# 10890             37        0.568
# 10891             37        0.000
#
# [30 rows x 31 columns]

# %% [markdown]
# # Goal-to-go situations
# We'll filter the pbp data by rows in which goal_to_go is True and the play is either a run or a pass. We find that on passing plays, some of the receiver_player_id values are null, but for running plays none of them are null. This implies that on plays in which the QB is sacked, no pass is thrown so there's no receiver.<br>
#
# Those plays probably should be discarded as we are looking for a percentage of times a RB-WR-TE gets the ball in goal-to-go situations. When a QB is sacked, no one gets the ball.<br>
#
# **Update:** goal_to_go leaves out situations where it's 3rd and 2 from the 4-yard line. Maybe we should see if filtering by yardline_100 <= 10 gives us more data points.

# %%
gtg_df_10 = pbp_df[(pbp_df['yardline_100'] <= 10) & ((pbp_df['play_type'] == 'run') | (pbp_df['play_type'] == 'pass'))]
#gtg_df = rb_wr_te_df[(rb_wr_te_df['goal_to_go'] == True) & ((rb_wr_te_df['play_type'] == 'run') | (rb_wr_te_df['play_type'] == 'pass'))]

# %%
gtg_df_10['play_type'].value_counts()
# Out:
# play_type
# run     2977
# pass    2863
# Name: count, dtype: int64

# %%
gtg_df_10 = gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) | (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df = gtg_df[(gtg_df['receiver_player_id'].notnull()) | (gtg_df['rusher_player_id'].notnull())]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].isnull()) & (gtg_df_10['rusher_player_id'].isnull())]
#gtg_df[(gtg_df['receiver_player_id'].isnull()) & (gtg_df['rusher_player_id'].isnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10[(gtg_df_10['receiver_player_id'].notnull()) & (gtg_df_10['rusher_player_id'].notnull())]
#gtg_df[(gtg_df['receiver_player_id'].notnull()) & (gtg_df['rusher_player_id'].notnull())]
# Out:
# Empty DataFrame
# Columns: [play_id, game_id, old_game_id, home_team, away_team, season_type, week, posteam, posteam_type, defteam, side_of_field, yardline_100, game_date, quarter_seconds_remaining, half_seconds_remaining, game_seconds_remaining, game_half, quarter_end, drive, sp, qtr, down, goal_to_go, time, yrdln, ydstogo, ydsnet, desc, play_type, yards_gained, shotgun, no_huddle, qb_dropback, qb_kneel, qb_spike, qb_scramble, pass_length, pass_location, air_yards, yards_after_catch, run_location, run_gap, field_goal_result, kick_distance, extra_point_result, two_point_conv_result, home_timeouts_remaining, away_timeouts_remaining, timeout, timeout_team, td_team, td_player_name, td_player_id, posteam_timeouts_remaining, defteam_timeouts_remaining, total_home_score, total_away_score, posteam_score, defteam_score, score_differential, posteam_score_post, defteam_score_post, score_differential_post, no_score_prob, opp_fg_prob, opp_safety_prob, opp_td_prob, fg_prob, safety_prob, td_prob, extra_point_prob, two_point_conversion_prob, ep, epa, total_home_epa, total_away_epa, total_home_rush_epa, total_away_rush_epa, total_home_pass_epa, total_away_pass_epa, air_epa, yac_epa, comp_air_epa, comp_yac_epa, total_home_comp_air_epa, total_away_comp_air_epa, total_home_comp_yac_epa, total_away_comp_yac_epa, total_home_raw_air_epa, total_away_raw_air_epa, total_home_raw_yac_epa, total_away_raw_yac_epa, wp, def_wp, home_wp, away_wp, wpa, vegas_wpa, vegas_home_wpa, home_wp_post, ...]
# Index: []
#
# [0 rows x 372 columns]

# %%
gtg_df_10['player_id'] = gtg_df_10['rusher_player_id'].fillna(gtg_df_10['receiver_player_id'])
#gtg_df['player_id'] = gtg_df['rusher_player_id'].fillna(gtg_df['receiver_player_id'])

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5499 entries, 31 to 110028
# Columns: 373 entries, play_id to player_id
# dtypes: float64(182), int64(39), object(152)
# memory usage: 15.7+ MB

# %%
#Total goal to go situations for each team in each game
grouped_gtg_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'plays_in_10')

#grouped_gtg = gtg_df.groupby(['season', 'week', 'posteam', 'defteam']).size().reset_index(name = 'gtg_plays')

# %%
gtg_df_10.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'home_opening_kickoff', 'qb_epa', 'xyac_epa', 'xyac_mean_yardage',
#        'xyac_median_yardage', 'xyac_success', 'xyac_fd', 'xpass', 'pass_oe',
#        'player_id'],
#       dtype='object', length=373)

# %%
gtg_cols = ['play_id','week', 'posteam', 'defteam', 'sp', 'desc', 'play_type', 'td_player_id',
      'incomplete_pass', 'rush_attempt', 'pass_attempt',
       'touchdown', 'pass_touchdown', 'rush_touchdown', 'complete_pass', 'receiver_player_id',
       'receiver_player_name', 'rusher_player_id',
       'rusher_player_name', 'season', 'weather', 'player_id']

# %%
gtg_df_10 = gtg_df_10[gtg_cols]

# %%
gtg_df_10 = pd.merge(gtg_df_10, grouped_gtg_10, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')
#gtg_df = pd.merge(gtg_df, grouped_gtg, on = ['season', 'week', 'posteam', 'defteam'], how = 'left')

# %%
##Next will be to derive how many times per gtg play a player gets the ball, and then when they get it their TD percentage

# %%
gtg_10_player = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'opps_in_10')
#gtg_player = gtg_df.groupby(['season', 'week', 'posteam', 'defteam', 'player_id']).size().reset_index(name = 'gtg_opps')

# %%
gtg_df_10 = pd.merge(gtg_df_10, gtg_10_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')
#gtg_df = pd.merge(gtg_df, gtg_player, on = ['season', 'week', 'posteam', 'defteam', 'player_id'], how = 'left')

# %%
gtg_df_10['in_10_share'] = round(gtg_df_10['opps_in_10']/gtg_df_10['plays_in_10'], 3)

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5499 entries, 0 to 5498
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   play_id               5499 non-null   int64
#  1   week                  5499 non-null   int64
#  2   posteam               5499 non-null   object
#  3   defteam               5499 non-null   object
#  4   sp                    5499 non-null   int64
#  5   desc                  5499 non-null   object
#  6   play_type             5499 non-null   object
#  7   td_player_id          1728 non-null   object
#  8   incomplete_pass       5499 non-null   float64
#  9   rush_attempt          5499 non-null   float64
#  10  pass_attempt          5499 non-null   float64
#  11  touchdown             5499 non-null   float64
#  12  pass_touchdown        5499 non-null   float64
#  13  rush_touchdown        5499 non-null   float64
#  14  complete_pass         5499 non-null   float64
#  15  receiver_player_id    2522 non-null   object
#  16  receiver_player_name  2522 non-null   object
#  17  rusher_player_id      2977 non-null   object
#  18  rusher_player_name    2977 non-null   object
#  19  season                5499 non-null   int64
#  20  weather               5291 non-null   object
#  21  player_id             5499 non-null   object
#  22  plays_in_10           5499 non-null   int64
#  23  opps_in_10            5499 non-null   int64
#  24  in_10_share           5499 non-null   float64
# dtypes: float64(8), int64(6), object(11)
# memory usage: 1.0+ MB

# %%
gtg_df_10['player_id'].nunique()
# Out:
# 575

# %%
flex_merge['player_id'].nunique()
# Out:
# 679

# %%
##Maybe we need to pause here. There are more players in our weekly data than we have in our gtg data, which makes sense.
#Not every player will be used in gtg situations.
#Maybe somehow just check that every player in flex_merge but not gtg doesn't have any True values in goal_to_go
####Maybe we should just use common sense
#We've filtered every gtg play that was a run or a pass.
#If there's any irregularity it's likely to come out during spot-checking

# %%
gtg_players = list(gtg_df_10['player_id'].unique())

# %%
flex_players = list(flex_merge['player_id'].unique())

# %%
len(gtg_players)
# Out:
# 575

# %%
len(flex_players)
# Out:
# 679

# %%
#gtg_df = gtg_df.sort_values(by = ['season', 'week', 'posteam', 'defteam'])

# %%
gtg_df_10 = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam', 'player_id'], as_index=False).agg({'in_10_share': 'mean'})

# %%
#gtg_df = gtg_df[['season', 'week', 'posteam', 'defteam', 'player_id', 'gtg_share']]

# %%
gtg_df_10.tail(30)
# Out:
#       season  week posteam defteam   player_id  in_10_share
# 3501    2024     4     PHI      TB  00-0034844        0.429
# 3502    2024     4     PHI      TB  00-0035639        0.143
# 3503    2024     4     PHI      TB  00-0036389        0.286
# 3504    2024     4     PHI      TB  00-0036919        0.143
# 3505    2024     4     PIT     IND  00-0036893        0.143
# 3506    2024     4     PIT     IND  00-0036894        0.143
# 3507    2024     4     PIT     IND  00-0036945        0.286
# 3508    2024     4     PIT     IND  00-0037247        0.429
# 3509    2024     4     SEA     DET  00-0032211        0.250
# 3510    2024     4     SEA     DET  00-0035640        0.125
# 3511    2024     4     SEA     DET  00-0038134        0.250
# 3512    2024     4     SEA     DET  00-0038543        0.125
# 3513    2024     4     SEA     DET  00-0038752        0.125
# 3514    2024     4     SEA     DET  00-0039793        0.125
# 3515    2024     4      SF      NE  00-0035719        0.333
# 3516    2024     4      SF      NE  00-0036259        0.167
# 3517    2024     4      SF      NE  00-0037525        0.500
# 3518    2024     4      TB     PHI  00-0031408        0.167
# 3519    2024     4      TB     PHI  00-0033921        0.167
# 3520    2024     4      TB     PHI  00-0034855        0.167
# 3521    2024     4      TB     PHI  00-0038129        0.083
# 3522    2024     4      TB     PHI  00-0039361        0.333
# 3523    2024     4      TB     PHI  00-0039589        0.083
# 3524    2024     4     TEN     MIA  00-0035261        0.714
# 3525    2024     4     TEN     MIA  00-0039032        0.286
# 3526    2024     4     WAS     ARI  00-0030061        0.143
# 3527    2024     4     WAS     ARI  00-0033955        0.286
# 3528    2024     4     WAS     ARI  00-0035659        0.143
# 3529    2024     4     WAS     ARI  00-0037746        0.286
# 3530    2024     4     WAS     ARI  00-0039910        0.143

# %%
check_for_one = gtg_df_10.groupby(['season', 'week', 'posteam', 'defteam'])['in_10_share'].sum()

# %%
check_for_one.min()
# Out:
# 0.9989999999999999

# %%
gtg_df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3531 entries, 0 to 3530
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   season       3531 non-null   int64
#  1   week         3531 non-null   int64
#  2   posteam      3531 non-null   object
#  3   defteam      3531 non-null   object
#  4   player_id    3531 non-null   object
#  5   in_10_share  3531 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 165.6+ KB

# %%
gtg_df_10.rename(columns = {'posteam': 'recent_team', 'defteam': 'opponent_team'}, inplace = True)

# %%
flex_merge = pd.merge(flex_merge, gtg_df_10, on = ['season', 'week', 'recent_team', 'opponent_team', 'player_id'], how = 'left')

# %%
flex_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10892 entries, 0 to 10891
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10892 non-null  int64
#  1   week                         10892 non-null  int64
#  2   recent_team                  10892 non-null  object
#  3   opponent_team                10892 non-null  object
#  4   player_id                    10892 non-null  object
#  5   player_display_name          10892 non-null  object
#  6   position                     10892 non-null  object
#  7   passing_yards                10892 non-null  int64
#  8   passing_tds                  10892 non-null  int64
#  9   interceptions                10892 non-null  int64
#  10  passing_2pt_conversions      10892 non-null  int64
#  11  rushing_yards                10892 non-null  int64
#  12  rushing_tds                  10892 non-null  int64
#  13  rushing_fumbles_lost         10892 non-null  int64
#  14  rushing_2pt_conversions      10892 non-null  int64
#  15  receptions                   10892 non-null  int64
#  16  receiving_yards              10892 non-null  int64
#  17  receiving_tds                10892 non-null  int64
#  18  receiving_fumbles_lost       10892 non-null  int64
#  19  receiving_2pt_conversions    10892 non-null  int64
#  20  sack_fumbles_lost            10892 non-null  int64
#  21  special_teams_tds            10892 non-null  int64
#  22  targets                      10892 non-null  int64
#  23  carries                      10892 non-null  int64
#  24  receiving_yards_after_catch  10892 non-null  int64
#  25  receiving_air_yards          10892 non-null  int64
#  26  air_yards_share              10892 non-null  float64
#  27  target_share                 10892 non-null  float64
#  28  game_id                      10892 non-null  object
#  29  total_carries                10892 non-null  int64
#  30  carry_share                  10892 non-null  float64
#  31  in_10_share                  3132 non-null   float64
# dtypes: float64(4), int64(22), object(6)
# memory usage: 2.7+ MB

# %% [markdown]
# # A lot of missing in_10_share variables
# At first glance it seems like there are too many nulls in the in_10_share column, which is the percentage of plays inside the 10-yard-line that each player gets the ball. But maybe it is plausible. After all, in those goal-line situations only the best players are called upon. We'll replace with zero and investigate further when we examine the data.

# %%
flex_merge.fillna(value={'in_10_share': 0}, inplace=True)

# %% [markdown]
# Let's rename flex_merge flex_df so we can run the following code

# %%
flex_df = flex_merge

# %% [markdown]
# # Fantasy points
# This is where we calculate FanDuel and DraftKings points.

# %%
flex_df['FD_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 0.5)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost'] * 2) - (flex_df['receiving_fumbles_lost'] * 2)\
- (flex_df['rushing_fumbles_lost'] * 2)

# %%
flex_df['DK_Pts'] = (flex_df['passing_yards'] * 0.04) + (flex_df['rushing_tds'] * 6) + (flex_df['rushing_yards'] * 0.1)\
+ (flex_df['passing_tds'] * 4) + (flex_df['receiving_yards'] * 0.1) + (flex_df['receiving_tds'] * 6) + (flex_df['receptions'] * 1)\
+ (flex_df['rushing_2pt_conversions'] * 2) + (flex_df['passing_2pt_conversions'] * 2) + (flex_df['receiving_2pt_conversions'] * 2)\
+ (flex_df['special_teams_tds'] * 6) - (flex_df['interceptions']) - (flex_df['sack_fumbles_lost']) - (flex_df['receiving_fumbles_lost'])\
- (flex_df['rushing_fumbles_lost'])

# %% [markdown]
# Adding DraftKings bonus points

# %%
flex_df['DK_Pts'] = np.where(flex_df['passing_yards'] >= 300, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['receiving_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])
flex_df['DK_Pts'] = np.where(flex_df['rushing_yards'] >= 100, flex_df['DK_Pts'] + 3, flex_df['DK_Pts'])

# %%
flex_df.tail()
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10887    2024     4         WAS           ARI  00-0035659      Terry McLaurin
# 10888    2024     4         WAS           ARI  00-0036626         Dyami Brown
# 10889    2024     4         WAS           ARI  00-0036628          John Bates
# 10890    2024     4         WAS           ARI  00-0037746      Brian Robinson
# 10891    2024     4         WAS           ARI  00-0039355      Luke McCaffrey
#
#       position  passing_yards  passing_tds  interceptions  ...  \
# 10887       WR              0            0              0  ...
# 10888       WR              0            0              0  ...
# 10889       TE              0            0              0  ...
# 10890       RB              0            0              0  ...
# 10891       WR              0            0              0  ...
#
#        receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 10887                            6                  103         0.591954
# 10888                            0                    4         0.022989
# 10889                            6                    3         0.017241
# 10890                           18                   -6        -0.034483
# 10891                            4                   13         0.074713
#
#        target_share          game_id  total_carries  carry_share  in_10_share  \
# 10887      0.333333  2024_04_WAS_ARI             37        0.000        0.143
# 10888      0.033333  2024_04_WAS_ARI             37        0.000        0.000
# 10889      0.033333  2024_04_WAS_ARI             37        0.000        0.000
# 10890      0.100000  2024_04_WAS_ARI             37        0.568        0.286
# 10891      0.033333  2024_04_WAS_ARI             37        0.000        0.000
#
#        FD_Pts  DK_Pts
# 10887    14.7    18.2
# 10888     0.9     1.4
# 10889     1.4     1.9
# 10890    18.8    23.3
# 10891     2.2     2.7
#
# [5 rows x 34 columns]

# %% [markdown]
# # Storing last week's points to evaluate model

# %%
flex_points_last_week = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week - 1)]\
[['season', 'week', 'player_display_name', 'recent_team', 'opponent_team', 'position', 'FD_Pts', 'DK_Pts']]

# %%
flex_points_last_week.to_csv('flex_target_' + str(season) + '_' + str(week - 1) + '.csv')

# %%
flex_df['position'].value_counts()
# Out:
# position
# WR    5068
# RB    3156
# TE    2475
# FB     193
# Name: count, dtype: int64

# %%
flex_df['position'] = np.where(flex_df['position'].isin(['HB', 'FB']), 'RB', flex_df['position'])

# %%
pos_mean_by_team = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position']).size().reset_index(name = 'num_players')

# %%
mean_by_pos = pos_mean_by_team.groupby('position')['num_players'].agg(['mean', 'max', 'min'])

# %%
mean_by_pos
# Out:
#               mean  max  min
# position
# RB        2.645340    5    1
# TE        1.968974    4    1
# WR        4.003160    7    2

# %% [markdown]
# # Grouping points allowed by position
# First step in deriving DvP variables.

# %%
grouped_pts = flex_df.groupby(['season', 'week', 'recent_team', 'opponent_team', 'position'])[['DK_Pts', 'FD_Pts']].sum().round(3)

# %%
grouped_pts
# Out:
#                                                 DK_Pts  FD_Pts
# season week recent_team opponent_team position
# 2022   1    ARI         KC            RB          25.6    21.6
#                                       TE          11.4    10.4
#                                       WR          32.9    25.9
#             ATL         NO            RB          28.3    23.3
#                                       TE           7.0     5.0
# ...                                                ...     ...
# 2024   4    TEN         MIA           TE           3.0     2.0
#                                       WR          15.0    12.0
#             WAS         ARI           RB          43.7    38.7
#                                       TE           9.1     7.1
#                                       WR          42.4    33.4
#
# [3789 rows x 2 columns]

# %%
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts = grouped_pts.sort_values(by = ['opponent_team', 'season', 'week'])
#grouped_pts['opp_game_num'] = grouped_pts.groupby(['opponent_team', 'season', 'week', 'recent_team']).cumcount() + 1
grouped_pts.reset_index(inplace = True)

# %%
grouped_pts_raw = grouped_pts.copy()

# %%
grouped_pts.drop(columns = ['index'], inplace = True)

# %%
grouped_pts
# Out:
#       season  week recent_team opponent_team position  DK_Pts  FD_Pts
# 0       2022     1          KC           ARI       RB    42.5    39.5
# 1       2022     1          KC           ARI       TE    38.2    30.2
# 2       2022     1          KC           ARI       WR    35.6    27.6
# 3       2022     2          LV           ARI       RB    12.6    11.6
# 4       2022     2          LV           ARI       TE    23.0    18.5
# ...      ...   ...         ...           ...      ...     ...     ...
# 3784    2024     3         CIN           WAS       TE    14.9    10.9
# 3785    2024     3         CIN           WAS       WR    55.9    45.9
# 3786    2024     4         ARI           WAS       RB    29.7    25.7
# 3787    2024     4         ARI           WAS       TE     3.2     2.2
# 3788    2024     4         ARI           WAS       WR    29.1    22.1
#
# [3789 rows x 7 columns]

# %%
# Create the pivot table
pivot_df = grouped_pts.pivot_table(
    index=['season', 'week', 'recent_team', 'opponent_team'],
    columns='position',
    values=['DK_Pts', 'FD_Pts'],
    aggfunc='sum',  # Assuming you want to sum the points if there are duplicates
    fill_value=0  # Fill missing values with 0
)

# %%
# Flatten the MultiIndex columns created by pivot_table
pivot_df.columns = ['_'.join(col).strip() for col in pivot_df.columns.values]

# %%
# Reset the index to turn the pivot table back into a DataFrame
pivot_df.reset_index(inplace=True)

# %%
pivot_df.head()
# Out:
#    season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 0    2022     1         ARI            KC       25.6       11.4       32.9
# 1    2022     1         ATL            NO       28.3        7.0       27.1
# 2    2022     1         BAL           NYJ       11.5       10.2       39.2
# 3    2022     1         BUF           LAR       16.0        1.5       63.7
# 4    2022     1         CAR           CLE       16.5        8.4       34.4
#
#    FD_Pts_RB  FD_Pts_TE  FD_Pts_WR
# 0       21.6       10.4       25.9
# 1       23.3        5.0       20.1
# 2        9.5        7.7       35.2
# 3       10.0        1.0       52.2
# 4       14.5        6.9       26.9

# %%
pivot_df = pivot_df.sort_values(by = ['opponent_team', 'season', 'week'])

# %% [markdown]
# # Bringing in current week's FanDuel and DraftKings rows here
# We're basically cloning this notebook from model training. We need features that apply to the current NFL week. We're trying the **one extra row** concept. For now we can probably add one row for each team, with the season value being 2024 and the week value being 1.

# %%
# Connect to the SQLite database
conn = sqlite3.connect('nfl_dfs.db')

# query_flex = "SELECT * FROM flex_dataset"
# #query_weekly = "SELECT * FROM weekly_data"
# query_fd_spread = "SELECT * FROM fd_spreads"
# query_dk_spread = "SELECT * FROM dk_spreads"
query_qb_model = "SELECT * FROM fd_qb_model_ready"
# # query_pbp = "S#ELECT * FROM pbp_non_defense"
query_fd = "SELECT * FROM fd_table"
query_dk = "SELECT * FROM dk_table"
#query_rb_wr_te = "SELECT * FROM rb_wr_te_data WHERE season >= 2022"

# flex_dataset = pd.read_sql_query(query_flex, conn)
# #weekly_df = pd.read_sql_query(query_weekly, conn)
# fd_spreads = pd.read_sql_query(query_fd_spread, conn)
# dk_spreads = pd.read_sql_query(query_dk_spread, conn)
# #pbp_df = pd.read_sql_query(query_pbp, conn)
fd_table = pd.read_sql_query(query_fd, conn)
dk_table = pd.read_sql_query(query_dk, conn)
qb_model = pd.read_sql_query(query_qb_model, conn)
# rb_wr_te_df = pd.read_sql_query(query_rb_wr_te, conn)

# Close the database connection
conn.close()

# %%
fanduel_df.head()
# Out:
#              ID           name position  salary team opponent  home_team  \
# 0  107566-86631    CeeDee Lamb       WR    9400  DAL      PIT          0
# 1  107566-85701  Ja'Marr Chase       WR    9300  CIN      BAL          1
# 2  107566-62239     Josh Allen       QB    9300  BUF      HOU          0
# 3  107566-39280  Derrick Henry       RB    9200  BAL      CIN          0
# 4  107566-91419   Nico Collins       WR    8800  HOU      BUF          1
#
#    status        date  week
# 0  Active  10-06-2024     5
# 1  Active  10-06-2024     5
# 2  Active  10-06-2024     5
# 3  Active  10-06-2024     5
# 4  Active  10-06-2024     5

# %%
draftkings_df.head()
# Out:
#          ID           name position  salary team opponent  home_team  status  \
# 0  36142122  Ja'Marr Chase       WR    8000  CIN      BAL          1  Active
# 1  36142124    Cooper Kupp       WR    7900  LAR       GB          1       O
# 2  36141894  Derrick Henry       RB    7800  BAL      CIN          0  Active
# 3  36141829     Josh Allen       QB    7700  BUF      HOU          0  Active
# 4  36142126   Nico Collins       WR    7700  HOU      BUF          1  Active
#
#          date  week
# 0  10-06-2024     5
# 1  10-06-2024     5
# 2  10-06-2024     5
# 3  10-06-2024     5
# 4  10-06-2024     5

# %%
# Initialize empty lists for teams and opponents
#We'll use FanDuel here because they tend to list more players than DK and we're less likely to miss anyone.
team_list = []
opponent_list = []

# Initialize a set to keep track of already added matchups
added_matchups = set()

# Loop through each row in the dataframe
for index, row in fanduel_df.iterrows():
    team = row['team']
    opponent = row['opponent']
    
    # Ensure each team and opponent are added only once in reverse order as well
    if (team, opponent) not in added_matchups and (opponent, team) not in added_matchups:
        # Add the matchup as-is
        team_list.append(team)
        opponent_list.append(opponent)
        
        # Add the reverse matchup
        team_list.append(opponent)
        opponent_list.append(team)
        
        # Track the added matchups
        added_matchups.add((team, opponent))
        added_matchups.add((opponent, team))

# Display the resulting lists
print("Team list:", team_list)
print("Opponent list:", opponent_list)
# Out:
# Team list: ['DAL', 'PIT', 'CIN', 'BAL', 'BUF', 'HOU', 'WAS', 'CLE', 'SF', 'ARI', 'MIA', 'NE', 'IND', 'JAX', 'LAR', 'GB', 'SEA', 'NYG', 'CHI', 'CAR', 'LV', 'DEN']
# Opponent list: ['PIT', 'DAL', 'BAL', 'CIN', 'HOU', 'BUF', 'CLE', 'WAS', 'ARI', 'SF', 'NE', 'MIA', 'JAX', 'IND', 'GB', 'LAR', 'NYG', 'SEA', 'CAR', 'CHI', 'DEN', 'LV']

# %%
len(team_list), len(opponent_list)
# Out:
# (22, 22)

# %%
append_to_pivot = {'season': [season] * len(team_list), 'week': [week] * len(team_list), 'recent_team': team_list, 'opponent_team': opponent_list}

# %%
append_to_pivot = pd.DataFrame(append_to_pivot)

# %%
pivot_df = pd.concat([pivot_df, append_to_pivot], axis = 0)

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1288 entries, 15 to 21
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1288 non-null   int64
#  1   week           1288 non-null   int64
#  2   recent_team    1288 non-null   object
#  3   opponent_team  1288 non-null   object
#  4   DK_Pts_RB      1266 non-null   float64
#  5   DK_Pts_TE      1266 non-null   float64
#  6   DK_Pts_WR      1266 non-null   float64
#  7   FD_Pts_RB      1266 non-null   float64
#  8   FD_Pts_TE      1266 non-null   float64
#  9   FD_Pts_WR      1266 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 110.7+ KB

# %%
pivot_df['opp_game_num'] = pivot_df.groupby(['opponent_team']).cumcount() + 1

# %%
cols_for_dvp = ['DK_Pts_RB', 'DK_Pts_TE', 'DK_Pts_WR', 'FD_Pts_RB', 'FD_Pts_TE', 'FD_Pts_WR']

# %%
pivot_df_by_game = pivot_df.copy()

# %%
pivot_df.head()
# Out:
#      season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 15     2022     1          KC           ARI       42.5       38.2       35.6
# 50     2022     2          LV           ARI       12.6       23.0       32.7
# 81     2022     3         LAR           ARI       12.8       13.9       37.0
# 100    2022     4         CAR           ARI       26.0        8.0       17.7
# 153    2022     5         PHI           ARI       10.4       17.5       29.8
#
#      FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 15        39.5       30.2       27.6             1
# 50        11.6       18.5       24.7             2
# 81        11.8       11.4       30.5             3
# 100       21.5        6.0       13.2             4
# 153        9.4       13.5       21.8             5

# %%
pivot_df.tail()
# Out:
#     season  week recent_team opponent_team  DK_Pts_RB  DK_Pts_TE  DK_Pts_WR  \
# 17    2024     5         NYG           SEA        NaN        NaN        NaN
# 18    2024     5         CHI           CAR        NaN        NaN        NaN
# 19    2024     5         CAR           CHI        NaN        NaN        NaN
# 20    2024     5          LV           DEN        NaN        NaN        NaN
# 21    2024     5         DEN            LV        NaN        NaN        NaN
#
#     FD_Pts_RB  FD_Pts_TE  FD_Pts_WR  opp_game_num
# 17        NaN        NaN        NaN            40
# 18        NaN        NaN        NaN            39
# 19        NaN        NaN        NaN            39
# 20        NaN        NaN        NaN            39
# 21        NaN        NaN        NaN            39

# %%
pivot_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # DvP variables
# We'll take an 8-game rolling mean for fantasy points allowed to RBs, WRs and TEs for each team, even if the games go back to last season. DvP means defense vs. position.

# %%
def calculate_equal_rolling_mean(group, cols, suffix):
    """
    This function calculates a rolling mean for the last eight games, going back to previous season if necessary.
    It also calculates when there are less than eight games to use.
    """
    for col in cols:
        group[f'{col}{suffix}'] = (
            group[col].shift().rolling(window=8, min_periods=1).mean()
        )
    return group

# %%
pivot_df = pivot_df.groupby('opponent_team', as_index = False).apply(calculate_equal_rolling_mean, cols=cols_for_dvp, suffix = '_DvP')

# %%
pivot_df.drop(columns = cols_for_dvp + ['opp_game_num'], inplace = True)

# %%
pivot_df
# Out:
#          season  week recent_team opponent_team  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0  15      2022     1          KC           ARI            NaN            NaN
#    50      2022     2          LV           ARI      42.500000      38.200000
#    81      2022     3         LAR           ARI      27.550000      30.600000
#    100     2022     4         CAR           ARI      22.633333      25.033333
#    153     2022     5         PHI           ARI      23.475000      20.775000
# ...         ...   ...         ...           ...            ...            ...
# 31 1167    2024     1          TB           WAS      33.962500       8.212500
#    1193    2024     2         NYG           WAS      33.500000       7.387500
#    1208    2024     3         CIN           WAS      31.725000       6.537500
#    1234    2024     4         ARI           WAS      31.437500       7.562500
#    7       2024     5         CLE           WAS      30.250000       7.425000
#
#          DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0  15              NaN            NaN            NaN            NaN
#    50          35.6000      39.500000      30.200000        27.6000
#    81          34.1500      25.550000      24.350000        26.1500
#    100         35.1000      20.966667      20.033333        27.6000
#    153         30.7500      21.100000      16.525000        24.0000
# ...                ...            ...            ...            ...
# 31 1167        47.3250      30.212500       6.275000        38.8875
#    1193        48.0625      29.562500       5.700000        40.0000
#    1208        50.0000      27.850000       5.037500        41.3125
#    1234        49.8000      27.562500       5.687500        40.6750
#    7           47.3000      26.187500       5.550000        38.4250
#
# [1288 rows x 10 columns]

# %%
pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1288 entries, (0, 15) to (31, 7)
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   season         1288 non-null   int64
#  1   week           1288 non-null   int64
#  2   recent_team    1288 non-null   object
#  3   opponent_team  1288 non-null   object
#  4   DK_Pts_RB_DvP  1256 non-null   float64
#  5   DK_Pts_TE_DvP  1256 non-null   float64
#  6   DK_Pts_WR_DvP  1256 non-null   float64
#  7   FD_Pts_RB_DvP  1256 non-null   float64
#  8   FD_Pts_TE_DvP  1256 non-null   float64
#  9   FD_Pts_WR_DvP  1256 non-null   float64
# dtypes: float64(6), int64(2), object(2)
# memory usage: 147.9+ KB

# %%
flex_df.head()
# Out:
#    season  week recent_team opponent_team   player_id player_display_name  \
# 0    2022     1         ARI            KC  00-0027942          A.J. Green
# 1    2022     1         ARI            KC  00-0030061           Zach Ertz
# 2    2022     1         ARI            KC  00-0033553        James Conner
# 3    2022     1         ARI            KC  00-0035500         Greg Dortch
# 4    2022     1         ARI            KC  00-0035527       Andy Isabella
#
#   position  passing_yards  passing_tds  interceptions  ...  \
# 0       WR              0            0              0  ...
# 1       TE              0            0              0  ...
# 2       RB              0            0              0  ...
# 3       WR              0            0              0  ...
# 4       WR              0            0              0  ...
#
#    receiving_yards_after_catch  receiving_air_yards  air_yards_share  \
# 0                            0                   42         0.157895
# 1                            4                   22         0.082707
# 2                           38                    7         0.026316
# 3                           31                   62         0.233083
# 4                            4                   30         0.112782
#
#    target_share         game_id  total_carries  carry_share  in_10_share  \
# 0      0.111111  2022_01_KC_ARI             21        0.000        0.143
# 1      0.111111  2022_01_KC_ARI             21        0.000        0.429
# 2      0.166667  2022_01_KC_ARI             21        0.476        0.286
# 3      0.250000  2022_01_KC_ARI             21        0.000        0.000
# 4      0.083333  2022_01_KC_ARI             21        0.000        0.000
#
#    FD_Pts  DK_Pts
# 0     2.3     3.3
# 1    10.4    11.4
# 2    14.0    16.5
# 3     9.8    13.3
# 4     1.5     2.0
#
# [5 rows x 34 columns]

# %%
flex_df = flex_df.merge(
    pivot_df, 
    on=['season', 'week', 'recent_team', 'opponent_team'],  # common columns to merge on
    how='outer'  # outer join to keep all rows from both dataframes
)

# %%
flex_df.tail(30)
# Out:
#        season  week recent_team opponent_team   player_id player_display_name  \
# 10884    2024     4         WAS           ARI  00-0033591          Noah Brown
# 10885    2024     4         WAS           ARI  00-0033955    Jeremy McNichols
# 10886    2024     4         WAS           ARI  00-0035208   Olamide Zaccheaus
# 10887    2024     4         WAS           ARI  00-0035659      Terry McLaurin
# 10888    2024     4         WAS           ARI  00-0036626         Dyami Brown
# 10889    2024     4         WAS           ARI  00-0036628          John Bates
# 10890    2024     4         WAS           ARI  00-0037746      Brian Robinson
# 10891    2024     4         WAS           ARI  00-0039355      Luke McCaffrey
# 10892    2024     5          SF           ARI         NaN                 NaN
# 10893    2024     5         CIN           BAL         NaN                 NaN
# 10894    2024     5         HOU           BUF         NaN                 NaN
# 10895    2024     5         CHI           CAR         NaN                 NaN
# 10896    2024     5         CAR           CHI         NaN                 NaN
# 10897    2024     5         BAL           CIN         NaN                 NaN
# 10898    2024     5         WAS           CLE         NaN                 NaN
# 10899    2024     5         PIT           DAL         NaN                 NaN
# 10900    2024     5          LV           DEN         NaN                 NaN
# 10901    2024     5         LAR            GB         NaN                 NaN
# 10902    2024     5         BUF           HOU         NaN                 NaN
# 10903    2024     5         JAX           IND         NaN                 NaN
# 10904    2024     5         IND           JAX         NaN                 NaN
# 10905    2024     5          GB           LAR         NaN                 NaN
# 10906    2024     5         DEN            LV         NaN                 NaN
# 10907    2024     5          NE           MIA         NaN                 NaN
# 10908    2024     5         MIA            NE         NaN                 NaN
# 10909    2024     5         SEA           NYG         NaN                 NaN
# 10910    2024     5         DAL           PIT         NaN                 NaN
# 10911    2024     5         NYG           SEA         NaN                 NaN
# 10912    2024     5         ARI            SF         NaN                 NaN
# 10913    2024     5         CLE           WAS         NaN                 NaN
#
#       position  passing_yards  passing_tds  interceptions  ...  carry_share  \
# 10884       WR            0.0          0.0            0.0  ...        0.000
# 10885       RB            0.0          0.0            0.0  ...        0.216
# 10886       WR            0.0          0.0            0.0  ...        0.000
# 10887       WR            0.0          0.0            0.0  ...        0.000
# 10888       WR            0.0          0.0            0.0  ...        0.000
# 10889       TE            0.0          0.0            0.0  ...        0.000
# 10890       RB            0.0          0.0            0.0  ...        0.568
# 10891       WR            0.0          0.0            0.0  ...        0.000
# 10892      NaN            NaN          NaN            NaN  ...          NaN
# 10893      NaN            NaN          NaN            NaN  ...          NaN
# 10894      NaN            NaN          NaN            NaN  ...          NaN
# 10895      NaN            NaN          NaN            NaN  ...          NaN
# 10896      NaN            NaN          NaN            NaN  ...          NaN
# 10897      NaN            NaN          NaN            NaN  ...          NaN
# 10898      NaN            NaN          NaN            NaN  ...          NaN
# 10899      NaN            NaN          NaN            NaN  ...          NaN
# 10900      NaN            NaN          NaN            NaN  ...          NaN
# 10901      NaN            NaN          NaN            NaN  ...          NaN
# 10902      NaN            NaN          NaN            NaN  ...          NaN
# 10903      NaN            NaN          NaN            NaN  ...          NaN
# 10904      NaN            NaN          NaN            NaN  ...          NaN
# 10905      NaN            NaN          NaN            NaN  ...          NaN
# 10906      NaN            NaN          NaN            NaN  ...          NaN
# 10907      NaN            NaN          NaN            NaN  ...          NaN
# 10908      NaN            NaN          NaN            NaN  ...          NaN
# 10909      NaN            NaN          NaN            NaN  ...          NaN
# 10910      NaN            NaN          NaN            NaN  ...          NaN
# 10911      NaN            NaN          NaN            NaN  ...          NaN
# 10912      NaN            NaN          NaN            NaN  ...          NaN
# 10913      NaN            NaN          NaN            NaN  ...          NaN
#
#        in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 10884        0.000     4.1     5.6        24.8100        11.7750
# 10885        0.286    19.9    20.4        24.8100        11.7750
# 10886        0.000    11.5    14.5        24.8100        11.7750
# 10887        0.143    14.7    18.2        24.8100        11.7750
# 10888        0.000     0.9     1.4        24.8100        11.7750
# 10889        0.000     1.4     1.9        24.8100        11.7750
# 10890        0.286    18.8    23.3        24.8100        11.7750
# 10891        0.000     2.2     2.7        24.8100        11.7750
# 10892          NaN     NaN     NaN        28.2475        12.1750
# 10893          NaN     NaN     NaN        21.8250        15.3375
# 10894          NaN     NaN     NaN        26.9750        12.3000
# 10895          NaN     NaN     NaN        26.9500        11.9375
# 10896          NaN     NaN     NaN        24.8000        11.1625
# 10897          NaN     NaN     NaN        25.0125         7.2625
# 10898          NaN     NaN     NaN        23.6125        11.9625
# 10899          NaN     NaN     NaN        27.7875         8.5125
# 10900          NaN     NaN     NaN        20.9375        12.7750
# 10901          NaN     NaN     NaN        22.2875        16.3125
# 10902          NaN     NaN     NaN        20.6000         9.7000
# 10903          NaN     NaN     NaN        23.2500        12.6000
# 10904          NaN     NaN     NaN        27.4750         7.8875
# 10905          NaN     NaN     NaN        23.5375        11.5250
# 10906          NaN     NaN     NaN        24.5625         9.8625
# 10907          NaN     NaN     NaN        25.1750        13.7125
# 10908          NaN     NaN     NaN        25.3200        10.6125
# 10909          NaN     NaN     NaN        21.7500        12.6750
# 10910          NaN     NaN     NaN        16.4500        12.5375
# 10911          NaN     NaN     NaN        27.5475        12.3875
# 10912          NaN     NaN     NaN        22.1250        11.7875
# 10913          NaN     NaN     NaN        30.2500         7.4250
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 10884        28.1375        21.5600         9.4625        23.3875
# 10885        28.1375        21.5600         9.4625        23.3875
# 10886        28.1375        21.5600         9.4625        23.3875
# 10887        28.1375        21.5600         9.4625        23.3875
# 10888        28.1375        21.5600         9.4625        23.3875
# 10889        28.1375        21.5600         9.4625        23.3875
# 10890        28.1375        21.5600         9.4625        23.3875
# 10891        28.1375        21.5600         9.4625        23.3875
# 10892        29.3375        24.5600         9.8000        24.2125
# 10893        29.3500        18.0750        11.5250        23.4125
# 10894        24.1625        24.2250         9.5500        19.1625
# 10895        27.6375        23.8250         9.4375        22.8250
# 10896        29.9500        21.0500         8.4125        23.7625
# 10897        36.6500        21.0750         5.2625        29.8375
# 10898        32.9500        20.5500         9.6500        27.2625
# 10899        33.5200        24.7250         6.7000        26.8325
# 10900        31.0125        17.4375        10.1500        24.4500
# 10901        32.5250        18.9125        13.6250        25.7125
# 10902        29.7500        17.9750         7.7625        23.9375
# 10903        36.9125        19.7500         9.9125        28.7250
# 10904        35.8250        24.4750         6.5125        27.9500
# 10905        41.6875        20.9750         9.3375        33.4375
# 10906        35.1250        20.6250         7.5500        28.7500
# 10907        35.0625        23.1750        11.0875        27.7500
# 10908        31.4750        21.8200         8.3625        24.7250
# 10909        34.6125        19.3750         9.8000        27.8000
# 10910        29.9250        13.7625        10.4125        23.6125
# 10911        25.1350        24.5475         9.5125        19.6975
# 10912        34.4500        18.7500         9.0375        28.7000
# 10913        47.3000        26.1875         5.5500        38.4250
#
# [30 rows x 40 columns]

# %%
flex_df.reset_index(inplace = True)

# %%
flex_df.columns
# Out:
# Index(['index', 'season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'passing_yards', 'passing_tds',
#        'interceptions', 'passing_2pt_conversions', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'rushing_2pt_conversions',
#        'receptions', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles_lost', 'receiving_2pt_conversions',
#        'sack_fumbles_lost', 'special_teams_tds', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'game_id', 'total_carries', 'carry_share',
#        'in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
#        'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_df['opponent_team'].nunique()
# Out:
# 32

# %% [markdown]
# # Paring down some of the columns
# We're drop columns that won't be needed for features.

# %%
cols_to_keep = ['season', 'week', 'recent_team', 'opponent_team', 'player_id',
       'player_display_name', 'position', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 
       'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
       'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share','in_10_share', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP',
       'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']

# %%
flex_df = flex_df[cols_to_keep]

# %%
#quarterback_df[quarterback_df['season'] >= 2006]['passing_air_yards']

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10914 entries, 0 to 10913
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10914 non-null  int64
#  1   week                         10914 non-null  int64
#  2   recent_team                  10914 non-null  object
#  3   opponent_team                10914 non-null  object
#  4   player_id                    10892 non-null  object
#  5   player_display_name          10892 non-null  object
#  6   position                     10892 non-null  object
#  7   rushing_yards                10892 non-null  float64
#  8   rushing_tds                  10892 non-null  float64
#  9   rushing_fumbles_lost         10892 non-null  float64
#  10  receptions                   10892 non-null  float64
#  11  receiving_yards              10892 non-null  float64
#  12  receiving_tds                10892 non-null  float64
#  13  receiving_fumbles_lost       10892 non-null  float64
#  14  targets                      10892 non-null  float64
#  15  carries                      10892 non-null  float64
#  16  receiving_yards_after_catch  10892 non-null  float64
#  17  receiving_air_yards          10892 non-null  float64
#  18  air_yards_share              10892 non-null  float64
#  19  target_share                 10892 non-null  float64
#  20  carry_share                  10892 non-null  float64
#  21  in_10_share                  10892 non-null  float64
#  22  FD_Pts                       10892 non-null  float64
#  23  DK_Pts                       10892 non-null  float64
#  24  DK_Pts_RB_DvP                10634 non-null  float64
#  25  DK_Pts_TE_DvP                10634 non-null  float64
#  26  DK_Pts_WR_DvP                10634 non-null  float64
#  27  FD_Pts_RB_DvP                10634 non-null  float64
#  28  FD_Pts_TE_DvP                10634 non-null  float64
#  29  FD_Pts_WR_DvP                10634 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# # Filling missing values
# We have found that dropping rows with missing values can affect calculations down the line. So we need to find ways to fill the missing values.<br>

# %% [markdown]
# The first row of every team grouping when we calculated DvP was NaN because there was no previous value. We'll fill those in with the mean.

# %%
flex_df['FD_Pts_RB_DvP'] = flex_df['FD_Pts_RB_DvP'].fillna(flex_df['FD_Pts_RB_DvP'].mean())
flex_df['DK_Pts_RB_DvP'] = flex_df['DK_Pts_RB_DvP'].fillna(flex_df['DK_Pts_RB_DvP'].mean())
flex_df['FD_Pts_TE_DvP'] = flex_df['FD_Pts_TE_DvP'].fillna(flex_df['FD_Pts_TE_DvP'].mean())
flex_df['DK_Pts_TE_DvP'] = flex_df['DK_Pts_TE_DvP'].fillna(flex_df['DK_Pts_TE_DvP'].mean())
flex_df['FD_Pts_WR_DvP'] = flex_df['FD_Pts_WR_DvP'].fillna(flex_df['FD_Pts_WR_DvP'].mean())
flex_df['DK_Pts_WR_DvP'] = flex_df['DK_Pts_WR_DvP'].fillna(flex_df['DK_Pts_WR_DvP'].mean())

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10914 entries, 0 to 10913
# Data columns (total 30 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   season                       10914 non-null  int64
#  1   week                         10914 non-null  int64
#  2   recent_team                  10914 non-null  object
#  3   opponent_team                10914 non-null  object
#  4   player_id                    10892 non-null  object
#  5   player_display_name          10892 non-null  object
#  6   position                     10892 non-null  object
#  7   rushing_yards                10892 non-null  float64
#  8   rushing_tds                  10892 non-null  float64
#  9   rushing_fumbles_lost         10892 non-null  float64
#  10  receptions                   10892 non-null  float64
#  11  receiving_yards              10892 non-null  float64
#  12  receiving_tds                10892 non-null  float64
#  13  receiving_fumbles_lost       10892 non-null  float64
#  14  targets                      10892 non-null  float64
#  15  carries                      10892 non-null  float64
#  16  receiving_yards_after_catch  10892 non-null  float64
#  17  receiving_air_yards          10892 non-null  float64
#  18  air_yards_share              10892 non-null  float64
#  19  target_share                 10892 non-null  float64
#  20  carry_share                  10892 non-null  float64
#  21  in_10_share                  10892 non-null  float64
#  22  FD_Pts                       10892 non-null  float64
#  23  DK_Pts                       10892 non-null  float64
#  24  DK_Pts_RB_DvP                10914 non-null  float64
#  25  DK_Pts_TE_DvP                10914 non-null  float64
#  26  DK_Pts_WR_DvP                10914 non-null  float64
#  27  FD_Pts_RB_DvP                10914 non-null  float64
#  28  FD_Pts_TE_DvP                10914 non-null  float64
#  29  FD_Pts_WR_DvP                10914 non-null  float64
# dtypes: float64(23), int64(2), object(5)
# memory usage: 2.5+ MB

# %%
flex_24 = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_24.head()
# Out:
#        season  week recent_team opponent_team player_id player_display_name  \
# 10892    2024     5          SF           ARI       NaN                 NaN
# 10893    2024     5         CIN           BAL       NaN                 NaN
# 10894    2024     5         HOU           BUF       NaN                 NaN
# 10895    2024     5         CHI           CAR       NaN                 NaN
# 10896    2024     5         CAR           CHI       NaN                 NaN
#
#       position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 10892      NaN            NaN          NaN                   NaN  ...
# 10893      NaN            NaN          NaN                   NaN  ...
# 10894      NaN            NaN          NaN                   NaN  ...
# 10895      NaN            NaN          NaN                   NaN  ...
# 10896      NaN            NaN          NaN                   NaN  ...
#
#        carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 10892          NaN          NaN     NaN     NaN        28.2475        12.1750
# 10893          NaN          NaN     NaN     NaN        21.8250        15.3375
# 10894          NaN          NaN     NaN     NaN        26.9750        12.3000
# 10895          NaN          NaN     NaN     NaN        26.9500        11.9375
# 10896          NaN          NaN     NaN     NaN        24.8000        11.1625
#
#        DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 10892        29.3375         24.560         9.8000        24.2125
# 10893        29.3500         18.075        11.5250        23.4125
# 10894        24.1625         24.225         9.5500        19.1625
# 10895        27.6375         23.825         9.4375        22.8250
# 10896        29.9500         21.050         8.4125        23.7625
#
# [5 rows x 30 columns]

# %%
fd_flex = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
dk_flex = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
fd_names = set(list(fd_flex['name'].unique()))
dk_names = set(list(dk_flex['name'].unique()))

# %%
# Initialize empty lists for names, positions, teams, and opponents
name_list = []
position_list = []
team_list = []
opponent_list = []

# Loop through the dataframe to extract names, positions, teams, and opponents
for index, row in fd_flex.iterrows():
    name_list.append(row['name'])          # Add player name to name_list
    position_list.append(row['position'])  # Add player position to position_list
    team_list.append(row['team'])          # Add player's team to team_list
    opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# dk_name_list = []
# dk_position_list = []
# dk_team_list = []
# dk_opponent_list = []

# for index, row in dk_flex.iterrows():
#     dk_name_list.append(row['name'])          # Add player name to name_list
#     dk_position_list.append(row['position'])  # Add player position to position_list
#     dk_team_list.append(row['team'])          # Add player's team to team_list
#     dk_opponent_list.append(row['opponent'])  # Add opponent team to opponent_list

# Display the resulting lists
# print("Name list:", name_list)
# print("Position list:", position_list)
# print("Team list:", team_list)
# print("Opponent list:", opponent_list)

# %%
len(name_list), len(position_list)
# Out:
# (603, 603)

# %%
to_concat = {'season': [season] * len(name_list), 'week': [week] * len(name_list), 'player_display_name': name_list, 'position': position_list,\
            'recent_team': team_list, 'opponent_team': opponent_list}

# %%
to_concat = pd.DataFrame(to_concat)

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team
# 0      2024     5         CeeDee Lamb       WR         DAL           PIT
# 1      2024     5       Ja'Marr Chase       WR         CIN           BAL
# 2      2024     5       Derrick Henry       RB         BAL           CIN
# 3      2024     5        Nico Collins       WR         HOU           BUF
# 4      2024     5        Jordan Mason       RB          SF           ARI
# ..      ...   ...                 ...      ...         ...           ...
# 598    2024     5          Tre Mosley       WR         CIN           BAL
# 599    2024     5          Matt Sokol       TE         PIT           DAL
# 600    2024     5      Jesper Horsted       TE         CAR           CHI
# 601    2024     5        Dalton Keene       TE         HOU           BUF
# 602    2024     5          John Kelly       RB         BAL           CIN
#
# [603 rows x 6 columns]

# %%
to_concat['recent_team'].value_counts()
# Out:
# recent_team
# CAR    32
# MIA    31
# BAL    30
# DAL    29
# PIT    29
# GB     29
# SEA    28
# JAX    28
# ARI    28
# IND    28
# NYG    27
# SF     27
# CHI    27
# CLE    27
# DEN    27
# CIN    26
# NE     26
# HOU    26
# BUF    25
# WAS    25
# LV     25
# LAR    23
# Name: count, dtype: int64

# %%
flex_24.columns
# Out:
# Index(['season', 'week', 'recent_team', 'opponent_team', 'player_id',
#        'player_display_name', 'position', 'rushing_yards', 'rushing_tds',
#        'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'FD_Pts', 'DK_Pts',
#        'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
#        'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP'],
#       dtype='object')

# %%
flex_24 = flex_24[['season', 'week', 'recent_team', 'opponent_team', 
       'DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP']]

# %%
to_concat = pd.merge(to_concat, flex_24, on = ['season', 'week', 'recent_team', 'opponent_team'])

# %%
to_concat
# Out:
#      season  week player_display_name position recent_team opponent_team  \
# 0      2024     5         CeeDee Lamb       WR         DAL           PIT
# 1      2024     5       Jake Ferguson       TE         DAL           PIT
# 2      2024     5         Rico Dowdle       RB         DAL           PIT
# 3      2024     5     Ezekiel Elliott       RB         DAL           PIT
# 4      2024     5       Brandin Cooks       WR         DAL           PIT
# ..      ...   ...                 ...      ...         ...           ...
# 598    2024     5        Salvon Ahmed       RB         DEN            LV
# 599    2024     5        Blake Watson       RB         DEN            LV
# 600    2024     5    Mitchell Fraboni       TE         DEN            LV
# 601    2024     5       Donald Parham       TE         DEN            LV
# 602    2024     5      Lincoln Victor       WR         DEN            LV
#
#      DK_Pts_RB_DvP  DK_Pts_TE_DvP  DK_Pts_WR_DvP  FD_Pts_RB_DvP  \
# 0          16.4500        12.5375         29.925        13.7625
# 1          16.4500        12.5375         29.925        13.7625
# 2          16.4500        12.5375         29.925        13.7625
# 3          16.4500        12.5375         29.925        13.7625
# 4          16.4500        12.5375         29.925        13.7625
# ..             ...            ...            ...            ...
# 598        24.5625         9.8625         35.125        20.6250
# 599        24.5625         9.8625         35.125        20.6250
# 600        24.5625         9.8625         35.125        20.6250
# 601        24.5625         9.8625         35.125        20.6250
# 602        24.5625         9.8625         35.125        20.6250
#
#      FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0          10.4125        23.6125
# 1          10.4125        23.6125
# 2          10.4125        23.6125
# 3          10.4125        23.6125
# 4          10.4125        23.6125
# ..             ...            ...
# 598         7.5500        28.7500
# 599         7.5500        28.7500
# 600         7.5500        28.7500
# 601         7.5500        28.7500
# 602         7.5500        28.7500
#
# [603 rows x 12 columns]

# %%
to_concat['opponent_team'].value_counts()
# Out:
# opponent_team
# CHI    32
# NE     31
# CIN    30
# PIT    29
# DAL    29
# LAR    29
# NYG    28
# IND    28
# SF     28
# JAX    28
# SEA    27
# ARI    27
# CAR    27
# WAS    27
# LV     27
# BAL    26
# MIA    26
# BUF    26
# HOU    25
# CLE    25
# DEN    25
# GB     23
# Name: count, dtype: int64

# %%
flex_df = flex_df[~((flex_df['season'] == season) & (flex_df['week'] == week))]

# %%
flex_df = pd.concat([flex_df, to_concat], axis = 0)

# %%
flex_df
# Out:
#      season  week recent_team opponent_team   player_id player_display_name  \
# 0      2022     1         ARI            KC  00-0027942          A.J. Green
# 1      2022     1         ARI            KC  00-0030061           Zach Ertz
# 2      2022     1         ARI            KC  00-0033553        James Conner
# 3      2022     1         ARI            KC  00-0035500         Greg Dortch
# 4      2022     1         ARI            KC  00-0035527       Andy Isabella
# ..      ...   ...         ...           ...         ...                 ...
# 598    2024     5         DEN            LV         NaN        Salvon Ahmed
# 599    2024     5         DEN            LV         NaN        Blake Watson
# 600    2024     5         DEN            LV         NaN    Mitchell Fraboni
# 601    2024     5         DEN            LV         NaN       Donald Parham
# 602    2024     5         DEN            LV         NaN      Lincoln Victor
#
#     position  rushing_yards  rushing_tds  rushing_fumbles_lost  ...  \
# 0         WR            0.0          0.0                   0.0  ...
# 1         TE            0.0          0.0                   0.0  ...
# 2         RB           26.0          1.0                   0.0  ...
# 3         WR            0.0          0.0                   0.0  ...
# 4         WR            0.0          0.0                   0.0  ...
# ..       ...            ...          ...                   ...  ...
# 598       RB            NaN          NaN                   NaN  ...
# 599       RB            NaN          NaN                   NaN  ...
# 600       TE            NaN          NaN                   NaN  ...
# 601       TE            NaN          NaN                   NaN  ...
# 602       WR            NaN          NaN                   NaN  ...
#
#      carry_share  in_10_share  FD_Pts  DK_Pts  DK_Pts_RB_DvP  DK_Pts_TE_DvP  \
# 0          0.000        0.143     2.3     3.3      22.681675      11.910102
# 1          0.000        0.429    10.4    11.4      22.681675      11.910102
# 2          0.476        0.286    14.0    16.5      22.681675      11.910102
# 3          0.000        0.000     9.8    13.3      22.681675      11.910102
# 4          0.000        0.000     1.5     2.0      22.681675      11.910102
# ..           ...          ...     ...     ...            ...            ...
# 598          NaN          NaN     NaN     NaN      24.562500       9.862500
# 599          NaN          NaN     NaN     NaN      24.562500       9.862500
# 600          NaN          NaN     NaN     NaN      24.562500       9.862500
# 601          NaN          NaN     NaN     NaN      24.562500       9.862500
# 602          NaN          NaN     NaN     NaN      24.562500       9.862500
#
#      DK_Pts_WR_DvP  FD_Pts_RB_DvP  FD_Pts_TE_DvP  FD_Pts_WR_DvP
# 0        34.423663      19.682594       9.413345       27.33893
# 1        34.423663      19.682594       9.413345       27.33893
# 2        34.423663      19.682594       9.413345       27.33893
# 3        34.423663      19.682594       9.413345       27.33893
# 4        34.423663      19.682594       9.413345       27.33893
# ..             ...            ...            ...            ...
# 598      35.125000      20.625000       7.550000       28.75000
# 599      35.125000      20.625000       7.550000       28.75000
# 600      35.125000      20.625000       7.550000       28.75000
# 601      35.125000      20.625000       7.550000       28.75000
# 602      35.125000      20.625000       7.550000       28.75000
#
# [11495 rows x 30 columns]

# %%
cols_L8 = ['rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards', 'receiving_tds', 'receiving_fumbles_lost', 'targets',\
           'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share', 'target_share', 'carry_share', 'in_10_share']

# %%
flex_L8_features = flex_df.groupby(['player_display_name', 'season', 'week'])[cols_L8].sum()

# %% [markdown]
# # L8 variables
# L8 variables are rolling means of features over the last eight games. Just like we did for the DvP variables, we'll calculate features over the previous eight games for individual QBs.

# %%
flex_L8_features = flex_L8_features.sort_values(by = ['player_display_name', 'season', 'week'])
flex_L8_features['game_num'] = flex_L8_features.groupby(['player_display_name', 'season']).cumcount() + 1
#quarterback_df.reset_index(drop = True, inplace = True)

# %%
flex_L8_features = flex_L8_features.groupby(['player_display_name'], as_index = False).apply(calculate_equal_rolling_mean, cols=cols_L8, suffix = '_L8')

# %%
flex_L8_features.reset_index(inplace = True)

# %%
flex_L8_features.columns
# Out:
# Index(['level_0', 'player_display_name', 'season', 'week', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
#        'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries',
#        'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
#        'target_share', 'carry_share', 'in_10_share', 'game_num',
#        'rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8',
#        'receptions_L8', 'receiving_yards_L8', 'receiving_tds_L8',
#        'receiving_fumbles_lost_L8', 'targets_L8', 'carries_L8',
#        'receiving_yards_after_catch_L8', 'receiving_air_yards_L8',
#        'air_yards_share_L8', 'target_share_L8', 'carry_share_L8',
#        'in_10_share_L8'],
#       dtype='object')

# %%
flex_L8_features.drop(columns = ['level_0', 'rushing_yards', 'rushing_tds', 'rushing_fumbles_lost', 'receptions', 'receiving_yards',
       'receiving_tds', 'receiving_fumbles_lost', 'targets', 'carries', 'receiving_yards_after_catch', 'receiving_air_yards', 'air_yards_share',
       'target_share', 'carry_share', 'in_10_share'], inplace = True)

# %%
flex_L8_features
# Out:
#       player_display_name  season  week  game_num  rushing_yards_L8  \
# 0             A.J. Barner    2024     3         1               NaN
# 1             A.J. Barner    2024     4         2          0.000000
# 2              A.J. Brown    2022     1         1               NaN
# 3              A.J. Brown    2022     2         2          0.000000
# 4              A.J. Brown    2022     3         3          0.000000
# ...                   ...     ...   ...       ...               ...
# 11490      Zonovan Knight    2022    16         5         63.250000
# 11491      Zonovan Knight    2022    17         6         50.200000
# 11492      Zonovan Knight    2022    18         7         46.333333
# 11493      Zonovan Knight    2023     3         1         42.857143
# 11494      Zonovan Knight    2023     5         2         39.125000
#
#        rushing_tds_L8  rushing_fumbles_lost_L8  receptions_L8  \
# 0                 NaN                      NaN            NaN
# 1            0.000000                      0.0       3.000000
# 2                 NaN                      NaN            NaN
# 3            0.000000                      0.0      10.000000
# 4            0.000000                      0.0       7.500000
# ...               ...                      ...            ...
# 11490        0.250000                      0.0       2.500000
# 11491        0.200000                      0.0       2.200000
# 11492        0.166667                      0.0       2.166667
# 11493        0.142857                      0.0       1.857143
# 11494        0.125000                      0.0       1.625000
#
#        receiving_yards_L8  receiving_tds_L8  receiving_fumbles_lost_L8  \
# 0                     NaN               NaN                        NaN
# 1               13.000000               0.0                        0.0
# 2                     NaN               NaN                        NaN
# 3              155.000000               0.0                        0.0
# 4              112.000000               0.0                        0.0
# ...                   ...               ...                        ...
# 11490           17.000000               0.0                        0.0
# 11491           16.600000               0.0                        0.0
# 11492           16.666667               0.0                        0.0
# 11493           14.285714               0.0                        0.0
# 11494           12.500000               0.0                        0.0
#
#        targets_L8  carries_L8  receiving_yards_after_catch_L8  \
# 0             NaN         NaN                             NaN
# 1        3.000000    0.000000                       11.000000
# 2             NaN         NaN                             NaN
# 3       13.000000    0.000000                       63.000000
# 4       10.500000    0.000000                       48.500000
# ...           ...         ...                             ...
# 11490    2.500000   14.750000                       25.000000
# 11491    2.200000   13.000000                       22.400000
# 11492    2.333333   12.166667                       22.000000
# 11493    2.000000   12.142857                       18.857143
# 11494    1.750000   11.000000                       16.500000
#
#        receiving_air_yards_L8  air_yards_share_L8  target_share_L8  \
# 0                         NaN                 NaN              NaN
# 1                    2.000000            0.010363         0.090909
# 2                         NaN                 NaN              NaN
# 3                   94.000000            0.728682         0.448276
# 4                  102.500000            0.557721         0.353170
# ...                       ...                 ...              ...
# 11490               -8.000000           -0.020311         0.060877
# 11491               -5.800000           -0.014043         0.055368
# 11492               -5.000000           -0.012165         0.057251
# 11493               -4.285714           -0.010427         0.049072
# 11494               -3.750000           -0.009124         0.042938
#
#        carry_share_L8  in_10_share_L8
# 0                 NaN             NaN
# 1            0.000000        0.000000
# 2                 NaN             NaN
# 3            0.000000        0.167000
# 4            0.000000        0.083500
# ...               ...             ...
# 11490        0.614000        0.145750
# 11491        0.551200        0.116600
# 11492        0.537833        0.097167
# 11493        0.546714        0.083286
# 11494        0.491750        0.072875
#
# [11495 rows x 19 columns]

# %%
flex_df = pd.merge(flex_df, flex_L8_features, on = ['player_display_name', 'season', 'week'], how = 'left')

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11495 entries, 0 to 11494
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11495 non-null  int64
#  1   week                            11495 non-null  int64
#  2   recent_team                     11495 non-null  object
#  3   opponent_team                   11495 non-null  object
#  4   player_id                       10892 non-null  object
#  5   player_display_name             11495 non-null  object
#  6   position                        11495 non-null  object
#  7   rushing_yards                   10892 non-null  float64
#  8   rushing_tds                     10892 non-null  float64
#  9   rushing_fumbles_lost            10892 non-null  float64
#  10  receptions                      10892 non-null  float64
#  11  receiving_yards                 10892 non-null  float64
#  12  receiving_tds                   10892 non-null  float64
#  13  receiving_fumbles_lost          10892 non-null  float64
#  14  targets                         10892 non-null  float64
#  15  carries                         10892 non-null  float64
#  16  receiving_yards_after_catch     10892 non-null  float64
#  17  receiving_air_yards             10892 non-null  float64
#  18  air_yards_share                 10892 non-null  float64
#  19  target_share                    10892 non-null  float64
#  20  carry_share                     10892 non-null  float64
#  21  in_10_share                     10892 non-null  float64
#  22  FD_Pts                          10892 non-null  float64
#  23  DK_Pts                          10892 non-null  float64
#  24  DK_Pts_RB_DvP                   11495 non-null  float64
#  25  DK_Pts_TE_DvP                   11495 non-null  float64
#  26  DK_Pts_WR_DvP                   11495 non-null  float64
#  27  FD_Pts_RB_DvP                   11495 non-null  float64
#  28  FD_Pts_TE_DvP                   11495 non-null  float64
#  29  FD_Pts_WR_DvP                   11495 non-null  float64
#  30  game_num                        11495 non-null  int64
#  31  rushing_yards_L8                10586 non-null  float64
#  32  rushing_tds_L8                  10586 non-null  float64
#  33  rushing_fumbles_lost_L8         10586 non-null  float64
#  34  receptions_L8                   10586 non-null  float64
#  35  receiving_yards_L8              10586 non-null  float64
#  36  receiving_tds_L8                10586 non-null  float64
#  37  receiving_fumbles_lost_L8       10586 non-null  float64
#  38  targets_L8                      10586 non-null  float64
#  39  carries_L8                      10586 non-null  float64
#  40  receiving_yards_after_catch_L8  10586 non-null  float64
#  41  receiving_air_yards_L8          10586 non-null  float64
#  42  air_yards_share_L8              10586 non-null  float64
#  43  target_share_L8                 10586 non-null  float64
#  44  carry_share_L8                  10586 non-null  float64
#  45  in_10_share_L8                  10586 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# # Filling missing values with mean
# In our QB model we made the mistake of dropping missing values at this point. Rookies making their debut won't have L8 variables because they haven't played before. So let's fill those values with the means.

# %%
cols_to_fill = ['rushing_yards_L8', 'rushing_tds_L8', 'rushing_fumbles_lost_L8', 'receptions_L8',
       'receiving_yards_L8', 'receiving_tds_L8', 'receiving_fumbles_lost_L8',
       'targets_L8', 'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
       'carry_share_L8', 'in_10_share_L8']

# %%
for col in cols_to_fill:
    flex_df[col] = flex_df.groupby('position')[col].transform(lambda x: x.fillna(x.mean()))

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11495 entries, 0 to 11494
# Data columns (total 46 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11495 non-null  int64
#  1   week                            11495 non-null  int64
#  2   recent_team                     11495 non-null  object
#  3   opponent_team                   11495 non-null  object
#  4   player_id                       10892 non-null  object
#  5   player_display_name             11495 non-null  object
#  6   position                        11495 non-null  object
#  7   rushing_yards                   10892 non-null  float64
#  8   rushing_tds                     10892 non-null  float64
#  9   rushing_fumbles_lost            10892 non-null  float64
#  10  receptions                      10892 non-null  float64
#  11  receiving_yards                 10892 non-null  float64
#  12  receiving_tds                   10892 non-null  float64
#  13  receiving_fumbles_lost          10892 non-null  float64
#  14  targets                         10892 non-null  float64
#  15  carries                         10892 non-null  float64
#  16  receiving_yards_after_catch     10892 non-null  float64
#  17  receiving_air_yards             10892 non-null  float64
#  18  air_yards_share                 10892 non-null  float64
#  19  target_share                    10892 non-null  float64
#  20  carry_share                     10892 non-null  float64
#  21  in_10_share                     10892 non-null  float64
#  22  FD_Pts                          10892 non-null  float64
#  23  DK_Pts                          10892 non-null  float64
#  24  DK_Pts_RB_DvP                   11495 non-null  float64
#  25  DK_Pts_TE_DvP                   11495 non-null  float64
#  26  DK_Pts_WR_DvP                   11495 non-null  float64
#  27  FD_Pts_RB_DvP                   11495 non-null  float64
#  28  FD_Pts_TE_DvP                   11495 non-null  float64
#  29  FD_Pts_WR_DvP                   11495 non-null  float64
#  30  game_num                        11495 non-null  int64
#  31  rushing_yards_L8                11495 non-null  float64
#  32  rushing_tds_L8                  11495 non-null  float64
#  33  rushing_fumbles_lost_L8         11495 non-null  float64
#  34  receptions_L8                   11495 non-null  float64
#  35  receiving_yards_L8              11495 non-null  float64
#  36  receiving_tds_L8                11495 non-null  float64
#  37  receiving_fumbles_lost_L8       11495 non-null  float64
#  38  targets_L8                      11495 non-null  float64
#  39  carries_L8                      11495 non-null  float64
#  40  receiving_yards_after_catch_L8  11495 non-null  float64
#  41  receiving_air_yards_L8          11495 non-null  float64
#  42  air_yards_share_L8              11495 non-null  float64
#  43  target_share_L8                 11495 non-null  float64
#  44  carry_share_L8                  11495 non-null  float64
#  45  in_10_share_L8                  11495 non-null  float64
# dtypes: float64(38), int64(3), object(5)
# memory usage: 4.0+ MB

# %% [markdown]
# # A few more features
# yards_per_carry, yards_per_reception, yards_per_target

# %%
flex_df['yards_per_carry_L8'] = flex_df['rushing_yards_L8']/flex_df['carries_L8']
flex_df['yards_per_reception_L8'] = flex_df['receiving_yards_L8']/flex_df['receptions_L8']
flex_df['yards_per_target_L8'] = flex_df['receiving_yards_L8']/flex_df['targets_L8']

# %% [markdown]
# # More missing
# Now this gives us some more missing values. In most cases, it's because we've tried to divide by zero when a player has averaged 0 carries over the last eight games. So here we should fill the missing values with 0

# %%
flex_df.fillna(0, inplace = True)

# %%
flex_df_full = flex_df.copy()

# %%
flex_df.drop(columns = cols_L8, inplace = True)

# %%
flex_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11495 entries, 0 to 11494
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   season                          11495 non-null  int64
#  1   week                            11495 non-null  int64
#  2   recent_team                     11495 non-null  object
#  3   opponent_team                   11495 non-null  object
#  4   player_id                       11495 non-null  object
#  5   player_display_name             11495 non-null  object
#  6   position                        11495 non-null  object
#  7   FD_Pts                          11495 non-null  float64
#  8   DK_Pts                          11495 non-null  float64
#  9   DK_Pts_RB_DvP                   11495 non-null  float64
#  10  DK_Pts_TE_DvP                   11495 non-null  float64
#  11  DK_Pts_WR_DvP                   11495 non-null  float64
#  12  FD_Pts_RB_DvP                   11495 non-null  float64
#  13  FD_Pts_TE_DvP                   11495 non-null  float64
#  14  FD_Pts_WR_DvP                   11495 non-null  float64
#  15  game_num                        11495 non-null  int64
#  16  rushing_yards_L8                11495 non-null  float64
#  17  rushing_tds_L8                  11495 non-null  float64
#  18  rushing_fumbles_lost_L8         11495 non-null  float64
#  19  receptions_L8                   11495 non-null  float64
#  20  receiving_yards_L8              11495 non-null  float64
#  21  receiving_tds_L8                11495 non-null  float64
#  22  receiving_fumbles_lost_L8       11495 non-null  float64
#  23  targets_L8                      11495 non-null  float64
#  24  carries_L8                      11495 non-null  float64
#  25  receiving_yards_after_catch_L8  11495 non-null  float64
#  26  receiving_air_yards_L8          11495 non-null  float64
#  27  air_yards_share_L8              11495 non-null  float64
#  28  target_share_L8                 11495 non-null  float64
#  29  carry_share_L8                  11495 non-null  float64
#  30  in_10_share_L8                  11495 non-null  float64
#  31  yards_per_carry_L8              11495 non-null  float64
#  32  yards_per_reception_L8          11495 non-null  float64
#  33  yards_per_target_L8             11495 non-null  float64
# dtypes: float64(26), int64(3), object(5)
# memory usage: 3.0+ MB

# %%
flex_df = flex_df[(flex_df['season'] == season) & (flex_df['week'] == week)]

# %%
flex_df['opponent_team'].nunique()
# Out:
# 22

# %%
flex_df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# # Odds, grass, outdoors, wind
# We'll bring in CSVs with FanDuel and DraftKings odds.<br>
# This will be where we need to separate FanDuel from DraftKings dataframes since the odds and totals might be different.

# %%
fd_spreads = pd.read_csv('fd_spreads_' + str(season) + '_' + str(week) + '.csv')
dk_spreads = pd.read_csv('dk_spreads_' + str(season) + '_' + str(week) + '.csv')

# %%
fd_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      MIN  NYJ        40.5         0      1          0
# 1           1      CIN  BAL        48.5         1      0          0
# 2           2      HOU  BUF        47.5         0      0          0
# 3           3      CHI  CAR        40.5         1      1          0
# 4           4      WAS  CLE        43.5         1      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -2.5       19.00      21.50     0    2024     5
# 1          2.5       25.50      23.00    12    2024     5
# 2         -1.5       23.00      24.50     0    2024     5
# 3         -3.5       18.50      22.00    17    2024     5
# 4         -3.0       20.25      23.25     5    2024     5

# %%
dk_spreads.head()
# Out:
#    Unnamed: 0 opponent team  total_line  outdoors  grass  home_team  \
# 0           0      MIN  NYJ        40.5         0      1          0
# 1           1      CIN  BAL        48.5         1      0          0
# 2           2      HOU  BUF        47.0         0      0          0
# 3           3      CHI  CAR        41.0         1      1          0
# 4           4      WAS  CLE        43.5         1      1          0
#
#    spread_line  pred_total  opp_total  wind  season  week
# 0         -2.0       19.25      21.25     0    2024     5
# 1          2.5       25.50      23.00    12    2024     5
# 2         -1.0       23.00      24.00     0    2024     5
# 3         -4.0       18.50      22.50    17    2024     5
# 4         -3.0       20.25      23.25     5    2024     5

# %%
fd_spreads.drop(columns = ['Unnamed: 0'], inplace = True)
dk_spreads.drop(columns = ['Unnamed: 0'], inplace = True)

# %%
flex_df.rename(columns = {'recent_team': 'team', 'opponent_team': 'opponent'}, inplace = True)

# %%
flex_df_fd = pd.merge(flex_df, fd_spreads, on = ['team', 'opponent', 'season', 'week'])
flex_df_dk = pd.merge(flex_df, dk_spreads, on = ['team', 'opponent', 'season', 'week'])

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (603, 603)

# %%
# weekly_df[weekly_df['player_display_name'] == 'Jonathan Taylor'].tail()

# %% [markdown]
# <!-- # Bringing in point spreads and totals
# Pulling this dataframe from our database. It also includes binary variables for indoors and grass. -->

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# # Query specific columns from the table
# query1 = "SELECT * FROM spreads_totals"
# spread_df = pd.read_sql_query(query1, conn)

# # Close the connection
# conn.close()

# %%
flex_df.columns
# Out:
# Index(['season', 'week', 'team', 'opponent', 'player_id',
#        'player_display_name', 'position', 'FD_Pts', 'DK_Pts', 'DK_Pts_RB_DvP',
#        'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP', 'FD_Pts_TE_DvP',
#        'FD_Pts_WR_DvP', 'game_num', 'rushing_yards_L8', 'rushing_tds_L8',
#        'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
#        'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
#        'carries_L8', 'receiving_yards_after_catch_L8',
#        'receiving_air_yards_L8', 'air_yards_share_L8', 'target_share_L8',
#        'carry_share_L8', 'in_10_share_L8', 'yards_per_carry_L8',
#        'yards_per_reception_L8', 'yards_per_target_L8'],
#       dtype='object')

# %%
#quarterback_df.drop(columns = ['defteam', 'passing_air_yards'], inplace = True)

# %%
flex_df.head()
# Out:
#        season  week team opponent  player_id player_display_name position  \
# 10892    2024     5  DAL      PIT          0         CeeDee Lamb       WR
# 10893    2024     5  DAL      PIT          0       Jake Ferguson       TE
# 10894    2024     5  DAL      PIT          0         Rico Dowdle       RB
# 10895    2024     5  DAL      PIT          0     Ezekiel Elliott       RB
# 10896    2024     5  DAL      PIT          0       Brandin Cooks       WR
#
#        FD_Pts  DK_Pts  DK_Pts_RB_DvP  ...  carries_L8  \
# 10892     0.0     0.0          16.45  ...       1.375
# 10893     0.0     0.0          16.45  ...       0.000
# 10894     0.0     0.0          16.45  ...       6.250
# 10895     0.0     0.0          16.45  ...       9.250
# 10896     0.0     0.0          16.45  ...       0.625
#
#        receiving_yards_after_catch_L8  receiving_air_yards_L8  \
# 10892                          52.125                 100.125
# 10893                          27.125                  42.000
# 10894                          18.125                   6.750
# 10895                          20.500                  -2.875
# 10896                           2.500                  75.125
#
#        air_yards_share_L8  target_share_L8  carry_share_L8  in_10_share_L8  \
# 10892            0.335701         0.291383        0.058125         0.21800
# 10893            0.134500         0.208697        0.000000         0.03125
# 10894            0.020864         0.075081        0.285375         0.18225
# 10895           -0.011907         0.136156        0.450625         0.37500
# 10896            0.243621         0.145635        0.025375         0.10125
#
#        yards_per_carry_L8  yards_per_reception_L8  yards_per_target_L8
# 10892            5.818182               14.245902             9.764045
# 10893            0.000000                9.630435             7.031746
# 10894            3.980000                9.375000             6.250000
# 10895            3.054054                4.730769             3.617647
# 10896            4.000000                8.964286             5.577778
#
# [5 rows x 34 columns]

# %%
divisions = {
    'CLE': 'AFC North',
    'LAR': 'NFC West',
    'LV': 'AFC West',
    'KC': 'AFC West',
    'CAR': 'NFC South',
    'NYG': 'NFC East',
    'HOU': 'AFC South',
    'DEN': 'AFC West',
    'MIN': 'NFC North',
    'TEN': 'AFC South',
    'JAX': 'AFC South',
    'SEA': 'NFC West',
    'DET': 'NFC North',
    'NO': 'NFC South',
    'CIN': 'AFC North',
    'ATL': 'NFC South',
    'NYJ': 'AFC East',
    'PHI': 'NFC East',
    'DAL': 'NFC East',
    'WAS': 'NFC East',
    'PIT': 'AFC North',
    'ARI': 'NFC West',
    'CHI': 'NFC North',
    'MIA': 'AFC East',
    'BUF': 'AFC East',
    'BAL': 'AFC North',
    'TB': 'NFC South',
    'SF': 'NFC West',
    'LAC': 'AFC West',
    'IND': 'AFC South',
    'GB': 'NFC North',
    'NE': 'AFC East'
}

# You now have a dictionary `divisions` where each team is mapped to its division.flex_df.info()

# %% [markdown]
# # Adding div_game binary column

# %%
# Map the team and opponent columns to their respective divisions
flex_df_fd['team_division'] = flex_df_fd['team'].map(divisions)
flex_df_fd['opponent_division'] = flex_df_fd['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_fd['div_game'] = np.where(flex_df_fd['team_division'] == flex_df_fd['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_fd.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Map the team and opponent columns to their respective divisions
flex_df_dk['team_division'] = flex_df_dk['team'].map(divisions)
flex_df_dk['opponent_division'] = flex_df_dk['opponent'].map(divisions)

# Create the div_game column (1 if they are in the same division, 0 otherwise)
flex_df_dk['div_game'] = np.where(flex_df_dk['team_division'] == flex_df_dk['opponent_division'], 1, 0)

# Optionally, drop the temporary division columns if you don't need them
flex_df_dk.drop(['team_division', 'opponent_division'], axis=1, inplace=True)

# %%
# Check for positive or negative infinity in the entire DataFrame
# infinity_mask_fd = np.isinf(flex_df_fd)
# infinity_mask_dk = np.isinf(flex_df_dk)

# # Display rows with infinity values
# infinity_rows_fd = flex_df_fd[infinity_mask_fd.any(axis=1)]
# infinity_rows_dk = flex_df_dk[infinity_mask_dk.any(axis=1)]
# print(infinity_rows_fd)
# print(infinity_rows_dk)

# %% [markdown]
# # One-hot encoding for position

# %%
position_dummies_fd = pd.get_dummies(flex_df_fd['position'], prefix='pos')
position_dummies_dk = pd.get_dummies(flex_df_dk['position'], prefix='pos')

# %%
flex_df_fd = pd.concat([flex_df_fd, position_dummies_fd], axis = 1)

# %%
flex_df_dk = pd.concat([flex_df_dk, position_dummies_dk], axis = 1)

# %%
flex_df_fd['pos_RB'] = flex_df_fd['pos_RB'].astype(int)
flex_df_fd['pos_TE'] = flex_df_fd['pos_TE'].astype(int)
flex_df_fd['pos_WR'] = flex_df_fd['pos_WR'].astype(int)
flex_df_dk['pos_RB'] = flex_df_dk['pos_RB'].astype(int)
flex_df_dk['pos_TE'] = flex_df_dk['pos_TE'].astype(int)
flex_df_dk['pos_WR'] = flex_df_dk['pos_WR'].astype(int)

# %%
flex_df_fd.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)
flex_df_dk.drop(columns = ['FD_Pts', 'DK_Pts'], inplace = True)

# %%
fanduel_df = fanduel_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]
draftkings_df = draftkings_df[['name', 'position', 'salary', 'team', 'opponent', 'status', 'week']]

# %%
fanduel_df = fanduel_df[fanduel_df['position'].isin(['RB', 'WR', 'TE'])]
draftkings_df = draftkings_df[draftkings_df['position'].isin(['RB', 'WR', 'TE'])]

# %%
len(fanduel_df), len(draftkings_df)
# Out:
# (603, 410)

# %%
#################### Sept. 16, 2024 #####################
#Just filtered for Flex positions.
#Next will be to rename player_display_name to name and try to merge again with the flex data.
#Don't forget QB strength variables!!!!!

# %%
len(flex_df_fd), len(flex_df_dk)
# Out:
# (603, 603)

# %%
flex_df_fd.rename(columns = {'player_display_name': 'name'}, inplace = True)
flex_df_dk.rename(columns = {'player_display_name': 'name'}, inplace = True)

# %% [markdown]
# # Name matching here

# %%
def clean_name(name):
    # Remove periods between initials like C.J., D.J. (case-sensitive)
    name = re.sub(r'\b([A-Z])\.\s*([A-Z])\.\b', r'\1\2', name)
    
    # Remove common suffixes like Jr., Sr., III, II, IV (case-sensitive)
    cleaned_name = re.sub(r'(\,|\.|Sr|Jr|III|II|IV)', '', name).strip()
    
    return cleaned_name

# %%
import re
from rapidfuzz import process, fuzz

# %%
flex_df_fd['name'] = flex_df_fd['name'].apply(clean_name)
flex_df_dk['name'] = flex_df_dk['name'].apply(clean_name)

# %%
SIMILARITY_THRESHOLD = 80

# %%
def fuzzy_match(name, dk_names):
    match, score, _ = process.extractOne(name, dk_names, scorer=fuzz.token_sort_ratio)
    return match if score >= SIMILARITY_THRESHOLD else None

# %%
flex_names = flex_df_fd['name']

# %%
flex_df_fd['matched_name'] = flex_df_fd['name'].apply(lambda x: fuzzy_match(x, flex_names))
flex_df_dk['matched_name'] = flex_df_dk['name'].apply(lambda x: fuzzy_match(x, flex_names))

# %%
unmatched_in_fd = flex_df_fd[flex_df_fd['matched_name'].isna()]

# %%
unmatched_in_fd.reset_index(inplace = True, drop = True)

# %%
unmatched_in_fd
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_fd[(flex_df_fd['name'] != flex_df_fd['matched_name']) & (flex_df_fd['matched_name'].notna())]
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
unmatched_in_dk = flex_df_dk[flex_df_dk['matched_name'].isna()]

# %%
unmatched_in_dk.reset_index(inplace = True, drop = True)

# %%
unmatched_in_dk
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_dk[(flex_df_dk['name'] != flex_df_dk['matched_name']) & (flex_df_dk['matched_name'].notna())]
# Out:
# Empty DataFrame
# Columns: [season, week, team, opponent, player_id, name, position, DK_Pts_RB_DvP, DK_Pts_TE_DvP, DK_Pts_WR_DvP, FD_Pts_RB_DvP, FD_Pts_TE_DvP, FD_Pts_WR_DvP, game_num, rushing_yards_L8, rushing_tds_L8, rushing_fumbles_lost_L8, receptions_L8, receiving_yards_L8, receiving_tds_L8, receiving_fumbles_lost_L8, targets_L8, carries_L8, receiving_yards_after_catch_L8, receiving_air_yards_L8, air_yards_share_L8, target_share_L8, carry_share_L8, in_10_share_L8, yards_per_carry_L8, yards_per_reception_L8, yards_per_target_L8, total_line, outdoors, grass, home_team, spread_line, pred_total, opp_total, wind, div_game, pos_RB, pos_TE, pos_WR, matched_name]
# Index: []
#
# [0 rows x 45 columns]

# %%
flex_df_fd = pd.merge(fanduel_df, flex_df_fd, on = ['name', 'team', 'opponent', 'week'], how = 'left')
flex_df_dk = pd.merge(draftkings_df, flex_df_dk, on = ['name', 'team', 'opponent', 'week'], how = 'left')

# %%
flex_df_fd['position'] = flex_df_fd['position_x']
flex_df_fd.drop(columns = ['position_x', 'position_y'], inplace = True)
flex_df_dk['position'] = flex_df_dk['position_x']
flex_df_dk.drop(columns = ['position_x', 'position_y'], inplace = True)

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 603 entries, 0 to 602
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            603 non-null    object
#  1   salary                          603 non-null    int64
#  2   team                            603 non-null    object
#  3   opponent                        603 non-null    object
#  4   status                          603 non-null    object
#  5   week                            603 non-null    int64
#  6   season                          603 non-null    int64
#  7   player_id                       603 non-null    int64
#  8   DK_Pts_RB_DvP                   603 non-null    float64
#  9   DK_Pts_TE_DvP                   603 non-null    float64
#  10  DK_Pts_WR_DvP                   603 non-null    float64
#  11  FD_Pts_RB_DvP                   603 non-null    float64
#  12  FD_Pts_TE_DvP                   603 non-null    float64
#  13  FD_Pts_WR_DvP                   603 non-null    float64
#  14  game_num                        603 non-null    int64
#  15  rushing_yards_L8                603 non-null    float64
#  16  rushing_tds_L8                  603 non-null    float64
#  17  rushing_fumbles_lost_L8         603 non-null    float64
#  18  receptions_L8                   603 non-null    float64
#  19  receiving_yards_L8              603 non-null    float64
#  20  receiving_tds_L8                603 non-null    float64
#  21  receiving_fumbles_lost_L8       603 non-null    float64
#  22  targets_L8                      603 non-null    float64
#  23  carries_L8                      603 non-null    float64
#  24  receiving_yards_after_catch_L8  603 non-null    float64
#  25  receiving_air_yards_L8          603 non-null    float64
#  26  air_yards_share_L8              603 non-null    float64
#  27  target_share_L8                 603 non-null    float64
#  28  carry_share_L8                  603 non-null    float64
#  29  in_10_share_L8                  603 non-null    float64
#  30  yards_per_carry_L8              603 non-null    float64
#  31  yards_per_reception_L8          603 non-null    float64
#  32  yards_per_target_L8             603 non-null    float64
#  33  total_line                      603 non-null    float64
#  34  outdoors                        603 non-null    int64
#  35  grass                           603 non-null    int64
#  36  home_team                       603 non-null    int64
#  37  spread_line                     603 non-null    float64
#  38  pred_total                      603 non-null    float64
#  39  opp_total                       603 non-null    float64
#  40  wind                            603 non-null    int64
#  41  div_game                        603 non-null    int32
#  42  pos_RB                          603 non-null    int32
#  43  pos_TE                          603 non-null    int32
#  44  pos_WR                          603 non-null    int32
#  45  matched_name                    603 non-null    object
#  46  position                        603 non-null    object
# dtypes: float64(28), int32(4), int64(9), object(6)
# memory usage: 212.1+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            410 non-null    object
#  1   salary                          410 non-null    int64
#  2   team                            410 non-null    object
#  3   opponent                        410 non-null    object
#  4   status                          410 non-null    object
#  5   week                            410 non-null    int64
#  6   season                          409 non-null    float64
#  7   player_id                       409 non-null    float64
#  8   DK_Pts_RB_DvP                   409 non-null    float64
#  9   DK_Pts_TE_DvP                   409 non-null    float64
#  10  DK_Pts_WR_DvP                   409 non-null    float64
#  11  FD_Pts_RB_DvP                   409 non-null    float64
#  12  FD_Pts_TE_DvP                   409 non-null    float64
#  13  FD_Pts_WR_DvP                   409 non-null    float64
#  14  game_num                        409 non-null    float64
#  15  rushing_yards_L8                409 non-null    float64
#  16  rushing_tds_L8                  409 non-null    float64
#  17  rushing_fumbles_lost_L8         409 non-null    float64
#  18  receptions_L8                   409 non-null    float64
#  19  receiving_yards_L8              409 non-null    float64
#  20  receiving_tds_L8                409 non-null    float64
#  21  receiving_fumbles_lost_L8       409 non-null    float64
#  22  targets_L8                      409 non-null    float64
#  23  carries_L8                      409 non-null    float64
#  24  receiving_yards_after_catch_L8  409 non-null    float64
#  25  receiving_air_yards_L8          409 non-null    float64
#  26  air_yards_share_L8              409 non-null    float64
#  27  target_share_L8                 409 non-null    float64
#  28  carry_share_L8                  409 non-null    float64
#  29  in_10_share_L8                  409 non-null    float64
#  30  yards_per_carry_L8              409 non-null    float64
#  31  yards_per_reception_L8          409 non-null    float64
#  32  yards_per_target_L8             409 non-null    float64
#  33  total_line                      409 non-null    float64
#  34  outdoors                        409 non-null    float64
#  35  grass                           409 non-null    float64
#  36  home_team                       409 non-null    float64
#  37  spread_line                     409 non-null    float64
#  38  pred_total                      409 non-null    float64
#  39  opp_total                       409 non-null    float64
#  40  wind                            409 non-null    float64
#  41  div_game                        409 non-null    float64
#  42  pos_RB                          409 non-null    float64
#  43  pos_TE                          409 non-null    float64
#  44  pos_WR                          409 non-null    float64
#  45  matched_name                    409 non-null    object
#  46  position                        410 non-null    object
# dtypes: float64(39), int64(2), object(6)
# memory usage: 150.7+ KB

# %%
###FANDUEL SCORING
#Rushing yards made = 0.1pts	
#Rushing touchdowns = 6pts	
#Passing yards = 0.04pts	
#Passing touchdowns = 4pts	
#Interceptions = -1pt	
#Receiving yards = 0.1pts	
#Receiving touchdowns = 6pts	
#Receptions = 0.5pts	
#Kickoff return touchdowns = 6pts	
#Punt return touchdowns = 6pts	
#Fumbles lost = -2pts	
#Own fumbles recovered touchdowns = 6pts	
#Two-point conversions scored = 2pts	
#Two-point conversion passes = 2pts	
#Field-goals from 0-39 yards = 3pts	
#Field-goals from 40-49 yards = 4pts	
#Field-goals from 50+ yards = 5pts	
#Extra-point conversions = 1pt

###DRAFTKINGS SCORING
#PAssing TD = 4 pts
#passing yards = .04 pts
#300 passing yards = 3 pts (bonus)
#Interception = -1 pts
#Rushing TD = 6 pts
#Rushing yds = 0.1 pts
#100 yd rushing game = 3 pts (bonus)
#Receiving TD = 6 pts
#Receiving yds = 0.1 pts
#100 receiving yards game = 3 pts (bonus)
#Receptions = 1 pt
#Punt/kickoff/FG return for TD = 6 pts
#Fumble lost = -1 pt
#2 pt conversion (pass, run or catch) = 2 pts
#Offensive fumble recovery TD = 6

# %%
features = ['DK_Pts_RB_DvP', 'DK_Pts_TE_DvP', 'DK_Pts_WR_DvP', 'FD_Pts_RB_DvP',
       'FD_Pts_TE_DvP', 'FD_Pts_WR_DvP', 'rushing_yards_L8', 'rushing_tds_L8',
       'rushing_fumbles_lost_L8', 'receptions_L8', 'receiving_yards_L8',
       'receiving_tds_L8', 'receiving_fumbles_lost_L8', 'targets_L8',
       'carries_L8', 'receiving_yards_after_catch_L8',
       'receiving_air_yards_L8', 'target_share_L8', 'carry_share_L8',
       'in_10_share_L8', 'yards_per_carry_L8', 'yards_per_reception_L8',
       'yards_per_target_L8', 'wind', 'div_game', 'spread_line', 'total_line',
       'outdoors', 'grass', 'home_team', 'pred_total', 'opp_total', 'qb_comp',
       'qb_att', 'qb_yds', 'qb_pass_td', 'qb_int', 'qb_comp_pct',
       'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct', 'pos_RB', 'pos_TE',
       'pos_WR']

# %% [markdown]
# # QB strength
# One last variable we want to try to add is a variable or variables that look at quarterback strength. If a team's backup QB is playing, the entire offense is downgraded and it could affect the fantasy performance of RBs, WRs and TEs.<br>
#
# We'll take the dataset we used for the QB model, filter for the primary QBs in each game and use some of the variables that look at L8 means.

# %%
# # Connect to the SQLite database
# conn = sqlite3.connect('nfl_dfs.db')

# query_qb = "SELECT * FROM qb_dataset WHERE season >= 2006"

# qb_df = pd.read_sql_query(query_qb, conn)

# # Close the database connection
# conn.close()

# %%
qb_data_fd = pd.read_csv('FD_QB_for_model_' + str(season) + '_' + str(week) + '.csv')
qb_data_dk = pd.read_csv('DK_QB_for_model_' + str(season) + '_' + str(week) + '.csv')

# %%
qb_data_fd = qb_data_fd[qb_data_fd['QB_role'] == 1]
qb_data_dk = qb_data_dk[qb_data_dk['QB_role'] == 1]

# %%
qb_data_fd.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_dk.rename(columns = {'completions_L8': 'qb_comp', 'attempts_L8': 'qb_att', 'passing_yards_L8': 'qb_yds',\
                       'passing_tds_L8': 'qb_pass_td', 'interceptions_L8': 'qb_int', 'comp_pct': 'qb_comp_pct',\
                       'yds_per_attempt': 'qb_yds_per_att', 'td_pct': 'qb_td_pct', 'int_pct': 'qb_int_pct'}, inplace = True)

# %%
qb_data_fd = qb_data_fd[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
qb_data_dk = qb_data_dk[['season', 'week', 'team', 'opponent', 'qb_comp', 'qb_att', 'qb_yds', 'qb_pass_td',\
               'qb_int', 'qb_comp_pct', 'qb_yds_per_att', 'qb_td_pct', 'qb_int_pct']]

# %%
flex_df_fd = pd.merge(flex_df_fd, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_dk = pd.merge(flex_df_dk, qb_data_fd, on = ['season', 'week', 'team', 'opponent'], how = 'left')

# %%
flex_df_fd = flex_df_fd.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)
flex_df_dk = flex_df_dk.set_index(['name', 'position', 'team', 'opponent', 'salary', 'status', 'week', 'season'], drop = True)

# %%
flex_df_fd = flex_df_fd[features]
flex_df_dk = flex_df_dk[features]

# %%
flex_df_fd.replace([np.inf, -np.inf], np.nan, inplace=True)
flex_df_dk.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
# flex_df_dk[flex_df_dk.isna().any(axis = 1)]

# %%
# flex_df_dk = flex_df_dk.dropna()

# %%
# Fill missing values with the mean of each column
flex_df_fd = flex_df_fd.groupby('position').transform(lambda x: x.fillna(x.mean()))
flex_df_dk = flex_df_dk.groupby('position').transform(lambda x: x.fillna(x.mean()))

# %%
flex_df_fd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 603 entries, ('CeeDee Lamb', 'WR', 'DAL', 'PIT', 9400, 'Active', 5, 2024) to ('John Kelly', 'RB', 'BAL', 'CIN', 4000, 'Active', 5, 2024)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   603 non-null    float64
#  1   DK_Pts_TE_DvP                   603 non-null    float64
#  2   DK_Pts_WR_DvP                   603 non-null    float64
#  3   FD_Pts_RB_DvP                   603 non-null    float64
#  4   FD_Pts_TE_DvP                   603 non-null    float64
#  5   FD_Pts_WR_DvP                   603 non-null    float64
#  6   rushing_yards_L8                603 non-null    float64
#  7   rushing_tds_L8                  603 non-null    float64
#  8   rushing_fumbles_lost_L8         603 non-null    float64
#  9   receptions_L8                   603 non-null    float64
#  10  receiving_yards_L8              603 non-null    float64
#  11  receiving_tds_L8                603 non-null    float64
#  12  receiving_fumbles_lost_L8       603 non-null    float64
#  13  targets_L8                      603 non-null    float64
#  14  carries_L8                      603 non-null    float64
#  15  receiving_yards_after_catch_L8  603 non-null    float64
#  16  receiving_air_yards_L8          603 non-null    float64
#  17  target_share_L8                 603 non-null    float64
#  18  carry_share_L8                  603 non-null    float64
#  19  in_10_share_L8                  603 non-null    float64
#  20  yards_per_carry_L8              603 non-null    float64
#  21  yards_per_reception_L8          603 non-null    float64
#  22  yards_per_target_L8             603 non-null    float64
#  23  wind                            603 non-null    int64
#  24  div_game                        603 non-null    int32
#  25  spread_line                     603 non-null    float64
#  26  total_line                      603 non-null    float64
#  27  outdoors                        603 non-null    int64
#  28  grass                           603 non-null    int64
#  29  home_team                       603 non-null    int64
#  30  pred_total                      603 non-null    float64
#  31  opp_total                       603 non-null    float64
#  32  qb_comp                         603 non-null    float64
#  33  qb_att                          603 non-null    float64
#  34  qb_yds                          603 non-null    float64
#  35  qb_pass_td                      603 non-null    float64
#  36  qb_int                          603 non-null    float64
#  37  qb_comp_pct                     603 non-null    float64
#  38  qb_yds_per_att                  603 non-null    float64
#  39  qb_td_pct                       603 non-null    float64
#  40  qb_int_pct                      603 non-null    float64
#  41  pos_RB                          603 non-null    int32
#  42  pos_TE                          603 non-null    int32
#  43  pos_WR                          603 non-null    int32
# dtypes: float64(36), int32(4), int64(4)
# memory usage: 227.9+ KB

# %%
flex_df_dk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 410 entries, ("Ja'Marr Chase", 'WR', 'CIN', 'BAL', 8000, 'Active', 5, 2024.0) to ('Joel Wilson', 'TE', 'NYG', 'SEA', 2500, 'Active', 5, 2024.0)
# Data columns (total 44 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DK_Pts_RB_DvP                   410 non-null    float64
#  1   DK_Pts_TE_DvP                   410 non-null    float64
#  2   DK_Pts_WR_DvP                   410 non-null    float64
#  3   FD_Pts_RB_DvP                   410 non-null    float64
#  4   FD_Pts_TE_DvP                   410 non-null    float64
#  5   FD_Pts_WR_DvP                   410 non-null    float64
#  6   rushing_yards_L8                410 non-null    float64
#  7   rushing_tds_L8                  410 non-null    float64
#  8   rushing_fumbles_lost_L8         410 non-null    float64
#  9   receptions_L8                   410 non-null    float64
#  10  receiving_yards_L8              410 non-null    float64
#  11  receiving_tds_L8                410 non-null    float64
#  12  receiving_fumbles_lost_L8       410 non-null    float64
#  13  targets_L8                      410 non-null    float64
#  14  carries_L8                      410 non-null    float64
#  15  receiving_yards_after_catch_L8  410 non-null    float64
#  16  receiving_air_yards_L8          410 non-null    float64
#  17  target_share_L8                 410 non-null    float64
#  18  carry_share_L8                  410 non-null    float64
#  19  in_10_share_L8                  410 non-null    float64
#  20  yards_per_carry_L8              410 non-null    float64
#  21  yards_per_reception_L8          410 non-null    float64
#  22  yards_per_target_L8             410 non-null    float64
#  23  wind                            410 non-null    float64
#  24  div_game                        410 non-null    float64
#  25  spread_line                     410 non-null    float64
#  26  total_line                      410 non-null    float64
#  27  outdoors                        410 non-null    float64
#  28  grass                           410 non-null    float64
#  29  home_team                       410 non-null    float64
#  30  pred_total                      410 non-null    float64
#  31  opp_total                       410 non-null    float64
#  32  qb_comp                         410 non-null    float64
#  33  qb_att                          410 non-null    float64
#  34  qb_yds                          410 non-null    float64
#  35  qb_pass_td                      410 non-null    float64
#  36  qb_int                          410 non-null    float64
#  37  qb_comp_pct                     410 non-null    float64
#  38  qb_yds_per_att                  410 non-null    float64
#  39  qb_td_pct                       410 non-null    float64
#  40  qb_int_pct                      410 non-null    float64
#  41  pos_RB                          410 non-null    float64
#  42  pos_TE                          410 non-null    float64
#  43  pos_WR                          410 non-null    float64
# dtypes: float64(44)
# memory usage: 168.8+ KB

# %%
flex_df_fd.head()
# Out:
#                                                                 DK_Pts_RB_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          16.4500
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          21.8250
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024          25.0125
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          26.9750
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          28.2475
#
#                                                                 DK_Pts_TE_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          12.5375
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          15.3375
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024           7.2625
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          12.3000
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          12.1750
#
#                                                                 DK_Pts_WR_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          29.9250
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          29.3500
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024          36.6500
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          24.1625
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          29.3375
#
#                                                                 FD_Pts_RB_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          13.7625
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          18.0750
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024          21.0750
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          24.2250
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          24.5600
#
#                                                                 FD_Pts_TE_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          10.4125
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          11.5250
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024           5.2625
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024           9.5500
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024           9.8000
#
#                                                                 FD_Pts_WR_DvP  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          23.6125
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          23.4125
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024          29.8375
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          19.1625
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          24.2125
#
#                                                                 rushing_yards_L8  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024               8.000
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024               0.000
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024              96.500
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024               1.375
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024              65.750
#
#                                                                 rushing_tds_L8  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024             0.000
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024             0.000
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024             0.875
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024             0.000
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024             0.500
#
#                                                                 rushing_fumbles_lost_L8  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024                        0.0
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024                        0.0
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024                        0.0
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024                        0.0
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024                        0.0
#
#                                                                 receptions_L8  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024            7.625
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024            4.125
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024            1.250
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024            7.125
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024            1.000
#
#                                                                 ...  \
# name          position team opponent salary status week season  ...
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024    ...
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024    ...
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024    ...
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024    ...
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024    ...
#
#                                                                     qb_yds  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024    294.000000
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024    257.125000
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024    231.875000
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024    196.322049
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024    266.750000
#
#                                                                 qb_pass_td  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024      2.125000
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024      1.875000
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024      1.875000
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024      1.025608
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024      1.250000
#
#                                                                   qb_int  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024    0.750000
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024    0.375000
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024    0.250000
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024    0.563368
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024    0.375000
#
#                                                                 qb_comp_pct  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024       0.679365
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024       0.719101
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024       0.668161
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024       0.645006
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024       0.666667
#
#                                                                 qb_yds_per_att  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024          7.466667
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024          7.704120
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024          8.318386
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024          6.825769
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024          8.271318
#
#                                                                 qb_td_pct  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024     0.053968
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024     0.056180
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024     0.067265
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024     0.034883
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024     0.038760
#
#                                                                 qb_int_pct  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024      0.019048
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024      0.011236
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024      0.008969
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024      0.020130
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024      0.011628
#
#                                                                 pos_RB  \
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024         0
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024         0
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024         1
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024         0
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024         1
#
#                                                                 pos_TE  pos_WR
# name          position team opponent salary status week season
# CeeDee Lamb   WR       DAL  PIT      9400   Active 5    2024         0       1
# Ja'Marr Chase WR       CIN  BAL      9300   Active 5    2024         0       1
# Derrick Henry RB       BAL  CIN      9200   Active 5    2024         0       0
# Nico Collins  WR       HOU  BUF      8800   Active 5    2024         0       1
# Jordan Mason  RB       SF   ARI      8700   Active 5    2024         0       0
#
# [5 rows x 44 columns]

# %%
flex_df_dk.head()
# Out:
#                                                                   DK_Pts_RB_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        21.8250
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        22.2875
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0        25.0125
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        26.9750
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0        27.4750
#
#                                                                   DK_Pts_TE_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        15.3375
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        16.3125
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0         7.2625
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        12.3000
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0         7.8875
#
#                                                                   DK_Pts_WR_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        29.3500
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        32.5250
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0        36.6500
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        24.1625
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0        35.8250
#
#                                                                   FD_Pts_RB_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        18.0750
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        18.9125
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0        21.0750
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        24.2250
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0        24.4750
#
#                                                                   FD_Pts_TE_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        11.5250
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        13.6250
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0         5.2625
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0         9.5500
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0         6.5125
#
#                                                                   FD_Pts_WR_DvP  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        23.4125
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        25.7125
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0        29.8375
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        19.1625
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0        27.9500
#
#                                                                   rushing_yards_L8  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0             0.000
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0             0.875
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0            96.500
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0             1.375
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0            95.875
#
#                                                                   rushing_tds_L8  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0           0.000
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0           0.000
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0           0.875
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0           0.000
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0           1.125
#
#                                                                   rushing_fumbles_lost_L8  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0                      0.0
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0                      0.0
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0                      0.0
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0                      0.0
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0                      0.0
#
#                                                                   receptions_L8  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0          4.125
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0          6.875
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0          1.250
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0          7.125
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0          1.125
#
#                                                                   ...  \
# name            position team opponent salary status week season  ...
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0  ...
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0  ...
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0  ...
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0  ...
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0  ...
#
#                                                                       qb_yds  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0  257.125000
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0  281.000000
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0  231.875000
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0  191.382682
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0  153.875000
#
#                                                                   qb_pass_td  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0    1.875000
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0    1.125000
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0    1.875000
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0    0.971369
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0    0.750000
#
#                                                                     qb_int  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0  0.375000
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0  0.500000
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0  0.250000
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0  0.558659
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0  0.875000
#
#                                                                   qb_comp_pct  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0     0.719101
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0     0.700375
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0     0.668161
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0     0.646489
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0     0.552795
#
#                                                                   qb_yds_per_att  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0        7.704120
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0        8.419476
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0        8.318386
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0        6.779520
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0        7.645963
#
#                                                                   qb_td_pct  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0   0.056180
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0   0.033708
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0   0.067265
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0   0.033994
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0   0.037267
#
#                                                                   qb_int_pct  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0    0.011236
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0    0.014981
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0    0.008969
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0    0.020194
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0    0.043478
#
#                                                                   pos_RB  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0     0.0
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0     0.0
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0     1.0
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0     0.0
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0     1.0
#
#                                                                   pos_TE  \
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0     0.0
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0     0.0
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0     0.0
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0     0.0
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0     0.0
#
#                                                                   pos_WR
# name            position team opponent salary status week season
# Ja'Marr Chase   WR       CIN  BAL      8000   Active 5    2024.0     1.0
# Cooper Kupp     WR       LAR  GB       7900   O      5    2024.0     1.0
# Derrick Henry   RB       BAL  CIN      7800   Active 5    2024.0     0.0
# Nico Collins    WR       HOU  BUF      7700   Active 5    2024.0     1.0
# Jonathan Taylor RB       IND  JAX      7700   O      5    2024.0     0.0
#
# [5 rows x 44 columns]

# %%
flex_df_fd.to_csv('FD_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
flex_df_dk.to_csv('DK_FLEX_for_model_' + str(season) + '_' + str(week) + '.csv')
